# %%
import pandas as pd
import numpy as np
from haversine import haversine, haversine_vector, Unit
import geopandas as gpd
import matplotlib.pyplot as plt
import cma

# %%
# To supress the scientific notation for easier reading.
np.set_printoptions(suppress=True)

# %% [markdown]
# # Test Development
#
# In developing the code, three main tests have been completed within one region: Amhara. The first at a very micro level with a custom dummy dataset with only two primary schools and 2 proposed secondary schools. The second is for one woreda/district with 21 primary schools and two secondary schools, whereby 5 secondary schools are proposed. The final test was a region wide test with 1765 primary schools and 1658 secondary schools, with 5 new secondary schools proposed.

# %%
# Specify which test to perform
declare_test = 3 # micro test

# %%
# Declare key variables according to the test being performed.
region = 'Amhara' # Test Amhara region
woreda = 'ET030908'

if declare_test == 1: # for micro test
    # read in the prepared dataset. Evaluate point data to make it readible by geopandas
    df = pd.read_csv('data/test_dataset2.csv', converters={'point': pd.eval})
    proposed_schools= 2
    gdf_woreda = gpd.read_file('eth_shape_files/json/eth_admin3v2.json')
    gdf_woreda_shp = gdf_woreda.loc[gdf_woreda['ADM3_PCODE']==woreda]['geometry'].reset_index(drop=True)
    df = df.loc[df['ADM3_PCODE'] == woreda]
    bounds = gdf_woreda_shp.bounds
elif declare_test == 2:
    df = pd.read_csv('data/test_dataset.csv', converters={'point': pd.eval})
    proposed_schools= 5
    gdf_woreda = gpd.read_file('eth_shape_files/json/eth_admin3v2.json')
    gdf_woreda_shp = gdf_woreda.loc[gdf_woreda['ADM3_PCODE']==woreda]['geometry'].reset_index(drop=True)
    df = df.loc[df['ADM3_PCODE'] == woreda]
    bounds = gdf_woreda_shp.bounds
else:
    proposed_schools= 5
    df = pd.read_csv('data/clean_dataset.csv', converters={'point': pd.eval})
    # limit geojson to only selected region
    # limit clean dataset to only selected region
    gdf_region = gpd.read_file('eth_shape_files/json//eth_admin1v2.json') # read in geojson
    gdf_region_shp = gdf_region.loc[gdf_region['ADM1_EN']==region]['geometry'].reset_index(drop=True)
    df = df.loc[df['region'] == region]
    bounds = gdf_region_shp.bounds

# %% [markdown]
# ## Data Preparation

# %%
# Establish boundaries based on the bounds of region or woreda.
# Latitude is the Y axis, longitude is the X axis.

lat_bounds = bounds[['miny','maxy']].to_numpy(dtype=float)[0]
lon_bounds = bounds[['minx','maxx']].to_numpy(dtype=float)[0]
bounds = np.array([[lat_bounds[0], lon_bounds[0]], [lat_bounds[1], lon_bounds[1]]])
# array - [[lower lat bounds, lower lon bounds],[upper lat bounds, upper lon bounds]]
# CMA expects a list of size 2 for bounds
x1y1 = np.repeat([bounds[0,:]],proposed_schools, axis=0).flatten()
x2y2 = np.repeat([bounds[1,:]],proposed_schools, axis=0).flatten()
boundsxy = [x1y1,x2y2]
boundsxy
# Out:
# [array([ 8.71481253, 35.26108445,  8.71481253, 35.26108445,  8.71481253,
#         35.26108445,  8.71481253, 35.26108445,  8.71481253, 35.26108445]),
#  array([13.76296565, 40.21243796, 13.76296565, 40.21243796, 13.76296565,
#         40.21243796, 13.76296565, 40.21243796, 13.76296565, 40.21243796])]

# %%
# Create subset arrays required as input for enrollment function.
# 1. Primary school enrollment data
# 2. Primary school location data: lat lon point data. 
# 3. Secondary schoool location data: lat lon point data. 
# 4. Secondary school enrollment data. Potentially required for calibration function.

df_prim = df.loc[ (df['gr_offer'] == 'G.1-8') | (df['gr_offer'] == 'G.5-8')]
df_prim_enroll = df_prim['grade5_8'].reset_index(drop=True).to_numpy(dtype=float)
df_prim_loc = df_prim['point'].reset_index(drop=True).to_numpy()
df_prim_loc = np.array([np.array(i) for i in df_prim_loc], dtype=float)

df_sec = df.loc[ (df['gr_offer'] == 'G. 9-10') | (df['gr_offer'] == 'G. 9-12')]
df_sec_loc = df_sec['point'].reset_index(drop=True).to_numpy()
df_sec_enroll = df_sec['grade9_10'].reset_index(drop=True).to_numpy(dtype=float)
df_sec_loc = np.array([np.array(i) for i in df_sec_loc], dtype=float)

# %% [markdown]
# ## Key functions

# %%
def check_woreda(vec):
    # lat = y, x=lon
    vec = gpd.points_from_xy(vec[:, 1], vec[:, 0])
    return vec.within(gdf_woreda_shp[0]).all()
            
def check_region(vec):
    # lat = y, x=lon
    vec = gpd.points_from_xy(vec[:, 1], vec[:, 0])
    return vec.within(gdf_region_shp[0]).all()

# %%
def shape(distance, enrollment):
    min_walk = 2 # distance not a factor issuing enrollment until 2km
    max_walk = 5 # distance greater than 5km assumes zero enrollment
    answer = np.rint(np.where(distance<min_walk, enrollment,
             np.where(distance>max_walk, 0.1,
                     enrollment*(1-(distance-min_walk)/(max_walk-min_walk)))
            ))
    return answer

# %%
def expected_enroll(prim_loc, x, prim_enroll, sec_loc):
    x = np.append(sec_loc, x) # The genotype
    x = np.array(np.array_split(x, (len(sec_loc)+proposed_schools)))
    distance = haversine_vector(prim_loc, x, Unit.KILOMETERS, comb=True)
    min_d = np.min(distance, axis=0) # array with minimum distance from each primacy school to every secondary.
    return np.sum(min_d*prim_enroll)

# %%
def expected_enroll2(prim_loc, x, prim_enroll, sec_loc):
    x = np.append(sec_loc, x) # The genotype
    x = np.array(np.array_split(x, (len(sec_loc)+proposed_schools)))
    distance = haversine_vector(prim_loc, x, Unit.KILOMETERS, comb=True)
    min_d = np.min(distance, axis=0) # array with minimum distance from each primacy school to every secondary.
    shaped_enroll = shape(min_d, prim_enroll)
    return np.sum(shaped_enroll)

# %%
# The Objective Function
def f(x):
    test_case = expected_enroll(df_prim_loc, x, df_prim_enroll, df_sec_loc)
    return np.round(test_case,3)

# %%
# The Objective Function with the shape function included.
def f2(x):
    test_case = expected_enroll2(df_prim_loc, x, df_prim_enroll, df_sec_loc)
    return np.round(test_case,3)*-1

# %%
# Create starting points within regional box boundaries.

def create_random_sp():
    sp1 = np.random.uniform(low=lat_bounds[0], high=lat_bounds[1], size=proposed_schools)
    sp2 = np.random.uniform(low=lon_bounds[0], high=lon_bounds[1], size=proposed_schools)
    sp = np.vstack((sp1, sp2)).T
    return sp

# create a random starting point within the target region.
def get_random_sp():
    sp = create_random_sp()
    for i in range(0,10000):
        if declare_test == 3:
            if check_region(sp) == True:
                return sp.flatten()
                break
            else:
                sp = create_random_sp()
        else:
            if check_woreda(sp) == True:
                return sp.flatten()
                break
            else:
                sp = create_random_sp()

# %% [markdown]
# ## Random Search

# %%
def random_search(f, n):
    x = [get_random_sp() for _ in range(n)] 
    fx = [(f(xi), xi) for xi in x]
    best_f, best_solution = min(fx, key=lambda x:x[0])
    return best_f, best_solution

# %%
fx = [random_search(f, 1000) for _ in range(4)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-fb77c3e73c53> in <module>
# ----> 1 fx = [random_search(f, 1000) for _ in range(4)]
#
# <ipython-input-21-fb77c3e73c53> in <listcomp>(.0)
# ----> 1 fx = [random_search(f, 1000) for _ in range(4)]
#
# <ipython-input-19-0b92067bdf69> in random_search(f, n)
#       1 def random_search(f, n):
# ----> 2     x = [get_random_sp() for _ in range(n)]
#       3     fx = [(f(xi), xi) for xi in x]
#       4     best_f, best_solution = min(fx, key=lambda x:x[0])
#       5     return best_f, best_solution
#
# <ipython-input-19-0b92067bdf69> in <listcomp>(.0)
#       1 def random_search(f, n):
# ----> 2     x = [get_random_sp() for _ in range(n)]
#       3     fx = [(f(xi), xi) for xi in x]
#       4     best_f, best_solution = min(fx, key=lambda x:x[0])
#       5     return best_f, best_solution
#
# <ipython-input-18-b371641640c7> in get_random_sp()
#      12     for i in range(0,10000):
#      13         if declare_test == 3:
# ---> 14             if check_region(sp) == True:
#      15                 return sp.flatten()
#      16                 break
#
# <ipython-input-7-795985cac51e> in check_region(vec)
#       7     # lat = y, x=lon
#       8     vec = gpd.points_from_xy(vec[:, 1], vec[:, 0])
# ----> 9     return vec.within(gdf_region_shp[0]).all()
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\geopandas\array.py in within(self, other)
#     513
#     514     def within(self, other):
# --> 515         return self._binary_method("within", self, other)
#     516
#     517     def geom_equals_exact(self, other, tolerance):
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\geopandas\array.py in _binary_method(op, left, right, **kwargs)
#     483             right = right.data
#     484
# --> 485         return getattr(vectorized, op)(left.data, right, **kwargs)
#     486
#     487     def covers(self, other):
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\geopandas\_vectorized.py in within(data, other)
#     688         return _binary_method("within", data, other)
#     689     else:
# --> 690         return _binary_predicate("within", data, other)
#     691
#     692
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\geopandas\_vectorized.py in _binary_predicate(op, left, right, *args, **kwargs)
#     329     # empty geometries are handled by shapely (all give False except disjoint)
#     330     if isinstance(right, BaseGeometry):
# --> 331         data = [
#     332             getattr(s, op)(right, *args, **kwargs) if s is not None else False
#     333             for s in left
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\geopandas\_vectorized.py in <listcomp>(.0)
#     330     if isinstance(right, BaseGeometry):
#     331         data = [
# --> 332             getattr(s, op)(right, *args, **kwargs) if s is not None else False
#     333             for s in left
#     334         ]
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\shapely\geometry\base.py in within(self, other)
#     777     def within(self, other):
#     778         """Returns True if geometry is within the other, else False"""
# --> 779         return bool(self.impl['within'](self, other))
#     780
#     781     def equals_exact(self, other, tolerance):
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\shapely\predicates.py in __call__(self, this, other, *args)
#      13         self._validate(other, stop_prepared=True)
#      14         try:
# ---> 15             return self.fn(this._geom, other._geom, *args)
#      16         except PredicateError as err:
#      17             # Dig deeper into causes of errors.
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\shapely\geos.py in errcheck_predicate(result, func, argtuple)
#     584
#     585
# --> 586 def errcheck_predicate(result, func, argtuple):
#     587     """Result is 2 on exception, 1 on True, 0 on False"""
#     588     if result == 2:
#
# KeyboardInterrupt:

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2, 2, figsize=(15,15))
fig.suptitle('Random Search F(1). 4 Outputs with Different Starting Points')

for i in range(4):
    ax = 'ax'+str(i)
    eval(ax).scatter(df_prim_loc[:, 1], df_prim_loc[:, 0], s=df_prim_enroll/100, label="Prim") # s gives size
    if(len(df_sec) != 0): eval(ax).scatter(df_sec_loc[:, 1], df_sec_loc[:, 0], s=df_sec_enroll/100, label="Secondary") # s gives size
    eval(ax).scatter(fx[i][1][1::2], fx[i][1][::2], s = 35, marker="o", label="New Secondary") # stars for supermarkets
    eval(ax).set_title(np.round(fx[i][0],0), fontstyle='italic')

for ax in fig.get_axes():
    ax.label_outer()

# %%
fx2 = [random_search(f2, 10000) for _ in range(4)]

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2, 2, figsize=(15,15))
fig.suptitle('Random Search F(2). 4 Outputs with Different Starting Points')

for i in range(4):
    ax = 'ax'+str(i)
    eval(ax).scatter(df_prim_loc[:, 1], df_prim_loc[:, 0], s=df_prim_enroll/100, label="Prim") # s gives size
    if(len(df_sec) != 0): eval(ax).scatter(df_sec_loc[:, 1], df_sec_loc[:, 0], s=df_sec_enroll/100, label="Secondary") # s gives size
    eval(ax).scatter(fx2[i][1][1::2], fx2[i][1][::2], s = 35, marker="o", label="New Secondary") # stars for supermarkets
    eval(ax).set_title(np.round(fx2[i][0],0), fontstyle='italic')

for ax in fig.get_axes():
    ax.label_outer()

# %% [markdown]
# ## CMA

# %%
sigmas = (0.01, 0.05, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24)
maxits = 10000

# %%
fcma = []

for i in range(4):
    for j in sigmas:
        es = cma.CMAEvolutionStrategy(get_random_sp(), sigma0=j,
                                  inopts={'bounds': boundsxy,'seed':1234})
        es.optimize(f, iterations=maxits / es.popsize)
        fcma.append((es.result[1], es.result[0], j))
        
fcma_s = sorted(fcma, key=lambda t: t[0])[:4]
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Thu Jun 30 23:33:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.171475520700000e+07 1.0e+00 9.82e-03  1e-02  1e-02 0:01.2
#     2     20 1.171472173700000e+07 1.2e+00 1.00e-02  1e-02  1e-02 0:02.5
#     3     30 1.170800892300000e+07 1.3e+00 9.93e-03  1e-02  1e-02 0:03.7
#     6     60 1.168798719300000e+07 1.6e+00 1.33e-02  1e-02  1e-02 0:07.3
#    10    100 1.162941529000000e+07 1.8e+00 2.51e-02  2e-02  3e-02 0:12.2
#    15    150 1.159109974200000e+07 2.0e+00 4.35e-02  4e-02  5e-02 0:18.4
#    20    200 1.159168511400000e+07 1.9e+00 4.58e-02  4e-02  5e-02 0:25.0
#    26    260 1.157936092000000e+07 2.0e+00 3.59e-02  3e-02  4e-02 0:32.6
#    33    330 1.157122974900000e+07 2.4e+00 3.25e-02  2e-02  4e-02 0:41.1
#    41    410 1.148444162700000e+07 3.1e+00 4.66e-02  3e-02  7e-02 0:51.0
#    49    490 1.146907802800000e+07 3.9e+00 4.20e-02  2e-02  6e-02 1:01.3
#    58    580 1.146805353700000e+07 3.9e+00 2.72e-02  1e-02  4e-02 1:12.5
#    68    680 1.145367286900000e+07 4.1e+00 1.88e-02  7e-03  2e-02 1:24.9
#    79    790 1.145280028400000e+07 4.4e+00 1.11e-02  3e-03  1e-02 1:38.7
#    91    910 1.145184126700000e+07 4.8e+00 6.04e-03  1e-03  6e-03 1:53.6
#   100   1000 1.145177441300000e+07 5.1e+00 3.66e-03  8e-04  4e-03 2:04.6
#   114   1140 1.145170531800000e+07 5.6e+00 1.80e-03  3e-04  2e-03 2:21.3
#   128   1280 1.145167940700000e+07 7.8e+00 9.84e-04  1e-04  9e-04 2:38.5
#   143   1430 1.145165920700000e+07 9.8e+00 7.80e-04  9e-05  7e-04 2:57.3
#   159   1590 1.145165188600000e+07 1.5e+01 3.27e-04  3e-05  3e-04 3:16.9
#   175   1750 1.145163227900000e+07 2.1e+01 7.97e-04  5e-05  9e-04 3:37.5
#   192   1920 1.145162676300000e+07 2.4e+01 3.04e-04  1e-05  3e-04 3:59.3
#   200   2000 1.145162638700000e+07 2.8e+01 3.29e-04  1e-05  3e-04 4:09.5
#   218   2180 1.145162524000000e+07 3.3e+01 1.41e-04  4e-06  1e-04 4:32.9
#   236   2360 1.145162504700000e+07 4.9e+01 8.31e-05  2e-06  7e-05 4:57.3
#   255   2550 1.145162495100000e+07 7.3e+01 4.19e-05  6e-07  4e-05 5:23.1
#   275   2750 1.145162490900000e+07 1.1e+02 2.51e-05  2e-07  2e-05 5:50.1
#   295   2950 1.145162489900000e+07 2.1e+02 2.60e-05  1e-07  2e-05 6:17.5
#   300   3000 1.145162489700000e+07 2.1e+02 1.93e-05  8e-08  2e-05 6:23.9
#   324   3240 1.145162488700000e+07 3.2e+02 8.20e-06  2e-08  7e-06 6:53.1
#   349   3490 1.145162488500000e+07 4.7e+02 5.48e-06  1e-08  4e-06 7:23.8
#   370   3700 1.145162488400000e+07 6.9e+02 3.57e-06  5e-09  3e-06 7:49.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Thu Jun 30 23:40:58 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.163928803300000e+07 1.0e+00 4.54e-02  4e-02  5e-02 0:01.2
#     2     20 1.163097395200000e+07 1.2e+00 4.32e-02  4e-02  4e-02 0:02.5
#     3     30 1.161185248000000e+07 1.2e+00 4.38e-02  4e-02  4e-02 0:03.6
#     6     60 1.158742291500000e+07 1.4e+00 6.67e-02  6e-02  7e-02 0:07.1
#    10    100 1.152130784000000e+07 1.7e+00 8.62e-02  8e-02  9e-02 0:11.7
#    15    150 1.148207136500000e+07 2.1e+00 1.21e-01  1e-01  1e-01 0:17.5
#    21    210 1.146344751900000e+07 1.9e+00 8.06e-02  7e-02  9e-02 0:24.5
#    28    280 1.143860645500000e+07 1.9e+00 5.19e-02  4e-02  6e-02 0:32.7
#    35    350 1.143477038600000e+07 2.2e+00 3.30e-02  2e-02  4e-02 0:40.7
#    43    430 1.142844955400000e+07 2.5e+00 2.18e-02  1e-02  2e-02 0:50.3
#    52    520 1.142809128000000e+07 2.4e+00 1.44e-02  8e-03  1e-02 1:00.9
#    62    620 1.142628146000000e+07 2.9e+00 1.15e-02  6e-03  1e-02 1:12.6
#    73    730 1.142496807800000e+07 4.0e+00 6.18e-03  2e-03  6e-03 1:25.8
#    85    850 1.142447694000000e+07 4.7e+00 4.81e-03  2e-03  4e-03 1:39.9
#    97    970 1.142415894600000e+07 4.8e+00 2.78e-03  7e-04  2e-03 1:54.0
#   100   1000 1.142407637900000e+07 5.3e+00 2.21e-03  5e-04  2e-03 1:57.4
#   114   1140 1.142402842900000e+07 5.2e+00 1.65e-03  3e-04  1e-03 2:13.8
#   129   1290 1.142400384600000e+07 5.9e+00 1.36e-03  2e-04  1e-03 2:31.5
#   145   1450 1.142396198600000e+07 8.6e+00 1.13e-03  2e-04  1e-03 2:50.7
#   161   1610 1.142395671900000e+07 9.4e+00 5.94e-04  7e-05  5e-04 3:10.2
#   178   1780 1.142395355900000e+07 1.1e+01 5.02e-04  5e-05  4e-04 3:30.4
#   195   1950 1.142395050000000e+07 1.3e+01 2.04e-04  2e-05  1e-04 3:51.7
#   200   2000 1.142395044800000e+07 1.4e+01 2.06e-04  2e-05  1e-04 3:57.7
#   218   2180 1.142394997700000e+07 2.1e+01 8.40e-05  4e-06  5e-05 4:20.8
#   238   2380 1.142394981900000e+07 3.2e+01 4.40e-05  1e-06  3e-05 4:45.3
#   259   2590 1.142394978800000e+07 5.1e+01 1.76e-05  3e-07  1e-05 5:10.8
#   281   2810 1.142394977300000e+07 9.7e+01 1.19e-05  1e-07  9e-06 5:37.4
#   300   3000 1.142394976900000e+07 1.9e+02 1.08e-05  6e-08  8e-06 6:00.4
#   323   3230 1.142394976800000e+07 3.2e+02 5.20e-06  2e-08  4e-06 6:28.6
#   331   3310 1.142394976700000e+07 3.7e+02 3.44e-06  9e-09  2e-06 6:38.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Thu Jun 30 23:47:38 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.164071648400000e+07 1.0e+00 9.04e-02  9e-02  9e-02 0:01.2
#     2     20 1.160825159400000e+07 1.2e+00 9.59e-02  9e-02  1e-01 0:02.4
#     3     30 1.158610705600000e+07 1.3e+00 9.92e-02  9e-02  1e-01 0:03.7
#     6     60 1.152964817100000e+07 1.6e+00 1.18e-01  1e-01  1e-01 0:07.6
#    10    100 1.151925169900000e+07 1.8e+00 9.82e-02  8e-02  1e-01 0:12.6
#    15    150 1.152235732200000e+07 1.9e+00 9.20e-02  7e-02  1e-01 0:18.8
#    20    200 1.145563209200000e+07 2.2e+00 7.01e-02  5e-02  9e-02 0:25.2
#    26    260 1.144764239400000e+07 2.3e+00 5.20e-02  3e-02  6e-02 0:32.7
#    33    330 1.144204409000000e+07 2.4e+00 3.04e-02  2e-02  3e-02 0:41.7
#    41    410 1.143869001000000e+07 2.8e+00 1.85e-02  1e-02  2e-02 0:51.8
#    49    490 1.143389117700000e+07 3.3e+00 1.35e-02  6e-03  1e-02 1:01.9
#    58    580 1.143302390800000e+07 3.7e+00 7.39e-03  3e-03  7e-03 1:13.1
#    68    680 1.143276022600000e+07 4.0e+00 3.31e-03  1e-03  3e-03 1:25.8
#    79    790 1.143266634600000e+07 5.6e+00 2.52e-03  6e-04  3e-03 1:39.8
#    91    910 1.143261131100000e+07 7.0e+00 1.38e-03  3e-04  1e-03 1:54.8
#   100   1000 1.143260159400000e+07 7.8e+00 1.20e-03  2e-04  1e-03 2:06.2
#   113   1130 1.143258652400000e+07 1.1e+01 6.46e-04  8e-05  6e-04 2:22.6
#   127   1270 1.143258241500000e+07 1.5e+01 3.87e-04  3e-05  4e-04 2:40.2
#   142   1420 1.143258141700000e+07 2.4e+01 2.13e-04  1e-05  2e-04 2:58.8
#   157   1570 1.143258086500000e+07 3.9e+01 1.23e-04  4e-06  1e-04 3:18.1
#   173   1730 1.143258069000000e+07 5.4e+01 7.04e-05  1e-06  7e-05 3:38.3
#   190   1900 1.143258062600000e+07 9.1e+01 3.50e-05  4e-07  3e-05 3:59.9
#   200   2000 1.143258060900000e+07 1.1e+02 2.95e-05  3e-07  3e-05 4:12.7
#   218   2180 1.143258059200000e+07 1.9e+02 1.77e-05  1e-07  2e-05 4:35.8
#   237   2370 1.143258058700000e+07 3.1e+02 1.49e-05  6e-08  2e-05 5:00.8
#   256   2560 1.143258058500000e+07 4.2e+02 6.08e-06  2e-08  6e-06 5:27.1
#   277   2770 1.143258058400000e+07 6.6e+02 3.19e-06  6e-09  3e-06 5:53.3
#   283   2830 1.143258058400000e+07 6.5e+02 2.89e-06  5e-09  2e-06 6:01.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Thu Jun 30 23:53:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.168267872400000e+07 1.0e+00 1.14e-01  1e-01  1e-01 0:01.2
#     2     20 1.168252089300000e+07 1.2e+00 1.14e-01  1e-01  1e-01 0:02.5
#     3     30 1.167982769700000e+07 1.2e+00 1.14e-01  1e-01  1e-01 0:03.8
#     6     60 1.166441505100000e+07 1.4e+00 1.17e-01  1e-01  1e-01 0:07.6
#    10    100 1.165880324500000e+07 1.7e+00 1.10e-01  9e-02  1e-01 0:12.7
#    15    150 1.162460709900000e+07 1.7e+00 9.22e-02  7e-02  1e-01 0:19.0
#    20    200 1.161645553600000e+07 1.7e+00 6.05e-02  5e-02  6e-02 0:25.4
#    26    260 1.160477399100000e+07 1.7e+00 4.75e-02  4e-02  5e-02 0:33.1
#    33    330 1.159910323700000e+07 1.8e+00 2.69e-02  2e-02  3e-02 0:42.1
#    41    410 1.159514146300000e+07 1.9e+00 1.73e-02  1e-02  2e-02 0:52.3
#    50    500 1.159434616300000e+07 2.2e+00 1.16e-02  6e-03  1e-02 1:03.5
#    59    590 1.159416956200000e+07 2.6e+00 6.82e-03  3e-03  6e-03 1:14.8
#    69    690 1.159391589500000e+07 3.3e+00 4.19e-03  1e-03  4e-03 1:27.2
#    80    800 1.159379488800000e+07 5.2e+00 3.17e-03  7e-04  3e-03 1:41.0
#    92    920 1.159375157600000e+07 7.0e+00 2.65e-03  4e-04  2e-03 1:55.9
#   100   1000 1.159368693200000e+07 7.8e+00 1.81e-03  3e-04  2e-03 2:06.0
#   113   1130 1.159367734900000e+07 9.0e+00 1.35e-03  1e-04  1e-03 2:22.4
#   127   1270 1.159366552700000e+07 1.2e+01 1.01e-03  8e-05  7e-04 2:40.0
#   142   1420 1.159365747400000e+07 1.6e+01 4.80e-04  3e-05  4e-04 2:59.1
#   158   1580 1.159365666000000e+07 1.9e+01 2.72e-04  1e-05  2e-04 3:18.9
#   175   1750 1.159365606100000e+07 2.7e+01 1.43e-04  5e-06  1e-04 3:40.1
#   192   1920 1.159365584000000e+07 3.0e+01 6.86e-05  2e-06  5e-05 4:01.5
#   200   2000 1.159365582900000e+07 3.4e+01 5.10e-05  1e-06  4e-05 4:11.6
#   219   2190 1.159365579600000e+07 4.9e+01 1.99e-05  3e-07  1e-05 4:35.4
#   239   2390 1.159365578600000e+07 6.9e+01 8.73e-06  9e-08  5e-06 5:00.3
#   259   2590 1.159365578300000e+07 1.4e+02 4.16e-06  3e-08  3e-06 5:26.3
#   265   2650 1.159365578300000e+07 1.6e+02 3.37e-06  2e-08  3e-06 5:33.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Thu Jun 30 23:59:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.161175807500000e+07 1.0e+00 1.33e-01  1e-01  1e-01 0:01.2
#     2     20 1.161858498900000e+07 1.2e+00 1.42e-01  1e-01  1e-01 0:02.5
#     3     30 1.151902750600000e+07 1.4e+00 1.44e-01  1e-01  2e-01 0:03.7
#     6     60 1.154457688600000e+07 1.6e+00 1.28e-01  1e-01  1e-01 0:07.6
#    10    100 1.149368345100000e+07 1.8e+00 1.08e-01  9e-02  1e-01 0:12.8
#    14    140 1.143158825800000e+07 2.0e+00 1.18e-01  8e-02  1e-01 0:17.9
#    19    190 1.144539733900000e+07 2.2e+00 8.86e-02  6e-02  1e-01 0:24.3
#    25    250 1.142968785200000e+07 2.3e+00 5.09e-02  3e-02  5e-02 0:31.8
#    32    320 1.140742324400000e+07 2.5e+00 4.45e-02  2e-02  5e-02 0:40.9
#    39    390 1.140143953200000e+07 2.6e+00 3.52e-02  2e-02  4e-02 0:50.0
#    47    470 1.139473287500000e+07 2.6e+00 2.79e-02  1e-02  3e-02 1:00.1
#    56    560 1.138879162000000e+07 2.8e+00 1.47e-02  6e-03  1e-02 1:11.5
#    66    660 1.138683507800000e+07 3.1e+00 8.44e-03  3e-03  8e-03 1:24.6
#    76    760 1.138564232600000e+07 3.3e+00 4.79e-03  2e-03  4e-03 1:37.7
#    87    870 1.138559081900000e+07 4.2e+00 3.51e-03  1e-03  3e-03 1:51.9
#    99    990 1.138536410000000e+07 5.1e+00 1.83e-03  4e-04  2e-03 2:07.5
#   100   1000 1.138537039800000e+07 5.0e+00 1.61e-03  4e-04  2e-03 2:08.8
#   114   1140 1.138525082500000e+07 6.0e+00 9.35e-04  2e-04  9e-04 2:26.7
#   129   1290 1.138522360000000e+07 8.9e+00 5.48e-04  7e-05  5e-04 2:45.6
#   145   1450 1.138521241300000e+07 1.2e+01 3.49e-04  3e-05  4e-04 3:05.8
#   161   1610 1.138520408900000e+07 1.8e+01 2.37e-04  2e-05  2e-04 3:26.0
#   178   1780 1.138520163900000e+07 2.8e+01 9.11e-05  5e-06  9e-05 3:47.4
#   196   1960 1.138520005300000e+07 3.6e+01 5.89e-05  2e-06  6e-05 4:10.3
#   200   2000 1.138520003600000e+07 4.0e+01 4.42e-05  1e-06  4e-05 4:15.6
#   219   2190 1.138519965600000e+07 6.6e+01 1.71e-05  3e-07  2e-05 4:40.1
#   239   2390 1.138519949300000e+07 9.1e+01 1.62e-05  2e-07  2e-05 5:06.2
#   260   2600 1.138519940700000e+07 1.4e+02 6.20e-06  6e-08  7e-06 5:32.8
#   282   2820 1.138519929500000e+07 2.6e+02 1.79e-05  1e-07  2e-05 6:00.8
#   300   3000 1.138519913800000e+07 3.6e+02 2.51e-05  1e-07  4e-05 6:23.8
#   323   3230 1.138519909500000e+07 6.8e+02 1.31e-05  4e-08  3e-05 6:53.1
#   346   3460 1.138519908200000e+07 9.6e+02 3.68e-06  1e-08  8e-06 7:24.3
#   369   3690 1.138519907900000e+07 1.3e+03 3.81e-06  6e-09  7e-06 7:55.8
#   393   3930 1.138519907700000e+07 2.2e+03 9.60e-07  1e-09  2e-06 8:28.9
#   394   3940 1.138519907700000e+07 2.1e+03 9.14e-07  1e-09  2e-06 8:30.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 00:07:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.163519915500000e+07 1.0e+00 1.58e-01  1e-01  2e-01 0:01.3
#     2     20 1.161191042900000e+07 1.2e+00 1.65e-01  2e-01  2e-01 0:02.7
#     3     30 1.161395694500000e+07 1.3e+00 1.65e-01  2e-01  2e-01 0:04.1
#     6     60 1.158514411600000e+07 1.5e+00 1.49e-01  1e-01  2e-01 0:08.1
#     9     90 1.154732074300000e+07 1.5e+00 1.25e-01  1e-01  1e-01 0:12.2
#    13    130 1.156951320600000e+07 1.9e+00 1.27e-01  1e-01  2e-01 0:17.7
#    18    180 1.154181517600000e+07 2.4e+00 1.24e-01  9e-02  2e-01 0:24.8
#    25    250 1.154504278500000e+07 2.7e+00 9.26e-02  6e-02  1e-01 0:32.8
#    33    330 1.150522744400000e+07 2.7e+00 6.87e-02  4e-02  9e-02 0:41.9
#    42    420 1.151637426500000e+07 2.6e+00 5.29e-02  3e-02  6e-02 0:52.0
#    51    510 1.149814119300000e+07 2.5e+00 3.84e-02  2e-02  4e-02 1:02.5
#    61    610 1.149658708400000e+07 2.7e+00 2.46e-02  1e-02  2e-02 1:14.4
#    71    710 1.149180503600000e+07 2.9e+00 1.73e-02  9e-03  2e-02 1:26.4
#    83    830 1.148651418400000e+07 2.4e+00 1.04e-02  5e-03  9e-03 1:40.6
#    95    950 1.148571731700000e+07 2.2e+00 7.32e-03  3e-03  5e-03 1:54.8
#   100   1000 1.148538468500000e+07 2.3e+00 4.75e-03  2e-03  3e-03 2:00.6
#   114   1140 1.148533251500000e+07 2.6e+00 2.00e-03  7e-04  1e-03 2:17.2
#   129   1290 1.148528586800000e+07 3.0e+00 1.13e-03  3e-04  7e-04 2:35.0
#   145   1450 1.148528333500000e+07 5.0e+00 7.04e-04  1e-04  5e-04 2:53.5
#   161   1610 1.148527720900000e+07 6.4e+00 3.46e-04  5e-05  2e-04 3:12.6
#   178   1780 1.148527514600000e+07 1.0e+01 1.89e-04  2e-05  1e-04 3:33.0
#   195   1950 1.148527480700000e+07 1.6e+01 9.32e-05  6e-06  6e-05 3:54.5
#   200   2000 1.148527484800000e+07 1.9e+01 6.57e-05  4e-06  5e-05 4:00.7
#   219   2190 1.148527468900000e+07 3.5e+01 3.83e-05  1e-06  3e-05 4:24.9
#   239   2390 1.148527466500000e+07 5.3e+01 2.12e-05  4e-07  2e-05 4:50.1
#   259   2590 1.148527463800000e+07 8.8e+01 3.61e-05  4e-07  3e-05 5:15.6
#   280   2800 1.148527462100000e+07 1.3e+02 2.15e-05  1e-07  2e-05 5:42.1
#   300   3000 1.148527461000000e+07 2.0e+02 3.27e-05  1e-07  2e-05 6:07.5
#   323   3230 1.148527460500000e+07 3.1e+02 9.00e-06  2e-08  5e-06 6:36.3
#   341   3410 1.148527460400000e+07 3.8e+02 5.46e-06  1e-08  3e-06 6:59.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 00:14:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.170658896100000e+07 1.0e+00 1.64e-01  2e-01  2e-01 0:01.1
#     2     20 1.169395864000000e+07 1.1e+00 1.57e-01  2e-01  2e-01 0:02.3
#     3     30 1.168774330200000e+07 1.2e+00 1.54e-01  1e-01  2e-01 0:03.5
#     6     60 1.167577830400000e+07 1.3e+00 1.37e-01  1e-01  1e-01 0:07.4
#    10    100 1.167151402500000e+07 1.5e+00 1.14e-01  9e-02  1e-01 0:12.2
#    14    140 1.164747334700000e+07 1.6e+00 1.08e-01  9e-02  1e-01 0:17.2
#    19    190 1.162123473500000e+07 1.8e+00 7.85e-02  6e-02  8e-02 0:23.7
#    25    250 1.160425049900000e+07 1.9e+00 4.50e-02  3e-02  5e-02 0:31.2
#    32    320 1.159349494000000e+07 1.9e+00 2.52e-02  2e-02  2e-02 0:40.0
#    40    400 1.159196751600000e+07 2.1e+00 1.91e-02  1e-02  2e-02 0:49.9
#    48    480 1.159136041200000e+07 2.1e+00 1.09e-02  6e-03  9e-03 0:59.9
#    57    570 1.159014783200000e+07 2.2e+00 7.11e-03  4e-03  6e-03 1:11.6
#    67    670 1.158975070600000e+07 2.2e+00 2.66e-03  1e-03  2e-03 1:24.7
#    78    780 1.158964895400000e+07 3.0e+00 1.66e-03  6e-04  1e-03 1:38.6
#    90    900 1.158962400100000e+07 4.0e+00 1.61e-03  4e-04  1e-03 1:53.7
#   100   1000 1.158959991800000e+07 5.0e+00 8.89e-04  2e-04  8e-04 2:06.0
#   113   1130 1.158957833900000e+07 5.7e+00 5.84e-04  1e-04  5e-04 2:22.5
#   127   1270 1.158956959100000e+07 7.6e+00 3.25e-04  4e-05  3e-04 2:39.6
#   142   1420 1.158956843700000e+07 1.1e+01 1.67e-04  2e-05  2e-04 2:58.3
#   157   1570 1.158956693500000e+07 1.5e+01 8.82e-05  7e-06  9e-05 3:17.7
#   173   1730 1.158956658200000e+07 1.9e+01 3.90e-05  2e-06  4e-05 3:37.9
#   190   1900 1.158956644600000e+07 2.8e+01 1.93e-05  8e-07  2e-05 3:59.8
#   200   2000 1.158956642000000e+07 4.3e+01 1.76e-05  6e-07  2e-05 4:12.6
#   218   2180 1.158956634400000e+07 8.4e+01 1.97e-05  5e-07  4e-05 4:35.9
#   237   2370 1.158956628900000e+07 1.1e+02 8.27e-06  2e-07  1e-05 5:00.2
#   257   2570 1.158956628000000e+07 1.5e+02 4.49e-06  7e-08  9e-06 5:25.8
#   278   2780 1.158956627500000e+07 2.4e+02 2.07e-06  2e-08  4e-06 5:52.8
#   300   3000 1.158956626900000e+07 3.3e+02 2.76e-06  2e-08  5e-06 6:20.6
#   323   3230 1.158956625800000e+07 4.2e+02 5.21e-06  3e-08  9e-06 6:49.7
#   346   3460 1.158956624300000e+07 5.3e+02 9.59e-06  3e-08  2e-05 7:18.7
#   370   3700 1.158956624000000e+07 7.3e+02 4.20e-06  1e-08  6e-06 7:49.7
#   388   3880 1.158956624000000e+07 9.6e+02 1.78e-06  3e-09  3e-06 8:12.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 00:23:02 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.164569248600000e+07 1.0e+00 2.08e-01  2e-01  2e-01 0:01.4
#     2     20 1.162625212800000e+07 1.2e+00 2.02e-01  2e-01  2e-01 0:02.6
#     3     30 1.164710053400000e+07 1.3e+00 2.07e-01  2e-01  2e-01 0:03.8
#     6     60 1.159979633800000e+07 1.5e+00 2.30e-01  2e-01  3e-01 0:07.6
#    10    100 1.161438998500000e+07 1.8e+00 2.57e-01  2e-01  3e-01 0:12.7
#    15    150 1.152342842200000e+07 2.1e+00 2.66e-01  2e-01  3e-01 0:18.8
#    20    200 1.145696893600000e+07 2.5e+00 2.30e-01  2e-01  3e-01 0:25.3
#    26    260 1.141464091600000e+07 2.8e+00 1.88e-01  1e-01  2e-01 0:32.8
#    33    330 1.141994826200000e+07 2.7e+00 1.21e-01  8e-02  1e-01 0:41.6
#    41    410 1.142389643300000e+07 3.0e+00 7.99e-02  5e-02  9e-02 0:51.6
#    49    490 1.132492904200000e+07 2.8e+00 4.95e-02  3e-02  5e-02 1:02.2
#    58    580 1.132860597100000e+07 3.2e+00 2.79e-02  2e-02  3e-02 1:13.4
#    68    680 1.130840319000000e+07 2.8e+00 1.80e-02  1e-02  2e-02 1:25.8
#    79    790 1.130806992000000e+07 3.2e+00 1.35e-02  7e-03  1e-02 1:39.3
#    91    910 1.130528134500000e+07 3.8e+00 1.08e-02  4e-03  1e-02 1:54.4
#   100   1000 1.130260258200000e+07 5.1e+00 1.32e-02  5e-03  2e-02 2:05.8
#   112   1120 1.130020735800000e+07 4.7e+00 6.90e-03  2e-03  7e-03 2:21.9
#   125   1250 1.129947023200000e+07 4.8e+00 3.88e-03  9e-04  3e-03 2:39.2
#   140   1400 1.129937908800000e+07 6.1e+00 1.52e-03  3e-04  1e-03 2:58.4
#   155   1550 1.129935131400000e+07 8.0e+00 9.59e-04  1e-04  7e-04 3:18.9
#   170   1700 1.129933204500000e+07 1.1e+01 4.67e-04  4e-05  3e-04 3:38.9
#   186   1860 1.129932351300000e+07 1.6e+01 3.92e-04  2e-05  3e-04 4:01.1
#   200   2000 1.129932124900000e+07 2.3e+01 3.01e-04  1e-05  2e-04 4:20.6
#   217   2170 1.129931977100000e+07 4.0e+01 2.07e-04  5e-06  1e-04 4:44.3
#   235   2350 1.129931950800000e+07 5.8e+01 1.08e-04  2e-06  7e-05 5:09.2
#   254   2540 1.129931934500000e+07 8.3e+01 5.75e-05  5e-07  4e-05 5:35.4
#   273   2730 1.129931928000000e+07 1.4e+02 3.00e-05  2e-07  2e-05 6:01.9
#   298   2980 1.129931926900000e+07 3.0e+02 1.44e-05  3e-08  9e-06 6:29.7
#   300   3000 1.129931926700000e+07 3.2e+02 1.29e-05  3e-08  8e-06 6:31.8
#   326   3260 1.129931925600000e+07 7.8e+02 8.65e-06  1e-08  7e-06 7:01.3
#   353   3530 1.129931925100000e+07 1.4e+03 6.20e-06  5e-09  6e-06 7:32.3
#   381   3810 1.129931924800000e+07 2.4e+03 6.89e-06  3e-09  6e-06 8:04.1
#   400   4000 1.129931924700000e+07 3.3e+03 5.97e-06  2e-09  6e-06 8:20.9
#   404   4040 1.129931924700000e+07 3.6e+03 5.65e-06  2e-09  5e-06 8:24.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 07:32:19 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.155511744700000e+07 1.0e+00 2.02e-01  2e-01  2e-01 0:00.8
#     2     20 1.150141389200000e+07 1.2e+00 1.92e-01  2e-01  2e-01 0:01.6
#     3     30 1.153566640900000e+07 1.2e+00 1.90e-01  2e-01  2e-01 0:02.4
#     7     70 1.149934121800000e+07 1.5e+00 1.83e-01  2e-01  2e-01 0:05.6
#    13    130 1.155126140300000e+07 2.0e+00 2.48e-01  2e-01  3e-01 0:10.2
#    20    200 1.140852921000000e+07 2.3e+00 1.42e-01  1e-01  2e-01 0:15.8
#    28    280 1.135803651400000e+07 2.4e+00 7.40e-02  5e-02  9e-02 0:22.5
#    35    350 1.133919741500000e+07 2.5e+00 5.27e-02  3e-02  6e-02 0:30.2
#    44    440 1.133149597500000e+07 2.6e+00 3.01e-02  2e-02  3e-02 0:38.4
#    55    550 1.132892715100000e+07 2.8e+00 2.17e-02  9e-03  2e-02 0:47.8
#    66    660 1.132650193200000e+07 3.1e+00 1.21e-02  4e-03  1e-02 0:58.5
#    76    760 1.132592247100000e+07 3.6e+00 8.32e-03  3e-03  8e-03 1:09.8
#    87    870 1.132575039300000e+07 5.0e+00 5.32e-03  1e-03  6e-03 1:22.4
#    99    990 1.132556266400000e+07 5.6e+00 2.35e-03  5e-04  2e-03 1:36.2
#   100   1000 1.132556186700000e+07 5.4e+00 2.20e-03  5e-04  2e-03 1:37.3
#   114   1140 1.132552262300000e+07 6.9e+00 1.21e-03  2e-04  1e-03 1:53.4
#   128   1280 1.132552143900000e+07 9.7e+00 6.03e-04  8e-05  6e-04 2:09.6
#   143   1430 1.132551418500000e+07 1.2e+01 4.86e-04  5e-05  5e-04 2:27.2
#   158   1580 1.132551253400000e+07 1.6e+01 2.50e-04  2e-05  2e-04 2:46.4
#   174   1740 1.132551099500000e+07 2.2e+01 1.99e-04  1e-05  2e-04 3:06.4
#   190   1900 1.132551034600000e+07 2.9e+01 2.18e-04  8e-06  2e-04 3:26.6
#   200   2000 1.132551009400000e+07 3.4e+01 1.56e-04  5e-06  1e-04 3:39.0
#   218   2180 1.132550971300000e+07 5.0e+01 7.07e-05  1e-06  5e-05 4:01.9
#   236   2360 1.132550963200000e+07 6.9e+01 8.44e-05  1e-06  6e-05 4:24.9
#   256   2560 1.132550955600000e+07 1.2e+02 4.14e-05  3e-07  3e-05 4:49.0
#   278   2780 1.132550953800000e+07 2.2e+02 1.84e-05  7e-08  1e-05 5:15.1
#   300   3000 1.132550953700000e+07 3.3e+02 9.47e-06  2e-08  6e-06 5:41.3
#   323   3230 1.132550953500000e+07 5.1e+02 7.43e-06  1e-08  4e-06 6:08.5
#   348   3480 1.132550953300000e+07 9.1e+02 6.48e-06  6e-09  4e-06 6:37.5
#   355   3550 1.132550953300000e+07 9.3e+02 3.70e-06  3e-09  2e-06 6:45.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 07:39:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.160182517700000e+07 1.0e+00 2.15e-01  2e-01  2e-01 0:01.2
#     2     20 1.161444416700000e+07 1.1e+00 2.01e-01  2e-01  2e-01 0:02.4
#     3     30 1.151553969300000e+07 1.2e+00 1.93e-01  2e-01  2e-01 0:03.6
#     6     60 1.157746020400000e+07 1.4e+00 1.87e-01  2e-01  2e-01 0:07.3
#    10    100 1.151564895400000e+07 1.7e+00 1.59e-01  1e-01  2e-01 0:12.0
#    15    150 1.149952638100000e+07 1.8e+00 9.92e-02  7e-02  1e-01 0:17.9
#    21    210 1.145302687700000e+07 2.1e+00 6.79e-02  4e-02  7e-02 0:25.1
#    28    280 1.144513393100000e+07 2.3e+00 5.61e-02  3e-02  6e-02 0:33.3
#    35    350 1.143303561600000e+07 2.4e+00 3.40e-02  2e-02  4e-02 0:41.5
#    43    430 1.142885645600000e+07 2.6e+00 2.15e-02  1e-02  2e-02 0:50.7
#    52    520 1.142508941500000e+07 2.7e+00 9.25e-03  4e-03  8e-03 1:01.1
#    62    620 1.142443195600000e+07 2.8e+00 5.86e-03  2e-03  5e-03 1:12.6
#    73    730 1.142407466500000e+07 3.3e+00 3.26e-03  9e-04  3e-03 1:25.3
#    85    850 1.142394053800000e+07 4.1e+00 1.75e-03  4e-04  2e-03 1:39.1
#    98    980 1.142392301800000e+07 5.0e+00 9.04e-04  2e-04  9e-04 1:54.0
#   100   1000 1.142390195900000e+07 5.1e+00 8.84e-04  2e-04  8e-04 1:56.3
#   114   1140 1.142389234800000e+07 5.5e+00 4.92e-04  9e-05  5e-04 2:12.3
#   129   1290 1.142387855700000e+07 6.7e+00 4.48e-04  7e-05  4e-04 2:29.5
#   145   1450 1.142387255800000e+07 8.8e+00 2.94e-04  3e-05  3e-04 2:48.2
#   162   1620 1.142386849600000e+07 1.1e+01 2.25e-04  2e-05  2e-04 3:07.9
#   180   1800 1.142386661700000e+07 1.3e+01 8.49e-05  6e-06  8e-05 3:28.6
#   199   1990 1.142386603000000e+07 1.6e+01 2.54e-05  1e-06  2e-05 3:50.5
#   200   2000 1.142386603400000e+07 1.7e+01 2.30e-05  1e-06  2e-05 3:51.7
#   220   2200 1.142386577300000e+07 2.1e+01 3.28e-05  2e-06  3e-05 4:14.7
#   241   2410 1.142386556100000e+07 3.5e+01 2.10e-05  8e-07  2e-05 4:39.0
#   263   2630 1.142386544800000e+07 5.0e+01 7.56e-06  2e-07  7e-06 5:04.4
#   286   2860 1.142386541400000e+07 6.1e+01 1.89e-06  4e-08  2e-06 5:31.0
#   300   3000 1.142386541100000e+07 7.5e+01 1.06e-06  2e-08  1e-06 5:47.1
#   325   3250 1.142386539900000e+07 2.1e+02 1.59e-06  2e-08  3e-06 6:15.9
#   351   3510 1.142386536800000e+07 5.1e+02 3.99e-06  4e-08  2e-05 6:45.8
#   377   3770 1.142386536000000e+07 6.3e+02 1.13e-06  9e-09  4e-06 7:16.6
#   389   3890 1.142386536000000e+07 8.1e+02 5.55e-07  4e-09  2e-06 7:31.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 07:46:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.168299133800000e+07 1.0e+00 9.25e-03  9e-03  9e-03 0:01.3
#     2     20 1.167931956000000e+07 1.2e+00 9.03e-03  8e-03  9e-03 0:02.4
#     3     30 1.167876651000000e+07 1.2e+00 9.34e-03  9e-03  1e-02 0:03.6
#     6     60 1.166468595200000e+07 1.6e+00 1.35e-02  1e-02  2e-02 0:07.3
#    10    100 1.165103715000000e+07 1.7e+00 2.26e-02  2e-02  3e-02 0:12.2
#    15    150 1.162710879400000e+07 2.1e+00 3.29e-02  3e-02  4e-02 0:18.1
#    21    210 1.160341490400000e+07 2.9e+00 4.45e-02  4e-02  6e-02 0:25.1
#    27    270 1.159770178500000e+07 3.0e+00 3.86e-02  3e-02  5e-02 0:32.2
#    34    340 1.157979726900000e+07 3.1e+00 3.35e-02  2e-02  4e-02 0:40.3
#    42    420 1.157482894300000e+07 3.5e+00 3.16e-02  2e-02  4e-02 0:49.5
#    51    510 1.157161887100000e+07 3.1e+00 1.77e-02  1e-02  2e-02 0:59.9
#    61    610 1.156912324800000e+07 3.0e+00 1.24e-02  7e-03  1e-02 1:11.4
#    72    720 1.156744737000000e+07 3.7e+00 1.08e-02  5e-03  1e-02 1:24.1
#    84    840 1.156658004900000e+07 5.2e+00 9.20e-03  4e-03  1e-02 1:37.8
#    97    970 1.156590168700000e+07 5.2e+00 5.63e-03  2e-03  7e-03 1:52.7
#   100   1000 1.156593612600000e+07 5.2e+00 4.00e-03  1e-03  5e-03 1:56.1
#   114   1140 1.156567268200000e+07 4.0e+00 1.84e-03  6e-04  2e-03 2:12.2
#   129   1290 1.156561603700000e+07 3.8e+00 8.05e-04  2e-04  7e-04 2:29.3
#   145   1450 1.156560282900000e+07 4.2e+00 8.01e-04  2e-04  7e-04 2:47.7
#   162   1620 1.156558773800000e+07 5.3e+00 1.88e-04  3e-05  1e-04 3:07.1
#   180   1800 1.156558681200000e+07 7.8e+00 9.91e-05  1e-05  7e-05 3:27.7
#   199   1990 1.156558640900000e+07 1.2e+01 7.17e-05  6e-06  6e-05 3:49.5
#   200   2000 1.156558627100000e+07 1.3e+01 6.70e-05  6e-06  5e-05 3:50.6
#   221   2210 1.156558583900000e+07 1.7e+01 2.53e-05  2e-06  2e-05 4:14.8
#   242   2420 1.156558572600000e+07 2.4e+01 1.26e-05  6e-07  1e-05 4:38.8
#   264   2640 1.156558569100000e+07 4.4e+01 7.35e-06  2e-07  7e-06 5:04.2
#   287   2870 1.156558562100000e+07 1.1e+02 1.27e-05  3e-07  2e-05 5:30.8
#   300   3000 1.156558561000000e+07 1.3e+02 8.03e-06  2e-07  1e-05 5:45.7
#   325   3250 1.156558559600000e+07 2.2e+02 9.01e-06  1e-07  2e-05 6:14.3
#   351   3510 1.156558558700000e+07 3.4e+02 3.81e-06  3e-08  7e-06 6:44.1
#   377   3770 1.156558557500000e+07 3.8e+02 7.50e-06  5e-08  1e-05 7:14.3
#   400   4000 1.156558556000000e+07 4.4e+02 9.89e-06  5e-08  1e-05 7:40.7
#   428   4280 1.156558555300000e+07 5.9e+02 4.23e-06  1e-08  6e-06 8:12.9
#   457   4570 1.156558555200000e+07 9.6e+02 1.92e-06  5e-09  3e-06 8:46.0
#   480   4800 1.156558555200000e+07 8.8e+02 1.55e-06  4e-09  2e-06 9:12.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 07:55:55 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.171774449800000e+07 1.0e+00 4.67e-02  4e-02  5e-02 0:01.1
#     2     20 1.171736176800000e+07 1.2e+00 4.24e-02  4e-02  5e-02 0:02.4
#     3     30 1.172193973300000e+07 1.3e+00 4.18e-02  4e-02  4e-02 0:03.6
#     6     60 1.171928806000000e+07 1.5e+00 4.09e-02  4e-02  5e-02 0:07.1
#    10    100 1.170625556900000e+07 1.9e+00 5.79e-02  5e-02  7e-02 0:11.8
#    15    150 1.160714896100000e+07 2.7e+00 9.28e-02  7e-02  1e-01 0:17.5
#    21    210 1.157532441800000e+07 2.6e+00 8.05e-02  6e-02  1e-01 0:24.4
#    28    280 1.157396819200000e+07 2.2e+00 5.34e-02  4e-02  6e-02 0:32.4
#    35    350 1.157449516100000e+07 2.1e+00 3.64e-02  3e-02  4e-02 0:40.4
#    43    430 1.157153416900000e+07 2.1e+00 1.82e-02  1e-02  2e-02 0:49.6
#    52    520 1.156868932400000e+07 2.3e+00 1.40e-02  8e-03  1e-02 0:59.9
#    62    620 1.156826820200000e+07 2.6e+00 8.06e-03  4e-03  8e-03 1:11.3
#    73    730 1.156797707500000e+07 2.7e+00 5.31e-03  2e-03  5e-03 1:23.9
#    85    850 1.156784148300000e+07 3.9e+00 3.29e-03  1e-03  4e-03 1:37.7
#    98    980 1.156783572500000e+07 4.5e+00 1.69e-03  5e-04  2e-03 1:52.7
#   100   1000 1.156783786700000e+07 4.8e+00 1.54e-03  5e-04  2e-03 1:55.0
#   114   1140 1.156782382400000e+07 6.5e+00 7.09e-04  2e-04  8e-04 2:11.1
#   129   1290 1.156782019000000e+07 1.2e+01 4.01e-04  6e-05  6e-04 2:28.4
#   145   1450 1.156781953400000e+07 2.2e+01 2.87e-04  3e-05  5e-04 2:46.7
#   162   1620 1.156781898300000e+07 3.2e+01 1.42e-04  1e-05  3e-04 3:06.1
#   180   1800 1.156781895400000e+07 4.9e+01 8.04e-05  4e-06  1e-04 3:26.8
#   199   1990 1.156781890500000e+07 7.0e+01 4.19e-05  1e-06  7e-05 3:48.6
#   200   2000 1.156781890500000e+07 7.4e+01 4.33e-05  1e-06  7e-05 3:49.8
#   221   2210 1.156781888100000e+07 1.6e+02 3.86e-05  5e-07  7e-05 4:13.8
#   243   2430 1.156781887400000e+07 2.6e+02 1.52e-05  1e-07  3e-05 4:38.7
#   259   2590 1.156781887100000e+07 3.5e+02 7.42e-06  4e-08  1e-05 5:03.8
#   275   2750 1.156781887000000e+07 4.8e+02 4.47e-06  2e-08  8e-06 5:29.9
#   282   2820 1.156781887000000e+07 5.3e+02 4.08e-06  2e-08  7e-06 5:38.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 08:01:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.169060868300000e+07 1.0e+00 9.51e-02  9e-02  1e-01 0:01.2
#     2     20 1.169702771300000e+07 1.1e+00 8.61e-02  8e-02  9e-02 0:02.5
#     3     30 1.167555479400000e+07 1.2e+00 7.92e-02  7e-02  8e-02 0:03.7
#     6     60 1.165105427900000e+07 1.4e+00 7.81e-02  7e-02  9e-02 0:07.5
#    10    100 1.165539973400000e+07 1.6e+00 7.44e-02  6e-02  8e-02 0:12.5
#    15    150 1.164374833400000e+07 1.8e+00 7.50e-02  6e-02  8e-02 0:18.5
#    21    210 1.163481958400000e+07 2.1e+00 5.14e-02  4e-02  6e-02 0:25.7
#    27    270 1.162821967800000e+07 2.6e+00 3.38e-02  2e-02  4e-02 0:32.9
#    34    340 1.162595024000000e+07 2.8e+00 2.22e-02  1e-02  3e-02 0:41.1
#    42    420 1.162215943200000e+07 3.1e+00 1.69e-02  1e-02  2e-02 0:50.6
#    51    510 1.162316485100000e+07 3.1e+00 1.14e-02  6e-03  1e-02 1:01.4
#    61    610 1.162159385200000e+07 3.2e+00 9.28e-03  5e-03  1e-02 1:13.3
#    72    720 1.162105914500000e+07 3.5e+00 3.81e-03  2e-03  4e-03 1:26.3
#    84    840 1.162072728900000e+07 2.8e+00 2.78e-03  1e-03  2e-03 1:39.6
#    97    970 1.162066763700000e+07 3.1e+00 1.69e-03  6e-04  1e-03 1:54.7
#   100   1000 1.162063619600000e+07 3.2e+00 1.62e-03  6e-04  1e-03 1:58.3
#   114   1140 1.162058739800000e+07 3.4e+00 8.62e-04  3e-04  6e-04 2:14.9
#   129   1290 1.162057595800000e+07 4.0e+00 4.69e-04  1e-04  4e-04 2:32.9
#   145   1450 1.162057220000000e+07 4.5e+00 1.79e-04  4e-05  1e-04 2:52.1
#   161   1610 1.162057083400000e+07 5.2e+00 8.42e-05  1e-05  6e-05 3:11.2
#   178   1780 1.162057002100000e+07 8.4e+00 5.55e-05  6e-06  4e-05 3:32.4
#   195   1950 1.162056967700000e+07 1.0e+01 2.09e-05  2e-06  1e-05 3:53.5
#   200   2000 1.162056968000000e+07 1.1e+01 1.57e-05  1e-06  9e-06 3:59.6
#   219   2190 1.162056964600000e+07 1.5e+01 5.72e-06  4e-07  3e-06 4:23.1
#   239   2390 1.162056961400000e+07 2.2e+01 6.18e-06  3e-07  4e-06 4:47.9
#   260   2600 1.162056959300000e+07 3.6e+01 2.77e-06  8e-08  2e-06 5:14.1
#   281   2810 1.162056957900000e+07 7.3e+01 2.26e-06  5e-08  2e-06 5:40.4
#   300   3000 1.162056955300000e+07 1.7e+02 6.06e-06  1e-07  1e-05 6:04.6
#   323   3230 1.162056952100000e+07 2.9e+02 1.24e-05  1e-07  3e-05 6:32.9
#   347   3470 1.162056951100000e+07 3.6e+02 4.91e-06  4e-08  8e-06 7:02.7
#   372   3720 1.162056950900000e+07 4.6e+02 1.86e-06  1e-08  3e-06 7:33.5
#   383   3830 1.162056950800000e+07 4.5e+02 1.00e-06  5e-09  1e-06 7:47.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 08:09:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.169234023300000e+07 1.0e+00 1.12e-01  1e-01  1e-01 0:01.2
#     2     20 1.164091138800000e+07 1.2e+00 1.06e-01  1e-01  1e-01 0:02.4
#     3     30 1.163291355700000e+07 1.2e+00 1.07e-01  9e-02  1e-01 0:03.6
#     6     60 1.160189595700000e+07 1.5e+00 1.17e-01  1e-01  1e-01 0:07.3
#    10    100 1.159531103100000e+07 1.5e+00 1.14e-01  1e-01  1e-01 0:12.3
#    15    150 1.157082138400000e+07 1.6e+00 1.23e-01  1e-01  1e-01 0:18.3
#    20    200 1.156336885100000e+07 2.0e+00 8.97e-02  7e-02  1e-01 0:24.3
#    26    260 1.155637737900000e+07 2.0e+00 1.01e-01  8e-02  1e-01 0:31.8
#    33    330 1.156188096300000e+07 2.4e+00 8.50e-02  6e-02  1e-01 0:40.6
#    41    410 1.155828176100000e+07 2.6e+00 7.10e-02  5e-02  1e-01 0:50.6
#    49    490 1.152493021800000e+07 3.1e+00 4.95e-02  3e-02  6e-02 1:00.6
#    58    580 1.151843105800000e+07 3.0e+00 3.42e-02  2e-02  4e-02 1:11.9
#    68    680 1.150214546300000e+07 3.4e+00 2.42e-02  1e-02  2e-02 1:24.4
#    79    790 1.150080358000000e+07 3.4e+00 2.37e-02  1e-02  2e-02 1:37.8
#    91    910 1.149117107900000e+07 3.8e+00 1.29e-02  4e-03  1e-02 1:52.8
#   100   1000 1.149017623000000e+07 4.5e+00 8.16e-03  2e-03  7e-03 2:03.6
#   114   1140 1.148778251300000e+07 5.6e+00 7.04e-03  2e-03  7e-03 2:20.8
#   128   1280 1.148738347500000e+07 6.5e+00 4.71e-03  8e-04  5e-03 2:38.1
#   143   1430 1.148721432100000e+07 1.0e+01 2.11e-03  3e-04  2e-03 2:56.6
#   158   1580 1.148712173500000e+07 1.4e+01 2.04e-03  2e-04  2e-03 3:16.2
#   175   1750 1.148704634600000e+07 1.8e+01 1.37e-03  9e-05  2e-03 3:37.2
#   192   1920 1.148702297100000e+07 2.2e+01 5.17e-04  3e-05  6e-04 3:58.6
#   200   2000 1.148702092100000e+07 2.4e+01 4.23e-04  2e-05  5e-04 4:08.6
#   219   2190 1.148701850600000e+07 2.4e+01 2.69e-04  1e-05  3e-04 4:32.5
#   238   2380 1.148701764800000e+07 2.8e+01 1.57e-04  6e-06  1e-04 4:56.8
#   259   2590 1.148701756600000e+07 3.0e+01 6.61e-05  2e-06  6e-05 5:23.1
#   281   2810 1.148701747000000e+07 6.0e+01 2.20e-05  6e-07  2e-05 5:50.0
#   300   3000 1.148701747000000e+07 9.8e+01 1.40e-05  2e-07  2e-05 6:13.5
#   323   3230 1.148701746500000e+07 1.6e+02 7.69e-06  7e-08  8e-06 6:41.8
#   347   3470 1.148701746300000e+07 2.7e+02 1.12e-05  6e-08  1e-05 7:11.4
#   372   3720 1.148701746200000e+07 4.1e+02 5.95e-06  2e-08  5e-06 7:41.9
#   379   3790 1.148701746200000e+07 4.6e+02 4.00e-06  1e-08  4e-06 7:50.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 08:17:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.169106708200000e+07 1.0e+00 1.19e-01  1e-01  1e-01 0:01.4
#     2     20 1.168311749200000e+07 1.1e+00 1.15e-01  1e-01  1e-01 0:02.5
#     3     30 1.169377958000000e+07 1.2e+00 1.15e-01  1e-01  1e-01 0:03.8
#     6     60 1.168106592400000e+07 1.4e+00 1.18e-01  1e-01  1e-01 0:07.4
#    10    100 1.167912918500000e+07 1.7e+00 1.02e-01  9e-02  1e-01 0:12.1
#    15    150 1.164669530400000e+07 1.9e+00 7.63e-02  6e-02  9e-02 0:18.2
#    20    200 1.164188460800000e+07 2.0e+00 5.93e-02  4e-02  6e-02 0:24.5
#    26    260 1.164316529900000e+07 2.3e+00 5.35e-02  3e-02  6e-02 0:31.9
#    33    330 1.163529331200000e+07 2.6e+00 3.16e-02  2e-02  3e-02 0:40.6
#    41    410 1.162500368300000e+07 3.0e+00 3.90e-02  2e-02  4e-02 0:50.5
#    49    490 1.161285995200000e+07 3.6e+00 4.32e-02  2e-02  5e-02 1:00.6
#    58    580 1.161311153400000e+07 3.7e+00 3.30e-02  2e-02  4e-02 1:11.6
#    68    680 1.160887106600000e+07 4.1e+00 1.71e-02  7e-03  2e-02 1:23.9
#    79    790 1.160901008100000e+07 4.4e+00 9.21e-03  4e-03  1e-02 1:37.5
#    91    910 1.160868414200000e+07 4.6e+00 7.26e-03  2e-03  9e-03 1:52.7
#   100   1000 1.160833061600000e+07 5.0e+00 4.22e-03  1e-03  5e-03 2:03.4
#   114   1140 1.160829120700000e+07 5.5e+00 2.01e-03  6e-04  3e-03 2:20.5
#   129   1290 1.160827120200000e+07 8.5e+00 1.11e-03  2e-04  2e-03 2:38.7
#   144   1440 1.160827044900000e+07 1.3e+01 6.13e-04  9e-05  1e-03 2:56.9
#   160   1600 1.160826994500000e+07 2.2e+01 3.34e-04  3e-05  5e-04 3:16.9
#   177   1770 1.160826993300000e+07 2.9e+01 1.40e-04  8e-06  2e-04 3:37.6
#   195   1950 1.160826971700000e+07 4.5e+01 1.13e-04  4e-06  1e-04 3:59.2
#   200   2000 1.160826972200000e+07 4.9e+01 8.41e-05  3e-06  1e-04 4:05.4
#   219   2190 1.160826966500000e+07 1.1e+02 9.74e-05  2e-06  2e-04 4:28.6
#   240   2400 1.160826965700000e+07 2.0e+02 3.87e-05  5e-07  7e-05 4:53.4
#   261   2610 1.160826965000000e+07 3.4e+02 1.59e-05  1e-07  3e-05 5:19.0
#   282   2820 1.160826964800000e+07 6.6e+02 8.99e-06  4e-08  2e-05 5:45.4
#   295   2950 1.160826964800000e+07 7.5e+02 6.67e-06  2e-08  1e-05 6:01.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 08:23:17 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.155948555600000e+07 1.0e+00 1.56e-01  1e-01  2e-01 0:01.2
#     2     20 1.158241510800000e+07 1.2e+00 1.46e-01  1e-01  2e-01 0:02.5
#     3     30 1.159057303500000e+07 1.3e+00 1.37e-01  1e-01  1e-01 0:03.7
#     6     60 1.156607714700000e+07 1.5e+00 1.48e-01  1e-01  2e-01 0:07.4
#     9     90 1.149422556100000e+07 1.8e+00 1.61e-01  1e-01  2e-01 0:11.6
#    13    130 1.149440364800000e+07 1.9e+00 1.41e-01  1e-01  2e-01 0:17.0
#    18    180 1.147834435900000e+07 1.9e+00 1.02e-01  7e-02  1e-01 0:23.1
#    24    240 1.143408420400000e+07 2.1e+00 7.11e-02  4e-02  8e-02 0:30.5
#    31    310 1.142542862000000e+07 2.7e+00 5.25e-02  3e-02  6e-02 0:39.1
#    39    390 1.142369951800000e+07 2.7e+00 3.83e-02  2e-02  4e-02 0:49.0
#    48    480 1.141610508100000e+07 3.2e+00 2.69e-02  1e-02  3e-02 1:00.0
#    57    570 1.141340501600000e+07 3.7e+00 2.12e-02  1e-02  3e-02 1:11.0
#    67    670 1.141132612000000e+07 4.2e+00 1.09e-02  5e-03  2e-02 1:23.2
#    78    780 1.140990540300000e+07 5.2e+00 6.25e-03  2e-03  1e-02 1:36.5
#    90    900 1.140974123800000e+07 6.0e+00 3.66e-03  1e-03  6e-03 1:51.1
#   100   1000 1.140964375700000e+07 6.9e+00 3.26e-03  8e-04  5e-03 2:03.2
#   113   1130 1.140949114000000e+07 8.9e+00 2.73e-03  5e-04  5e-03 2:19.7
#   128   1280 1.140946862800000e+07 1.5e+01 1.38e-03  2e-04  3e-03 2:36.8
#   142   1420 1.140942032300000e+07 1.8e+01 8.04e-04  9e-05  1e-03 2:55.5
#   158   1580 1.140941464800000e+07 1.9e+01 5.75e-04  5e-05  1e-03 3:14.6
#   176   1760 1.140940894300000e+07 3.0e+01 3.79e-04  2e-05  7e-04 3:35.6
#   195   1950 1.140940707900000e+07 3.3e+01 1.45e-04  8e-06  2e-04 3:57.4
#   200   2000 1.140940693600000e+07 3.7e+01 1.12e-04  6e-06  2e-04 4:03.2
#   220   2200 1.140940662800000e+07 4.9e+01 3.56e-05  2e-06  6e-05 4:26.3
#   241   2410 1.140940655000000e+07 6.1e+01 2.32e-05  8e-07  4e-05 4:50.7
#   263   2630 1.140940651200000e+07 1.1e+02 1.15e-05  3e-07  2e-05 5:16.8
#   285   2850 1.140940650100000e+07 1.7e+02 6.86e-06  1e-07  1e-05 5:43.0
#   300   3000 1.140940649900000e+07 2.1e+02 5.24e-06  7e-08  9e-06 5:60.0
#   323   3230 1.140940649300000e+07 3.1e+02 5.18e-06  5e-08  1e-05 6:28.9
#   347   3470 1.140940649100000e+07 4.5e+02 3.21e-06  2e-08  6e-06 6:59.0
#   372   3720 1.140940649000000e+07 4.9e+02 2.79e-06  1e-08  5e-06 7:29.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 08:30:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.159967635100000e+07 1.0e+00 1.64e-01  2e-01  2e-01 0:01.2
#     2     20 1.161917730800000e+07 1.1e+00 1.58e-01  2e-01  2e-01 0:02.5
#     3     30 1.161304330300000e+07 1.3e+00 1.59e-01  1e-01  2e-01 0:03.6
#     6     60 1.158164670400000e+07 1.5e+00 1.36e-01  1e-01  2e-01 0:07.2
#    10    100 1.159075927400000e+07 1.7e+00 1.43e-01  1e-01  2e-01 0:12.2
#    14    140 1.155761324600000e+07 1.9e+00 1.28e-01  1e-01  2e-01 0:17.2
#    19    190 1.155754705600000e+07 2.3e+00 9.99e-02  7e-02  1e-01 0:23.6
#    25    250 1.152599435300000e+07 2.5e+00 8.49e-02  5e-02  1e-01 0:31.1
#    32    320 1.152970030800000e+07 2.9e+00 5.93e-02  3e-02  9e-02 0:39.6
#    40    400 1.150967746900000e+07 3.6e+00 3.51e-02  2e-02  5e-02 0:49.5
#    49    490 1.150404834800000e+07 3.9e+00 1.98e-02  7e-03  3e-02 1:00.2
#    59    590 1.150345178100000e+07 4.9e+00 1.24e-02  4e-03  2e-02 1:12.2
#    69    690 1.150268967400000e+07 5.6e+00 5.49e-03  1e-03  7e-03 1:24.3
#    80    800 1.150254366700000e+07 7.3e+00 3.98e-03  1e-03  6e-03 1:38.4
#    92    920 1.150250630100000e+07 8.0e+00 2.49e-03  5e-04  4e-03 1:52.5
#   100   1000 1.150249000400000e+07 9.6e+00 2.37e-03  5e-04  4e-03 2:01.4
#   114   1140 1.150247782200000e+07 1.0e+01 1.22e-03  2e-04  2e-03 2:18.2
#   129   1290 1.150247604700000e+07 1.1e+01 5.20e-04  9e-05  8e-04 2:35.6
#   145   1450 1.150247567800000e+07 1.3e+01 2.09e-04  3e-05  3e-04 2:54.2
#   162   1620 1.150247559400000e+07 1.6e+01 9.55e-05  1e-05  2e-04 3:14.1
#   179   1790 1.150247558700000e+07 1.8e+01 4.89e-05  6e-06  8e-05 3:34.9
#   196   1960 1.150247558600000e+07 2.0e+01 2.15e-05  2e-06  3e-05 3:56.6
#   200   2000 1.150247558600000e+07 2.0e+01 1.62e-05  2e-06  2e-05 4:01.7
#   206   2060 1.150247558600000e+07 1.9e+01 1.21e-05  1e-06  2e-05 4:09.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 08:34:58 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.167331718000000e+07 1.0e+00 1.81e-01  2e-01  2e-01 0:01.2
#     2     20 1.161890320800000e+07 1.2e+00 1.85e-01  2e-01  2e-01 0:02.5
#     3     30 1.161591423700000e+07 1.3e+00 1.85e-01  2e-01  2e-01 0:03.7
#     6     60 1.163975974600000e+07 1.4e+00 1.60e-01  1e-01  2e-01 0:07.5
#    10    100 1.163966677000000e+07 1.6e+00 1.40e-01  1e-01  2e-01 0:12.2
#    15    150 1.162018811100000e+07 1.9e+00 1.09e-01  8e-02  1e-01 0:18.6
#    20    200 1.161132893900000e+07 2.1e+00 8.07e-02  5e-02  9e-02 0:24.7
#    26    260 1.159904608500000e+07 2.3e+00 6.82e-02  4e-02  8e-02 0:32.0
#    33    330 1.156823785500000e+07 2.3e+00 4.71e-02  3e-02  5e-02 0:40.6
#    41    410 1.156393011800000e+07 2.5e+00 2.41e-02  1e-02  3e-02 0:50.2
#    50    500 1.155715061200000e+07 2.5e+00 2.34e-02  1e-02  2e-02 1:01.3
#    59    590 1.155534320400000e+07 2.9e+00 1.35e-02  7e-03  1e-02 1:12.5
#    69    690 1.155439328200000e+07 3.2e+00 6.55e-03  3e-03  6e-03 1:24.6
#    80    800 1.155428878000000e+07 3.4e+00 3.83e-03  2e-03  4e-03 1:38.1
#    92    920 1.155425756300000e+07 4.0e+00 2.41e-03  9e-04  2e-03 1:53.1
#   100   1000 1.155423829300000e+07 4.2e+00 1.84e-03  6e-04  2e-03 2:03.3
#   113   1130 1.155423028800000e+07 5.2e+00 8.86e-04  3e-04  1e-03 2:19.6
#   128   1280 1.155422765600000e+07 5.4e+00 3.23e-04  8e-05  3e-04 2:37.7
#   144   1440 1.155422739000000e+07 6.0e+00 1.06e-04  2e-05  1e-04 2:56.9
#   160   1600 1.155422736900000e+07 6.0e+00 2.50e-05  4e-06  2e-05 3:16.1
#   174   1740 1.155422736800000e+07 6.7e+00 1.35e-05  2e-06  1e-05 3:32.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 08:38:31 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.157729392700000e+07 1.0e+00 2.13e-01  2e-01  2e-01 0:01.3
#     2     20 1.159257852900000e+07 1.2e+00 1.90e-01  2e-01  2e-01 0:02.5
#     3     30 1.157129664400000e+07 1.3e+00 1.85e-01  2e-01  2e-01 0:03.7
#     6     60 1.157624742600000e+07 1.5e+00 1.97e-01  2e-01  2e-01 0:07.4
#    10    100 1.154112451500000e+07 1.7e+00 1.41e-01  1e-01  1e-01 0:12.3
#    15    150 1.148235721400000e+07 1.7e+00 1.26e-01  1e-01  1e-01 0:18.0
#    21    210 1.149492998500000e+07 1.9e+00 8.84e-02  7e-02  9e-02 0:25.2
#    27    270 1.144926768300000e+07 2.0e+00 5.98e-02  4e-02  6e-02 0:32.7
#    34    340 1.144043371000000e+07 2.0e+00 3.39e-02  2e-02  3e-02 0:41.7
#    41    410 1.143551966700000e+07 2.1e+00 1.86e-02  1e-02  2e-02 0:51.0
#    49    490 1.142849415500000e+07 2.3e+00 1.49e-02  8e-03  1e-02 1:01.3
#    58    580 1.142738200100000e+07 2.7e+00 9.07e-03  4e-03  8e-03 1:12.6
#    68    680 1.142693061800000e+07 2.5e+00 4.01e-03  2e-03  3e-03 1:24.9
#    79    790 1.142685657000000e+07 2.5e+00 1.94e-03  8e-04  1e-03 1:38.9
#    91    910 1.142682214200000e+07 2.6e+00 1.50e-03  6e-04  1e-03 1:53.9
#   100   1000 1.142678999400000e+07 2.8e+00 1.05e-03  4e-04  7e-04 2:05.7
#   113   1130 1.142676655700000e+07 2.8e+00 5.92e-04  2e-04  4e-04 2:21.8
#   127   1270 1.142675790400000e+07 3.6e+00 3.01e-04  8e-05  2e-04 2:39.6
#   142   1420 1.142675479100000e+07 4.7e+00 1.78e-04  3e-05  1e-04 2:58.4
#   158   1580 1.142675290100000e+07 6.7e+00 1.02e-04  2e-05  7e-05 3:18.2
#   175   1750 1.142675184500000e+07 8.3e+00 4.25e-05  5e-06  3e-05 3:38.8
#   192   1920 1.142675171200000e+07 1.3e+01 2.00e-05  2e-06  1e-05 3:59.9
#   200   2000 1.142675164900000e+07 1.5e+01 2.04e-05  1e-06  1e-05 4:10.1
#   219   2190 1.142675161100000e+07 2.4e+01 1.05e-05  5e-07  9e-06 4:33.8
#   239   2390 1.142675159000000e+07 3.5e+01 6.24e-06  2e-07  6e-06 4:58.6
#   260   2600 1.142675157100000e+07 4.5e+01 3.50e-06  1e-07  3e-06 5:24.3
#   281   2810 1.142675154800000e+07 7.3e+01 5.43e-06  1e-07  6e-06 5:50.5
#   300   3000 1.142675153500000e+07 1.5e+02 5.67e-06  8e-08  7e-06 6:13.6
#   322   3220 1.142675152700000e+07 2.0e+02 9.33e-06  9e-08  1e-05 6:41.7
#   346   3460 1.142675152200000e+07 2.4e+02 3.46e-06  2e-08  4e-06 7:11.2
#   370   3700 1.142675152100000e+07 3.2e+02 1.43e-06  7e-09  1e-06 7:41.3
#   373   3730 1.142675152100000e+07 2.9e+02 1.24e-06  6e-09  1e-06 7:44.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Fri Jul  1 08:46:17 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 1.160885368800000e+07 1.0e+00 2.18e-01  2e-01  2e-01 0:01.2
#     2     20 1.160594899600000e+07 1.1e+00 1.96e-01  2e-01  2e-01 0:02.4
#     3     30 1.157832594100000e+07 1.2e+00 1.72e-01  2e-01  2e-01 0:03.6
#     6     60 1.155915053700000e+07 1.3e+00 1.60e-01  1e-01  2e-01 0:07.4
#     9     90 1.158104165300000e+07 1.4e+00 1.48e-01  1e-01  2e-01 0:11.6
#    14    140 1.158299476200000e+07 1.8e+00 1.40e-01  1e-01  2e-01 0:17.6
#    19    190 1.154972370600000e+07 1.8e+00 1.04e-01  8e-02  1e-01 0:23.7
#    25    250 1.151796255500000e+07 2.0e+00 6.26e-02  5e-02  6e-02 0:31.0
#    32    320 1.145567695800000e+07 2.0e+00 3.84e-02  3e-02  4e-02 0:39.4
#    40    400 1.144914843200000e+07 2.1e+00 2.28e-02  1e-02  2e-02 0:49.1
#    48    480 1.143730272200000e+07 2.1e+00 1.77e-02  9e-03  2e-02 0:59.8
#    57    570 1.143466711900000e+07 2.2e+00 1.06e-02  5e-03  9e-03 1:11.3
#    67    670 1.143117708200000e+07 2.3e+00 4.60e-03  2e-03  4e-03 1:23.8
#    78    780 1.143078226600000e+07 2.5e+00 3.49e-03  2e-03  3e-03 1:37.7
#    90    900 1.143040730900000e+07 2.9e+00 1.51e-03  6e-04  1e-03 1:52.6
#   100   1000 1.143034367000000e+07 3.8e+00 1.21e-03  4e-04  1e-03 2:04.5
#   113   1130 1.143023562100000e+07 4.9e+00 7.09e-04  2e-04  7e-04 2:20.6
#   127   1270 1.143020107000000e+07 4.9e+00 3.73e-04  9e-05  3e-04 2:38.0
#   142   1420 1.143016834900000e+07 7.2e+00 1.74e-04  3e-05  2e-04 2:56.8
#   158   1580 1.143016329500000e+07 9.8e+00 8.73e-05  1e-05  1e-04 3:16.1
#   175   1750 1.143015909200000e+07 1.2e+01 3.91e-05  4e-06  4e-05 3:37.8
#   192   1920 1.143015753300000e+07 1.4e+01 1.56e-05  1e-06  2e-05 3:59.3

# %%
fcma_s

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2, 2, figsize=(15,15))
fig.suptitle('CMA f(1). 4 Outputs with Different Starting Points')

for i in range(4):
    ax = 'ax'+str(i)
    eval(ax).scatter(df_prim_loc[:, 1], df_prim_loc[:, 0], s=df_prim_enroll/100, label="Prim") # s gives size
    if(len(df_sec) != 0): eval(ax).scatter(df_sec_loc[:, 1], df_sec_loc[:, 0], s=df_sec_enroll/100, label="Secondary") # s gives size
    eval(ax).scatter(fcma_s[i][1][1::2], fcma_s[i][1][::2], s = 35, marker="o", label="New Secondary") # stars for supermarkets
    eval(ax).set_title('Max: ' + str(np.round(fcma_s[i][0],0))+ ' . Sigma: ' + str(fcma_s[i][2]), fontstyle='italic')

for ax in fig.get_axes():
    ax.label_outer()

# %%
fcma2 = []

for i in range(4):
    for j in sigmas:
        es = cma.CMAEvolutionStrategy(get_random_sp(), sigma0=j,
                                  inopts={'bounds': boundsxy,'seed':1234})
        es.optimize(f2, iterations=maxits / es.popsize)
        fcma2.append((es.result[1], es.result[0], j))
        
fcma2_s = sorted(fcma2, key=lambda t: t[0])[:4]

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2, 2, figsize=(15,15))
fig.suptitle('CMA F(2). 4 Outputs with Different Starting Points')

for i in range(4):
    ax = 'ax'+str(i)
    eval(ax).scatter(df_prim_loc[:, 1], df_prim_loc[:, 0], s=df_prim_enroll/100, label="Prim") # s gives size
    if(len(df_sec) != 0): eval(ax).scatter(df_sec_loc[:, 1], df_sec_loc[:, 0], s=df_sec_enroll/100, label="Secondary") # s gives size
    eval(ax).scatter(fcma2_s[i][1][1::2], fcma2_s[i][1][::2], s = 35, marker="o", label="New Secondary") # stars for supermarkets
    eval(ax).set_title('Max: ' + str(np.round(fcma2_s[i][0],0))+ ' . Sigma: ' + str(fcma2_s[i][2]), fontstyle='italic')

for ax in fig.get_axes():
    ax.label_outer()
