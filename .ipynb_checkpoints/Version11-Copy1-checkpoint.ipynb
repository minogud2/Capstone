# %% [markdown]
# # MSc. AI
# ## Capstone Project
# ### Darragh Minogue
#
# ### 1. Background
#
#
# This project adopts the facility location problem to the school network in Ethiopia to expand access to secondary education. Of the 40,776 schools in the country, 37,039 offer primary and middle school education (grades 1-8), but only 3,737 offer secondary (grades 10-12). On average, middle schools are located more than 6km away from the nearest secondary school, meaning children face long journeys or they don't access secondary at all.
#
# The expansion of secondary education is a major priority for the Ministry of Education, Ethiopia. Ambitious five year targets are set in the Education Sector Development Plans (ESDP). In 2013/2014, the Gross Enrollment Rate (GER) for lower secondary was 38.9% (3,466,972/8,914,837 children) and a target of 74% (6,596,979/8,914,837 children) was set. However, by 2019/2020, the actual GER was 51.05% (4,551,024/8,914,837 children), a more modest increase of 12.15% rather than 35.1%.  In the latest five year ESDP (2020/2021-2024/2025), an increase of 24% was set, but under the key-performance indicator of 'Number of newly established secondary schools', it says TBD- for 'To Be Determined'. Therein lies part of the problem: planning. Often, a portion of the budget is allocated for secondary, then each region decides how and where to spend it. Planners then, at the macro level, identify primary schools with the highest demand (i.e. largest enrollment) and seek to construct schools to serve that particular school population. While this can often yeild good results, the goal of this project is to improve on this approach in a way that allows for the potential construction of secondary schools across a catchment of multiple primary schools, if enrollment is sufficient and distance is minimal. Meta-heuristic optimisation techniques are used to achieve this.
#
# The project makes use of readily available data from the Ministry of Education, Ethiopia, mainly 1) enrollment data from the Education Managament Information System (EMIS) and 2) geolocation data, recently obtained from the World Bank in 2020. Since national population and census data is inaccurate and outdated in Ethiopia, this was not considered a reliable source for this project. Instead, it is assumed that middle schools are located within the community and new secondary schools should therefore be constructed close to existing middle schools.
#
# ### 2. The Problem
#
# In the problem, there is a list of existing middle schools and secondary schools in Ethiopia, their enrollment and location data (region, zone, district, longitude and latitude). The aim is to expand the secondary school network by constructing new secondary schools that best serve the demand from the existing middle school network. No limit is placed on capacity as this is determined by budget which is not known in advance and subject to change. Key to solving the problem is understanding that when a school is located within a village, there is no impact of distance on enrolment nor dropout. However, beyond the aspirational norm of 1-2km, distance affects initial access to school but also creates barriers to retention, completion and transition to higher level. As such, the aim is to minimise distance, but construct schools in locations with the highest demand.
#
# ### 3. Approach
#
# <b> Glossary of terms</b>
# * MS: Middle Schools
# * SS: Secondary Schools
# * EE: Expected Enrollment
# * EEI: Expected Enrollment Increase
# * Feeder: a middle school that is part of the secondary school catchment area.
# * x: proposed new secondary schools (the genotype).
# * d: distance in km between primary schools
# * catchment: a middle school is considered within a catchment if it's
# * n: total number of proposed new SS to construct
#
# This solution proposes new SS locations that can provide the highest estimated enrollment from feeder MS whilst also ensuring they are constructed within at minimal distance. Given the multitude of different languages and the decentralised Government of Ethiopia, models are developed at a regional level.
#
# Two different algorithms are used in this project to find an optimal solution: Random Search, and CMA-ES. In each of the algorithms, the objective function f() aims to <b> maximise overall expected enrollment </b> given a set of feasible locations: x. Feasibility of the locations or the genotype, x, is controlled using a box boundary of longitudes and latitudes for a given region. Initial starting points are also provided within the box boundary using a generate_random_sp() helper function.
#
# The fitness is determined using an expected_enrollment function. This takes in the parameters: 1) the location of existing MS, 2) the enrollment of existing MS, 3) x, and 4) the current distance between existing MS and existing SS. The function then calculates the haversine distance in kilometers (km) between each new SS in x and all MS within a given region. This vector, <b> d </b>, is of size: (proposed_schools, len(ps)). Using this data, the algorithm then addresses three key challenges:
#
# 1) **The need to identify the MS with the minimal distance to the new SS**. In this case, if a MS is close to two or more new SS, only the closest is selected. But if the MS is closer to an existing SS, then it's ignored as it's already a feeder school to the existing SS.
#
# 2) **The need to estimate the expected enrollment of the new SS, based on the distance to its feeder MS**. If a school is beyond a certain threshold distance in km, then the MS should not be considered a feeder school for a SS. To handle this, situation, a helper function is used to estimate the expected enrollment from a feeder MS to the nearby SS. It takes in as parameters a) distance to nearest SS and b) MS enrollment. It then makes some assumptions about distance to return the expected enrollment per school. Theunynck (2014) recommends the adoptation of a norm of 2 or 3km for junior secondary schools and the function therefore assumes that if a school is constructed within 3km of a MS, there is no negative effect on expected enrollment of it's nearby SS. Above 3km, a linear dropoff is assumed between 3-5km. If a MS is located more than 5km away from the new location proposed, it is expected that zero students will attend from that feeder school.
#
# 3) **The need to divert expected enrollment from a MS if it is currently a feeder school to an existing SS but the new SS proposed is closer**. This is dealt with by subtracting the expected enrollment from the MS to the existing SS using the shape function, and then allocating it to the new SS which is closer.
#
# A fitness evaluation budget of 10,000 is set to ensure there are sufficient iterations to achieve convergance. Each algorithm is run 30 times with different random starting points. The results are stored in a csv file, with the top 4 results plotted below.
#
# ### Assumptions and Limitations
#
# 1. It is assumed that 1km is equivalent to a 15 minute walk for children (Theunynck, S. 2014: p6).
# 2. Distance is calculated using the haversine function and as a result distance is calculated as a straight line. The travel distances could therefore be further. Ethiopia is not well mapped and since most children are walking to school using other means like Google Maps API don't yeild useful results on a large scale and don't factor in more informal walking routes. Final results require close inspection for elevation and other issues that might impact walking distance or construction e.g. buildings, rivers. The final results should therefore be observed as an approximation and using a tool like ArcGIS or QGIS, the the results are observed for these types of obstacles.
# 3. It is assumed that children beyond 5km are not likely to attend, but in some cases, this is not true. Some children walk extremely long distances to attend secondary school, while others stay with relatives or family friends to attend a school that is beyond 5km. Despite this being a reality, this shouldn't guide the construction as the goal is to minimise distance and create more equitable access to secondary.

# %%
# Key imports
import pandas as pd
import numpy as np
from haversine import haversine, haversine_vector, Unit # for distance
import geopandas as gpd
import matplotlib.pyplot as plt
import cma
import time
import os.path

# Supress the scientific notation on numpy for easierx reading.
np.set_printoptions(suppress=True)

# %%
df = pd.read_csv('data/clean_dataset_final.csv', converters={'point': pd.eval}) # read in cleaned dataset.
gdf_region = gpd.read_file('eth_shape_files/json//eth_admin1v2.json') # read in geojson

# %%
# drop Afar as only 5% of schools are mapped.
df = df[df['ADM1_EN'] != 'Afar']

# %% [markdown]
# # Helper Functions

# %%
def shape(distance, enrollment):
    """ Returns the expected enrollment based on distance.
    
        If distance is less than 3km, all children are expected to contribute to the supply of a new school. 
        The full enrollment is returned. If above 5km, the school is considered too far and no children contribute to 
        the supply. Zero enrollment is returned. If between 3-5km, a linear dropoff is assumed. e.g. for 100 children
        at a distance of 4km, 50 is returned. 

        Parameters:
            distance (float): the distance in km of a school to the next level school.
            enrollment (int): the enrollment of the school.
        
        Returns:
            shaped_enroll(float): expected feeder enrollment from one school.
    
    """
    min_walk = 3 # minimum km walking distance
    max_walk = 5 # maximum km walking distance
    shaped_enroll = np.where(distance < min_walk, enrollment,
             np.where(distance>max_walk, 0, enrollment*(1-(distance-min_walk)/(max_walk-min_walk))))
    return shaped_enroll

def generate_random_sp(bounds):
    """  Function to generate a vector of 40000 random (lat, lon) starting points for each 
         proposed school within box boundary.
    """
    lat = np.random.uniform(low=bounds[0][0], high=bounds[1][0], size=40000)
    lon = np.random.uniform(low=bounds[0][1], high=bounds[1][1], size=40000)
    sp = np.vstack((lat, lon)).T
    return sp

def check_region(vec, region_shp):
    """ Function to check if initial vector of starting points are located within the regional boundaries/polygon. 
        Returns boolean vector
    """
    vec = gpd.points_from_xy(vec[:, 1], vec[:, 0]) # lat = y, x=lon
    return vec.within(region_shp[0])

def generate_sp_proposed(sp_list, proposed_schools):
    """ Returns a vector of random starting points of size (proposed_schools)
    """
    return sp_list[np.random.choice(sp_list.shape[0], proposed_schools,replace=False)]

def get_bounds(df_):
    """ Returns the minimum and maximum box boundary for school construction.
    """
    bounds = np.array([[np.min(df_[:,0]), np.min(df_[:,1])], [np.max(df_[:,0]), np.max(df_[:,1])]])
    return bounds

def get_cma_bounds(bounds, n):
    """ CMA-ES expects a list of size 2 for bounds. This function returns the bounds reshaped for CMA-ES
    """
    x1y1 = np.repeat([bounds[0,:]],n, axis=0).flatten()
    x2y2 = np.repeat([bounds[1,:]],n, axis=0).flatten()
    boundsxy = [x1y1,x2y2]
    return boundsxy

def create_results_table():
    """ Function that checks to see if a results csv exists, it creates the csv.
    """
    if os.path.isfile('./results.csv') == False:
        results = pd.DataFrame(columns=['region','maxits', 'proposed_schools_n','starting_point', 'algorithm','std', 'ee',
                                        'eei', 'proposed_locations', 'time', 'sigma'])
        results.to_csv('results.csv', index=False)

# %% [markdown]
# # Data Preparation
#
# To maximise efficiency, data is further prepared. Most experiments use numpy arrays which are faster and use less memory.

# %%
def prepare_datasets(df_, region):
    """ A function which prepares MS and SS datasets for the experiments.
    
        Parameters: 
            df_ (pd Dataset): a pandas dataframe
            region (str): specified region to prepare.
            
        Returns array of prepared datasets: 
            [0] (pd Dataset): df_middle: Dataset filtered to only middle schools. 
            [1] (np float64) df_middle_enroll: Vector of MS enrollment data. Only the last two grades.
            [2]: (np float64) df_middle_loc: 2d vector of MS location data- lat lon point data. 
            [3]: (np float64) df_sec_enroll: Vector of SS enrollment data. Only grades 9 and 10 enrollment.
            [4]: (np float64) df_sec_loc: 2d vector of SS location data- lat lon point data. 
            [5]: (np float64) current_ms_distance: Vector of existing distances from MS to SS
    """
    
    df_ = df_.loc[df_['ADM1_EN'] == region] # filter dataset by region
    df_middle = df_.loc[df_['grade_7_8'] > 0] # 1
    df_middle_enroll = df_middle['grade_7_8'].reset_index(drop=True).to_numpy(dtype=float) # 2
    df_middle_loc = df_middle['point'].reset_index(drop=True).to_numpy()
    df_middle_loc = np.array([np.array(i) for i in df_middle_loc], dtype=float) # 3
    df_sec = df_.loc[ (df_['gr_offer'] == 'G. 9-10') | (df_['gr_offer'] == 'G. 9-12')]
    df_sec_enroll = df_sec['grade9_10'].reset_index(drop=True).to_numpy(dtype=float) # 4
    df_sec_loc = df_sec['point'].reset_index(drop=True).to_numpy() 
    df_sec_loc = np.array([np.array(i) for i in df_sec_loc], dtype=float) # 5
    current_ms_distance = df_middle['nearest_lwr_sec'].to_numpy() # 6
    return [df_middle, df_middle_enroll, df_middle_loc, df_sec_enroll, df_sec_loc, current_ms_distance]

# %%
# Use this for CMA. 
def find_eligible_MS(data, n, min_dict):
    
    """ A function that finds n clusters of schools with enrolment > minimum capacity: 200.
        If n clusters are not found, it returns the max possible that meet the minimum capacity requirements. 
    
        Parameters:
            data: (PD dataset): initial school dataset.
            n (int): number of new SS to construct
            min_dict (dict): Dictionary of regions (str) as keys and values (ints) are equal to minimum distance expected.
            
        Returns array of prepared datasets: 
            [0] (PD dataset): cluster_schools: Dataset of groupings of schools. 
            [1] (str): region: name of region
            [2]: (int): max_possible: total number of SS that can be constructed, always <=n

    """
    
    # Step 1. Check is distance is > variable minimum distance by region outlined above.
    data = data[data['nearest_lwr_sec'] > data['ADM1_EN'].map(min_dict)]
    region = data['ADM1_EN'].unique()[0]

    # Step 2. Prepare key MS datasets. 
    df_middle = data.loc[data['grade_7_8'] > 0].reset_index(drop=True) # Filter to MS only
    df_middle_enroll = df_middle['grade_7_8'].reset_index(drop=True).to_numpy(dtype=float) # Convert MS Enrolment to np
    df_middle_loc = df_middle['point'].reset_index(drop=True).to_numpy()
    df_middle_loc = np.array([np.array(i) for i in df_middle_loc], dtype=float) # Convert MS locational data to np.
    
    # Step 3. Calculate distance from MS to all other MS and check if < minimum distance per region
    dist = haversine_vector(df_middle_loc,df_middle_loc, Unit.KILOMETERS, comb=True) < min_dict[region]
    # Step 4. Find MS enrolment if within 5km
    find_enrolment = np.where(dist, df_middle_enroll,0) 
    new_enroll_ss = find_enrolment # create a copy for manipulation
    
    # Step 5. Expected new SS must be < length of dist. e.g. If length_dist = 15, new SS must be less than 15.
    length_dist = len(np.sum(new_enroll_ss, axis=1)) 
    
    # Step 6. Iteratively find top n enrolment of schools within 5km of each other. n=expected_schools or length_dist
    # To ensure there is no double counting, find  first max, then subtract from array of new_enroll_ss.
    # Repeat until expected enrolment found for top n schools. 

    for i in range(min(n, length_dist)):
        expected_enrol = np.sum(new_enroll_ss, axis=1) 
        max_ee_index = np.argpartition(expected_enrol, -(i+1))[-(i+1):][-(i+1)]
        max_array = new_enroll_ss[max_ee_index]
        new_enroll_ss = (new_enroll_ss - new_enroll_ss[max_ee_index])
        new_enroll_ss = new_enroll_ss.clip(min=0)
        new_enroll_ss[max_ee_index] = max_array
        
    # Step 7. Find new schools above minimum capacity of 200.
    new_enroll_ss = new_enroll_ss[np.sum(new_enroll_ss, axis=1) > 200] # minimum capacity of 200
    max_possible = min(len(new_enroll_ss), n) # total new SS possible
    new_schools_ee = np.sum(new_enroll_ss, axis=1) #  total ee possible from new SS.
    new_schools_index = np.argpartition(new_schools_ee, -(max_possible))[-(max_possible):]

    # Step 8. Find index of all new schools included in the final sample & return MS dataframe with only these MS.
    cluster_schools = np.where(new_enroll_ss[new_schools_index])[1] 
    cluster_schools = df_middle.loc[cluster_schools]
    region = list(pd.unique(data['ADM1_EN']))[0]
    return cluster_schools, region, max_possible

# %%
def prepare_all_datasets(df_):
    """Function that takes in pd dataset, prepares regional datasets for experiments and returns dictionary 
       key=region, values=output of prepare_datasets()"""
    regions = set(df_['ADM1_EN'])
    datasets = {}
    for i in regions:
        datasets[i] = prepare_datasets(df_, i)
    return datasets

# %%
def prepare_all_eligible_n(df_, n, min_dict):
    """Function that takes in pd datasets, finds all eligible MS, prepares them for experiments 
       and returns a dictionary  dictionary.
       
    Parameters:
        df_: (pd dataframe): initial school dataset.
        n: (int) total number of SS to construct
        min_dict: (dict) recommended distance per region
    
    Returns
        datasets2: (dict): key= region, values=output of prepare_datasets()
        regions_mx_possible: (dict): region and max number of new SS possible, always <=n
    """
    regions = set(df_['ADM1_EN'])
    dataframes = [find_eligible_MS(df_[df_['ADM1_EN']==i], n, min_dict) for i in regions]
    regions_mx_possible = dict([ [i[1], i[2]] for i in dataframes]) # region & total new SS possible.
    revised_df = pd.concat([df_[0] for df_ in dataframes], ignore_index=False)
    datasets2 = {}
    for i in regions:
        datasets2[i] = prepare_datasets(revised_df, i)
    return datasets2, regions_mx_possible

# %%
def create_random_sps(region, data_bounds, gdf_region):
    gdf_region_shp = gdf_region.loc[gdf_region['ADM1_EN']==region]['geometry'].reset_index(drop=True)
    bounds = get_bounds(data_bounds) # bounds from MS locations
    sp = generate_random_sp(bounds)# Create a large sample of starting points
    sp = sp[check_region(sp, gdf_region_shp)] # only include points that are within regional boundaries.
    return sp

# %%
def update_dataset_random(df_, gdf_r):
    for i in df_:
        df_[i].append(create_random_sps(i, df_[i][2], gdf_r))

# %%
# Variable filtering of dataset based on max distance for inclusion. 
# This is a decision variable and should be set by the Government. If >5km, only MS 5km from SS are considered. 
# If below 2, distance is not such an issue for maximising enrolment. Other appraoches should be sought.

### TO DO: CREATE A FUNCTION THAT DOES THIS. 

min_dist_dict = { 
'Addis Ababa': 2, # Insufficient only 3 >5km: X, 9 MS > 3km: X, 21 > 2km: ✓
 'Amhara': 5, # 3376 MS > 5km: ✓
 'Benishangul Gumz': 5, # 204 MS > 5km: ✓
 'Dire Dawa': 5, # 29 MS > 5km: ✓
 'Harari': 3, # Insufficient only 10 MS >5km: X 21 > 3km: ✓
 'Oromia': 5, # 5037 MS > 5km: ✓
 'SNNP': 5, # 675 MS > 5km: ✓
 'Somali': 5, # 272 MS > 5km: ✓
 'Tigray': 5 # 686 MS > 5km: ✓
}

# %%
# %%time 
# Create datasets for experiments. n=5, and n=10.
df_all = prepare_all_datasets(df)
df_5, new_ss_regions_5 = prepare_all_eligible_n(df, 5, min_dist_dict)
df_10, new_ss_regions_10 = prepare_all_eligible_n(df, 10, min_dist_dict)
# Out:
# Wall time: 7.13 s

# %%
new_ss_regions_5
# Out:
# {'Tigray': 5,
#  'Dire Dawa': 4,
#  'SNNP': 5,
#  'Somali': 5,
#  'Amhara': 5,
#  'Benishangul Gumz': 5,
#  'Oromia': 5,
#  'Addis Ababa': 5,
#  'Harari': 2}

# %%
new_ss_regions_10
# Out:
# {'Tigray': 10,
#  'Dire Dawa': 4,
#  'SNNP': 10,
#  'Somali': 10,
#  'Amhara': 10,
#  'Benishangul Gumz': 10,
#  'Oromia': 10,
#  'Addis Ababa': 10,
#  'Harari': 2}

# %%
# For two regions, they are not required for n=10, as there are not sufficient schools to meet minimum capacity.
del new_ss_regions_10['Dire Dawa']
del new_ss_regions_10['Harari']

# %%
# %%time
update_dataset_random(df_all, gdf_region)
# Out:
# Wall time: 2min 16s

# %%
# %%time
update_dataset_random(df_5, gdf_region)
# Out:
# Wall time: 2min 37s

# %%
# %%time
update_dataset_random(df_10, gdf_region)
# Out:
# Wall time: 2min 34s

# %% [markdown]
# ## Experiments

# %%
### FITNESS FUNCTION

def expected_enrollment(middle_loc, x, middle_enroll, current_dist, ee_old_constant, min_dict):

    """ The Fitness Function returns the overall total expected enrollment increase given the new school locations x. 

        The function calculates the distance between each new school in x and the current middle schools to determine 
        the expected enrollment per new school. If a new school proposed is closer than the current secondary school, 
        enrollment from that subtracted from the overall enrollment gains. 

        Parameters:
            middle_loc: a vector of longitude and latitude coordinates of all middle schools
            x: a vector longitude and latitude coordinates for the newly proposed secondary schools
            middle_enroll: a vector of current enrollment at each middle school
            current_distnce: a vector of the current distances between each middle school and secondary school.

        Returns:
            eei + ee_old (float): the expected enrollment increase from each school in x  (eei)
                                  + the current secondary enrollment (ee_old)

    """

    ee_old = ee_old_constant.copy() # Overall SS Enrollment
    d = haversine_vector(middle_loc,x, Unit.KILOMETERS, comb=True) # distance of MS to x.
    d_min = np.min(d, axis=0) # select only closest schools to avoid duplication. 

    d_index = np.argmin(d, axis=0) # index of min distance of MS to x
    d2 = np.where((d_min < min_dict) & (d_min < current_dist)) # limit to only schools < 5km and schools < current distance
    # Put into dataframe for manipulation in pandas
    # index 0 = x, index 1 = MS, index 2 = distance, index 3 = shaped enrollment 
    d3 = pd.DataFrame(np.vstack((d_index[d2], d2[0], d_min[d2], shape(d_min[d2], middle_enroll[d2[0]]))).T) 
    d32 = d3.loc[d3.groupby([1])[2].idxmin()] # find only nearby SS if MS is close to more than 1 SS.
    d32 = d32.groupby(0)[3].sum() # The overall shaped enrollment for each school in x.
    eei = np.sum(d32) # overall expected enrollment increase for each school in x.
    # Find MS enrollment of MS if close to old SS. 
    distance_current = np.sum(shape(current_dist[d2], middle_enroll[d2]))
    ee_old -= distance_current # subtract shaped enrollment from overall SS enrollment as new school is close
    return eei + ee_old # return overall expected enrollment + current secondary enrollment

# %%
def f2(x, n, ms_loc, ms_enrol, ms_dist, ee_old, min_dict): # modified fitness function for advanced benchmark. 
    """ The Objective Function returns the maximum expected enrollment.
    """
    x = x.reshape(n,2) # reshape for input into expected enrolment.
    t_case = expected_enrollment(ms_loc, x, ms_enrol, ms_dist, ee_old, min_dict) # run fitness function.
    return t_case*-1 # Multiply by -1 for maximising.

# %%
def establish_benchmarks(data, n, min_dict):
    # *** ESTABLISH BENCHMARK ****
    
    # Basic Benchmark
    # Step 1. Find all MS with distance > 5km. 
    # Step 2. Sort by enrollment and select n schools with the highest enrollment
    # Step 3. Sum the enrollment to assume that the new schools will only serve n schoools.
    # Step 4. Save the results to results.csv
    start_time_basic = time.time()
    df_ms, df_ms_enrol, df_ms_loc, current_ms_dist = data[0], data[1], data[2], data[5]
    region = df_ms['ADM1_EN'].unique()[0]
    ee_old_constant = np.sum(data[3])
    df_ms = df_ms[df_ms['nearest_lwr_sec'] > df_ms['ADM1_EN'].map(min_dict)]
    min_dict_dist = min_dict[region]
    dd = df_ms.sort_values(['grade_7_8'], ascending=False).head(n) # filter by number of SS to construct
    n = len(dd)
    benchmark = sum(dd['grade_7_8']) # sum the enrollment for a basic indication of expected enrollment
    basic_time = time.time() - start_time_basic

    # Advanced Benchmark
    # Since MS with the highest enrollment are likely to be close to other MS, apply the fitness function to these schools
    # Step 1. Assume x is the locations of the top n schools
    # Step 2. Run fitness Function on these schools. 
    start_time_adv = time.time()
    benchmark_loc = dd['point'].reset_index(drop=True).to_numpy()
    benchmark_loc = np.array([np.array(i) for i in benchmark_loc], dtype=float)
    
    # Run Benchmark on objecitve function. 
    benchmark_f = f2(benchmark_loc, n, df_ms_loc, df_ms_enrol, current_ms_dist, ee_old_constant, min_dict_dist) # Run Fitness Function
    # Store results
    create_results_table() # create table for results, if it doesn't already exist.
    results = pd.read_csv('results.csv')

    row1 = (pd.Series({'region': region, 'maxits':np.nan, 'proposed_schools_n': n,
                       'starting_point':np.nan, 'algorithm':'Basic Benchmark', 'std':np.nan,
                       'ee': benchmark + ee_old_constant, 'eei': benchmark,
                       'proposed_locations': benchmark_loc, 'time':np.nan, 'sigma':np.nan}))

    row2 = (pd.Series({'region': region, 'maxits':np.nan, 'proposed_schools_n': n,'starting_point': np.nan, 'std':np.nan,
                       'algorithm':'Advanced Benchmark', 'ee': abs(round(benchmark_f,0)),
                       'eei': round(abs(benchmark_f)-ee_old_constant,0), 
                        'proposed_locations': benchmark_loc, 'time':np.nan, 'sigma':np.nan}))

    results = results.append([row1,row2], ignore_index=True)
    results.to_csv('results.csv', index=False)

    print(region, 'n=', n, ', Basic Algorithm Time:', basic_time)
    print(region, 'n=', n, ', ', 'Advanced Algorithm Time:', time.time() - start_time_adv)

# %%
def random_search(f, max_iterations, sp, n):
    """ Random Search Algorithm. Generates n random samples for max_iterations and applies fitness function and finds
        maximum expected enrolment.
        
        Parameters:
            f(): fitness function
            max_iterations (int): Maximum iterations
            sp(2d numpy array): starting point solution
            n(int): number of new schools to construct.
        
        Returns:
            best_f() (float): maximum expected enrolment
            best_solution: the longitude and latitude coordinates associated with the best f() value found.
    """
    x = [generate_sp_proposed(sp, n) for _ in range(max_iterations)]
    fx = [[f(xi), xi] for xi in x]
    best_f, best_solution = min(fx, key=lambda x:x[0])
    return best_f, best_solution

# %%
def run_random_search(n, n_sp, max_iterations, data, min_dict):
    """ Function which runs the random search algorithm.
    
        Parameters:
            max_iterations (int): Maximum iterations
            n_sp(2d numpy array): total number of starting points e.g. 30
            n(int): number of new schools to construct.
            data(dict): dictionary of prepared datasets.
        Returns: None
            New csv created with results stored: results.csv 
    """
    start_time_rs = time.time()
    df_ms, df_ms_enrol, df_ms_loc, current_ms_dist, sp = data[0], data[1], data[2], data[5], data[6]
    ee_old_constant = np.sum(data[3])
    region = df_ms['ADM1_EN'].unique()[0]
    min_dict_dist = min_dict[region]
    
    def f(x):
        """ The Objective Function for Random Search.
        """
        x = x.reshape(n,2) # reshape for input into expected enrolment.
        test_case = expected_enrollment(df_ms_loc, x, df_ms_enrol, current_ms_dist, ee_old_constant, min_dict_dist) # run fitness function.
        return test_case*-1 # Multiply by -1 for maximising.
    
    fx = []
    for _ in range(n_sp):
        start_time = time.time()
        fx.append([random_search(f, max_iterations, sp, n), time.time() - start_time])
    
    create_results_table() # create table for results, if it doesn't already exist.
    results = pd.read_csv('results.csv')

    for i in range(0, len(fx)):
        row = (pd.Series({'region': region, 'maxits':max_iterations, 'proposed_schools_n': n, 'std':np.nan,
                        'starting_point':i, 'algorithm':'Random Search', 'ee':round(abs(fx[i][0][0]),0),
                                    'eei':round(abs(ee_old_constant - abs(fx[i][0][0])),0), 
                                    'proposed_locations': fx[i][0][1], 'time':fx[i][1], 'sigma':'NA'}))
        results = results.append(row, ignore_index=True)
    results.to_csv('results.csv', index=False)

    print(region, 'n=', n, ', RS complete. Total time:', round(time.time() - start_time_rs,2))

# %%
def cma_region(n, n_starting_points, max_iterations, data, data_sub, min_dict_dist, set_sigma=None):
    
    """ Covariance Matrix Adaptation Evolution Strategy Algorithm (CMA-ES)
    
        Parameters:
            n: Number of SS to construct
            n_starting_points: Number of different starting points
            max_iterations: maximum iterations
            data: Datasets in the format of the output of the prepare_all_datasets() function.
            data_sub: Filtered Dataset in the format of the output of prepare_all_eligible_n() function
            set_sigma: Set sigma value or std for experiment. Default is None. If none, it will try 10 values from std.
        
        Returns: None
            New csv created with results stored: results.csv 
    
    """
    algorithm = 'CMA-ES - 2'
    if len(data) == len(data_sub) : algorithm = 'CMA-ES - 1'
    start_time_cma = time.time()
    df_ms_sub, df_ms_enrol_sub, df_ms_loc_sub, current_ms_dist_sub = data_sub[0], data_sub[1], data_sub[2], data_sub[5]
    sp = data_sub[6] # random starting points
    ee_old_constant = np.sum(data[3]) # secondary school total
    region = df_ms_sub['ADM1_EN'].unique()[0]
    bounds = get_bounds(sp)
    cma_bounds = get_cma_bounds(bounds, n)

    def f(x):
        """ The Objective Function returns the maximum expected enrollment.
        """
        x = x.reshape(n,2) # reshape for input into expected enrolment.
        ee = expected_enrollment(df_ms_loc_sub, x, df_ms_enrol_sub, current_ms_dist_sub, ee_old_constant, min_dict_dist) # fitness function.
        return ee*-1 # Multiply by -1 for maximising.
       
    # Sigma is the initial standard deviation. Problem variables need to be scaled per region.
    # Square root of variance is std.
    sigma0 = np.sqrt(np.std(df_ms_loc_sub[:,0])**2 + np.std(df_ms_loc_sub[:,1])**2)
    
    if set_sigma:
        sigmas = [set_sigma]
    else:
        sigmas = np.linspace(0, sigma0, 11)[1:] # Take 10 values evenly spaced out between 0 to sigma0
    
    start_time_cma = time.time()
    fcma = []
    for i in range(n_starting_points):
        start_time = time.time()
        for j in sigmas:
            es = cma.CMAEvolutionStrategy(generate_sp_proposed(sp, n).flatten(), sigma0=j,
                                      inopts={'bounds': cma_bounds,'seed':1234})
            es.optimize(f, iterations=(max_iterations/ es.popsize))
            fcma.append((es.result[1], es.result[0].reshape(n, 2), (time.time() - start_time), j, i))
    
    create_results_table() # create table for results, if it doesn't already exist.
    results = pd.read_csv('results.csv')
    
    for i in range(0, len(fcma)):
        row = (pd.Series({'region': region, 'maxits':max_iterations,'proposed_schools_n': n,'std':sigma0,
                    'starting_point':fcma[i][4], 'algorithm':algorithm, 'ee':round(abs(fcma[i][0]),0),
                                'eei':round(abs(ee_old_constant - abs(fcma[i][0])),0), 
                                'proposed_locations': fcma[i][1], 'time':fcma[i][2], 'sigma':fcma[i][3]}))
        results = results.append(row, ignore_index=True)
    
    results.to_csv('results.csv', index=False)
    print(region, 'CMA complete. Total time:', round(time.time() - start_time_cma,2))

# %% [markdown]
# # Experiments

# %% [markdown]
# ## How to:
#
# 1. Indicte the number of random starting points.
# 2. Set the maximum iterations
# 3. Loop through the keys of df_all- which is a dictionary of the prepared datasets.
# 4. run establish_benchmark().
# 5. run_random_search()
#
# - df_all = dictionary of prepared datasets
# - new_ss_regions_5 = total number of SS that can be constructed. Max=5
# - min_dist_dict = the dictionary of recommended minimum distance per region
#
# Wall time refers to the overall time it has taken to execute the entire cell.

# %% [markdown]
# #### 1. Establish Basic and Advanced Benchmarks

# %%
# %%time
# Benchmarks for n<=5
for i in new_ss_regions_5.keys():
    establish_benchmarks(df_all[i], new_ss_regions_5[i], min_dist_dict)
# Out:
# Tigray n= 5 , Basic Algorithm Time: 0.002973794937133789
# Tigray n= 5 ,  Advanced Algorithm Time: 0.019999265670776367
# Dire Dawa n= 4 , Basic Algorithm Time: 0.001997232437133789
# Dire Dawa n= 4 ,  Advanced Algorithm Time: 0.023999929428100586
# Amhara n= 5 , Basic Algorithm Time: 0.003999948501586914
# Amhara n= 5 ,  Advanced Algorithm Time: 0.027001619338989258
# Oromia n= 5 , Basic Algorithm Time: 0.005997657775878906
# Oromia n= 5 ,  Advanced Algorithm Time: 0.028999805450439453
# Somali n= 5 , Basic Algorithm Time: 0.0009996891021728516
# Somali n= 5 ,  Advanced Algorithm Time: 0.02300119400024414
# Addis Ababa n= 5 , Basic Algorithm Time: 0.0019989013671875
# Addis Ababa n= 5 ,  Advanced Algorithm Time: 0.022039413452148438
# Harari n= 2 , Basic Algorithm Time: 0.0009620189666748047
# Harari n= 2 ,  Advanced Algorithm Time: 0.022999048233032227
# SNNP n= 5 , Basic Algorithm Time: 0.002001047134399414
# SNNP n= 5 ,  Advanced Algorithm Time: 0.0230405330657959
# Benishangul Gumz n= 5 , Basic Algorithm Time: 0.001958131790161133
# Benishangul Gumz n= 5 ,  Advanced Algorithm Time: 0.025000810623168945
# Wall time: 241 ms

# %%
# %%time
# Benchmarks for n<=10 
for i in new_ss_regions_10.keys():
    establish_benchmarks(df_all[i], new_ss_regions_10[i], min_dist_dict)
# Out:
# Tigray n= 10 , Basic Algorithm Time: 0.0020012855529785156
# Tigray n= 10 ,  Advanced Algorithm Time: 0.028045654296875
# Amhara n= 10 , Basic Algorithm Time: 0.003979921340942383
# Amhara n= 10 ,  Advanced Algorithm Time: 0.0329742431640625
# Oromia n= 10 , Basic Algorithm Time: 0.006998538970947266
# Oromia n= 10 ,  Advanced Algorithm Time: 0.031000852584838867
# Somali n= 10 , Basic Algorithm Time: 0.003000497817993164
# Somali n= 10 ,  Advanced Algorithm Time: 0.02705097198486328
# Addis Ababa n= 10 , Basic Algorithm Time: 0.001947164535522461
# Addis Ababa n= 10 ,  Advanced Algorithm Time: 0.025037050247192383
# SNNP n= 10 , Basic Algorithm Time: 0.002966642379760742
# SNNP n= 10 ,  Advanced Algorithm Time: 0.026035070419311523
# Benishangul Gumz n= 10 , Basic Algorithm Time: 0.0010008811950683594
# Benishangul Gumz n= 10 ,  Advanced Algorithm Time: 0.02399897575378418
# Wall time: 216 ms

# %% [markdown]
# #### 2. Run random search (maxits=20,000, n=5, n=10)

# %%
# %%time 
n_starting_points = 30
maxits= 20000
# for maximum of 10. 
for i in new_ss_regions_5.keys():
    run_random_search(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], min_dist_dict)
# Out:
# Tigray n= 5 , RS complete. Total time: 1765.8
# Dire Dawa n= 4 , RS complete. Total time: 1728.43
# Amhara n= 5 , RS complete. Total time: 2156.19
# Oromia n= 5 , RS complete. Total time: 3088.16
# Somali n= 5 , RS complete. Total time: 1484.19
# Addis Ababa n= 5 , RS complete. Total time: 1488.53
# Harari n= 2 , RS complete. Total time: 1473.96
# SNNP n= 5 , RS complete. Total time: 1747.86
# Benishangul Gumz n= 5 , RS complete. Total time: 1462.5
# Wall time: 4h 33min 15s

# %%
# %%time 
n_starting_points = 3043
maxits= 20000
# for maximum of 10. 
for i in new_ss_regions_10.keys():
    run_random_search(new_ss_regions_10[i], n_starting_points, maxits, df_all[i], min_dist_dict)
# Out:
# Tigray n= 10 , RS complete. Total time: 2335.63
# Amhara n= 10 , RS complete. Total time: 3077.75
# Oromia n= 10 , RS complete. Total time: 4007.96
# Somali n= 10 , RS complete. Total time: 1338.55
# Addis Ababa n= 10 , RS complete. Total time: 2255.85
# SNNP n= 10 , RS complete. Total time: 2232.66
# Benishangul Gumz n= 10 , RS complete. Total time: 1644.77
# Wall time: 4h 41min 33s

# %% [markdown]
# #### 3. Run CMA-ES-2 (maxits=20,000, n=5)
#
# ## How to:
#
# CMA-ES-1 can be run by not using the filtered dataset e.g. See the format below:
#
# * cma_region(new_ss_regions_5[i], n_starting_points, maxits, <b> df_all[i], df_all[i] <b>)
#
# CMA-ES-2 can be run by using the filtered dataset e.g:  see the format below:
#
# * cma_region(new_ss_regions_5[i], n_starting_points, maxits, <b> df_all[i], df_5[i] <b>)

# %%
# %%time
n_starting_points = 30
maxits= 20000
# for maximum of 5. 
for i in df_all.keys():
    cma_region(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], df_5[i], min_dist_dict[i])
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:06:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:06:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:06:42 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:06:42 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222650000000000e+05 1.0e+00 2.23e-01  2e-01  2e-01 0:00.0
#     2     20 -1.222650000000000e+05 1.2e+00 2.21e-01  2e-01  2e-01 0:00.0
#     3     30 -1.214210000000000e+05 1.3e+00 2.14e-01  2e-01  2e-01 0:00.1
#    82    820 -1.227400000000000e+05 4.0e+00 7.06e-02  4e-02  9e-02 0:01.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:06:43 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.215485518062810e+05 1.0e+00 2.61e-01  3e-01  3e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 2.46e-01  2e-01  3e-01 0:00.0
#     3     30 -1.214361126888441e+05 1.2e+00 2.32e-01  2e-01  2e-01 0:00.0
#   100   1000 -1.250764370212307e+05 6.2e+00 7.28e-03  2e-03  8e-03 0:02.3
#   200   2000 -1.250786622209965e+05 1.2e+02 1.05e-03  2e-05  1e-03 0:04.7
#   300   3000 -1.250786886086825e+05 1.7e+03 3.85e-05  2e-07  5e-05 0:07.2
#   400   4000 -1.250786886872629e+05 3.2e+04 2.93e-06  1e-08  5e-06 0:09.9
#   500   5000 -1.250786886877689e+05 7.8e+05 3.81e-07  1e-09  8e-07 0:12.4
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=507)
#   warnings.warn(msg + ' (' +
#   600   6000 -1.250786886876296e+05 6.0e+00 6.19e-08  3e-08  8e-08 0:15.0
#   700   7000 -1.250786886876819e+05 2.4e+01 1.66e-07  1e-07  3e-07 0:17.8
#   725   7250 -1.250786886876753e+05 2.9e+01 1.22e-07  7e-08  2e-07 0:18.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:07:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.234725659643909e+05 1.0e+00 3.16e-01  3e-01  3e-01 0:00.0
#     2     20 -1.232124609635058e+05 1.2e+00 3.20e-01  3e-01  3e-01 0:00.0
#     3     30 -1.238388618282351e+05 1.2e+00 3.22e-01  3e-01  3e-01 0:00.1
#   100   1000 -1.250537317393730e+05 1.5e+01 4.66e-02  6e-03  5e-02 0:02.5
#   132   1320 -1.251570000000000e+05 3.1e+01 6.95e-02  5e-03  9e-02 0:03.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:07:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:07:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227079776421747e+05 1.0e+00 4.47e-01  4e-01  5e-01 0:00.0
#     2     20 -1.225668610043541e+05 1.2e+00 4.43e-01  4e-01  5e-01 0:00.0
#     3     30 -1.227066978699590e+05 1.3e+00 4.48e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.251570000000000e+05 1.1e+01 4.02e-02  7e-03  5e-02 0:02.7
#   110   1100 -1.251570000000000e+05 1.3e+01 3.04e-02  5e-03  4e-02 0:03.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:07:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225378279683042e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.225540933980103e+05 1.2e+00 5.07e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223464809552527e+05 1.2e+00 5.31e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.274460984483836e+05 1.0e+01 3.18e-02  5e-03  4e-02 0:02.7
#   198   1980 -1.274955646817578e+05 5.8e+01 1.83e-03  7e-05  3e-03 0:06.7
#   200   2000 -1.274954588764295e+05 6.0e+01 1.71e-03  6e-05  3e-03 0:06.8
#   300   3000 -1.274956885490531e+05 9.1e+02 9.69e-05  7e-07  2e-04 0:11.0
#   400   4000 -1.274956886841129e+05 1.5e+04 1.44e-05  6e-08  3e-05 0:15.1
#   500   5000 -1.274956886877643e+05 3.6e+05 1.51e-06  7e-09  4e-06 0:19.5
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.0e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=540)
#   warnings.warn(msg + ' (' +
#   600   6000 -1.274956886877554e+05 3.8e+00 4.86e-07  4e-07  6e-07 0:24.0
#   700   7000 -1.274956886877515e+05 1.2e+01 1.25e-07  8e-08  2e-07 0:28.4
#   800   8000 -1.274956886877656e+05 2.2e+01 5.14e-08  3e-08  7e-08 0:32.8
#   900   9000 -1.274956886877628e+05 4.2e+01 8.19e-08  4e-08  1e-07 0:37.5
#  1000  10000 -1.274956886877582e+05 9.1e+01 1.29e-07  6e-08  2e-07 0:42.1
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1070  10700 -1.274956886877613e+05 8.8e+01 3.40e-07  1e-07  3e-07 0:44.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:07:57 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.235746395763153e+05 1.0e+00 5.24e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214831872275073e+05 1.2e+00 5.00e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214586320686102e+05 1.3e+00 4.94e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.249000000000000e+05 6.4e+00 1.17e-01  5e-02  1e-01 0:02.5
#   172   1720 -1.304976547105363e+05 7.3e+00 1.38e-02  3e-03  1e-02 0:06.5
#   200   2000 -1.305761340564871e+05 1.3e+01 8.00e-03  9e-04  8e-03 0:08.1
#   297   2970 -1.305878327960773e+05 1.4e+02 3.92e-04  2e-05  4e-04 0:14.2
#   300   3000 -1.305878536827163e+05 1.5e+02 4.13e-04  2e-05  4e-04 0:14.4
#   400   4000 -1.305878557549294e+05 2.2e+03 7.40e-05  2e-06  8e-05 0:21.1
#   500   5000 -1.305878558183336e+05 2.7e+04 5.63e-06  1e-07  5e-06 0:27.3
#   600   6000 -1.305878558194273e+05 3.3e+05 3.31e-07  6e-09  4e-07 0:33.3
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=628)
#   warnings.warn(msg + ' (' +
#   700   7000 -1.305878558194238e+05 3.3e+00 2.30e-08  2e-08  3e-08 0:39.4
#   800   8000 -1.305878558193926e+05 8.0e+00 9.39e-09  3e-09  1e-08 0:45.1
#   900   9000 -1.305878558193506e+05 2.4e+01 4.64e-08  4e-09  6e-08 0:51.5
#  1000  10000 -1.305878558194056e+05 5.2e+01 2.33e-08  1e-09  3e-08 0:58.0
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.305878558194067e+05 8.1e+01 5.33e-08  2e-09  5e-08 1:03.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222650000000000e+05 1.0e+00 2.23e-01  2e-01  2e-01 0:00.0
#     2     20 -1.222650000000000e+05 1.2e+00 2.21e-01  2e-01  2e-01 0:00.0
#     3     30 -1.214210000000000e+05 1.3e+00 2.14e-01  2e-01  2e-01 0:00.1
#    82    820 -1.227400000000000e+05 4.0e+00 7.06e-02  4e-02  9e-02 0:02.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.215485518062810e+05 1.0e+00 2.61e-01  3e-01  3e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 2.46e-01  2e-01  3e-01 0:00.0
#     3     30 -1.214361126888441e+05 1.2e+00 2.32e-01  2e-01  2e-01 0:00.1
#   100   1000 -1.250764370212307e+05 6.2e+00 7.28e-03  2e-03  8e-03 0:03.1
#   200   2000 -1.250786622209965e+05 1.2e+02 1.05e-03  2e-05  1e-03 0:06.3
#   300   3000 -1.250786886086825e+05 1.7e+03 3.85e-05  2e-07  5e-05 0:09.5
#   400   4000 -1.250786886872629e+05 3.2e+04 2.93e-06  1e-08  5e-06 0:14.3
#   500   5000 -1.250786886877689e+05 7.8e+05 3.81e-07  1e-09  8e-07 0:18.3
#   600   6000 -1.250786886876296e+05 6.0e+00 6.19e-08  3e-08  8e-08 0:21.9
#   700   7000 -1.250786886876819e+05 2.4e+01 1.66e-07  1e-07  3e-07 0:25.0
#   725   7250 -1.250786886876753e+05 2.9e+01 1.22e-07  7e-08  2e-07 0:25.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:32 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.234725659643909e+05 1.0e+00 3.16e-01  3e-01  3e-01 0:00.0
#     2     20 -1.232124609635058e+05 1.2e+00 3.20e-01  3e-01  3e-01 0:00.0
#     3     30 -1.238388618282351e+05 1.2e+00 3.22e-01  3e-01  3e-01 0:00.1
#    92    920 -1.249918074880478e+05 1.3e+01 6.82e-02  9e-03  8e-02 0:03.1
#   100   1000 -1.250537317393730e+05 1.5e+01 4.66e-02  6e-03  5e-02 0:03.4
#   132   1320 -1.251570000000000e+05 3.1e+01 6.95e-02  5e-03  9e-02 0:04.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227079776421747e+05 1.0e+00 4.47e-01  4e-01  5e-01 0:00.0
#     2     20 -1.225668610043541e+05 1.2e+00 4.43e-01  4e-01  5e-01 0:00.1
#     3     30 -1.227066978699590e+05 1.3e+00 4.48e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.251570000000000e+05 1.1e+01 4.02e-02  7e-03  5e-02 0:03.0
#   110   1100 -1.251570000000000e+05 1.3e+01 3.04e-02  5e-03  4e-02 0:03.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:09:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225378279683042e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.225540933980103e+05 1.2e+00 5.07e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223464809552527e+05 1.2e+00 5.31e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.274460984483836e+05 1.0e+01 3.18e-02  5e-03  4e-02 0:03.0
#   193   1930 -1.274954474778724e+05 5.3e+01 2.20e-03  1e-04  3e-03 0:07.1
#   200   2000 -1.274954588764295e+05 6.0e+01 1.71e-03  6e-05  3e-03 0:07.4
#   300   3000 -1.274956885490531e+05 9.1e+02 9.69e-05  7e-07  2e-04 0:11.7
#   400   4000 -1.274956886841129e+05 1.5e+04 1.44e-05  6e-08  3e-05 0:15.9
#   500   5000 -1.274956886877643e+05 3.6e+05 1.51e-06  7e-09  4e-06 0:20.4
#   600   6000 -1.274956886877554e+05 3.8e+00 4.86e-07  4e-07  6e-07 0:24.4
#   700   7000 -1.274956886877515e+05 1.2e+01 1.25e-07  8e-08  2e-07 0:28.6
#   800   8000 -1.274956886877656e+05 2.2e+01 5.14e-08  3e-08  7e-08 0:32.5
#   900   9000 -1.274956886877628e+05 4.2e+01 8.19e-08  4e-08  1e-07 0:36.6
#  1000  10000 -1.274956886877582e+05 9.1e+01 1.29e-07  6e-08  2e-07 0:40.5
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1070  10700 -1.274956886877613e+05 8.8e+01 3.40e-07  1e-07  3e-07 0:43.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:10:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.235746395763153e+05 1.0e+00 5.24e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214831872275073e+05 1.2e+00 5.00e-01  5e-01  5e-01 0:00.0
#     3     30 -1.214586320686102e+05 1.3e+00 4.94e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.249000000000000e+05 6.4e+00 1.17e-01  5e-02  1e-01 0:02.7
#   176   1760 -1.305233562549237e+05 6.7e+00 1.19e-02  2e-03  1e-02 0:06.7
#   200   2000 -1.305761340564871e+05 1.3e+01 8.00e-03  9e-04  8e-03 0:08.3
#   289   2890 -1.305878371240907e+05 1.3e+02 3.79e-04  2e-05  4e-04 0:14.3
#   300   3000 -1.305878536827163e+05 1.5e+02 4.13e-04  2e-05  4e-04 0:15.0
#   400   4000 -1.305878557549294e+05 2.2e+03 7.40e-05  2e-06  8e-05 0:21.0
#   500   5000 -1.305878558183336e+05 2.7e+04 5.63e-06  1e-07  5e-06 0:28.9
#   600   6000 -1.305878558194273e+05 3.3e+05 3.31e-07  6e-09  4e-07 0:35.1
#   700   7000 -1.305878558194238e+05 3.3e+00 2.30e-08  2e-08  3e-08 0:41.4
#   800   8000 -1.305878558193926e+05 8.0e+00 9.39e-09  3e-09  1e-08 0:47.2
#   900   9000 -1.305878558193506e+05 2.4e+01 4.64e-08  4e-09  6e-08 0:53.3
#  1000  10000 -1.305878558194056e+05 5.2e+01 2.33e-08  1e-09  3e-08 0:59.3
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.305878558194067e+05 8.1e+01 5.33e-08  2e-09  5e-08 1:05.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:11:34 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:11:34 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:11:34 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:11:34 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222650000000000e+05 1.0e+00 2.23e-01  2e-01  2e-01 0:00.0
#     2     20 -1.222650000000000e+05 1.2e+00 2.21e-01  2e-01  2e-01 0:00.0
#     3     30 -1.214210000000000e+05 1.3e+00 2.14e-01  2e-01  2e-01 0:00.1
#    82    820 -1.227400000000000e+05 4.0e+00 7.06e-02  4e-02  9e-02 0:02.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:11:36 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.215485518062810e+05 1.0e+00 2.61e-01  3e-01  3e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 2.46e-01  2e-01  3e-01 0:00.0
#     3     30 -1.214361126888441e+05 1.2e+00 2.32e-01  2e-01  2e-01 0:00.1
#   100   1000 -1.250764370212307e+05 6.2e+00 7.28e-03  2e-03  8e-03 0:02.7
#   200   2000 -1.250786622209965e+05 1.2e+02 1.05e-03  2e-05  1e-03 0:05.9
#   300   3000 -1.250786886086825e+05 1.7e+03 3.85e-05  2e-07  5e-05 0:09.0
#   400   4000 -1.250786886872629e+05 3.2e+04 2.93e-06  1e-08  5e-06 0:12.2
#   500   5000 -1.250786886877689e+05 7.8e+05 3.81e-07  1e-09  8e-07 0:15.3
#   600   6000 -1.250786886876296e+05 6.0e+00 6.19e-08  3e-08  8e-08 0:18.6
#   700   7000 -1.250786886876819e+05 2.4e+01 1.66e-07  1e-07  3e-07 0:21.7
#   725   7250 -1.250786886876753e+05 2.9e+01 1.22e-07  7e-08  2e-07 0:22.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:12:00 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.234725659643909e+05 1.0e+00 3.16e-01  3e-01  3e-01 0:00.0
#     2     20 -1.232124609635058e+05 1.2e+00 3.20e-01  3e-01  3e-01 0:00.1
#     3     30 -1.238388618282351e+05 1.2e+00 3.22e-01  3e-01  3e-01 0:00.1
#   100   1000 -1.250537317393730e+05 1.5e+01 4.66e-02  6e-03  5e-02 0:03.0
#   132   1320 -1.251570000000000e+05 3.1e+01 6.95e-02  5e-03  9e-02 0:04.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:12:04 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:12:04 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227079776421747e+05 1.0e+00 4.47e-01  4e-01  5e-01 0:00.0
#     2     20 -1.225668610043541e+05 1.2e+00 4.43e-01  4e-01  5e-01 0:00.0
#     3     30 -1.227066978699590e+05 1.3e+00 4.48e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.251570000000000e+05 1.1e+01 4.02e-02  7e-03  5e-02 0:02.9
#   110   1100 -1.251570000000000e+05 1.3e+01 3.04e-02  5e-03  4e-02 0:03.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:12:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225378279683042e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.225540933980103e+05 1.2e+00 5.07e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223464809552527e+05 1.2e+00 5.31e-01  5e-01  6e-01 0:00.1
#    96    960 -1.274736312069426e+05 9.2e+00 3.77e-02  6e-03  5e-02 0:03.1
#   100   1000 -1.274460984483836e+05 1.0e+01 3.18e-02  5e-03  4e-02 0:03.3
#   200   2000 -1.274954588764295e+05 6.0e+01 1.71e-03  6e-05  3e-03 0:07.6
#   300   3000 -1.274956885490531e+05 9.1e+02 9.69e-05  7e-07  2e-04 0:11.8
#   400   4000 -1.274956886841129e+05 1.5e+04 1.44e-05  6e-08  3e-05 0:16.2
#   500   5000 -1.274956886877643e+05 3.6e+05 1.51e-06  7e-09  4e-06 0:20.4
#   600   6000 -1.274956886877554e+05 3.8e+00 4.86e-07  4e-07  6e-07 0:24.5
#   700   7000 -1.274956886877515e+05 1.2e+01 1.25e-07  8e-08  2e-07 0:28.7
#   800   8000 -1.274956886877656e+05 2.2e+01 5.14e-08  3e-08  7e-08 0:32.8
#   900   9000 -1.274956886877628e+05 4.2e+01 8.19e-08  4e-08  1e-07 0:37.1
#  1000  10000 -1.274956886877582e+05 9.1e+01 1.29e-07  6e-08  2e-07 0:41.2
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1070  10700 -1.274956886877613e+05 8.8e+01 3.40e-07  1e-07  3e-07 0:44.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:12:53 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.235746395763153e+05 1.0e+00 5.24e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214831872275073e+05 1.2e+00 5.00e-01  5e-01  5e-01 0:00.0
#     3     30 -1.214586320686102e+05 1.3e+00 4.94e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.249000000000000e+05 6.4e+00 1.17e-01  5e-02  1e-01 0:02.6
#   178   1780 -1.304934237420612e+05 7.0e+00 1.39e-02  3e-03  1e-02 0:06.6
#   200   2000 -1.305761340564871e+05 1.3e+01 8.00e-03  9e-04  8e-03 0:07.8
#   300   3000 -1.305878536827163e+05 1.5e+02 4.13e-04  2e-05  4e-04 0:13.7
#   400   4000 -1.305878557549294e+05 2.2e+03 7.40e-05  2e-06  8e-05 0:19.5
#   500   5000 -1.305878558183336e+05 2.7e+04 5.63e-06  1e-07  5e-06 0:25.4
#   600   6000 -1.305878558194273e+05 3.3e+05 3.31e-07  6e-09  4e-07 0:31.1
#   700   7000 -1.305878558194238e+05 3.3e+00 2.30e-08  2e-08  3e-08 0:37.1
#   800   8000 -1.305878558193926e+05 8.0e+00 9.39e-09  3e-09  1e-08 0:42.9
#   900   9000 -1.305878558193506e+05 2.4e+01 4.64e-08  4e-09  6e-08 0:49.0
#  1000  10000 -1.305878558194056e+05 5.2e+01 2.33e-08  1e-09  3e-08 0:54.9
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.305878558194067e+05 8.1e+01 5.33e-08  2e-09  5e-08 1:01.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:13:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:13:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:13:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:13:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222650000000000e+05 1.0e+00 2.23e-01  2e-01  2e-01 0:00.0
#     2     20 -1.222650000000000e+05 1.2e+00 2.21e-01  2e-01  2e-01 0:00.0
#     3     30 -1.214210000000000e+05 1.3e+00 2.14e-01  2e-01  2e-01 0:00.1
#    82    820 -1.227400000000000e+05 4.0e+00 7.06e-02  4e-02  9e-02 0:01.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:13:59 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.215485518062810e+05 1.0e+00 2.61e-01  3e-01  3e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 2.46e-01  2e-01  3e-01 0:00.0
#     3     30 -1.214361126888441e+05 1.2e+00 2.32e-01  2e-01  2e-01 0:00.1
#   100   1000 -1.250764370212307e+05 6.2e+00 7.28e-03  2e-03  8e-03 0:02.8
#   200   2000 -1.250786622209965e+05 1.2e+02 1.05e-03  2e-05  1e-03 0:05.9
#   300   3000 -1.250786886086825e+05 1.7e+03 3.85e-05  2e-07  5e-05 0:09.1
#   400   4000 -1.250786886872629e+05 3.2e+04 2.93e-06  1e-08  5e-06 0:12.2
#   500   5000 -1.250786886877689e+05 7.8e+05 3.81e-07  1e-09  8e-07 0:15.2
#   600   6000 -1.250786886876296e+05 6.0e+00 6.19e-08  3e-08  8e-08 0:18.4
#   700   7000 -1.250786886876819e+05 2.4e+01 1.66e-07  1e-07  3e-07 0:21.6
#   725   7250 -1.250786886876753e+05 2.9e+01 1.22e-07  7e-08  2e-07 0:22.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:14:22 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.234725659643909e+05 1.0e+00 3.16e-01  3e-01  3e-01 0:00.0
#     2     20 -1.232124609635058e+05 1.2e+00 3.20e-01  3e-01  3e-01 0:00.0
#     3     30 -1.238388618282351e+05 1.2e+00 3.22e-01  3e-01  3e-01 0:00.1
#   100   1000 -1.250537317393730e+05 1.5e+01 4.66e-02  6e-03  5e-02 0:02.9
#   132   1320 -1.251570000000000e+05 3.1e+01 6.95e-02  5e-03  9e-02 0:04.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:14:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:14:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227079776421747e+05 1.0e+00 4.47e-01  4e-01  5e-01 0:00.0
#     2     20 -1.225668610043541e+05 1.2e+00 4.43e-01  4e-01  5e-01 0:00.0
#     3     30 -1.227066978699590e+05 1.3e+00 4.48e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.251570000000000e+05 1.1e+01 4.02e-02  7e-03  5e-02 0:02.9
#   110   1100 -1.251570000000000e+05 1.3e+01 3.04e-02  5e-03  4e-02 0:03.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:14:30 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225378279683042e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.225540933980103e+05 1.2e+00 5.07e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223464809552527e+05 1.2e+00 5.31e-01  5e-01  6e-01 0:00.1
#    96    960 -1.274736312069426e+05 9.2e+00 3.77e-02  6e-03  5e-02 0:03.1
#   100   1000 -1.274460984483836e+05 1.0e+01 3.18e-02  5e-03  4e-02 0:03.2
#   200   2000 -1.274954588764295e+05 6.0e+01 1.71e-03  6e-05  3e-03 0:07.4
#   300   3000 -1.274956885490531e+05 9.1e+02 9.69e-05  7e-07  2e-04 0:11.6
#   381   3810 -1.274956886855778e+05 7.4e+03 2.09e-05  9e-08  3e-05 0:18.7
#   400   4000 -1.274956886841129e+05 1.5e+04 1.44e-05  6e-08  3e-05 0:20.6
#   489   4890 -1.274956886877348e+05 2.8e+05 1.41e-06  6e-09  3e-06 0:29.7
#   500   5000 -1.274956886877643e+05 3.6e+05 1.51e-06  7e-09  4e-06 0:30.8
#   600   6000 -1.274956886877554e+05 3.8e+00 4.86e-07  4e-07  6e-07 0:39.7
#   700   7000 -1.274956886877515e+05 1.2e+01 1.25e-07  8e-08  2e-07 0:46.4
#   800   8000 -1.274956886877656e+05 2.2e+01 5.14e-08  3e-08  7e-08 0:54.0
#   900   9000 -1.274956886877628e+05 4.2e+01 8.19e-08  4e-08  1e-07 1:03.4
#  1000  10000 -1.274956886877582e+05 9.1e+01 1.29e-07  6e-08  2e-07 1:13.1
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1070  10700 -1.274956886877613e+05 8.8e+01 3.40e-07  1e-07  3e-07 1:19.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:15:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.235746395763153e+05 1.0e+00 5.24e-01  5e-01  5e-01 0:00.1
#     2     20 -1.214831872275073e+05 1.2e+00 5.00e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214586320686102e+05 1.3e+00 4.94e-01  5e-01  5e-01 0:00.2
#    56    560 -1.250055969849908e+05 3.4e+00 3.40e-01  2e-01  4e-01 0:03.3
#   100   1000 -1.249000000000000e+05 6.4e+00 1.17e-01  5e-02  1e-01 0:06.3
#   151   1510 -1.303224622599803e+05 7.6e+00 2.84e-02  9e-03  3e-02 0:11.5
#   194   1940 -1.305539821694818e+05 1.1e+01 9.01e-03  1e-03  1e-02 0:17.6
#   200   2000 -1.305761340564871e+05 1.3e+01 8.00e-03  9e-04  8e-03 0:18.6
#   259   2590 -1.305877486777254e+05 5.7e+01 1.44e-03  9e-05  1e-03 0:26.6
#   300   3000 -1.305878536827163e+05 1.5e+02 4.13e-04  2e-05  4e-04 0:31.4
#   398   3980 -1.305878556234036e+05 2.0e+03 6.88e-05  2e-06  7e-05 0:41.4
#   400   4000 -1.305878557549294e+05 2.2e+03 7.40e-05  2e-06  8e-05 0:41.6
#   480   4800 -1.305878558172268e+05 1.5e+04 8.11e-06  2e-07  8e-06 0:53.8
#   500   5000 -1.305878558183336e+05 2.7e+04 5.63e-06  1e-07  5e-06 0:58.6
#   600   6000 -1.305878558194273e+05 3.3e+05 3.31e-07  6e-09  4e-07 1:11.8
#   700   7000 -1.305878558194238e+05 3.3e+00 2.30e-08  2e-08  3e-08 1:25.0
#   800   8000 -1.305878558193926e+05 8.0e+00 9.39e-09  3e-09  1e-08 1:40.3
#   900   9000 -1.305878558193506e+05 2.4e+01 4.64e-08  4e-09  6e-08 1:53.9
#  1000  10000 -1.305878558194056e+05 5.2e+01 2.33e-08  1e-09  3e-08 2:08.3
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.305878558194067e+05 8.1e+01 5.33e-08  2e-09  5e-08 2:23.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:18:22 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:18:22 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:18:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:18:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222650000000000e+05 1.0e+00 2.23e-01  2e-01  2e-01 0:00.0
#     2     20 -1.222650000000000e+05 1.2e+00 2.21e-01  2e-01  2e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 2.14e-01  2e-01  2e-01 0:00.1
#    47    470 -1.227400000000000e+05 2.9e+00 1.84e-01  1e-01  2e-01 0:03.1
#    82    820 -1.227400000000000e+05 4.0e+00 7.06e-02  4e-02  9e-02 0:05.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:18:28 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.215485518062810e+05 1.0e+00 2.61e-01  3e-01  3e-01 0:00.1
#     2     20 -1.214210000000000e+05 1.2e+00 2.46e-01  2e-01  3e-01 0:00.1
#     3     30 -1.214361126888441e+05 1.2e+00 2.32e-01  2e-01  2e-01 0:00.2
#    50    500 -1.248567901442939e+05 2.6e+00 7.52e-02  4e-02  8e-02 0:03.2
#   100   1000 -1.250764370212307e+05 6.2e+00 7.28e-03  2e-03  8e-03 0:07.1
#   168   1680 -1.250784614699376e+05 5.5e+01 3.92e-03  2e-04  6e-03 0:12.2
#   200   2000 -1.250786622209965e+05 1.2e+02 1.05e-03  2e-05  1e-03 0:14.6
#   296   2960 -1.250786884715903e+05 1.6e+03 4.02e-05  2e-07  6e-05 0:21.6
#   300   3000 -1.250786886086825e+05 1.7e+03 3.85e-05  2e-07  5e-05 0:21.9
#   400   4000 -1.250786886872629e+05 3.2e+04 2.93e-06  1e-08  5e-06 0:29.6
#   500   5000 -1.250786886877689e+05 7.8e+05 3.81e-07  1e-09  8e-07 0:37.2
#   600   6000 -1.250786886876296e+05 6.0e+00 6.19e-08  3e-08  8e-08 0:44.8
#   700   7000 -1.250786886876819e+05 2.4e+01 1.66e-07  1e-07  3e-07 0:51.9
#   725   7250 -1.250786886876753e+05 2.9e+01 1.22e-07  7e-08  2e-07 0:54.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:19:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.234725659643909e+05 1.0e+00 3.16e-01  3e-01  3e-01 0:00.1
#     2     20 -1.232124609635058e+05 1.2e+00 3.20e-01  3e-01  3e-01 0:00.1
#     3     30 -1.238388618282351e+05 1.2e+00 3.22e-01  3e-01  3e-01 0:00.1
#    52    520 -1.247583084298007e+05 3.4e+00 1.36e-01  6e-02  2e-01 0:03.2
#   100   1000 -1.250537317393730e+05 1.5e+01 4.66e-02  6e-03  5e-02 0:07.2
#   132   1320 -1.251570000000000e+05 3.1e+01 6.95e-02  5e-03  9e-02 0:10.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:19:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:19:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227079776421747e+05 1.0e+00 4.47e-01  4e-01  5e-01 0:00.1
#     2     20 -1.225668610043541e+05 1.2e+00 4.43e-01  4e-01  5e-01 0:00.1
#     3     30 -1.227066978699590e+05 1.3e+00 4.48e-01  4e-01  5e-01 0:00.2
#    52    520 -1.238774065158300e+05 3.3e+00 2.35e-01  1e-01  3e-01 0:03.2
#    96    960 -1.251570000000000e+05 9.9e+00 5.50e-02  1e-02  7e-02 0:07.3
#   100   1000 -1.251570000000000e+05 1.1e+01 4.02e-02  7e-03  5e-02 0:07.6
#   110   1100 -1.251570000000000e+05 1.3e+01 3.04e-02  5e-03  4e-02 0:08.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:19:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225378279683042e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.1
#     2     20 -1.225540933980103e+05 1.2e+00 5.07e-01  5e-01  5e-01 0:00.1
#     3     30 -1.223464809552527e+05 1.2e+00 5.31e-01  5e-01  6e-01 0:00.2
#    55    550 -1.266038203631058e+05 3.5e+00 1.59e-01  8e-02  2e-01 0:03.3
#    92    920 -1.273745353518027e+05 8.3e+00 4.90e-02  9e-03  6e-02 0:07.3
#   100   1000 -1.274460984483836e+05 1.0e+01 3.18e-02  5e-03  4e-02 0:08.0
#   157   1570 -1.274953200670608e+05 1.8e+01 3.28e-03  3e-04  4e-03 0:14.1
#   200   2000 -1.274954588764295e+05 6.0e+01 1.71e-03  6e-05  3e-03 0:18.5
#   275   2750 -1.274956871109196e+05 4.4e+02 1.97e-04  2e-06  3e-04 0:26.5
#   300   3000 -1.274956885490531e+05 9.1e+02 9.69e-05  7e-07  2e-04 0:29.4
#   396   3960 -1.274956886860180e+05 1.2e+04 1.52e-05  6e-08  3e-05 0:39.5
#   400   4000 -1.274956886841129e+05 1.5e+04 1.44e-05  6e-08  3e-05 0:39.8
#   500   5000 -1.274956886877643e+05 3.6e+05 1.51e-06  7e-09  4e-06 0:51.2
#   600   6000 -1.274956886877554e+05 3.8e+00 4.86e-07  4e-07  6e-07 1:02.6
#   700   7000 -1.274956886877515e+05 1.2e+01 1.25e-07  8e-08  2e-07 1:15.3
#   800   8000 -1.274956886877656e+05 2.2e+01 5.14e-08  3e-08  7e-08 1:28.0
#   900   9000 -1.274956886877628e+05 4.2e+01 8.19e-08  4e-08  1e-07 1:39.6
#  1000  10000 -1.274956886877582e+05 9.1e+01 1.29e-07  6e-08  2e-07 1:50.4
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1070  10700 -1.274956886877613e+05 8.8e+01 3.40e-07  1e-07  3e-07 1:57.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:21:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.235746395763153e+05 1.0e+00 5.24e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214831872275073e+05 1.2e+00 5.00e-01  5e-01  5e-01 0:00.0
#     3     30 -1.214586320686102e+05 1.3e+00 4.94e-01  5e-01  5e-01 0:00.1
#    53    530 -1.246974194489764e+05 3.2e+00 3.84e-01  3e-01  5e-01 0:03.1
#   100   1000 -1.249000000000000e+05 6.4e+00 1.17e-01  5e-02  1e-01 0:06.0
#   141   1410 -1.303585327076715e+05 6.3e+00 2.58e-02  8e-03  2e-02 0:11.1
#   182   1820 -1.305453317751992e+05 7.6e+00 1.54e-02  3e-03  2e-02 0:17.2
#   200   2000 -1.305761340564871e+05 1.3e+01 8.00e-03  9e-04  8e-03 0:20.1
#   250   2500 -1.305875648435903e+05 4.5e+01 1.63e-03  1e-04  1e-03 0:28.2
#   297   2970 -1.305878327960773e+05 1.4e+02 3.92e-04  2e-05  4e-04 0:37.2
#   300   3000 -1.305878536827163e+05 1.5e+02 4.13e-04  2e-05  4e-04 0:37.7
#   354   3540 -1.305878547642765e+05 6.6e+02 1.10e-04  4e-06  1e-04 0:48.8
#   400   4000 -1.305878557549294e+05 2.2e+03 7.40e-05  2e-06  8e-05 0:58.6
#   468   4680 -1.305878558159537e+05 1.2e+04 1.38e-05  3e-07  1e-05 1:11.9
#   500   5000 -1.305878558183336e+05 2.7e+04 5.63e-06  1e-07  5e-06 1:19.5
#   570   5700 -1.305878558194250e+05 1.5e+05 7.72e-07  1e-08  8e-07 1:34.7
#   600   6000 -1.305878558194273e+05 3.3e+05 3.31e-07  6e-09  4e-07 1:40.5
#   699   6990 -1.305878558193883e+05 3.2e+00 2.26e-08  2e-08  3e-08 1:57.6
#   700   7000 -1.305878558194238e+05 3.3e+00 2.30e-08  2e-08  3e-08 1:57.9
#   800   8000 -1.305878558193926e+05 8.0e+00 9.39e-09  3e-09  1e-08 2:15.3
#   900   9000 -1.305878558193506e+05 2.4e+01 4.64e-08  4e-09  6e-08 2:33.8
#  1000  10000 -1.305878558194056e+05 5.2e+01 2.33e-08  1e-09  3e-08 2:53.1
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.305878558194067e+05 8.1e+01 5.33e-08  2e-09  5e-08 3:13.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:25:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:25:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:25:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:25:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222650000000000e+05 1.0e+00 2.23e-01  2e-01  2e-01 0:00.1
#     2     20 -1.222650000000000e+05 1.2e+00 2.21e-01  2e-01  2e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 2.14e-01  2e-01  2e-01 0:00.2
#    44    440 -1.227400000000000e+05 2.9e+00 2.18e-01  1e-01  2e-01 0:03.2
#    82    820 -1.227400000000000e+05 4.0e+00 7.06e-02  4e-02  9e-02 0:06.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:25:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.215485518062810e+05 1.0e+00 2.61e-01  3e-01  3e-01 0:00.1
#     2     20 -1.214210000000000e+05 1.2e+00 2.46e-01  2e-01  3e-01 0:00.1
#     3     30 -1.214361126888441e+05 1.2e+00 2.32e-01  2e-01  2e-01 0:00.2
#    40    400 -1.233320280051721e+05 2.8e+00 1.76e-01  1e-01  2e-01 0:03.2
#    74    740 -1.250675167775296e+05 4.2e+00 2.52e-02  9e-03  3e-02 0:07.2
#   100   1000 -1.250764370212307e+05 6.2e+00 7.28e-03  2e-03  8e-03 0:10.2
#   146   1460 -1.250779109776348e+05 2.8e+01 4.28e-03  3e-04  6e-03 0:16.3
#   200   2000 -1.250786622209965e+05 1.2e+02 1.05e-03  2e-05  1e-03 0:22.1
#   272   2720 -1.250786879834978e+05 7.6e+02 7.46e-05  5e-07  1e-04 0:30.1
#   300   3000 -1.250786886086825e+05 1.7e+03 3.85e-05  2e-07  5e-05 0:33.2
#   398   3980 -1.250786886870036e+05 3.1e+04 3.05e-06  1e-08  5e-06 0:43.2
#   400   4000 -1.250786886872629e+05 3.2e+04 2.93e-06  1e-08  5e-06 0:43.5
#   500   5000 -1.250786886877689e+05 7.8e+05 3.81e-07  1e-09  8e-07 0:54.8
#   600   6000 -1.250786886876296e+05 6.0e+00 6.19e-08  3e-08  8e-08 1:06.2
#   700   7000 -1.250786886876819e+05 2.4e+01 1.66e-07  1e-07  3e-07 1:16.6
#   725   7250 -1.250786886876753e+05 2.9e+01 1.22e-07  7e-08  2e-07 1:19.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:26:38 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.234725659643909e+05 1.0e+00 3.16e-01  3e-01  3e-01 0:00.1
#     2     20 -1.232124609635058e+05 1.2e+00 3.20e-01  3e-01  3e-01 0:00.2
#     3     30 -1.238388618282351e+05 1.2e+00 3.22e-01  3e-01  3e-01 0:00.2
#    38    380 -1.242097967683342e+05 2.2e+00 1.80e-01  1e-01  2e-01 0:03.3
#    74    740 -1.250658230796205e+05 6.7e+00 8.06e-02  2e-02  1e-01 0:07.4
#   100   1000 -1.250537317393730e+05 1.5e+01 4.66e-02  6e-03  5e-02 0:10.3
#   132   1320 -1.251570000000000e+05 3.1e+01 6.95e-02  5e-03  9e-02 0:14.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:26:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:26:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227079776421747e+05 1.0e+00 4.47e-01  4e-01  5e-01 0:00.0
#     2     20 -1.225668610043541e+05 1.2e+00 4.43e-01  4e-01  5e-01 0:00.1
#     3     30 -1.227066978699590e+05 1.3e+00 4.48e-01  4e-01  5e-01 0:00.2
#    39    390 -1.242600330985487e+05 2.8e+00 2.68e-01  2e-01  3e-01 0:03.3
#    85    850 -1.251570000000000e+05 7.4e+00 5.93e-02  1e-02  7e-02 0:07.4
#   100   1000 -1.251570000000000e+05 1.1e+01 4.02e-02  7e-03  5e-02 0:08.9
#   110   1100 -1.251570000000000e+05 1.3e+01 3.04e-02  5e-03  4e-02 0:10.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:27:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225378279683042e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.1
#     2     20 -1.225540933980103e+05 1.2e+00 5.07e-01  5e-01  5e-01 0:00.1
#     3     30 -1.223464809552527e+05 1.2e+00 5.31e-01  5e-01  6e-01 0:00.2
#    38    380 -1.264301567941080e+05 2.5e+00 1.93e-01  1e-01  2e-01 0:03.3
#    75    750 -1.271795049630491e+05 5.4e+00 7.50e-02  2e-02  1e-01 0:07.5
#   100   1000 -1.274460984483836e+05 1.0e+01 3.18e-02  5e-03  4e-02 0:11.0
#   146   1460 -1.274952282760158e+05 1.4e+01 4.05e-03  6e-04  5e-03 0:17.0
#   198   1980 -1.274955646817578e+05 5.8e+01 1.83e-03  7e-05  3e-03 0:24.2
#   200   2000 -1.274954588764295e+05 6.0e+01 1.71e-03  6e-05  3e-03 0:24.4
#   261   2610 -1.274956871238602e+05 3.3e+02 3.11e-04  3e-06  5e-04 0:33.5
#   300   3000 -1.274956885490531e+05 9.1e+02 9.69e-05  7e-07  2e-04 0:38.7
#   378   3780 -1.274956886769531e+05 7.0e+03 2.13e-05  1e-07  3e-05 0:49.8
#   400   4000 -1.274956886841129e+05 1.5e+04 1.44e-05  6e-08  3e-05 0:52.8
#   493   4930 -1.274956886877175e+05 3.0e+05 1.49e-06  6e-09  4e-06 1:06.0
#   500   5000 -1.274956886877643e+05 3.6e+05 1.51e-06  7e-09  4e-06 1:06.8
#   600   6000 -1.274956886877554e+05 3.8e+00 4.86e-07  4e-07  6e-07 1:21.4
#   700   7000 -1.274956886877515e+05 1.2e+01 1.25e-07  8e-08  2e-07 1:35.2
#   800   8000 -1.274956886877656e+05 2.2e+01 5.14e-08  3e-08  7e-08 1:49.4
#   900   9000 -1.274956886877628e+05 4.2e+01 8.19e-08  4e-08  1e-07 2:03.7
#  1000  10000 -1.274956886877582e+05 9.1e+01 1.29e-07  6e-08  2e-07 2:18.6
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1070  10700 -1.274956886877613e+05 8.8e+01 3.40e-07  1e-07  3e-07 2:29.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:29:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.235746395763153e+05 1.0e+00 5.24e-01  5e-01  5e-01 0:00.1
#     2     20 -1.214831872275073e+05 1.2e+00 5.00e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214586320686102e+05 1.3e+00 4.94e-01  5e-01  5e-01 0:00.2
#    45    450 -1.236246204044648e+05 2.7e+00 4.87e-01  4e-01  5e-01 0:03.2
#    95    950 -1.249839271731871e+05 5.9e+00 1.60e-01  7e-02  2e-01 0:07.2
#   100   1000 -1.249000000000000e+05 6.4e+00 1.17e-01  5e-02  1e-01 0:07.9
#   138   1380 -1.301787596701653e+05 6.0e+00 2.97e-02  1e-02  3e-02 0:13.9
#   170   1700 -1.305143105688724e+05 7.4e+00 1.41e-02  3e-03  2e-02 0:21.1
#   200   2000 -1.305761340564871e+05 1.3e+01 8.00e-03  9e-04  8e-03 0:27.6
#   249   2490 -1.305876227728153e+05 4.4e+01 1.66e-03  1e-04  1e-03 0:36.7
#   298   2980 -1.305878375374812e+05 1.4e+02 3.92e-04  2e-05  4e-04 0:46.8
#   300   3000 -1.305878536827163e+05 1.5e+02 4.13e-04  2e-05  4e-04 0:47.0
#   361   3610 -1.305878552535185e+05 8.9e+02 1.48e-04  6e-06  1e-04 0:59.2
#   400   4000 -1.305878557549294e+05 2.2e+03 7.40e-05  2e-06  8e-05 1:06.9
#   468   4680 -1.305878558159537e+05 1.2e+04 1.38e-05  3e-07  1e-05 1:21.2
#   500   5000 -1.305878558183336e+05 2.7e+04 5.63e-06  1e-07  5e-06 1:29.3
#   587   5870 -1.305878558194243e+05 2.5e+05 4.55e-07  8e-09  5e-07 1:45.4
#   600   6000 -1.305878558194273e+05 3.3e+05 3.31e-07  6e-09  4e-07 1:48.1
#   684   6840 -1.305878558192950e+05 3.4e+00 3.04e-08  2e-08  4e-08 2:06.3
#   700   7000 -1.305878558194238e+05 3.3e+00 2.30e-08  2e-08  3e-08 2:09.5
#   800   8000 -1.305878558193926e+05 8.0e+00 9.39e-09  3e-09  1e-08 2:29.3
#   900   9000 -1.305878558193506e+05 2.4e+01 4.64e-08  4e-09  6e-08 2:50.3
#  1000  10000 -1.305878558194056e+05 5.2e+01 2.33e-08  1e-09  3e-08 3:10.4
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.305878558194067e+05 8.1e+01 5.33e-08  2e-09  5e-08 3:30.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:33:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:33:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:33:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:33:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222650000000000e+05 1.0e+00 2.23e-01  2e-01  2e-01 0:00.0
#     2     20 -1.222650000000000e+05 1.2e+00 2.21e-01  2e-01  2e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 2.14e-01  2e-01  2e-01 0:00.1
#    42    420 -1.227400000000000e+05 2.8e+00 2.63e-01  2e-01  3e-01 0:03.2
#    82    820 -1.227400000000000e+05 4.0e+00 7.06e-02  4e-02  9e-02 0:06.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:33:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.215485518062810e+05 1.0e+00 2.61e-01  3e-01  3e-01 0:00.1
#     2     20 -1.214210000000000e+05 1.2e+00 2.46e-01  2e-01  3e-01 0:00.1
#     3     30 -1.214361126888441e+05 1.2e+00 2.32e-01  2e-01  2e-01 0:00.2
#    39    390 -1.238578745610737e+05 2.7e+00 1.86e-01  1e-01  2e-01 0:03.2
#    77    770 -1.250677850030900e+05 4.9e+00 2.16e-02  7e-03  2e-02 0:07.2
#   100   1000 -1.250764370212307e+05 6.2e+00 7.28e-03  2e-03  8e-03 0:09.7
#   155   1550 -1.250784111413241e+05 4.0e+01 3.00e-03  2e-04  4e-03 0:15.7
#   200   2000 -1.250786622209965e+05 1.2e+02 1.05e-03  2e-05  1e-03 0:20.5
#   275   2750 -1.250786884129307e+05 8.6e+02 8.45e-05  5e-07  1e-04 0:28.6
#   300   3000 -1.250786886086825e+05 1.7e+03 3.85e-05  2e-07  5e-05 0:30.9
#   400   4000 -1.250786886872629e+05 3.2e+04 2.93e-06  1e-08  5e-06 0:39.7
#   493   4930 -1.250786886877664e+05 6.1e+05 3.33e-07  1e-09  7e-07 0:50.9
#   500   5000 -1.250786886877689e+05 7.8e+05 3.81e-07  1e-09  8e-07 0:51.8
#   600   6000 -1.250786886876296e+05 6.0e+00 6.19e-08  3e-08  8e-08 1:04.6
#   700   7000 -1.250786886876819e+05 2.4e+01 1.66e-07  1e-07  3e-07 1:17.8
#   725   7250 -1.250786886876753e+05 2.9e+01 1.22e-07  7e-08  2e-07 1:20.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:34:50 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.234725659643909e+05 1.0e+00 3.16e-01  3e-01  3e-01 0:00.1
#     2     20 -1.232124609635058e+05 1.2e+00 3.20e-01  3e-01  3e-01 0:00.1
#     3     30 -1.238388618282351e+05 1.2e+00 3.22e-01  3e-01  3e-01 0:00.2
#    48    480 -1.244272533029348e+05 3.3e+00 1.51e-01  8e-02  2e-01 0:03.2
#    86    860 -1.250013043568003e+05 1.1e+01 7.06e-02  1e-02  8e-02 0:07.3
#   100   1000 -1.250537317393730e+05 1.5e+01 4.66e-02  6e-03  5e-02 0:08.9
#   132   1320 -1.251570000000000e+05 3.1e+01 6.95e-02  5e-03  9e-02 0:13.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:35:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:35:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227079776421747e+05 1.0e+00 4.47e-01  4e-01  5e-01 0:00.1
#     2     20 -1.225668610043541e+05 1.2e+00 4.43e-01  4e-01  5e-01 0:00.2
#     3     30 -1.227066978699590e+05 1.3e+00 4.48e-01  4e-01  5e-01 0:00.3
#    39    390 -1.242600330985487e+05 2.8e+00 2.68e-01  2e-01  3e-01 0:03.3
#    80    800 -1.251152157327417e+05 6.4e+00 8.78e-02  2e-02  1e-01 0:07.3
#   100   1000 -1.251570000000000e+05 1.1e+01 4.02e-02  7e-03  5e-02 0:09.9
#   110   1100 -1.251570000000000e+05 1.3e+01 3.04e-02  5e-03  4e-02 0:11.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 04:35:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225378279683042e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.1
#     2     20 -1.225540933980103e+05 1.2e+00 5.07e-01  5e-01  5e-01 0:00.2
#     3     30 -1.223464809552527e+05 1.2e+00 5.31e-01  5e-01  6e-01 0:00.2
#    40    400 -1.248427716415814e+05 2.7e+00 1.73e-01  1e-01  2e-01 0:03.3
#    76    760 -1.271642830104520e+05 5.7e+00 7.37e-02  2e-02  1e-01 0:07.4
#   100   1000 -1.274460984483836e+05 1.0e+01 3.18e-02  5e-03  4e-02 0:11.1
#   143   1430 -1.274945467432032e+05 1.4e+01 5.24e-03  7e-04  6e-03 0:17.2
#   197   1970 -1.274956536850461e+05 5.9e+01 1.79e-03  7e-05  3e-03 0:24.2
#   200   2000 -1.274954588764295e+05 6.0e+01 1.71e-03  6e-05  3e-03 0:24.7
#   278   2780 -1.274956875782559e+05 4.8e+02 1.57e-04  1e-06  2e-04 0:33.8
#   300   3000 -1.274956885490531e+05 9.1e+02 9.69e-05  7e-07  2e-04 0:36.1
#   385   3850 -1.274956886772162e+05 8.4e+03 1.78e-05  8e-08  3e-05 0:47.1
#   400   4000 -1.274956886841129e+05 1.5e+04 1.44e-05  6e-08  3e-05 0:48.7
#   496   4960 -1.274956886877270e+05 3.3e+05 1.46e-06  6e-09  3e-06 1:01.8
#   500   5000 -1.274956886877643e+05 3.6e+05 1.51e-06  7e-09  4e-06 1:02.3
#   600   6000 -1.274956886877554e+05 3.8e+00 4.86e-07  4e-07  6e-07 1:16.7
#   700   7000 -1.274956886877515e+05 1.2e+01 1.25e-07  8e-08  2e-07 1:31.0
#   800   8000 -1.274956886877656e+05 2.2e+01 5.14e-08  3e-08  7e-08 1:44.6
#   900   9000 -1.274956886877628e+05 4.2e+01 8.19e-08  4e-08  1e-07 1:58.7
#  1000  10000 -1.274956886877582e+05 9.1e+01 1.29e-07  6e-08  2e-07 2:12.8
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1070  10700 -1.274956886877613e+05 8.8e+01 3.40e-07  1e-07  3e-07 2:21.3
# ...
#   222   2220 -2.511400000000000e+04 4.6e+02 7.31e-03  6e-05  1e-02 0:04.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 4.66e-01  5e-01  5e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 4.36e-01  4e-01  4e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.2e+00 4.53e-01  4e-01  5e-01 0:00.1
#   100   1000 -2.545492649374017e+04 4.2e+00 1.42e-01  5e-02  1e-01 0:01.9
#   143   1430 -2.552800000000000e+04 4.8e+00 3.29e-02  1e-02  4e-02 0:03.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:38 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 5.91e-01  6e-01  6e-01 0:00.0
#     2     20 -2.461100000000000e+04 1.2e+00 6.35e-01  6e-01  8e-01 0:00.0
#     3     30 -2.445200000000000e+04 1.4e+00 6.86e-01  6e-01  8e-01 0:00.0
#   100   1000 -2.461400000000000e+04 8.1e+00 6.54e-01  2e-01  1e+00 0:02.3
#   148   1480 -2.499600000000000e+04 1.4e+01 2.87e-01  6e-02  5e-01 0:03.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:42 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 6.54e-01  6e-01  7e-01 0:00.0
#     2     20 -2.455134275045258e+04 1.2e+00 6.52e-01  6e-01  7e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.3e+00 6.91e-01  6e-01  8e-01 0:00.1
#    51    510 -2.499600000000000e+04 3.0e+00 1.54e-01  8e-02  2e-01 0:01.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:43 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.461400000000000e+04 1.0e+00 7.37e-01  7e-01  8e-01 0:00.0
#     2     20 -2.499600000000000e+04 1.2e+00 7.39e-01  7e-01  8e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.3e+00 7.27e-01  7e-01  8e-01 0:00.1
#   100   1000 -2.533445228426607e+04 4.8e+00 6.31e-02  2e-02  6e-02 0:02.0
#   189   1890 -2.552800000000000e+04 5.5e+01 3.11e-03  8e-05  3e-03 0:04.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.427713757353439e+04 1.0e+00 7.94e-01  8e-01  8e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 8.42e-01  8e-01  9e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.4e+00 8.94e-01  9e-01  9e-01 0:00.1
#    13    130 -2.420000000000000e+04 1.8e+00 1.59e+00  1e+00  2e+00 0:00.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 8.10e-02  8e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 1.62e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 2.43e-01  2e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.446624381071939e+04 1.0e+00 3.26e-01  3e-01  3e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 2.92e-01  3e-01  3e-01 0:00.0
#     3     30 -2.461400000000000e+04 1.3e+00 2.79e-01  3e-01  3e-01 0:00.0
#   100   1000 -2.535100000000000e+04 1.4e+01 1.61e-01  3e-02  3e-01 0:02.2
#   200   2000 -2.590744272461913e+04 3.7e+01 2.20e-02  2e-03  5e-02 0:04.6
#   273   2730 -2.591200000000000e+04 1.8e+02 4.12e-03  5e-05  7e-03 0:06.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 3.95e-01  4e-01  4e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 3.74e-01  4e-01  4e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.2e+00 3.75e-01  4e-01  4e-01 0:00.1
#   100   1000 -2.507491734012728e+04 6.0e+00 8.52e-02  2e-02  9e-02 0:01.8
#   200   2000 -2.511400000000000e+04 2.1e+02 9.10e-03  1e-04  1e-02 0:03.9
#   222   2220 -2.511400000000000e+04 4.6e+02 7.31e-03  6e-05  1e-02 0:04.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:45:59 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 4.66e-01  5e-01  5e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 4.36e-01  4e-01  4e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.2e+00 4.53e-01  4e-01  5e-01 0:00.1
#   100   1000 -2.545492649374017e+04 4.2e+00 1.42e-01  5e-02  1e-01 0:02.2
#   143   1430 -2.552800000000000e+04 4.8e+00 3.29e-02  1e-02  4e-02 0:03.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 5.91e-01  6e-01  6e-01 0:00.0
#     2     20 -2.461100000000000e+04 1.2e+00 6.35e-01  6e-01  8e-01 0:00.0
#     3     30 -2.445200000000000e+04 1.4e+00 6.86e-01  6e-01  8e-01 0:00.1
#   100   1000 -2.461400000000000e+04 8.1e+00 6.54e-01  2e-01  1e+00 0:02.0
#   148   1480 -2.499600000000000e+04 1.4e+01 2.87e-01  6e-02  5e-01 0:02.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 6.54e-01  6e-01  7e-01 0:00.0
#     2     20 -2.455134275045258e+04 1.2e+00 6.52e-01  6e-01  7e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.3e+00 6.91e-01  6e-01  8e-01 0:00.1
#    51    510 -2.499600000000000e+04 3.0e+00 1.54e-01  8e-02  2e-01 0:01.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.461400000000000e+04 1.0e+00 7.37e-01  7e-01  8e-01 0:00.0
#     2     20 -2.499600000000000e+04 1.2e+00 7.39e-01  7e-01  8e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.3e+00 7.27e-01  7e-01  8e-01 0:00.1
#   100   1000 -2.533445228426607e+04 4.8e+00 6.31e-02  2e-02  6e-02 0:02.0
#   189   1890 -2.552800000000000e+04 5.5e+01 3.11e-03  8e-05  3e-03 0:04.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.427713757353439e+04 1.0e+00 7.94e-01  8e-01  8e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 8.42e-01  8e-01  9e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.4e+00 8.94e-01  9e-01  9e-01 0:00.1
#    13    130 -2.420000000000000e+04 1.8e+00 1.59e+00  1e+00  2e+00 0:00.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 8.10e-02  8e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 1.62e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 2.43e-01  2e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.446624381071939e+04 1.0e+00 3.26e-01  3e-01  3e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 2.92e-01  3e-01  3e-01 0:00.0
#     3     30 -2.461400000000000e+04 1.3e+00 2.79e-01  3e-01  3e-01 0:00.1
#   100   1000 -2.535100000000000e+04 1.4e+01 1.61e-01  3e-02  3e-01 0:02.1
#   200   2000 -2.590744272461913e+04 3.7e+01 2.20e-02  2e-03  5e-02 0:04.5
#   273   2730 -2.591200000000000e+04 1.8e+02 4.12e-03  5e-05  7e-03 0:06.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 3.95e-01  4e-01  4e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 3.74e-01  4e-01  4e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.2e+00 3.75e-01  4e-01  4e-01 0:00.1
#   100   1000 -2.507491734012728e+04 6.0e+00 8.52e-02  2e-02  9e-02 0:01.8
#   200   2000 -2.511400000000000e+04 2.1e+02 9.10e-03  1e-04  1e-02 0:03.8
#   222   2220 -2.511400000000000e+04 4.6e+02 7.31e-03  6e-05  1e-02 0:04.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 4.66e-01  5e-01  5e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 4.36e-01  4e-01  4e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.2e+00 4.53e-01  4e-01  5e-01 0:00.1
#   100   1000 -2.545492649374017e+04 4.2e+00 1.42e-01  5e-02  1e-01 0:01.8
#   143   1430 -2.552800000000000e+04 4.8e+00 3.29e-02  1e-02  4e-02 0:02.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 5.91e-01  6e-01  6e-01 0:00.0
#     2     20 -2.461100000000000e+04 1.2e+00 6.35e-01  6e-01  8e-01 0:00.0
#     3     30 -2.445200000000000e+04 1.4e+00 6.86e-01  6e-01  8e-01 0:00.1
#   100   1000 -2.461400000000000e+04 8.1e+00 6.54e-01  2e-01  1e+00 0:01.8
#   148   1480 -2.499600000000000e+04 1.4e+01 2.87e-01  6e-02  5e-01 0:02.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:29 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 6.54e-01  6e-01  7e-01 0:00.0
#     2     20 -2.455134275045258e+04 1.2e+00 6.52e-01  6e-01  7e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.3e+00 6.91e-01  6e-01  8e-01 0:00.0
#    51    510 -2.499600000000000e+04 3.0e+00 1.54e-01  8e-02  2e-01 0:01.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:30 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.461400000000000e+04 1.0e+00 7.37e-01  7e-01  8e-01 0:00.0
#     2     20 -2.499600000000000e+04 1.2e+00 7.39e-01  7e-01  8e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.3e+00 7.27e-01  7e-01  8e-01 0:00.1
#   100   1000 -2.533445228426607e+04 4.8e+00 6.31e-02  2e-02  6e-02 0:02.1
#   189   1890 -2.552800000000000e+04 5.5e+01 3.11e-03  8e-05  3e-03 0:04.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.427713757353439e+04 1.0e+00 7.94e-01  8e-01  8e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 8.42e-01  8e-01  9e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.4e+00 8.94e-01  9e-01  9e-01 0:00.1
#    13    130 -2.420000000000000e+04 1.8e+00 1.59e+00  1e+00  2e+00 0:00.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 8.10e-02  8e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 1.62e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.420000000000000e+04 1.0e+00 2.43e-01  2e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.446624381071939e+04 1.0e+00 3.26e-01  3e-01  3e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 2.92e-01  3e-01  3e-01 0:00.0
#     3     30 -2.461400000000000e+04 1.3e+00 2.79e-01  3e-01  3e-01 0:00.1
#   100   1000 -2.535100000000000e+04 1.4e+01 1.61e-01  3e-02  3e-01 0:02.1
#   200   2000 -2.590744272461913e+04 3.7e+01 2.20e-02  2e-03  5e-02 0:04.5
#   273   2730 -2.591200000000000e+04 1.8e+02 4.12e-03  5e-05  7e-03 0:06.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:42 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 3.95e-01  4e-01  4e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 3.74e-01  4e-01  4e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.2e+00 3.75e-01  4e-01  4e-01 0:00.0
#   100   1000 -2.507491734012728e+04 6.0e+00 8.52e-02  2e-02  9e-02 0:01.8
#   200   2000 -2.511400000000000e+04 2.1e+02 9.10e-03  1e-04  1e-02 0:03.8
#   222   2220 -2.511400000000000e+04 4.6e+02 7.31e-03  6e-05  1e-02 0:04.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 4.66e-01  5e-01  5e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 4.36e-01  4e-01  4e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.2e+00 4.53e-01  4e-01  5e-01 0:00.1
#   100   1000 -2.545492649374017e+04 4.2e+00 1.42e-01  5e-02  1e-01 0:02.1
#   143   1430 -2.552800000000000e+04 4.8e+00 3.29e-02  1e-02  4e-02 0:03.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:50 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 5.91e-01  6e-01  6e-01 0:00.0
#     2     20 -2.461100000000000e+04 1.2e+00 6.35e-01  6e-01  8e-01 0:00.0
#     3     30 -2.445200000000000e+04 1.4e+00 6.86e-01  6e-01  8e-01 0:00.0
#   100   1000 -2.461400000000000e+04 8.1e+00 6.54e-01  2e-01  1e+00 0:01.8
#   148   1480 -2.499600000000000e+04 1.4e+01 2.87e-01  6e-02  5e-01 0:02.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:53 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.458200000000000e+04 1.0e+00 6.54e-01  6e-01  7e-01 0:00.0
#     2     20 -2.455134275045258e+04 1.2e+00 6.52e-01  6e-01  7e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.3e+00 6.91e-01  6e-01  8e-01 0:00.0
#    51    510 -2.499600000000000e+04 3.0e+00 1.54e-01  8e-02  2e-01 0:00.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.461400000000000e+04 1.0e+00 7.37e-01  7e-01  8e-01 0:00.0
#     2     20 -2.499600000000000e+04 1.2e+00 7.39e-01  7e-01  8e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.3e+00 7.27e-01  7e-01  8e-01 0:00.1
#   100   1000 -2.533445228426607e+04 4.8e+00 6.31e-02  2e-02  6e-02 0:01.9
#   189   1890 -2.552800000000000e+04 5.5e+01 3.11e-03  8e-05  3e-03 0:03.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 09:46:58 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.427713757353439e+04 1.0e+00 7.94e-01  8e-01  8e-01 0:00.0
#     2     20 -2.458200000000000e+04 1.2e+00 8.42e-01  8e-01  9e-01 0:00.0
#     3     30 -2.458200000000000e+04 1.4e+00 8.94e-01  9e-01  9e-01 0:00.0
#    13    130 -2.420000000000000e+04 1.8e+00 1.59e+00  1e+00  2e+00 0:00.2
# Benishangul Gumz CMA complete. Total time: 723.69
# Wall time: 5h 40min 18s

# %% [markdown]
# #### 4. Run CMA-ES-2 (maxits=20,000, n=10)

# %%
# %%time
n_starting_points = 30
maxits= 20000
# for maximum of 5
for i in df_all.keys():
    cma_region(new_ss_regions_10[i], n_starting_points, maxits, df_all[i], df_10[i], min_dist_dict[i])
# Out:
# (6_w,12)-aCMA-ES (mu_w=3.7,w_1=40%) in dimension 20 (seed=1234, Tue Sep  6 00:26:35 2022)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-406-9b4cd6d1e4e0> in cma_region(n, n_starting_points, max_iterations, data, data_sub, min_dict_dist, set_sigma)
#      48             es = cma.CMAEvolutionStrategy(generate_sp_proposed(sp, n).flatten(), sigma0=j,
#      49                                       inopts={'bounds': cma_bounds,'seed':1234})
# ---> 50             es.optimize(f, iterations=(max_iterations/ es.popsize))
#      51             fcma.append((es.result[1], es.result[0].reshape(n, 2), (time.time() - start_time), j))
#      52
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\interfaces.py in optimize(self, objective_fct, maxfun, iterations, min_iterations, args, verb_disp, callback, n_jobs, **kwargs)
#     206                 X = self.ask()  # deliver candidate solutions
#     207                 # fitvals = [objective_fct(x, *args) for x in X]
# --> 208                 fitvals = eval_all(X, args=args)
#     209                 cevals += len(fitvals)
#     210                 self.tell(X, fitvals)  # all the work is done here
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in __call__(self, solutions, fitness_function, args, timeout)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in <listcomp>(.0)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# <ipython-input-406-9b4cd6d1e4e0> in f(x)
#      29         """
#      30         x = x.reshape(n,2) # reshape for input into expected enrolment.
# ---> 31         ee = expected_enrollment(df_ms_loc_sub, x, df_ms_enrol_sub, current_ms_dist_sub, ee_old_constant) # fitness function.
#      32         return ee*-1 # Multiply by -1 for maximising.
#      33
#
# TypeError: expected_enrollment() missing 1 required positional argument: 'min_dict'

# %% [markdown]
# #### 5. Run CMA-ES-1 (maxits=20,000, n=5)

# %%
# %%time
n_starting_points = 30
maxits= 20000
# for maximum of 5. 
for i in df_all.keys():
    cma_region(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], df_all[i], min_dist_dict[i])
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:38:28 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.219349788879924e+05 1.0e+00 9.53e-02  9e-02  1e-01 0:00.0
#     2     20 -1.222971899569808e+05 1.3e+00 9.14e-02  9e-02  1e-01 0:00.0
#     3     30 -1.223847741514681e+05 1.3e+00 8.44e-02  8e-02  9e-02 0:00.1
#   100   1000 -1.237016329310183e+05 6.4e+00 2.16e-03  5e-04  3e-03 0:02.5
#   200   2000 -1.237027087360525e+05 1.4e+02 1.07e-04  1e-05  2e-04 0:05.5
#   300   3000 -1.237027097185529e+05 4.2e+03 8.59e-06  6e-07  1e-05 0:08.3
#   400   4000 -1.237027097210406e+05 1.4e+05 1.18e-06  3e-08  1e-06 0:11.0
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=456)
#   warnings.warn(msg + ' (' +
#   500   5000 -1.237027097210194e+05 3.0e+00 1.98e-07  1e-07  2e-07 0:13.7
#   600   6000 -1.237027097210731e+05 8.8e+00 8.00e-07  5e-07  1e-06 0:16.5
#   700   7000 -1.237027097210744e+05 1.2e+01 2.47e-07  1e-07  3e-07 0:19.4
#   800   8000 -1.237027097210728e+05 1.9e+01 9.83e-07  4e-07  1e-06 0:22.2
#   900   9000 -1.237027097210776e+05 3.4e+01 1.92e-06  5e-07  2e-06 0:25.1
#   990   9900 -1.237027097210679e+05 7.2e+01 9.03e-07  2e-07  1e-06 0:28.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:38:58 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217804548301928e+05 1.0e+00 1.69e-01  2e-01  2e-01 0:00.0
#     2     20 -1.219600000000000e+05 1.2e+00 1.57e-01  1e-01  2e-01 0:00.0
#     3     30 -1.218735266679198e+05 1.2e+00 1.46e-01  1e-01  1e-01 0:00.0
#   100   1000 -1.239673021838907e+05 6.4e+00 7.57e-03  2e-03  8e-03 0:02.6
#   200   2000 -1.239883156827908e+05 4.9e+01 7.85e-05  4e-06  1e-04 0:05.7
#   300   3000 -1.239883247928408e+05 2.8e+02 1.04e-06  2e-08  1e-06 0:09.0
#   400   4000 -1.239883248298128e+05 2.0e+03 9.32e-08  2e-10  1e-07 0:12.2
#   500   5000 -1.239883248305721e+05 1.3e+04 3.21e-09  2e-12  5e-09 0:15.4
# NOTE (module=cma, iteration=559):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.0e+09 to 2.8e+02
#   600   6000 -1.239883248305750e+05 3.4e+01 2.51e-10  3e-14  5e-10 0:18.7
#   623   6230 -1.239883248305750e+05 4.5e+01 2.49e-10  2e-14  5e-10 0:19.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:39:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220355456287740e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
#     2     20 -1.221563505748531e+05 1.2e+00 2.74e-01  3e-01  3e-01 0:00.1
#     3     30 -1.223781659487075e+05 1.2e+00 2.85e-01  3e-01  3e-01 0:00.1
#   100   1000 -1.237305974826036e+05 5.0e+00 1.28e-02  4e-03  1e-02 0:02.3
#   200   2000 -1.238451227013648e+05 3.0e+01 4.61e-04  2e-05  4e-04 0:05.0
#   300   3000 -1.238453487851333e+05 1.7e+02 8.87e-06  8e-08  8e-06 0:07.8
#   400   4000 -1.238453496906272e+05 1.5e+03 3.13e-07  6e-10  4e-07 0:10.6
#   500   5000 -1.238453496948312e+05 7.8e+03 2.58e-09  9e-13  3e-09 0:13.3
# NOTE (module=cma, iteration=549):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 4.0e+08 to 3.7e+02
#   597   5970 -1.238453496948377e+05 2.3e+01 2.53e-10  2e-14  4e-10 0:16.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:39:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225561556775898e+05 1.0e+00 3.60e-01  3e-01  4e-01 0:00.0
#     2     20 -1.222383524368344e+05 1.2e+00 3.68e-01  4e-01  4e-01 0:00.0
#     3     30 -1.223285671767545e+05 1.3e+00 3.75e-01  4e-01  4e-01 0:00.1
#   100   1000 -1.244832904008266e+05 6.6e+00 9.69e-03  3e-03  1e-02 0:02.5
#   200   2000 -1.246302524125067e+05 5.0e+01 9.51e-04  4e-05  1e-03 0:05.5
#   300   3000 -1.246311810852966e+05 2.8e+02 9.22e-05  6e-07  1e-04 0:08.5
#   400   4000 -1.246311902921707e+05 1.7e+03 4.20e-06  1e-08  7e-06 0:11.4
#   500   5000 -1.246311904749631e+05 1.1e+04 6.20e-07  2e-09  1e-06 0:14.4
#   600   6000 -1.246311904783416e+05 8.1e+04 1.83e-07  1e-10  5e-07 0:17.4
# NOTE (module=cma, iteration=663):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.0e+10 to 4.4e+08
#   700   7000 -1.246311904789603e+05 4.1e+04 2.23e-08  3e-12  4e-08 0:20.3
#   800   8000 -1.246311904789643e+05 2.6e+05 2.78e-09  6e-14  8e-09 0:23.3
#   900   9000 -1.246311904789644e+05 6.0e+05 4.85e-09  9e-14  1e-08 0:26.5
#   976   9760 -1.246311904788902e+05 1.0e+00 6.57e-09  6e-09  7e-09 0:28.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:40:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227533433442708e+05 1.0e+00 4.36e-01  4e-01  4e-01 0:00.0
#     2     20 -1.227371761796013e+05 1.2e+00 4.25e-01  4e-01  4e-01 0:00.0
#     3     30 -1.222919152627532e+05 1.2e+00 4.30e-01  4e-01  4e-01 0:00.1
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.0e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=975)
#   warnings.warn(msg + ' (' +
#   100   1000 -1.243077454645686e+05 4.0e+00 2.51e-01  2e-01  3e-01 0:02.4
#   200   2000 -1.276656552853511e+05 6.9e+00 4.54e-02  7e-03  4e-02 0:05.4
#   300   3000 -1.277398687002005e+05 9.2e+01 1.61e-03  4e-05  1e-03 0:09.5
#   400   4000 -1.277399686683778e+05 8.6e+02 2.43e-04  1e-06  3e-04 0:13.5
#   500   5000 -1.277399708856703e+05 1.1e+04 3.18e-05  2e-08  4e-05 0:17.6
# NOTE (module=cma, iteration=556):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.6e+09 to 3.4e+06
#   600   6000 -1.277399709222093e+05 4.3e+03 1.51e-06  9e-11  2e-06 0:22.6
#   700   7000 -1.277399709224267e+05 6.7e+04 1.42e-07  9e-13  3e-07 0:27.0
#   780   7800 -1.277399709224281e+05 4.7e+05 1.87e-08  2e-14  5e-08 0:30.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:40:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.223917462030829e+05 1.0e+00 5.01e-01  5e-01  5e-01 0:00.0
#     2     20 -1.224333821721599e+05 1.1e+00 4.75e-01  5e-01  5e-01 0:00.1
#     3     30 -1.226523204395152e+05 1.2e+00 4.96e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.226473032781509e+05 4.5e+00 2.34e-01  1e-01  3e-01 0:02.5
#   200   2000 -1.246952853889737e+05 6.0e+00 2.56e-02  5e-03  2e-02 0:05.6
#   300   3000 -1.248637443849281e+05 7.5e+00 2.12e-04  2e-05  1e-04 0:09.0
#   400   4000 -1.248643217490793e+05 7.4e+01 1.57e-05  3e-07  1e-05 0:12.7
#   500   5000 -1.248644040038242e+05 5.5e+02 7.62e-06  4e-08  2e-05 0:16.7
#   600   6000 -1.248644046138196e+05 2.3e+03 8.36e-08  1e-10  2e-07 0:20.8
# NOTE (module=cma, iteration=688):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.6e+08 to 1.3e+07
#   700   7000 -1.248644046165372e+05 5.7e+03 1.44e-08  5e-12  8e-08 0:24.3
#   800   8000 -1.248644046198641e+05 1.5e+04 6.49e-09  7e-13  4e-08 0:27.5
#   900   9000 -1.248644046199003e+05 1.2e+05 1.19e-09  3e-14  1e-08 0:30.6
#   912   9120 -1.248644046199007e+05 1.5e+05 6.13e-10  1e-14  7e-09 0:31.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:41:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221951566852443e+05 1.0e+00 6.32e-01  6e-01  7e-01 0:00.0
#     2     20 -1.229290403555311e+05 1.2e+00 6.24e-01  6e-01  7e-01 0:00.0
#     3     30 -1.221847865564539e+05 1.3e+00 6.16e-01  6e-01  7e-01 0:00.1
#   100   1000 -1.244196255506321e+05 6.4e+00 9.51e-02  2e-02  1e-01 0:02.4
#   200   2000 -1.256817943186197e+05 1.1e+01 6.88e-03  7e-04  8e-03 0:05.7
#   300   3000 -1.258152500714007e+05 1.8e+01 3.18e-03  2e-04  3e-03 0:09.3
#   400   4000 -1.258193066905239e+05 6.7e+01 3.00e-04  8e-06  3e-04 0:12.9
#   500   5000 -1.258193636827541e+05 3.8e+02 1.43e-05  2e-07  2e-05 0:16.3
#   600   6000 -1.258193711151647e+05 2.5e+03 1.52e-05  4e-08  3e-05 0:19.9
#   700   7000 -1.258193715287079e+05 7.4e+03 7.08e-07  1e-09  1e-06 0:23.5
#   800   8000 -1.258193715425921e+05 2.3e+04 3.90e-07  2e-10  1e-06 0:27.0
# NOTE (module=cma, iteration=839):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.2e+09 to 6.6e+07
#   900   9000 -1.258193715580576e+05 1.1e+04 4.08e-07  9e-11  1e-06 0:30.8
#  1000  10000 -1.258193715586962e+05 4.2e+04 6.18e-09  4e-13  2e-08 0:34.5
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1050  10500 -1.258193715586999e+05 1.1e+05 8.49e-10  3e-14  4e-09 0:36.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:41:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220200599013136e+05 1.0e+00 7.21e-01  7e-01  8e-01 0:00.0
#     2     20 -1.218765796797454e+05 1.3e+00 6.81e-01  6e-01  7e-01 0:00.0
#     3     30 -1.217981887988416e+05 1.2e+00 6.89e-01  6e-01  7e-01 0:00.1
#   100   1000 -1.222359155416623e+05 4.6e+00 4.00e-01  2e-01  5e-01 0:02.3
#   200   2000 -1.265129482537272e+05 8.2e+00 6.30e-02  1e-02  5e-02 0:06.0
#   292   2920 -1.272123111288186e+05 3.1e+01 1.22e-03  7e-05  8e-04 0:11.1
#   300   3000 -1.272126743538110e+05 3.1e+01 7.85e-04  4e-05  5e-04 0:11.5
#   400   4000 -1.272136275381251e+05 8.8e+01 3.51e-05  9e-07  3e-05 0:16.5
#   500   5000 -1.272136346460821e+05 4.8e+02 3.41e-07  2e-09  4e-07 0:21.3
#   600   6000 -1.272136347866964e+05 7.3e+03 1.98e-07  2e-10  7e-07 0:25.9
# NOTE (module=cma, iteration=674):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 5.2e+08 to 3.9e+08
#   700   7000 -1.272136347888294e+05 3.5e+04 9.30e-10  2e-13  4e-09 0:30.5
#   800   8000 -1.272136347888468e+05 3.3e+05 1.30e-09  8e-14  2e-08 0:35.2
#   820   8200 -1.272136347888473e+05 3.8e+05 4.31e-10  2e-14  5e-09 0:36.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:42:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.219261499897474e+05 1.0e+00 8.44e-01  8e-01  9e-01 0:00.0
#     2     20 -1.220874015034900e+05 1.2e+00 7.90e-01  8e-01  8e-01 0:00.1
#     3     30 -1.220535317539410e+05 1.3e+00 7.27e-01  7e-01  8e-01 0:00.1
#   100   1000 -1.256327904723525e+05 8.1e+00 2.88e-02  9e-03  4e-02 0:02.4
#   200   2000 -1.258165918851823e+05 2.9e+01 7.68e-04  4e-05  1e-03 0:05.4
#   300   3000 -1.258167848090518e+05 3.4e+02 4.56e-05  3e-07  7e-05 0:09.0
#   400   4000 -1.258167865821979e+05 3.4e+03 3.84e-06  3e-09  6e-06 0:12.9
# NOTE (module=cma, iteration=459):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.5e+08 to 3.4e+06
#   500   5000 -1.258167866033972e+05 3.8e+03 3.08e-07  3e-11  8e-07 0:16.1
#   600   6000 -1.258167866040022e+05 5.3e+04 6.52e-08  8e-13  3e-07 0:19.3
#   679   6790 -1.258167866040055e+05 3.3e+05 6.72e-09  2e-14  3e-08 0:21.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:42:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.219136504937207e+05 1.0e+00 8.40e-01  8e-01  9e-01 0:00.0
#     2     20 -1.224595382174652e+05 1.1e+00 8.20e-01  8e-01  8e-01 0:00.0
#     3     30 -1.220977401482678e+05 1.2e+00 8.29e-01  8e-01  9e-01 0:00.1
#   100   1000 -1.231052145239336e+05 3.5e+00 1.63e-01  7e-02  2e-01 0:02.5
#   200   2000 -1.243860833557092e+05 8.5e+00 6.08e-03  1e-03  7e-03 0:05.4
#   300   3000 -1.243969322557272e+05 1.7e+02 3.03e-04  3e-06  5e-04 0:08.3
#   400   4000 -1.243969483317768e+05 2.9e+03 1.36e-05  4e-08  2e-05 0:11.4
#   500   5000 -1.243969483758104e+05 3.6e+04 1.23e-06  4e-09  2e-06 0:14.5
#   600   6000 -1.243969483760360e+05 5.9e+05 1.12e-07  3e-10  2e-07 0:17.6
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.0e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=614)
#   warnings.warn(msg + ' (' +
#   700   7000 -1.243969483760370e+05 5.4e+00 3.24e-08  3e-08  4e-08 0:20.7
#   800   8000 -1.243969483760355e+05 8.2e+00 7.15e-08  4e-08  8e-08 0:23.7
#   900   9000 -1.243969483760366e+05 2.4e+01 5.97e-08  2e-08  7e-08 0:26.9
#  1000  10000 -1.243969483760359e+05 3.6e+01 7.61e-08  3e-08  9e-08 0:29.9
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.243969483760352e+05 4.7e+01 1.18e-07  3e-08  1e-07 0:32.8
#  1120  11200 -1.243969483760329e+05 5.1e+01 1.23e-07  4e-08  1e-07 0:33.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:43:24 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.218994024654510e+05 1.0e+00 8.89e-02  8e-02  9e-02 0:00.0
#     2     20 -1.220786476636908e+05 1.2e+00 9.44e-02  9e-02  1e-01 0:00.1
#     3     30 -1.218234091329573e+05 1.4e+00 9.30e-02  9e-02  1e-01 0:00.1
#   100   1000 -1.226572969907962e+05 1.5e+01 3.24e-02  4e-03  5e-02 0:02.3
#   200   2000 -1.226701799226144e+05 8.1e+01 1.19e-03  3e-05  2e-03 0:05.0
#   300   3000 -1.226702757367510e+05 3.6e+02 2.89e-05  2e-07  4e-05 0:07.9
#   400   4000 -1.226702759818676e+05 4.1e+03 5.60e-06  6e-09  1e-05 0:10.9
# NOTE (module=cma, iteration=486):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 8.3e+08 to 7.4e+06
#   500   5000 -1.226702759880390e+05 4.0e+03 6.17e-07  1e-10  2e-06 0:13.6
#   600   6000 -1.226702759883407e+05 3.7e+04 1.05e-07  3e-12  3e-07 0:16.3
#   700   7000 -1.226702759883435e+05 1.8e+05 5.50e-09  3e-14  2e-08 0:19.1
#   710   7100 -1.226702759883435e+05 1.9e+05 3.50e-09  2e-14  1e-08 0:19.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:43:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220763818929328e+05 1.0e+00 1.72e-01  2e-01  2e-01 0:00.0
#     2     20 -1.218051879907993e+05 1.2e+00 1.57e-01  1e-01  2e-01 0:00.0
#     3     30 -1.224805952754780e+05 1.2e+00 1.47e-01  1e-01  2e-01 0:00.1
#   100   1000 -1.227469398023245e+05 1.1e+01 3.02e-03  5e-04  3e-03 0:02.5
#   200   2000 -1.227486473692624e+05 3.9e+02 2.15e-04  2e-06  4e-04 0:05.0
#   300   3000 -1.227486545800699e+05 5.6e+03 3.85e-06  2e-09  8e-06 0:07.7
# NOTE (module=cma, iteration=345):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.9e+08 to 6.3e+01
#   400   4000 -1.227486545849912e+05 1.7e+01 2.70e-07  1e-11  6e-07 0:11.2
#   500   5000 -1.227486545850222e+05 2.7e+02 1.05e-08  3e-14  3e-08 0:14.0
#   513   5130 -1.227486545850222e+05 4.5e+02 1.02e-08  2e-14  2e-08 0:14.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:43:59 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.219668638913446e+05 1.0e+00 2.54e-01  2e-01  3e-01 0:00.0
#     2     20 -1.220801149251594e+05 1.1e+00 2.28e-01  2e-01  2e-01 0:00.1
#     3     30 -1.221021819687796e+05 1.2e+00 2.24e-01  2e-01  2e-01 0:00.1
#   100   1000 -1.248563238725516e+05 4.6e+00 9.85e-03  3e-03  1e-02 0:02.8
#   200   2000 -1.248997595937645e+05 2.4e+01 2.19e-04  4e-05  2e-04 0:06.2
#   300   3000 -1.248998142031767e+05 4.3e+02 2.29e-05  2e-06  3e-05 0:09.9
#   400   4000 -1.248998143446783e+05 7.6e+03 1.71e-06  3e-07  2e-06 0:13.0
#   500   5000 -1.248998143454753e+05 1.4e+05 2.98e-07  4e-08  4e-07 0:16.2
#   600   6000 -1.248998143453635e+05 3.1e+00 1.52e-07  1e-07  2e-07 0:19.3
#   700   7000 -1.248998143454497e+05 1.3e+01 8.59e-08  7e-08  2e-07 0:22.8
#   750   7500 -1.248998143453987e+05 1.7e+01 1.37e-07  1e-07  2e-07 0:24.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:44:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222337967909744e+05 1.0e+00 3.37e-01  3e-01  3e-01 0:00.0
#     2     20 -1.218086478070971e+05 1.1e+00 3.34e-01  3e-01  4e-01 0:00.1
#     3     30 -1.223191341308491e+05 1.2e+00 3.18e-01  3e-01  3e-01 0:00.1
#   100   1000 -1.241686408372190e+05 4.6e+00 1.12e-01  4e-02  1e-01 0:02.9
#   200   2000 -1.256289229729715e+05 9.3e+00 6.39e-03  7e-04  5e-03 0:06.9
#   300   3000 -1.256312898582651e+05 6.8e+01 2.78e-04  9e-06  3e-04 0:11.1
#   400   4000 -1.256313199767583e+05 4.4e+02 4.58e-05  4e-07  6e-05 0:14.9
#   500   5000 -1.256313211604318e+05 3.2e+03 3.33e-06  7e-09  6e-06 0:18.8
#   600   6000 -1.256313211807675e+05 2.0e+04 1.75e-07  7e-11  4e-07 0:23.1
# NOTE (module=cma, iteration=642):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.7e+09 to 1.7e+02
#   700   7000 -1.256313211809845e+05 2.8e+01 4.19e-09  4e-13  1e-08 0:27.1
#   772   7720 -1.256313211809852e+05 9.5e+01 4.56e-10  1e-14  1e-09 0:29.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:44:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.231292325386703e+05 1.0e+00 4.21e-01  4e-01  4e-01 0:00.0
#     2     20 -1.224458459944811e+05 1.2e+00 3.97e-01  4e-01  4e-01 0:00.0
#     3     30 -1.224984191264298e+05 1.2e+00 3.90e-01  4e-01  4e-01 0:00.1
#    98    980 -1.267220069953961e+05 6.1e+00 7.14e-02  2e-02  1e-01 0:03.1
#   100   1000 -1.268312552221941e+05 6.4e+00 6.12e-02  2e-02  8e-02 0:03.2
#   200   2000 -1.279866133209270e+05 5.0e+00 3.12e-03  6e-04  2e-03 0:07.4
#   300   3000 -1.279971567921033e+05 2.3e+01 3.45e-05  5e-06  2e-05 0:11.8
#   400   4000 -1.279971955156465e+05 1.1e+02 3.78e-06  2e-07  3e-06 0:16.8
#   500   5000 -1.279972137612607e+05 7.0e+02 5.00e-06  9e-08  9e-06 0:21.0
#   600   6000 -1.279972143780815e+05 2.6e+03 6.68e-07  3e-09  1e-06 0:25.1
#   700   7000 -1.279972152577895e+05 5.0e+03 7.31e-06  1e-08  1e-05 0:29.2
#   800   8000 -1.279972155101727e+05 7.8e+03 5.72e-07  6e-10  7e-07 0:33.2
# NOTE (module=cma, iteration=890):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.1e+09 to 4.8e+08
#   900   9000 -1.279972155134204e+05 2.6e+04 1.16e-07  3e-11  4e-07 0:38.2
#  1000  10000 -1.279972155141880e+05 7.3e+04 2.23e-08  2e-12  4e-08 0:43.1
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.279972155143545e+05 1.9e+05 1.58e-08  7e-13  2e-08 0:47.3
#  1142  11420 -1.279972155143578e+05 2.8e+05 2.88e-09  8e-14  4e-09 0:49.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:45:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.225275557724716e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.244144358449773e+05 1.2e+00 4.29e-01  4e-01  4e-01 0:00.1
#     3     30 -1.222504475311671e+05 1.2e+00 3.87e-01  4e-01  4e-01 0:00.1
#   100   1000 -1.265961397474258e+05 5.1e+00 1.16e-02  4e-03  1e-02 0:02.8
#   200   2000 -1.266688659666043e+05 1.6e+01 3.60e-04  2e-05  3e-04 0:06.1
#   300   3000 -1.266695183000890e+05 1.5e+02 1.79e-04  2e-06  2e-04 0:09.3
#   400   4000 -1.266695293447060e+05 1.3e+03 3.79e-06  5e-09  5e-06 0:12.7
# NOTE (module=cma, iteration=497):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.7e+08 to 2.3e+07
#   500   5000 -1.266695293849703e+05 4.9e+03 2.18e-07  3e-11  3e-07 0:16.4
#   600   6000 -1.266695293852466e+05 5.2e+04 1.48e-08  3e-13  3e-08 0:21.0
#   650   6500 -1.266695293852488e+05 1.4e+05 1.41e-09  1e-14  3e-09 0:23.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:46:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.231717687323964e+05 1.0e+00 5.93e-01  6e-01  6e-01 0:00.0
#     2     20 -1.220137312726148e+05 1.1e+00 5.57e-01  5e-01  6e-01 0:00.0
#     3     30 -1.221993517244317e+05 1.2e+00 5.15e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.245859061897132e+05 4.6e+00 1.15e-01  7e-02  1e-01 0:02.7
#   200   2000 -1.259876402559221e+05 4.7e+00 8.05e-03  2e-03  5e-03 0:06.0
#   300   3000 -1.260121116714256e+05 3.5e+01 1.43e-04  3e-06  9e-05 0:09.6
#   400   4000 -1.260121360851186e+05 4.4e+02 1.47e-05  2e-07  1e-05 0:13.0
#   500   5000 -1.260121439681422e+05 2.1e+03 1.75e-05  9e-08  1e-05 0:16.2
#   600   6000 -1.260121441355223e+05 2.1e+04 1.08e-06  5e-09  1e-06 0:19.4
#   700   7000 -1.260121441362788e+05 3.7e+05 1.73e-07  9e-10  4e-07 0:22.7
#   800   8000 -1.260121441361753e+05 5.1e+00 6.67e-08  6e-08  9e-08 0:25.8
#   900   9000 -1.260121441362342e+05 9.7e+00 7.45e-08  5e-08  1e-07 0:28.9
#   985   9850 -1.260121441361589e+05 1.7e+01 5.86e-08  3e-08  1e-07 0:31.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:46:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.224442912991668e+05 1.0e+00 6.92e-01  7e-01  7e-01 0:00.0
#     2     20 -1.221132430868600e+05 1.2e+00 6.08e-01  6e-01  6e-01 0:00.0
#     3     30 -1.222413650703159e+05 1.2e+00 5.32e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.234154441099437e+05 4.9e+00 5.06e-01  3e-01  6e-01 0:02.2
#   200   2000 -1.257436599524304e+05 1.7e+01 2.64e-02  3e-03  3e-02 0:05.3
#   300   3000 -1.258852377872825e+05 3.6e+02 6.65e-04  7e-06  7e-04 0:09.9
#   400   4000 -1.258852468188538e+05 8.9e+03 2.34e-04  2e-07  4e-04 0:14.3
# NOTE (module=cma, iteration=456):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.7e+09 to 1.7e+02
#   500   5000 -1.258852469047836e+05 3.9e+01 3.81e-05  2e-09  6e-05 0:19.1
#   600   6000 -1.258852469069075e+05 6.3e+02 3.38e-06  8e-12  7e-06 0:23.4
#   700   7000 -1.258852469069098e+05 1.2e+04 8.84e-07  1e-13  2e-06 0:27.8
#   730   7300 -1.258852469069099e+05 3.4e+04 5.98e-07  3e-14  2e-06 0:29.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:47:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220870893741675e+05 1.0e+00 7.48e-01  7e-01  8e-01 0:00.0
#     2     20 -1.222559567664552e+05 1.1e+00 7.22e-01  7e-01  7e-01 0:00.0
#     3     30 -1.218201217350848e+05 1.2e+00 7.45e-01  7e-01  8e-01 0:00.1
#   100   1000 -1.248438815045077e+05 7.8e+00 1.38e-01  3e-02  2e-01 0:02.6
#   200   2000 -1.261102436860833e+05 1.0e+01 5.23e-03  1e-03  6e-03 0:06.0
#   300   3000 -1.261317569983912e+05 5.2e+01 9.55e-04  3e-05  1e-03 0:09.6
#   400   4000 -1.261347411950862e+05 3.2e+02 8.77e-05  4e-07  1e-04 0:13.1
#   500   5000 -1.261347538808925e+05 1.6e+03 3.15e-06  3e-09  4e-06 0:17.0
#   600   6000 -1.261347539429368e+05 1.1e+04 5.53e-08  9e-12  7e-08 0:20.8
# NOTE (module=cma, iteration=609):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.6e+02
#   700   7000 -1.261347539430603e+05 4.8e+01 2.18e-09  6e-14  3e-09 0:24.5
#   713   7130 -1.261347539430610e+05 5.3e+01 7.86e-10  2e-14  9e-10 0:24.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:47:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222869520426263e+05 1.0e+00 9.25e-01  9e-01  1e+00 0:00.0
#     2     20 -1.219636668703231e+05 1.3e+00 8.94e-01  9e-01  1e+00 0:00.0
#     3     30 -1.218370657875244e+05 1.3e+00 8.13e-01  8e-01  9e-01 0:00.1
#   100   1000 -1.229874552452521e+05 4.4e+00 2.87e-01  2e-01  4e-01 0:02.1
#   200   2000 -1.242617173757201e+05 6.4e+00 1.45e-02  4e-03  1e-02 0:04.9
#   300   3000 -1.243456538426533e+05 5.0e+01 5.43e-04  6e-05  5e-04 0:08.2
#   400   4000 -1.243457649667619e+05 1.0e+03 3.38e-05  4e-06  4e-05 0:11.5
#   500   5000 -1.243457655073589e+05 1.5e+04 5.07e-06  6e-07  5e-06 0:15.0
#   600   6000 -1.243457655107016e+05 1.6e+05 2.76e-07  2e-08  2e-07 0:18.1
#   700   7000 -1.243457655106194e+05 2.5e+00 1.07e-07  9e-08  1e-07 0:21.8
#   800   8000 -1.243457655104198e+05 8.1e+00 1.63e-07  1e-07  2e-07 0:25.5
#   855   8550 -1.243457655105164e+05 1.3e+01 3.57e-07  2e-07  5e-07 0:27.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:48:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227729694361227e+05 1.0e+00 8.77e-02  9e-02  9e-02 0:00.0
#     2     20 -1.243733207428890e+05 1.2e+00 8.37e-02  8e-02  9e-02 0:00.1
#     3     30 -1.244971273141668e+05 1.2e+00 8.16e-02  8e-02  8e-02 0:00.1
#    69    690 -1.257207509803777e+05 1.3e+01 8.35e-03  1e-03  1e-02 0:03.1
#   100   1000 -1.257276991546109e+05 3.6e+01 1.80e-03  1e-04  2e-03 0:04.8
#   181   1810 -1.257285508821005e+05 4.2e+02 3.07e-04  6e-06  6e-04 0:09.8
#   200   2000 -1.257285566640758e+05 5.9e+02 1.72e-04  3e-06  3e-04 0:10.8
#   300   3000 -1.257285661820276e+05 4.0e+03 1.18e-05  2e-08  2e-05 0:17.2
# NOTE (module=cma, iteration=391):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.6e+09 to 5.4e+02
#   400   4000 -1.257285662299255e+05 2.9e+01 1.31e-06  3e-10  3e-06 0:24.6
#   500   5000 -1.257285662309491e+05 3.3e+02 1.00e-07  3e-12  3e-07 0:32.7
#   600   6000 -1.257285662309540e+05 4.3e+03 6.33e-09  2e-14  2e-08 0:38.9
#   619   6190 -1.257285662309540e+05 5.9e+03 2.18e-09  5e-15  8e-09 0:40.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:48:52 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.224959853954766e+05 1.0e+00 1.75e-01  2e-01  2e-01 0:00.0
#     2     20 -1.218225411447365e+05 1.1e+00 1.66e-01  2e-01  2e-01 0:00.1
#     3     30 -1.223654444397267e+05 1.2e+00 1.60e-01  2e-01  2e-01 0:00.1
#    65    650 -1.252414120258346e+05 4.4e+00 1.06e-02  3e-03  1e-02 0:03.1
#   100   1000 -1.253961085945001e+05 8.1e+00 3.05e-03  7e-04  4e-03 0:04.8
#   175   1750 -1.254154129161468e+05 4.3e+01 2.43e-04  3e-05  5e-04 0:09.8
#   200   2000 -1.254155482507472e+05 6.3e+01 4.56e-05  5e-06  8e-05 0:11.0
#   300   3000 -1.254156759769415e+05 4.5e+02 1.32e-05  6e-07  3e-05 0:15.9
#   400   4000 -1.254156792381023e+05 3.1e+03 4.35e-06  3e-08  1e-05 0:20.5
#   500   5000 -1.254156793480420e+05 1.4e+04 9.10e-08  1e-10  2e-07 0:24.4
# NOTE (module=cma, iteration=571):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 6.8e+09 to 6.2e+08
#   600   6000 -1.254156793484959e+05 4.0e+04 3.38e-08  9e-12  2e-07 0:28.2
#   680   6800 -1.254156793485311e+05 2.5e+05 1.38e-09  1e-13  1e-08 0:31.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:49:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.219653306514562e+05 1.0e+00 2.53e-01  2e-01  3e-01 0:00.0
#     2     20 -1.221418671645984e+05 1.2e+00 2.49e-01  2e-01  3e-01 0:00.0
#     3     30 -1.223928314446103e+05 1.2e+00 2.55e-01  2e-01  3e-01 0:00.1
#   100   1000 -1.236283218851137e+05 6.3e+00 1.12e-02  3e-03  1e-02 0:02.6
#   200   2000 -1.237826528575168e+05 3.8e+01 5.86e-04  3e-05  8e-04 0:05.9
#   300   3000 -1.237827431997102e+05 3.4e+02 3.60e-05  6e-07  4e-05 0:09.1
#   400   4000 -1.237827438615094e+05 2.5e+03 4.50e-06  1e-08  6e-06 0:12.1
#   500   5000 -1.237827438856760e+05 2.5e+04 2.08e-07  1e-10  3e-07 0:15.1
# NOTE (module=cma, iteration=556):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 7.0e+09 to 2.4e+07
#   600   6000 -1.237827438858613e+05 1.4e+04 5.11e-08  3e-12  9e-08 0:18.1
#   700   7000 -1.237827438858630e+05 8.4e+04 3.89e-09  3e-14  9e-09 0:21.1
#   730   7300 -1.237827438858630e+05 1.3e+05 2.08e-09  9e-15  5e-09 0:22.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:49:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.226012080624724e+05 1.0e+00 3.52e-01  3e-01  4e-01 0:00.0
#     2     20 -1.237903839097768e+05 1.2e+00 3.52e-01  3e-01  4e-01 0:00.1
#     3     30 -1.223791142581549e+05 1.3e+00 3.63e-01  3e-01  4e-01 0:00.1
#   100   1000 -1.240361917815779e+05 4.5e+00 3.48e-01  2e-01  4e-01 0:02.7
#   200   2000 -1.278800072438438e+05 7.6e+00 2.73e-02  7e-03  2e-02 0:06.0
#   300   3000 -1.285714536262009e+05 2.0e+01 1.28e-03  9e-05  7e-04 0:10.6
#   400   4000 -1.285720093152324e+05 1.2e+02 8.18e-05  1e-06  4e-05 0:15.2
#   500   5000 -1.285720147757028e+05 5.4e+02 2.37e-06  9e-09  1e-06 0:19.8
#   600   6000 -1.285720148083851e+05 3.2e+03 7.08e-08  4e-11  4e-08 0:24.2
#   700   7000 -1.285720148084783e+05 2.5e+04 2.12e-09  2e-13  1e-09 0:28.7
# NOTE (module=cma, iteration=717):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.0e+09 to 1.3e+02
#   769   7690 -1.285720148084789e+05 1.5e+01 1.77e-10  6e-15  2e-10 0:31.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:50:21 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.219182876017026e+05 1.0e+00 4.48e-01  4e-01  5e-01 0:00.0
#     2     20 -1.220525089288256e+05 1.2e+00 5.04e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223597895338435e+05 1.3e+00 5.50e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.259402230043103e+05 4.3e+00 6.56e-01  4e-01  7e-01 0:02.2
#   200   2000 -1.258437359908253e+05 7.3e+00 7.72e-02  2e-02  7e-02 0:04.8
#   297   2970 -1.277812518012652e+05 1.0e+01 1.04e-02  8e-04  5e-03 0:09.8
#   300   3000 -1.277931316747982e+05 1.0e+01 8.23e-03  6e-04  4e-03 0:09.9
#   400   4000 -1.279510760597035e+05 2.4e+01 5.11e-04  3e-05  3e-04 0:15.3
#   500   5000 -1.279522965960629e+05 9.2e+01 3.22e-05  1e-06  3e-05 0:20.9
#   600   6000 -1.279523137227296e+05 3.8e+02 7.56e-07  1e-08  6e-07 0:26.4
#   700   7000 -1.279523142567912e+05 1.9e+03 1.95e-07  1e-09  3e-07 0:31.5
#   800   8000 -1.279523142715872e+05 1.3e+04 1.26e-08  2e-11  6e-08 0:36.6
#   900   9000 -1.279523144091569e+05 1.6e+04 2.02e-06  2e-09  4e-06 0:41.7
#  1000  10000 -1.279523145113392e+05 2.2e+04 1.86e-07  7e-11  4e-07 0:47.0
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# NOTE (module=cma, iteration=1032):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.0e+09 to 6.1e+07
#  1100  11000 -1.279523145126963e+05 1.7e+04 1.22e-08  2e-12  3e-08 0:52.2
#  1200  12000 -1.279523145127752e+05 1.0e+05 9.73e-09  6e-13  5e-08 0:57.6
#  1300  13000 -1.279523145128042e+05 2.7e+05 3.04e-09  8e-14  1e-08 1:03.5
#  1330  13300 -1.279523145128052e+05 3.6e+05 1.92e-09  4e-14  7e-09 1:05.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:51:28 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.224799415161643e+05 1.0e+00 4.94e-01  5e-01  5e-01 0:00.0
#     2     20 -1.229832973934657e+05 1.1e+00 4.55e-01  4e-01  5e-01 0:00.1
#     3     30 -1.218572234328961e+05 1.2e+00 4.24e-01  4e-01  4e-01 0:00.1
#   100   1000 -1.232060991912454e+05 4.5e+00 6.94e-02  2e-02  7e-02 0:02.9
#   200   2000 -1.247451747756887e+05 1.4e+01 1.68e-03  3e-04  1e-03 0:05.9
#   300   3000 -1.247463390175795e+05 2.2e+02 4.18e-05  4e-06  4e-05 0:08.6
#   400   4000 -1.247463445331968e+05 4.6e+03 1.60e-05  2e-06  2e-05 0:11.2
#   500   5000 -1.247463445936334e+05 1.0e+05 1.14e-06  1e-07  1e-06 0:13.9
#   600   6000 -1.247463445926758e+05 2.2e+00 1.68e-07  1e-07  2e-07 0:16.5
#   700   7000 -1.247463445927260e+05 8.6e+00 1.90e-07  1e-07  2e-07 0:19.3
#   760   7600 -1.247463445936123e+05 1.9e+01 1.26e-06  7e-07  2e-06 0:21.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:51:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.224050000000000e+05 1.0e+00 5.97e-01  6e-01  6e-01 0:00.0
#     2     20 -1.222800186055038e+05 1.2e+00 5.48e-01  5e-01  6e-01 0:00.0
#     3     30 -1.226712452850565e+05 1.2e+00 5.05e-01  5e-01  5e-01 0:00.0
#   100   1000 -1.226063185372018e+05 5.6e+00 3.31e-01  2e-01  4e-01 0:02.6
#   200   2000 -1.256798862297626e+05 5.8e+00 8.67e-03  1e-03  6e-03 0:05.9
#   300   3000 -1.257801309346920e+05 1.7e+01 3.11e-04  2e-05  2e-04 0:09.7
#   400   4000 -1.257802082616218e+05 1.3e+02 1.83e-05  3e-07  2e-05 0:13.3
#   500   5000 -1.257802108931614e+05 6.3e+02 1.22e-06  5e-09  1e-06 0:17.2
#   600   6000 -1.257802131803931e+05 4.7e+03 3.73e-06  4e-09  7e-06 0:21.0
#   700   7000 -1.257802132251763e+05 2.4e+04 1.99e-07  6e-11  5e-07 0:24.8
# NOTE (module=cma, iteration=708):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 9.6e+08 to 2.1e+07
#   800   8000 -1.257802132259525e+05 2.0e+04 1.50e-08  1e-12  6e-08 0:28.4
#   900   9000 -1.257802132260395e+05 1.6e+05 1.09e-08  3e-13  1e-07 0:32.2
#   940   9400 -1.257802132260409e+05 2.2e+05 8.15e-10  1e-14  5e-09 0:33.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:52:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220413946130138e+05 1.0e+00 7.17e-01  7e-01  7e-01 0:00.0
#     2     20 -1.221208243193305e+05 1.2e+00 6.57e-01  6e-01  7e-01 0:00.1
#     3     30 -1.222615746017145e+05 1.2e+00 6.23e-01  6e-01  6e-01 0:00.1
#   100   1000 -1.236575566654915e+05 3.0e+00 2.19e-02  1e-02  2e-02 0:02.6
#   200   2000 -1.240562589652642e+05 1.1e+01 1.64e-04  2e-05  1e-04 0:06.1
#   300   3000 -1.240564832154231e+05 8.0e+01 2.96e-05  6e-07  4e-05 0:09.4
#   400   4000 -1.240564934681552e+05 3.5e+02 9.04e-06  5e-08  9e-06 0:12.8
#   500   5000 -1.240564946489612e+05 1.9e+03 1.01e-06  1e-09  2e-06 0:16.3
# NOTE (module=cma, iteration=594):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.7e+08 to 1.2e+07
#   600   6000 -1.240564946602889e+05 4.0e+03 9.84e-08  2e-11  2e-07 0:19.6
#   700   7000 -1.240564946603987e+05 2.2e+04 1.12e-09  3e-14  3e-09 0:22.9
#   723   7230 -1.240564946603988e+05 3.1e+04 6.78e-10  2e-14  2e-09 0:23.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:52:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221430026123395e+05 1.0e+00 7.61e-01  7e-01  8e-01 0:00.0
#     2     20 -1.221887044295779e+05 1.2e+00 6.77e-01  6e-01  7e-01 0:00.1
#     3     30 -1.219542307243405e+05 1.2e+00 6.14e-01  6e-01  6e-01 0:00.1
#   100   1000 -1.224459131715052e+05 5.5e+00 2.47e-01  1e-01  3e-01 0:02.4
#   200   2000 -1.264361732839386e+05 4.5e+00 7.12e-03  2e-03  4e-03 0:05.4
#   300   3000 -1.264562857029495e+05 1.9e+01 1.12e-04  7e-06  6e-05 0:08.9
#   400   4000 -1.264564850148793e+05 1.8e+02 5.12e-05  9e-07  4e-05 0:12.2
#   500   5000 -1.264564890866121e+05 1.1e+03 5.47e-06  2e-08  6e-06 0:15.3
#   600   6000 -1.264564891556696e+05 8.2e+03 5.20e-07  4e-10  7e-07 0:18.5
# NOTE (module=cma, iteration=686):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+09 to 4.9e+08
#   700   7000 -1.264564891560630e+05 2.9e+04 5.73e-08  8e-12  1e-07 0:22.1
#   800   8000 -1.264564891561154e+05 2.4e+05 2.80e-09  1e-13  9e-09 0:25.5
#   850   8500 -1.264564891561164e+05 6.2e+05 1.61e-09  3e-14  7e-09 0:27.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:53:19 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222683940913525e+05 1.0e+00 8.74e-01  9e-01  9e-01 0:00.0
#     2     20 -1.238226572310143e+05 1.2e+00 8.44e-01  8e-01  9e-01 0:00.1
#     3     30 -1.223310614543591e+05 1.3e+00 8.61e-01  8e-01  9e-01 0:00.1
#   100   1000 -1.249817502376089e+05 4.9e+00 4.77e-02  2e-02  5e-02 0:02.4
#   200   2000 -1.253377884343516e+05 1.5e+01 2.64e-03  2e-04  2e-03 0:05.1
#   300   3000 -1.253379300507947e+05 1.3e+03 1.71e-04  2e-06  2e-04 0:07.9
#   400   4000 -1.253379300737381e+05 1.1e+05 7.85e-05  3e-07  2e-04 0:10.6
#   500   5000 -1.253379300752449e+05 5.7e+00 3.22e-05  9e-06  4e-05 0:13.6
#   600   6000 -1.253379300752544e+05 1.4e+02 6.96e-06  1e-06  1e-05 0:16.4
#   700   7000 -1.253379300752549e+05 4.4e+02 7.67e-06  9e-07  1e-05 0:19.8
#   800   8000 -1.253379300752554e+05 4.2e+02 4.03e-06  4e-07  5e-06 0:23.2
#   900   9000 -1.253379300752554e+05 3.1e+02 5.72e-06  4e-07  5e-06 0:26.3
#  1000  10000 -1.253379300752554e+05 3.5e+02 2.54e-06  1e-07  2e-06 0:29.3
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1030  10300 -1.253379300752554e+05 3.0e+02 4.46e-06  2e-07  3e-06 0:30.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:53:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.223799535139508e+05 1.0e+00 8.53e-02  8e-02  9e-02 0:00.0
#     2     20 -1.227279711345721e+05 1.2e+00 8.22e-02  8e-02  9e-02 0:00.1
#     3     30 -1.224526690404291e+05 1.3e+00 8.15e-02  8e-02  9e-02 0:00.1
#   100   1000 -1.238585058763659e+05 5.6e+00 1.51e-03  4e-04  2e-03 0:03.1
#   200   2000 -1.238644207243774e+05 2.9e+01 7.61e-05  1e-05  1e-04 0:07.0
#   300   3000 -1.238648813848103e+05 1.3e+02 1.04e-05  5e-07  1e-05 0:10.8
#   400   4000 -1.238648873208625e+05 6.8e+02 2.90e-06  5e-08  5e-06 0:15.1
#   500   5000 -1.238648875186274e+05 2.1e+03 7.62e-08  4e-10  1e-07 0:19.2
#   600   6000 -1.238648875325735e+05 1.0e+04 1.30e-07  2e-10  5e-07 0:23.3
#   700   7000 -1.238648875347142e+05 2.7e+04 3.48e-09  2e-12  1e-08 0:26.9
# NOTE (module=cma, iteration=746):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 4.9e+09 to 3.8e+09
#   800   8000 -1.238648875348620e+05 1.2e+05 2.08e-09  4e-13  1e-08 0:30.7
#   900   9000 -1.238648875348658e+05 5.2e+05 7.67e-10  5e-14  8e-09 0:34.8
#   910   9100 -1.238648875348659e+05 5.7e+05 5.06e-10  3e-14  5e-09 0:35.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:54:27 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.224627809005071e+05 1.0e+00 1.82e-01  2e-01  2e-01 0:00.0
#     2     20 -1.222583525751824e+05 1.2e+00 1.74e-01  2e-01  2e-01 0:00.0
#     3     30 -1.225153136971931e+05 1.3e+00 1.77e-01  2e-01  2e-01 0:00.1
#    81    810 -1.272537667033841e+05 5.3e+00 1.50e-02  3e-03  2e-02 0:03.1
#   100   1000 -1.280619182024885e+05 7.1e+00 7.82e-03  1e-03  8e-03 0:04.4
#   200   2000 -1.282580921162115e+05 1.4e+01 7.81e-04  7e-05  5e-04 0:09.4
#   300   3000 -1.282598787978760e+05 3.5e+01 1.00e-05  8e-07  6e-06 0:15.1
#   400   4000 -1.282599723528625e+05 2.1e+02 6.36e-05  2e-06  7e-05 0:21.2
#   500   5000 -1.282601487082310e+05 4.4e+02 2.73e-05  3e-07  3e-05 0:26.9
#   600   6000 -1.282601532969004e+05 1.4e+03 1.69e-06  7e-09  2e-06 0:32.0
#   700   7000 -1.282601536627981e+05 4.8e+03 2.22e-07  3e-10  2e-07 0:37.0
#   800   8000 -1.282601536662041e+05 1.8e+04 2.04e-08  9e-12  2e-08 0:41.9
# NOTE (module=cma, iteration=851):
# condition in coordinate system exceeded 1.2e+08, rescaled to 1.0e+00,
# condition changed from 7.9e+09 to 2.7e+09
#   900   9000 -1.282601536671499e+05 6.2e+04 4.32e-08  8e-12  1e-07 0:46.9
#  1000  10000 -1.282601536674561e+05 1.5e+05 2.01e-08  1e-12  5e-08 0:51.8
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.282601536675093e+05 3.9e+05 2.77e-09  4e-14  7e-09 0:56.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:55:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221104721744403e+05 1.0e+00 2.70e-01  3e-01  3e-01 0:00.0
#     2     20 -1.223961172815400e+05 1.2e+00 2.69e-01  3e-01  3e-01 0:00.0
#     3     30 -1.220804025757507e+05 1.3e+00 2.76e-01  3e-01  3e-01 0:00.1
#   100   1000 -1.252554272498671e+05 7.8e+00 7.78e-02  2e-02  9e-02 0:02.6
#   198   1980 -1.268732618779972e+05 1.3e+01 5.26e-03  6e-04  6e-03 0:06.6
#   200   2000 -1.268757555095686e+05 1.3e+01 4.77e-03  5e-04  5e-03 0:06.7
#   300   3000 -1.269006852272030e+05 5.6e+01 4.45e-04  5e-05  5e-04 0:10.9
#   400   4000 -1.269007704646665e+05 4.0e+02 1.46e-05  4e-07  2e-05 0:15.1
#   500   5000 -1.269007766029390e+05 4.2e+03 6.84e-06  4e-08  2e-05 0:19.6
#   600   6000 -1.269007767508427e+05 2.2e+04 1.93e-07  2e-10  5e-07 0:23.8
# NOTE (module=cma, iteration=676):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 6.9e+09 to 1.1e+09
#   700   7000 -1.269007767526190e+05 4.3e+04 3.63e-08  7e-12  1e-07 0:28.7
#   800   8000 -1.269007767526415e+05 2.0e+05 2.03e-09  8e-14  1e-08 0:33.3
#   830   8300 -1.269007767526417e+05 3.8e+05 1.66e-09  4e-14  1e-08 0:34.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:56:02 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.223884851086080e+05 1.0e+00 3.45e-01  3e-01  3e-01 0:00.0
#     2     20 -1.221982510976893e+05 1.2e+00 3.54e-01  3e-01  4e-01 0:00.0
#     3     30 -1.223655071525857e+05 1.3e+00 3.51e-01  3e-01  4e-01 0:00.1
#   100   1000 -1.243596744089180e+05 8.4e+00 3.29e-02  1e-02  4e-02 0:02.6
#   200   2000 -1.248408331355584e+05 1.9e+01 8.45e-04  6e-05  9e-04 0:05.7
#   300   3000 -1.248414663073786e+05 1.9e+02 1.18e-05  9e-08  1e-05 0:08.8
#   400   4000 -1.248414674125276e+05 2.3e+03 5.35e-06  7e-09  9e-06 0:12.4
# NOTE (module=cma, iteration=492):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 8.5e+08 to 4.0e+04
#   500   5000 -1.248414674682049e+05 2.8e+02 9.32e-07  1e-10  2e-06 0:15.6
#   600   6000 -1.248414674690437e+05 2.4e+03 1.29e-07  2e-12  3e-07 0:18.9
#   700   7000 -1.248414674690663e+05 2.4e+04 1.25e-08  3e-14  3e-08 0:21.7
#   712   7120 -1.248414674690665e+05 2.4e+04 9.60e-09  2e-14  2e-08 0:22.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:56:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.233336692722633e+05 1.0e+00 4.36e-01  4e-01  4e-01 0:00.0
#     2     20 -1.224637750040252e+05 1.1e+00 4.11e-01  4e-01  4e-01 0:00.0
#     3     30 -1.224159192053746e+05 1.2e+00 3.84e-01  4e-01  4e-01 0:00.0
#   100   1000 -1.231687725342099e+05 4.9e+00 1.10e-01  4e-02  1e-01 0:02.4
#   200   2000 -1.243782334573606e+05 8.5e+00 2.13e-03  4e-04  2e-03 0:05.1
#   300   3000 -1.243841094474398e+05 6.0e+01 4.66e-05  3e-06  5e-05 0:08.0
#   400   4000 -1.243841580830266e+05 3.8e+02 8.16e-05  1e-06  1e-04 0:11.2
#   500   5000 -1.243841641710861e+05 2.5e+03 4.05e-06  2e-08  7e-06 0:14.2
#   600   6000 -1.243841642532124e+05 1.7e+04 2.61e-07  3e-10  6e-07 0:17.0
# NOTE (module=cma, iteration=686):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 8.0e+09 to 3.0e+09
#   700   7000 -1.243841642545602e+05 7.8e+04 9.37e-09  2e-12  3e-08 0:19.9
#   800   8000 -1.243841642545788e+05 5.8e+05 1.52e-08  6e-13  8e-08 0:22.5
#   900   9000 -1.243841642533339e+05 4.1e+00 1.52e-08  1e-08  2e-08 0:25.3
#   930   9300 -1.243841642536333e+05 4.7e+00 1.31e-08  8e-09  2e-08 0:26.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:56:53 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220366030755775e+05 1.0e+00 5.47e-01  5e-01  6e-01 0:00.0
#     2     20 -1.223907072930758e+05 1.2e+00 4.82e-01  5e-01  5e-01 0:00.0
#     3     30 -1.222337408141311e+05 1.3e+00 4.67e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.262974698208846e+05 3.4e+00 1.19e-02  5e-03  1e-02 0:03.1
#   200   2000 -1.264325480707340e+05 2.2e+01 3.36e-04  6e-05  4e-04 0:07.1
#   300   3000 -1.264327139177549e+05 1.9e+02 2.06e-05  4e-06  2e-05 0:11.1
#   400   4000 -1.264327276292585e+05 1.4e+03 1.10e-05  2e-06  1e-05 0:15.0
#   500   5000 -1.264327276883794e+05 1.5e+04 4.34e-07  1e-07  7e-07 0:19.3
#   600   6000 -1.264327276888679e+05 2.2e+05 9.46e-08  2e-08  3e-07 0:23.6
#   700   7000 -1.264327276875322e+05 2.1e+00 1.64e-08  1e-08  2e-08 0:28.2
#   775   7750 -1.264327276870107e+05 6.3e+00 1.60e-08  1e-08  3e-08 0:31.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:57:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.218182065141905e+05 1.0e+00 6.62e-01  6e-01  7e-01 0:00.0
#     2     20 -1.218835429582011e+05 1.3e+00 6.42e-01  6e-01  7e-01 0:00.1
#     3     30 -1.230193810193157e+05 1.3e+00 6.18e-01  6e-01  7e-01 0:00.1
#   100   1000 -1.234704709788714e+05 3.8e+00 2.58e-01  1e-01  3e-01 0:02.3
#   200   2000 -1.246532979026973e+05 8.0e+00 2.30e-02  4e-03  3e-02 0:05.1
#   300   3000 -1.247684423320580e+05 6.0e+01 4.89e-04  3e-05  5e-04 0:08.3
#   400   4000 -1.247684617485516e+05 8.3e+02 3.08e-05  3e-07  4e-05 0:11.5
#   500   5000 -1.247684628076415e+05 7.4e+03 2.67e-06  6e-09  4e-06 0:14.8
#   600   6000 -1.247684628162247e+05 6.2e+04 1.69e-07  6e-11  2e-07 0:18.1
# NOTE (module=cma, iteration=633):
# condition in coordinate system exceeded 1.2e+08, rescaled to 1.0e+00,
# condition changed from 4.6e+10 to 4.7e+09
#   700   7000 -1.247684628165079e+05 1.5e+05 7.36e-08  4e-12  1e-07 0:21.7
#   790   7900 -1.247684628165124e+05 6.7e+05 9.01e-09  9e-14  2e-08 0:24.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:57:52 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.218511194541726e+05 1.0e+00 7.55e-01  7e-01  8e-01 0:00.0
#     2     20 -1.218446442321647e+05 1.2e+00 7.75e-01  7e-01  8e-01 0:00.0
#     3     30 -1.218067455412360e+05 1.3e+00 7.85e-01  7e-01  9e-01 0:00.1
#   100   1000 -1.232598626460199e+05 4.2e+00 1.77e-01  1e-01  2e-01 0:02.1
#   200   2000 -1.249020529715135e+05 5.9e+00 1.91e-02  4e-03  1e-02 0:05.0
#   300   3000 -1.250217292778664e+05 2.0e+01 7.74e-04  3e-05  6e-04 0:08.5
#   400   4000 -1.250224429179809e+05 1.2e+02 2.97e-05  3e-07  3e-05 0:12.2
#   500   5000 -1.250224486176635e+05 7.2e+02 6.33e-07  4e-09  9e-07 0:15.5
#   600   6000 -1.250224488476857e+05 4.3e+03 1.81e-06  1e-08  3e-06 0:18.7
#   700   7000 -1.250224491392491e+05 1.1e+04 7.63e-07  1e-09  1e-06 0:21.8
#   800   8000 -1.250224491473503e+05 3.6e+04 6.21e-08  5e-11  1e-07 0:25.0
#   900   9000 -1.250224491477559e+05 1.7e+05 5.53e-09  9e-13  9e-09 0:28.1
# NOTE (module=cma, iteration=900):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.9e+10 to 2.1e+09
#   951   9510 -1.250224491477589e+05 1.2e+05 8.68e-10  8e-14  2e-09 0:29.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 10:58:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.240435717735246e+05 1.0e+00 7.65e-01  7e-01  8e-01 0:00.0
#     2     20 -1.219665435275627e+05 1.1e+00 6.99e-01  7e-01  7e-01 0:00.0
#     3     30 -1.226856335973072e+05 1.2e+00 6.30e-01  6e-01  6e-01 0:00.1
#    92    920 -1.280615393362708e+05 6.7e+00 3.19e-02  7e-03  3e-02 0:03.1
#   100   1000 -1.283134028870520e+05 7.7e+00 1.91e-02  3e-03  2e-02 0:03.6
#   184   1840 -1.287846247841728e+05 1.1e+01 8.22e-04  9e-05  4e-04 0:08.7
#   200   2000 -1.287867426989608e+05 1.2e+01 4.97e-04  5e-05  2e-04 0:09.9
#   300   3000 -1.287881454829647e+05 5.3e+01 4.01e-05  3e-06  4e-05 0:15.4
#   400   4000 -1.287881869756462e+05 4.1e+01 6.31e-07  3e-08  4e-07 0:21.0
#   500   5000 -1.287882265050712e+05 6.1e+02 1.03e-05  2e-07  3e-05 0:26.9
#   600   6000 -1.287882490756124e+05 1.0e+03 2.44e-05  2e-07  8e-05 0:32.9
#   700   7000 -1.287882550376571e+05 1.2e+03 5.26e-07  2e-09  9e-07 0:38.8
#   800   8000 -1.287882550663354e+05 1.1e+04 1.83e-07  3e-10  1e-06 0:45.0
#   900   9000 -1.287882551043854e+05 1.5e+04 1.89e-07  1e-10  7e-07 0:50.9
#  1000  10000 -1.287882551061654e+05 4.1e+04 7.31e-10  2e-13  2e-09 0:56.7
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# NOTE (module=cma, iteration=1016):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.7e+09 to 1.2e+09
#  1040  10400 -1.287882551061686e+05 4.4e+04 8.78e-11  2e-14  3e-10 0:59.1
# ...
# condition changed from 5.6e+08 to 6.2e+02
#   300   3000 -2.409335427791429e+03 3.0e+01 4.54e-05  2e-09  2e-04 0:08.2
#   400   4000 -2.409335427939481e+03 1.4e+03 4.22e-06  8e-12  2e-05 0:11.1
# NOTE (module=cma, iteration=477):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 7.4e+08 to 4.2e+03
#   493   4930 -2.409335427940089e+03 7.4e+01 1.37e-07  1e-14  9e-07 0:13.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:28:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.994185015414313e+03 1.0e+00 2.03e-02  2e-02  2e-02 0:00.0
#     2     20 -2.072215333956652e+03 1.3e+00 1.97e-02  2e-02  2e-02 0:00.0
#     3     30 -2.116218512151164e+03 1.3e+00 1.96e-02  2e-02  2e-02 0:00.1
#   100   1000 -2.141554928909009e+03 1.3e+02 7.78e-04  1e-05  2e-03 0:03.0
#   200   2000 -2.141617360846021e+03 7.9e+03 2.50e-05  1e-08  6e-05 0:06.1
# NOTE (module=cma, iteration=214):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.1e+08 to 9.4e+01
#   300   3000 -2.141617373839796e+03 7.8e+01 1.23e-06  9e-12  4e-06 0:08.5
#   382   3820 -2.141617373860524e+03 2.7e+03 6.85e-08  2e-14  2e-07 0:10.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:28:34 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.588767584426922e+03 1.0e+00 3.33e-02  3e-02  3e-02 0:00.0
#     2     20 -2.648185707150797e+03 1.2e+00 3.72e-02  3e-02  4e-02 0:00.1
#     3     30 -3.058142190575830e+03 1.4e+00 4.10e-02  4e-02  5e-02 0:00.1
#    95    950 -3.812295483161170e+03 1.2e+01 8.13e-04  1e-04  1e-03 0:03.1
#   100   1000 -3.812992032383939e+03 1.3e+01 8.01e-04  9e-05  1e-03 0:03.3
#   200   2000 -3.813194652788311e+03 2.2e+02 2.02e-05  2e-07  5e-05 0:07.1
#   300   3000 -3.813195749905728e+03 2.5e+03 3.88e-07  5e-10  1e-06 0:10.5
# NOTE (module=cma, iteration=386):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.3e+08 to 2.1e+01
#   400   4000 -3.813195751730193e+03 5.7e+00 7.37e-09  1e-12  2e-08 0:14.2
#   463   4630 -3.813195751735220e+03 4.6e+01 2.70e-10  1e-14  1e-09 0:16.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:28:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.019209265983463e+03 1.0e+00 4.17e-02  4e-02  4e-02 0:00.0
#     2     20 -2.138830991019140e+03 1.2e+00 4.27e-02  4e-02  5e-02 0:00.1
#     3     30 -2.200761352732096e+03 1.4e+00 4.01e-02  4e-02  4e-02 0:00.1
#    91    910 -2.576615172197028e+03 2.9e+01 9.29e-04  1e-04  1e-03 0:03.1
#   100   1000 -2.576631822878581e+03 4.6e+01 7.96e-04  9e-05  1e-03 0:03.3
#   200   2000 -2.576672011222098e+03 4.8e+03 2.56e-04  1e-06  7e-04 0:05.9
# NOTE (module=cma, iteration=272):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 5.3e+09 to 5.5e+02
#   300   3000 -2.576672144913613e+03 3.1e+01 6.36e-05  1e-08  2e-04 0:08.6
#   400   4000 -2.576672146154800e+03 1.2e+03 7.48e-06  3e-11  2e-05 0:11.5
#   500   5000 -2.576672146160504e+03 7.9e+04 1.00e-06  1e-13  5e-06 0:14.2
# NOTE (module=cma, iteration=514):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.4e+10 to 6.6e+03
#   600   6000 -2.576672146160518e+03 1.4e+02 2.89e-06  7e-14  3e-05 0:16.8
#   671   6710 -2.576672146160518e+03 3.1e+02 5.30e-06  1e-14  5e-05 0:18.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:29:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.374198979760336e+03 1.0e+00 5.09e-02  5e-02  5e-02 0:00.0
#     2     20 -2.504033578078273e+03 1.2e+00 4.71e-02  4e-02  5e-02 0:00.0
#     3     30 -2.458708155075014e+03 1.2e+00 4.18e-02  4e-02  4e-02 0:00.1
#   100   1000 -3.256668025153383e+03 1.5e+01 2.38e-03  3e-04  4e-03 0:02.8
#   200   2000 -3.256859416732124e+03 1.0e+03 6.74e-04  2e-06  2e-03 0:05.9
# NOTE (module=cma, iteration=260):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.8e+08 to 1.7e+02
#   300   3000 -3.256860320419761e+03 1.0e+01 4.91e-05  4e-09  2e-04 0:09.2
#   400   4000 -3.256860323779778e+03 7.5e+02 1.32e-05  2e-11  8e-05 0:12.3
# NOTE (module=cma, iteration=466):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.9e+08 to 5.8e+02
#   500   5000 -3.256860323795159e+03 3.1e+01 7.10e-07  3e-14  9e-06 0:15.3
#   516   5160 -3.256860323795173e+03 3.6e+01 7.97e-07  2e-14  1e-05 0:15.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:29:27 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.905347224734264e+03 1.0e+00 5.76e-02  6e-02  6e-02 0:00.0
#     2     20 -2.092829794129630e+03 1.2e+00 5.45e-02  5e-02  6e-02 0:00.0
#     3     30 -2.093518179830712e+03 1.3e+00 5.21e-02  5e-02  6e-02 0:00.1
#   100   1000 -3.474590817314706e+03 5.4e+01 3.99e-04  2e-05  6e-04 0:02.9
#   200   2000 -3.474617357461264e+03 4.1e+03 1.76e-05  1e-08  4e-05 0:05.9
# NOTE (module=cma, iteration=235):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.5e+08 to 1.1e+02
#   300   3000 -3.474617373858318e+03 3.0e+01 8.21e-07  1e-11  2e-06 0:08.9
#   395   3950 -3.474617373860496e+03 1.8e+03 4.68e-08  2e-14  2e-07 0:12.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:29:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.214753048752440e+03 1.0e+00 7.17e-02  7e-02  8e-02 0:00.0
#     2     20 -2.367248628472225e+03 1.3e+00 7.88e-02  7e-02  9e-02 0:00.0
#     3     30 -2.495201070941096e+03 1.4e+00 8.42e-02  8e-02  1e-01 0:00.1
#   100   1000 -3.013165018421943e+03 1.9e+01 1.37e-03  2e-04  2e-03 0:02.6
#   200   2000 -3.013621393860536e+03 1.4e+03 8.42e-05  2e-07  2e-04 0:05.5
# NOTE (module=cma, iteration=245):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.9e+08 to 1.3e+02
#   300   3000 -3.013621833616540e+03 2.4e+01 7.89e-06  3e-10  3e-05 0:08.3
#   400   4000 -3.013621833976606e+03 1.7e+03 1.44e-06  7e-13  7e-06 0:12.1
# NOTE (module=cma, iteration=450):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 3.0e+08 to 8.6e+02
#   452   4520 -3.013621833976949e+03 2.9e+01 2.32e-07  2e-14  2e-06 0:13.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:29:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.535952477879780e+03 1.0e+00 8.07e-02  8e-02  8e-02 0:00.0
#     2     20 -2.178036122135256e+03 1.2e+00 8.40e-02  8e-02  9e-02 0:00.0
#     3     30 -2.671381562329120e+03 1.3e+00 9.13e-02  8e-02  1e-01 0:00.1
#   100   1000 -3.597500921631678e+03 1.8e+01 1.17e-03  9e-05  1e-03 0:03.1
#   189   1890 -3.597681029545296e+03 8.0e+02 7.90e-05  2e-07  1e-04 0:07.1
#   200   2000 -3.597681304040906e+03 1.3e+03 4.23e-05  6e-08  6e-05 0:07.6
# NOTE (module=cma, iteration=251):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.9e+08 to 9.8e+01
#   300   3000 -3.597681382974064e+03 2.5e+01 2.01e-06  4e-11  4e-06 0:10.6
#   400   4000 -3.597681383045488e+03 9.0e+02 7.54e-08  3e-14  2e-07 0:13.6
#   405   4050 -3.597681383045503e+03 1.1e+03 5.73e-08  2e-14  1e-07 0:13.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:30:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.662904310720027e+03 1.0e+00 9.41e-02  9e-02  1e-01 0:00.0
#     2     20 -2.873692089771541e+03 1.2e+00 9.86e-02  1e-01  1e-01 0:00.0
#     3     30 -2.939568609224630e+03 1.3e+00 1.14e-01  1e-01  1e-01 0:00.1
#   100   1000 -3.225175147034451e+03 3.6e+00 7.36e-02  3e-02  6e-02 0:02.4
#   200   2000 -3.752573153115941e+03 1.1e+01 2.30e-03  2e-04  2e-03 0:05.7
#   300   3000 -3.752952076986172e+03 2.2e+02 1.51e-04  7e-07  1e-04 0:08.9
#   400   4000 -3.752957245335532e+03 1.7e+03 4.23e-06  3e-09  3e-06 0:12.4
# NOTE (module=cma, iteration=461):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.3e+08 to 6.3e+02
#   500   5000 -3.752957261716982e+03 2.8e+01 4.11e-07  3e-11  6e-07 0:15.7
#   600   6000 -3.752957261916732e+03 2.2e+02 6.37e-09  4e-14  2e-08 0:19.1
#   623   6230 -3.752957261916917e+03 2.6e+02 3.82e-09  2e-14  1e-08 0:19.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:30:30 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.832697475275387e+03 1.0e+00 1.04e-01  1e-01  1e-01 0:00.0
#     2     20 -2.884803927832624e+03 1.2e+00 1.06e-01  1e-01  1e-01 0:00.0
#     3     30 -2.952242760366312e+03 1.3e+00 1.11e-01  1e-01  1e-01 0:00.1
#   100   1000 -3.457503995220181e+03 1.1e+01 6.24e-03  1e-03  8e-03 0:02.9
#   200   2000 -3.458947184830715e+03 2.2e+02 8.39e-05  7e-07  2e-04 0:06.0
#   300   3000 -3.458952784523997e+03 3.4e+03 3.38e-06  3e-09  9e-06 0:09.1
# NOTE (module=cma, iteration=334):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.7e+01
#   400   4000 -3.458952801756352e+03 1.3e+01 6.13e-08  7e-12  2e-07 0:12.3
#   490   4900 -3.458952801800480e+03 9.4e+01 1.23e-09  2e-14  5e-09 0:15.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:30:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.670000000000000e+03 1.0e+00 1.04e-02  1e-02  1e-02 0:00.0
#     2     20 -1.724704398392984e+03 1.2e+00 1.01e-02  9e-03  1e-02 0:00.0
#     3     30 -1.738562233378469e+03 1.4e+00 9.58e-03  9e-03  1e-02 0:00.1
#   100   1000 -2.409320149983379e+03 9.3e+01 1.18e-03  6e-05  2e-03 0:02.5
#   200   2000 -2.409335390559366e+03 3.8e+03 2.05e-04  4e-07  7e-04 0:05.3
# NOTE (module=cma, iteration=244):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 5.6e+08 to 6.2e+02
#   300   3000 -2.409335427791429e+03 3.0e+01 4.54e-05  2e-09  2e-04 0:07.9
#   400   4000 -2.409335427939481e+03 1.4e+03 4.22e-06  8e-12  2e-05 0:10.5
# NOTE (module=cma, iteration=477):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 7.4e+08 to 4.2e+03
#   493   4930 -2.409335427940089e+03 7.4e+01 1.37e-07  1e-14  9e-07 0:12.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:30:59 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.994185015414313e+03 1.0e+00 2.03e-02  2e-02  2e-02 0:00.0
#     2     20 -2.072215333956652e+03 1.3e+00 1.97e-02  2e-02  2e-02 0:00.0
#     3     30 -2.116218512151164e+03 1.3e+00 1.96e-02  2e-02  2e-02 0:00.1
#   100   1000 -2.141554928909009e+03 1.3e+02 7.78e-04  1e-05  2e-03 0:02.5
#   200   2000 -2.141617360846021e+03 7.9e+03 2.50e-05  1e-08  6e-05 0:04.7
# NOTE (module=cma, iteration=214):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.1e+08 to 9.4e+01
#   300   3000 -2.141617373839796e+03 7.8e+01 1.23e-06  9e-12  4e-06 0:07.2
#   382   3820 -2.141617373860524e+03 2.7e+03 6.85e-08  2e-14  2e-07 0:09.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:31:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.588767584426922e+03 1.0e+00 3.33e-02  3e-02  3e-02 0:00.0
#     2     20 -2.648185707150797e+03 1.2e+00 3.72e-02  3e-02  4e-02 0:00.1
#     3     30 -3.058142190575830e+03 1.4e+00 4.10e-02  4e-02  5e-02 0:00.1
#    97    970 -3.812301273705484e+03 1.3e+01 7.46e-04  9e-05  9e-04 0:03.1
#   100   1000 -3.812992032383939e+03 1.3e+01 8.01e-04  9e-05  1e-03 0:03.2
#   200   2000 -3.813194652788311e+03 2.2e+02 2.02e-05  2e-07  5e-05 0:06.3
#   300   3000 -3.813195749905728e+03 2.5e+03 3.88e-07  5e-10  1e-06 0:09.8
# NOTE (module=cma, iteration=386):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.3e+08 to 2.1e+01
#   400   4000 -3.813195751730193e+03 5.7e+00 7.37e-09  1e-12  2e-08 0:12.9
#   463   4630 -3.813195751735220e+03 4.6e+01 2.70e-10  1e-14  1e-09 0:14.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:31:24 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.019209265983463e+03 1.0e+00 4.17e-02  4e-02  4e-02 0:00.0
#     2     20 -2.138830991019140e+03 1.2e+00 4.27e-02  4e-02  5e-02 0:00.0
#     3     30 -2.200761352732096e+03 1.4e+00 4.01e-02  4e-02  4e-02 0:00.1
#   100   1000 -2.576631822878581e+03 4.6e+01 7.96e-04  9e-05  1e-03 0:02.7
#   200   2000 -2.576672011222098e+03 4.8e+03 2.56e-04  1e-06  7e-04 0:05.3
# NOTE (module=cma, iteration=272):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 5.3e+09 to 5.5e+02
#   300   3000 -2.576672144913613e+03 3.1e+01 6.36e-05  1e-08  2e-04 0:07.9
#   400   4000 -2.576672146154800e+03 1.2e+03 7.48e-06  3e-11  2e-05 0:10.6
#   500   5000 -2.576672146160504e+03 7.9e+04 1.00e-06  1e-13  5e-06 0:13.3
# NOTE (module=cma, iteration=514):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.4e+10 to 6.6e+03
#   600   6000 -2.576672146160518e+03 1.4e+02 2.89e-06  7e-14  3e-05 0:16.2
#   671   6710 -2.576672146160518e+03 3.1e+02 5.30e-06  1e-14  5e-05 0:18.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:31:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.374198979760336e+03 1.0e+00 5.09e-02  5e-02  5e-02 0:00.0
#     2     20 -2.504033578078273e+03 1.2e+00 4.71e-02  4e-02  5e-02 0:00.0
#     3     30 -2.458708155075014e+03 1.2e+00 4.18e-02  4e-02  4e-02 0:00.1
#    99    990 -3.254491345814693e+03 1.6e+01 2.55e-03  3e-04  5e-03 0:03.1
#   100   1000 -3.256668025153383e+03 1.5e+01 2.38e-03  3e-04  4e-03 0:03.1
#   200   2000 -3.256859416732124e+03 1.0e+03 6.74e-04  2e-06  2e-03 0:06.2
# NOTE (module=cma, iteration=260):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.8e+08 to 1.7e+02
#   300   3000 -3.256860320419761e+03 1.0e+01 4.91e-05  4e-09  2e-04 0:09.2
#   400   4000 -3.256860323779778e+03 7.5e+02 1.32e-05  2e-11  8e-05 0:12.4
# NOTE (module=cma, iteration=466):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.9e+08 to 5.8e+02
#   500   5000 -3.256860323795159e+03 3.1e+01 7.10e-07  3e-14  9e-06 0:15.4
#   516   5160 -3.256860323795173e+03 3.6e+01 7.97e-07  2e-14  1e-05 0:15.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:32:00 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.905347224734264e+03 1.0e+00 5.76e-02  6e-02  6e-02 0:00.0
#     2     20 -2.092829794129630e+03 1.2e+00 5.45e-02  5e-02  6e-02 0:00.0
#     3     30 -2.093518179830712e+03 1.3e+00 5.21e-02  5e-02  6e-02 0:00.1
#    74    740 -3.474043459379009e+03 1.3e+01 2.07e-03  3e-04  3e-03 0:03.1
#   100   1000 -3.474590817314706e+03 5.4e+01 3.99e-04  2e-05  6e-04 0:04.1
#   200   2000 -3.474617357461264e+03 4.1e+03 1.76e-05  1e-08  4e-05 0:07.2
# NOTE (module=cma, iteration=235):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.5e+08 to 1.1e+02
#   300   3000 -3.474617373858318e+03 3.0e+01 8.21e-07  1e-11  2e-06 0:10.8
#   395   3950 -3.474617373860496e+03 1.8e+03 4.68e-08  2e-14  2e-07 0:14.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Tue Sep  6 14:32:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.214753048752440e+03 1.0e+00 7.17e-02  7e-02  8e-02 0:00.0
#     2     20 -2.367248628472225e+03 1.3e+00 7.88e-02  7e-02  9e-02 0:00.1
#     3     30 -2.495201070941096e+03 1.4e+00 8.42e-02  8e-02  1e-01 0:00.1

# %%
# %%time
n_starting_points = 30
maxits= 20000
# for maximum of 5. 
for i in df_all.keys():
    cma_region(new_ss_regions_10[i], n_starting_points, maxits, df_all[i], df_all[i], min_dist_dict[i])
# Out:
# (6_w,12)-aCMA-ES (mu_w=3.7,w_1=40%) in dimension 20 (seed=1234, Tue Sep  6 00:26:35 2022)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-406-9b4cd6d1e4e0> in cma_region(n, n_starting_points, max_iterations, data, data_sub, min_dict_dist, set_sigma)
#      48             es = cma.CMAEvolutionStrategy(generate_sp_proposed(sp, n).flatten(), sigma0=j,
#      49                                       inopts={'bounds': cma_bounds,'seed':1234})
# ---> 50             es.optimize(f, iterations=(max_iterations/ es.popsize))
#      51             fcma.append((es.result[1], es.result[0].reshape(n, 2), (time.time() - start_time), j))
#      52
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\interfaces.py in optimize(self, objective_fct, maxfun, iterations, min_iterations, args, verb_disp, callback, n_jobs, **kwargs)
#     206                 X = self.ask()  # deliver candidate solutions
#     207                 # fitvals = [objective_fct(x, *args) for x in X]
# --> 208                 fitvals = eval_all(X, args=args)
#     209                 cevals += len(fitvals)
#     210                 self.tell(X, fitvals)  # all the work is done here
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in __call__(self, solutions, fitness_function, args, timeout)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in <listcomp>(.0)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# <ipython-input-406-9b4cd6d1e4e0> in f(x)
#      29         """
#      30         x = x.reshape(n,2) # reshape for input into expected enrolment.
# ---> 31         ee = expected_enrollment(df_ms_loc_sub, x, df_ms_enrol_sub, current_ms_dist_sub, ee_old_constant) # fitness function.
#      32         return ee*-1 # Multiply by -1 for maximising.
#      33
#
# TypeError: expected_enrollment() missing 1 required positional argument: 'min_dict'

# %% [markdown]
# #### 7. Find best sigma values, run CMA-ES- 2 with only the best sigma values (maxits=30,000, n=5)

# %%
df_results = pd.read_csv('Results/results_test.csv') # read in cleaned dataset.
df_results5 = df_results[df_results['proposed_schools_n'] <= 5]
df_results5 = df_results5[df_results5['algorithm'] =='CMA-ES - 2']
bs = df_results5.groupby(['region', 'sigma'], sort=False)['ee'].max() 
bs = bs.groupby(['region']).head(1).reset_index(drop=False)
best_sigma = dict(zip(bs['region'], bs['sigma'])) # if more than 1 sigma value gets the best, it will choose just one.

# %%
best_sigma
# Out:
# {'Tigray': 0.575633926,
#  'Dire Dawa': 0.015484862,
#  'Amhara': 0.424346324,
#  'Oromia': 1.284014196,
#  'Somali': 0.180498131,
#  'Addis Ababa': 0.027203672,
#  'Harari': 0.009493837,
#  'SNNP': 0.375972752,
#  'Benishangul Gumz': 0.675717749}

# %%
# %%time
n_starting_points = 30
maxits= 40000
# for maximum of 5. 
for i in df_all.keys():
    cma_region(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], df_5[i], best_sigma[i])
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.1
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.10e-01  1e-01  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 1.66e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.21e-01  2e-01  2e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 2.76e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.31e-01  3e-01  3e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 3.86e-01  4e-01  4e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 4.41e-01  4e-01  5e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.217110000000000e+05 1.0e+00 4.96e-01  5e-01  5e-01 0:00.0
#     2     20 -1.214210000000000e+05 1.2e+00 4.79e-01  5e-01  5e-01 0:00.0
#     3     30 -1.214210000000000e+05 1.3e+00 4.55e-01  4e-01  5e-01 0:00.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-01  5e-01  6e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.214210000000000e+05 1.0e+00 5.52e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:50:14 2022)
# ...
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 8.45e-02  8e-02  9e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-02  9e-02  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-03  9e-03  1e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 1.88e-02  2e-02  2e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 2.82e-02  3e-02  3e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 3.76e-02  4e-02  4e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 4.69e-02  5e-02  5e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 5.63e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 6.57e-02  6e-02  7e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 7.51e-02  7e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 8.45e-02  8e-02  9e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:44 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-02  9e-02  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-03  9e-03  1e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 1.88e-02  2e-02  2e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 2.82e-02  3e-02  3e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 3.76e-02  4e-02  4e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 4.69e-02  5e-02  5e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 5.63e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 6.57e-02  6e-02  7e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 7.51e-02  7e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 8.45e-02  8e-02  9e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-02  9e-02  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-03  9e-03  1e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 1.88e-02  2e-02  2e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 2.82e-02  3e-02  3e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 3.76e-02  4e-02  4e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 4.69e-02  5e-02  5e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 5.63e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 6.57e-02  6e-02  7e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 7.51e-02  7e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 8.45e-02  8e-02  9e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-02  9e-02  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-03  9e-03  1e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 1.88e-02  2e-02  2e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 2.82e-02  3e-02  3e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 3.76e-02  4e-02  4e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 4.69e-02  5e-02  5e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 5.63e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 6.57e-02  6e-02  7e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 7.51e-02  7e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 8.45e-02  8e-02  9e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-02  9e-02  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-03  9e-03  1e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 1.88e-02  2e-02  2e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 2.82e-02  3e-02  3e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 3.76e-02  4e-02  4e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 4.69e-02  5e-02  5e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 5.63e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 6.57e-02  6e-02  7e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 7.51e-02  7e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 8.45e-02  8e-02  9e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-02  9e-02  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-03  9e-03  1e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 1.88e-02  2e-02  2e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 2.82e-02  3e-02  3e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 3.76e-02  4e-02  4e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 4.69e-02  5e-02  5e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 5.63e-02  5e-02  6e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 6.57e-02  6e-02  7e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 7.51e-02  7e-02  8e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 8.45e-02  8e-02  9e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-02  9e-02  1e-01 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 9.39e-03  9e-03  1e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 1.88e-02  2e-02  2e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 2.82e-02  3e-02  3e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 3.76e-02  4e-02  4e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 4.69e-02  5e-02  5e-02 0:00.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Tue Sep  6 14:52:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -6.616600000000000e+04 1.0e+00 5.63e-02  5e-02  6e-02 0:00.0

# %%
# %%time
n_starting_points = 30
maxits= 40000
# for maximum of 5. 
for i in df_all.keys():
    cma_region(new_ss_regions_10[i], n_starting_points, maxits, df_all[i], df_10[i], best_sigma[i])

# %% [markdown]
# #### 8. Find best sigma values, run CMA-ES- 1 with only the best sigma values (maxits=30,000, n=5)

# %%
# %%time
n_starting_points = 30
maxits= 30000
# for maximum of 5. 
for i in df_all.keys():
    cma_region(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], df_all[i], best_sigma[i])
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:07:31 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221079148561853e+05 1.0e+00 5.42e-01  5e-01  6e-01 0:00.0
#     2     20 -1.222104519176451e+05 1.2e+00 5.34e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223276601525485e+05 1.2e+00 5.22e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.237086753310066e+05 7.5e+00 1.20e-02  3e-03  1e-02 0:02.3
#   200   2000 -1.238407353302864e+05 2.9e+01 3.13e-04  2e-05  4e-04 0:05.0
#   300   3000 -1.238411621531468e+05 2.0e+02 2.11e-05  2e-07  3e-05 0:07.7
#   400   4000 -1.238412524760204e+05 8.5e+02 8.97e-06  5e-08  2e-05 0:10.7
#   500   5000 -1.238412529723470e+05 5.2e+03 2.26e-07  3e-10  5e-07 0:13.7
# NOTE (module=cma, iteration=569):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 7.4e+08 to 1.0e+05
#   600   6000 -1.238412529809417e+05 6.0e+02 8.13e-08  2e-11  4e-07 0:16.6
#   700   7000 -1.238412529817397e+05 3.5e+03 4.77e-09  3e-13  4e-08 0:19.9
#   800   8000 -1.238412529817457e+05 6.9e+03 4.09e-10  1e-14  3e-09 0:22.9
#   900   9000 -1.238412529817459e+05 1.4e+04 7.64e-10  1e-14  5e-09 0:26.4
#   911   9110 -1.238412529817460e+05 1.7e+04 6.77e-10  8e-15  5e-09 0:26.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:07:59 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222376382706250e+05 1.0e+00 5.27e-01  5e-01  5e-01 0:00.0
#     2     20 -1.223848570039976e+05 1.2e+00 4.86e-01  5e-01  5e-01 0:00.0
#     3     30 -1.221593192439421e+05 1.2e+00 4.50e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.243357542407196e+05 4.9e+00 1.86e-02  6e-03  2e-02 0:02.7
#   200   2000 -1.245579061101252e+05 2.9e+01 2.70e-04  1e-05  3e-04 0:06.5
#   300   3000 -1.245581664638193e+05 2.7e+02 1.90e-05  3e-07  3e-05 0:10.0
#   400   4000 -1.245581909108784e+05 1.3e+03 5.85e-06  4e-08  9e-06 0:13.3
#   500   5000 -1.245581910341196e+05 8.9e+03 1.14e-07  4e-10  2e-07 0:17.3
#   600   6000 -1.245581910355455e+05 7.2e+04 4.50e-08  2e-11  1e-07 0:20.5
# NOTE (module=cma, iteration=650):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 5.5e+10 to 1.2e+09
#   700   7000 -1.245581910355980e+05 6.5e+04 1.78e-09  2e-13  5e-09 0:23.7
#   710   7100 -1.245581910355983e+05 7.8e+04 1.41e-09  2e-13  4e-09 0:24.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:08:24 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221856730671486e+05 1.0e+00 5.50e-01  5e-01  6e-01 0:00.0
#     2     20 -1.220662044671324e+05 1.2e+00 5.49e-01  5e-01  6e-01 0:00.1
#     3     30 -1.222845619915608e+05 1.3e+00 4.96e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.249097633685189e+05 4.7e+00 1.63e-01  8e-02  2e-01 0:02.5
#   200   2000 -1.255036051683804e+05 7.0e+00 2.16e-03  3e-04  2e-03 0:05.7
#   300   3000 -1.255062382270477e+05 8.2e+01 1.48e-04  3e-06  1e-04 0:09.1
#   400   4000 -1.255062486297012e+05 9.6e+02 1.55e-04  3e-06  1e-04 0:12.5
#   500   5000 -1.255062531345319e+05 6.7e+03 3.21e-06  4e-08  3e-06 0:15.8
#   600   6000 -1.255062531425759e+05 6.6e+04 6.84e-07  8e-09  8e-07 0:19.1
#   700   7000 -1.255062531428664e+05 7.5e+05 1.77e-07  2e-09  3e-07 0:22.4
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.0e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=721)
#   warnings.warn(msg + ' (' +
#   800   8000 -1.255062531425212e+05 3.7e+00 7.85e-08  6e-08  9e-08 0:25.8
#   885   8850 -1.255062531426761e+05 9.3e+00 4.86e-08  3e-08  7e-08 0:28.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:08:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221350841040355e+05 1.0e+00 5.64e-01  5e-01  6e-01 0:00.0
#     2     20 -1.219170919063590e+05 1.2e+00 5.06e-01  5e-01  5e-01 0:00.0
#     3     30 -1.225074110299667e+05 1.2e+00 4.95e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.242895589649241e+05 4.6e+00 8.90e-02  5e-02  1e-01 0:02.5
#   186   1860 -1.281161888413395e+05 6.2e+00 2.93e-03  4e-04  2e-03 0:06.5
#   200   2000 -1.281308624673405e+05 7.5e+00 1.28e-03  2e-04  7e-04 0:07.3
#   300   3000 -1.281396924425624e+05 3.1e+01 1.05e-04  8e-06  8e-05 0:12.5
#   400   4000 -1.281398896427370e+05 2.3e+02 6.40e-06  2e-07  8e-06 0:17.7
#   500   5000 -1.281398957527921e+05 6.0e+02 3.17e-06  6e-08  5e-06 0:22.9
#   600   6000 -1.281398996616367e+05 2.5e+03 2.46e-07  2e-09  6e-07 0:28.1
#   700   7000 -1.281398996794680e+05 1.5e+04 5.88e-08  1e-10  4e-07 0:33.4
#   800   8000 -1.281398997750740e+05 1.2e+04 3.59e-07  3e-10  1e-06 0:38.6
#   900   9000 -1.281398997847376e+05 3.4e+04 2.81e-08  2e-11  1e-07 0:43.8
# NOTE (module=cma, iteration=998):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 6.4e+09 to 5.7e+09
#  1000  10000 -1.281398997849239e+05 7.5e+04 3.83e-10  1e-13  1e-09 0:49.0
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1010  10100 -1.281398997849244e+05 6.6e+04 2.19e-10  5e-14  5e-10 0:49.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:09:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.238673278542457e+05 1.0e+00 5.28e-01  5e-01  5e-01 0:00.0
#     2     20 -1.221497069690608e+05 1.2e+00 5.01e-01  5e-01  5e-01 0:00.0
#     3     30 -1.220809603255214e+05 1.2e+00 4.78e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.236317795974695e+05 3.2e+00 1.28e-02  5e-03  1e-02 0:02.4
#   200   2000 -1.236916633028379e+05 3.5e+01 1.14e-03  2e-04  1e-03 0:05.2
#   300   3000 -1.236916829872762e+05 1.7e+03 1.25e-04  7e-06  1e-04 0:08.1
#   400   4000 -1.236916830171079e+05 9.7e+04 2.41e-05  4e-07  3e-05 0:10.9
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.2e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=456)
#   warnings.warn(msg + ' (' +
#   500   5000 -1.236916830171424e+05 1.1e+01 3.71e-05  2e-05  6e-05 0:13.7
#   600   6000 -1.236916830171529e+05 4.1e+01 9.30e-06  3e-06  1e-05 0:16.5
#   700   7000 -1.236916830171505e+05 6.1e+01 3.43e-06  9e-07  4e-06 0:19.3
#   800   8000 -1.236916830171499e+05 2.4e+02 5.28e-06  3e-06  1e-05 0:22.1
#   850   8500 -1.236916830171539e+05 4.8e+02 3.26e-06  2e-06  1e-05 0:23.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:10:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221786394657239e+05 1.0e+00 5.89e-01  6e-01  6e-01 0:00.0
#     2     20 -1.230173558358760e+05 1.2e+00 5.96e-01  6e-01  6e-01 0:00.0
#     3     30 -1.227752107655398e+05 1.3e+00 6.32e-01  6e-01  7e-01 0:00.1
#   100   1000 -1.242528614505829e+05 9.3e+00 9.67e-02  3e-02  1e-01 0:02.4
#   200   2000 -1.270725905230021e+05 7.6e+00 4.98e-03  7e-04  3e-03 0:06.0
#   300   3000 -1.270824358833328e+05 5.3e+01 3.41e-04  1e-05  4e-04 0:09.9
#   400   4000 -1.270827428432987e+05 3.4e+02 3.61e-05  3e-07  5e-05 0:14.1
#   500   5000 -1.270827439887951e+05 2.1e+03 6.58e-06  1e-08  1e-05 0:18.1
#   600   6000 -1.270827440624702e+05 1.3e+04 2.56e-07  8e-11  5e-07 0:22.0
# NOTE (module=cma, iteration=627):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.5e+08 to 2.0e+07
#   700   7000 -1.270827440632676e+05 2.4e+04 1.67e-08  9e-13  4e-08 0:26.0
#   799   7990 -1.270827440632757e+05 2.0e+05 1.35e-09  1e-14  6e-09 0:29.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:10:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220020000000000e+05 1.0e+00 5.22e-01  5e-01  5e-01 0:00.0
#     2     20 -1.220482480729748e+05 1.1e+00 5.14e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223517097059696e+05 1.2e+00 5.00e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.248048826985271e+05 5.4e+00 2.39e-01  1e-01  3e-01 0:02.6
#   197   1970 -1.267607472876489e+05 6.2e+00 1.48e-02  3e-03  1e-02 0:06.6
#   200   2000 -1.267531198452716e+05 5.9e+00 1.25e-02  2e-03  9e-03 0:06.8
#   233   2330 -1.268127550587910e+05 4.6e+00 3.82e-03  8e-04  2e-03 0:08.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:10:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221390970719806e+05 1.0e+00 5.58e-01  5e-01  6e-01 0:00.0
#     2     20 -1.222082053838683e+05 1.2e+00 5.28e-01  5e-01  6e-01 0:00.1
#     3     30 -1.238982441942593e+05 1.2e+00 5.34e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.230556497715609e+05 4.6e+00 1.24e-01  6e-02  1e-01 0:03.0
#   200   2000 -1.237305573850443e+05 8.3e+00 7.42e-03  1e-03  8e-03 0:06.1
#   300   3000 -1.237496094801916e+05 5.1e+01 1.19e-04  3e-06  1e-04 0:09.2
#   400   4000 -1.237497228061314e+05 4.2e+02 4.98e-05  6e-07  7e-05 0:12.3
#   500   5000 -1.237497289240979e+05 2.8e+03 1.78e-06  3e-09  3e-06 0:15.6
#   600   6000 -1.237497289424678e+05 3.5e+04 6.06e-08  2e-11  2e-07 0:18.7
# NOTE (module=cma, iteration=616):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.9e+09 to 7.7e+07
#   700   7000 -1.237497289425968e+05 6.7e+04 4.05e-09  2e-13  2e-08 0:22.0
#   800   8000 -1.237497289426000e+05 6.4e+05 2.65e-09  3e-14  1e-08 0:25.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:11:17 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.231201464719874e+05 1.0e+00 5.49e-01  5e-01  6e-01 0:00.0
#     2     20 -1.223576538505325e+05 1.2e+00 5.38e-01  5e-01  6e-01 0:00.1
#     3     30 -1.230669127872736e+05 1.3e+00 5.59e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.223487223766189e+05 4.1e+00 1.23e+00  7e-01  2e+00 0:02.2
#   200   2000 -1.240782333395477e+05 1.2e+01 1.87e-01  8e-02  3e-01 0:04.6
#   300   3000 -1.281233103170249e+05 1.2e+01 1.72e-02  2e-03  1e-02 0:08.6
#   400   4000 -1.282064543489972e+05 1.2e+02 1.70e-03  5e-05  2e-03 0:13.8
#   500   5000 -1.282070915376498e+05 3.4e+02 2.47e-05  3e-07  3e-05 0:19.1
#   600   6000 -1.282071018725846e+05 2.0e+03 9.45e-05  3e-07  2e-04 0:24.1
#   700   7000 -1.282071076459276e+05 3.9e+03 3.01e-06  3e-09  4e-06 0:29.0
#   800   8000 -1.282071076650969e+05 1.9e+04 2.35e-07  6e-11  4e-07 0:34.0
# NOTE (module=cma, iteration=805):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 7.6e+08 to 1.7e+07
#   900   9000 -1.282071076667306e+05 3.7e+04 2.86e-08  2e-12  1e-07 0:38.9
#   980   9800 -1.282071076667428e+05 7.9e+04 1.14e-09  3e-14  4e-09 0:43.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:12:02 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221151285390132e+05 1.0e+00 5.21e-01  5e-01  5e-01 0:00.0
#     2     20 -1.223916477707341e+05 1.2e+00 4.95e-01  5e-01  5e-01 0:00.1
#     3     30 -1.223003935209542e+05 1.2e+00 4.84e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.276301465613111e+05 4.9e+00 5.37e-02  2e-02  6e-02 0:02.9
#   171   1710 -1.284784741395752e+05 1.2e+01 3.40e-03  4e-04  3e-03 0:06.9
#   200   2000 -1.285005088506144e+05 2.3e+01 1.73e-03  2e-04  2e-03 0:08.3
#   300   3000 -1.285045668220706e+05 1.5e+02 3.65e-04  1e-05  5e-04 0:13.7
#   400   4000 -1.285046816888881e+05 7.5e+02 1.58e-05  1e-07  3e-05 0:19.2
#   500   5000 -1.285046830276305e+05 3.3e+03 9.45e-06  2e-08  2e-05 0:23.9
#   600   6000 -1.285046831644190e+05 2.3e+04 2.73e-07  1e-10  5e-07 0:28.5
# NOTE (module=cma, iteration=648):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.9e+09 to 3.4e+08
#   700   7000 -1.285046831651509e+05 5.9e+04 1.02e-07  9e-12  3e-07 0:33.2
#   800   8000 -1.285046831652025e+05 3.9e+05 8.49e-09  1e-13  4e-08 0:37.9
#   830   8300 -1.285046831652029e+05 6.9e+05 3.39e-09  3e-14  2e-08 0:39.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:12:43 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.226135930375922e+05 1.0e+00 5.40e-01  5e-01  5e-01 0:00.0
#     2     20 -1.221022650515008e+05 1.2e+00 4.80e-01  5e-01  5e-01 0:00.0
#     3     30 -1.221953046871245e+05 1.2e+00 4.63e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.241123671779851e+05 3.9e+00 8.33e-03  3e-03  8e-03 0:02.9
#   200   2000 -1.241297837133790e+05 3.4e+01 2.10e-04  2e-05  2e-04 0:06.4
#   300   3000 -1.241298217650954e+05 3.5e+02 5.49e-06  6e-08  5e-06 0:09.8
#   400   4000 -1.241298219061395e+05 5.6e+03 5.72e-07  7e-10  6e-07 0:13.3
# NOTE (module=cma, iteration=492):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.1e+09 to 3.0e+08
#   500   5000 -1.241298219067750e+05 2.0e+04 3.56e-08  5e-12  5e-08 0:16.8
#   600   6000 -1.241298219067883e+05 2.3e+05 2.76e-09  4e-14  4e-09 0:20.4
#   643   6430 -1.241298219067883e+05 4.0e+05 2.28e-09  2e-14  4e-09 0:21.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:13:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.218515270995629e+05 1.0e+00 4.88e-01  5e-01  5e-01 0:00.0
#     2     20 -1.220962810805684e+05 1.2e+00 4.43e-01  4e-01  5e-01 0:00.0
#     3     30 -1.238356051921176e+05 1.2e+00 4.27e-01  4e-01  4e-01 0:00.1
#   100   1000 -1.244075243029475e+05 5.0e+00 1.09e-01  4e-02  1e-01 0:02.3
#   200   2000 -1.262418662236884e+05 8.9e+00 2.00e-03  4e-04  2e-03 0:05.7
#   300   3000 -1.262456917976541e+05 6.2e+01 1.20e-04  3e-06  1e-04 0:09.4
#   400   4000 -1.262457130712396e+05 3.1e+02 9.75e-06  7e-08  1e-05 0:13.1
#   500   5000 -1.262457173205943e+05 1.9e+03 9.36e-06  2e-08  2e-05 0:16.8
#   600   6000 -1.262457175927964e+05 1.1e+04 4.65e-07  2e-10  1e-06 0:20.5
# NOTE (module=cma, iteration=627):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.5e+08 to 1.1e+07
#   700   7000 -1.262457175953648e+05 2.4e+04 4.01e-08  4e-12  2e-07 0:24.3
#   800   8000 -1.262457175954124e+05 1.9e+05 2.79e-09  7e-14  3e-08 0:28.0
#   849   8490 -1.262457175954142e+05 3.6e+05 1.15e-09  2e-14  1e-08 0:29.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:13:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.224168100747763e+05 1.0e+00 5.61e-01  6e-01  6e-01 0:00.0
#     2     20 -1.222331164425004e+05 1.2e+00 5.19e-01  5e-01  6e-01 0:00.1
#     3     30 -1.224614459209046e+05 1.3e+00 4.96e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.251834014048470e+05 5.2e+00 3.43e-02  1e-02  4e-02 0:02.5
#   200   2000 -1.257457584686308e+05 3.0e+01 1.12e-03  6e-05  2e-03 0:05.6
#   300   3000 -1.257472722815357e+05 2.4e+02 6.01e-05  5e-07  9e-05 0:08.6
#   400   4000 -1.257474653366181e+05 2.4e+03 6.59e-05  2e-07  2e-04 0:11.7
#   500   5000 -1.257474670704969e+05 2.2e+04 3.88e-06  1e-08  1e-05 0:14.9
#   600   6000 -1.257474670848968e+05 2.5e+05 2.76e-07  9e-10  9e-07 0:18.1
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=654)
#   warnings.warn(msg + ' (' +
#   700   7000 -1.257474670849684e+05 3.4e+00 7.28e-08  4e-08  9e-08 0:21.2
#   800   8000 -1.257474670849689e+05 1.2e+01 2.40e-08  7e-09  4e-08 0:24.4
#   900   9000 -1.257474670849681e+05 1.3e+01 5.82e-08  2e-08  9e-08 0:27.4
#  1000  10000 -1.257474670849696e+05 2.4e+01 2.74e-08  6e-09  4e-08 0:30.6
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1090  10900 -1.257474670849656e+05 5.0e+01 2.67e-08  6e-09  4e-08 0:33.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:14:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.237067546589278e+05 1.0e+00 5.15e-01  5e-01  5e-01 0:00.0
#     2     20 -1.220732954213705e+05 1.2e+00 4.90e-01  5e-01  5e-01 0:00.1
#     3     30 -1.221277895530439e+05 1.2e+00 5.06e-01  5e-01  6e-01 0:00.1
#    97    970 -1.284548605365226e+05 4.9e+00 2.42e-02  7e-03  3e-02 0:03.1
#   100   1000 -1.285839423135352e+05 4.9e+00 2.73e-02  8e-03  3e-02 0:03.3
#   190   1900 -1.291573373776516e+05 2.6e+01 5.35e-04  4e-05  5e-04 0:08.3
#   200   2000 -1.291577739095486e+05 2.8e+01 3.38e-04  3e-05  3e-04 0:08.9
#   300   3000 -1.291582125760243e+05 6.8e+01 1.34e-06  6e-08  1e-06 0:14.6
#   400   4000 -1.291582129449643e+05 2.5e+02 2.83e-08  3e-10  3e-08 0:20.4
#   500   5000 -1.291582129466016e+05 1.5e+03 5.58e-10  2e-12  9e-10 0:26.4
#   600   6000 -1.291582129466161e+05 4.8e+03 2.56e-11  3e-14  4e-11 0:32.6
#   610   6100 -1.291582129466161e+05 5.6e+03 2.09e-11  2e-14  4e-11 0:33.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:14:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.219044031583876e+05 1.0e+00 5.28e-01  5e-01  5e-01 0:00.0
#     2     20 -1.219569090285459e+05 1.2e+00 4.95e-01  5e-01  5e-01 0:00.0
#     3     30 -1.219791397950378e+05 1.2e+00 4.78e-01  4e-01  5e-01 0:00.1
#    99    990 -1.236947660043164e+05 6.0e+00 7.30e-02  2e-02  1e-01 0:03.1
#   100   1000 -1.233426357828452e+05 5.9e+00 7.30e-02  2e-02  9e-02 0:03.1
#   200   2000 -1.241001404900195e+05 2.0e+01 1.09e-03  1e-04  1e-03 0:06.8
#   300   3000 -1.241027076196643e+05 8.1e+01 1.99e-05  5e-07  2e-05 0:11.0
#   400   4000 -1.241027333906768e+05 3.9e+02 5.40e-06  4e-08  7e-06 0:15.7
#   500   5000 -1.241027345064941e+05 2.4e+03 9.08e-07  2e-09  1e-06 0:19.5
# NOTE (module=cma, iteration=582):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 5.5e+08 to 5.5e+07
#   600   6000 -1.241027345456796e+05 1.2e+04 1.71e-07  4e-11  7e-07 0:23.6
#   700   7000 -1.241027345464569e+05 1.1e+05 8.06e-09  5e-13  4e-08 0:27.1
#   800   8000 -1.241027345464670e+05 5.5e+05 2.49e-09  3e-14  2e-08 0:31.0
#   810   8100 -1.241027345464670e+05 5.9e+05 2.04e-09  2e-14  2e-08 0:31.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:15:19 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.227032251469842e+05 1.0e+00 5.85e-01  6e-01  6e-01 0:00.0
#     2     20 -1.238314486436918e+05 1.3e+00 6.05e-01  6e-01  7e-01 0:00.0
#     3     30 -1.219958528161268e+05 1.3e+00 6.17e-01  6e-01  7e-01 0:00.1
#   100   1000 -1.228332115948583e+05 4.5e+00 2.19e-01  1e-01  3e-01 0:02.3
#   200   2000 -1.259634106739128e+05 5.7e+00 5.22e-02  1e-02  3e-02 0:05.6
#   300   3000 -1.268936893975353e+05 5.2e+00 1.41e-03  1e-04  6e-04 0:09.0
#   400   4000 -1.268958188932194e+05 6.4e+01 5.28e-05  8e-07  4e-05 0:12.5
#   500   5000 -1.268958397889302e+05 6.5e+02 2.06e-05  1e-07  3e-05 0:16.0
#   600   6000 -1.268958554577484e+05 7.4e+02 5.97e-06  3e-08  3e-06 0:19.6
#   700   7000 -1.268958672726921e+05 1.4e+03 1.62e-05  5e-08  1e-05 0:23.2
#   800   8000 -1.268958674759797e+05 6.7e+03 3.20e-07  2e-10  2e-07 0:27.0
# NOTE (module=cma, iteration=889):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.7e+09 to 3.1e+08
#   900   9000 -1.268958674791555e+05 2.2e+04 2.81e-07  5e-11  5e-07 0:30.8
#  1000  10000 -1.268958674802163e+05 9.5e+04 2.03e-07  9e-12  3e-07 0:35.4
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -1.268958674802824e+05 2.6e+05 4.34e-09  6e-14  5e-09 0:39.4
#  1101  11010 -1.268958674802824e+05 2.5e+05 4.36e-09  6e-14  5e-09 0:39.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:16:00 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.246748201026838e+05 1.0e+00 5.48e-01  5e-01  6e-01 0:00.0
#     2     20 -1.226925957004244e+05 1.2e+00 5.32e-01  5e-01  6e-01 0:00.0
#     3     30 -1.223753254950768e+05 1.2e+00 5.29e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.252976632871180e+05 5.9e+00 8.91e-02  3e-02  1e-01 0:02.7
#   151   1510 -1.260624988435330e+05 5.3e+00 1.06e-02  3e-03  9e-03 0:05.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:16:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220031738951106e+05 1.0e+00 5.30e-01  5e-01  5e-01 0:00.0
#     2     20 -1.223216419105499e+05 1.2e+00 5.31e-01  5e-01  5e-01 0:00.0
#     3     30 -1.220948737068421e+05 1.2e+00 5.42e-01  5e-01  6e-01 0:00.1
#    93    930 -1.237422475326216e+05 4.3e+00 1.72e-02  7e-03  2e-02 0:03.1
#   100   1000 -1.237806689941604e+05 5.0e+00 1.38e-02  5e-03  2e-02 0:03.3
#   200   2000 -1.238747634095770e+05 1.4e+01 4.67e-04  5e-05  5e-04 0:06.6
#   300   3000 -1.238749664651730e+05 1.1e+02 1.01e-05  4e-07  1e-05 0:09.6
#   400   4000 -1.238749684158419e+05 8.9e+02 4.95e-06  4e-08  8e-06 0:12.6
#   500   5000 -1.238749685910955e+05 2.7e+03 5.55e-07  1e-09  8e-07 0:15.7
#   600   6000 -1.238749685938413e+05 1.9e+04 2.63e-08  1e-11  4e-08 0:18.6
# NOTE (module=cma, iteration=639):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.0e+09 to 6.0e+08
#   700   7000 -1.238749685938741e+05 9.8e+04 1.49e-09  1e-13  4e-09 0:21.5
#   800   8000 -1.238749685938758e+05 4.2e+05 2.21e-09  5e-14  8e-09 0:24.6
#   840   8400 -1.238749685938759e+05 5.2e+05 1.06e-09  2e-14  3e-09 0:25.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:16:33 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.223205533102529e+05 1.0e+00 5.02e-01  5e-01  5e-01 0:00.0
#     2     20 -1.224353226758349e+05 1.1e+00 4.91e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223165504707003e+05 1.2e+00 4.58e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.230694505923204e+05 3.6e+00 1.53e-01  7e-02  2e-01 0:02.6
#   200   2000 -1.247371579586589e+05 4.3e+00 4.06e-03  7e-04  2e-03 0:05.8
#   300   3000 -1.247732173334294e+05 1.6e+01 1.13e-04  4e-06  5e-05 0:09.6
#   400   4000 -1.247732991663674e+05 7.8e+01 1.41e-06  2e-08  9e-07 0:12.8
#   500   5000 -1.247733039887364e+05 6.2e+02 6.09e-06  5e-08  9e-06 0:16.4
#   600   6000 -1.247733070069132e+05 2.2e+03 8.17e-07  2e-09  9e-07 0:19.8
#   700   7000 -1.247733070844416e+05 1.1e+04 1.08e-07  6e-11  1e-07 0:23.2
# NOTE (module=cma, iteration=778):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.8e+09 to 1.8e+08
#   800   8000 -1.247733070854650e+05 2.1e+04 1.35e-07  2e-11  3e-07 0:26.4
#   900   9000 -1.247733070859119e+05 7.7e+04 4.88e-09  2e-13  7e-09 0:29.7
#   940   9400 -1.247733070859129e+05 2.5e+05 1.27e-09  3e-14  2e-09 0:31.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:17:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.224317852008905e+05 1.0e+00 5.24e-01  5e-01  5e-01 0:00.0
#     2     20 -1.227735638652226e+05 1.1e+00 4.51e-01  4e-01  5e-01 0:00.0
#     3     30 -1.227867935871619e+05 1.2e+00 4.41e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.251462587300613e+05 5.3e+00 1.55e-02  5e-03  2e-02 0:02.6
#   200   2000 -1.252134678135759e+05 4.2e+01 4.69e-04  6e-05  5e-04 0:05.6
#   300   3000 -1.252135664669829e+05 6.1e+02 6.15e-05  1e-05  7e-05 0:08.6
#   400   4000 -1.252135667698108e+05 1.2e+04 5.73e-06  7e-07  9e-06 0:11.8
#   500   5000 -1.252135667721564e+05 1.6e+05 1.21e-06  1e-07  2e-06 0:15.1
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.0e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=564)
#   warnings.warn(msg + ' (' +
#   600   6000 -1.252135667719449e+05 2.6e+00 1.93e-07  2e-07  2e-07 0:18.4
#   700   7000 -1.252135667720361e+05 1.5e+01 2.04e-07  1e-07  4e-07 0:21.5
#   745   7450 -1.252135667720549e+05 2.1e+01 5.18e-07  2e-07  1e-06 0:22.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:17:29 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221598438662863e+05 1.0e+00 5.33e-01  5e-01  5e-01 0:00.0
#     2     20 -1.222584405242939e+05 1.2e+00 5.08e-01  5e-01  5e-01 0:00.1
#     3     30 -1.220408048009634e+05 1.2e+00 5.09e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.238408442843155e+05 4.0e+00 1.49e-01  7e-02  1e-01 0:02.6
#   200   2000 -1.250750982069483e+05 6.9e+00 5.42e-03  9e-04  5e-03 0:05.5
#   300   3000 -1.250766573241230e+05 4.2e+01 1.78e-04  6e-06  1e-04 0:08.6
#   400   4000 -1.250766613912138e+05 2.5e+02 1.55e-05  1e-07  1e-05 0:12.1
#   500   5000 -1.250766615089165e+05 1.5e+03 1.03e-06  1e-09  6e-07 0:15.6
#   600   6000 -1.250766615105126e+05 1.1e+04 9.72e-08  2e-11  6e-08 0:18.9
# NOTE (module=cma, iteration=656):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.3e+09 to 2.8e+08
#   700   7000 -1.250766615105362e+05 5.0e+04 3.28e-09  7e-14  2e-09 0:22.0
#   720   7200 -1.250766615105362e+05 9.1e+04 1.85e-09  3e-14  2e-09 0:22.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:17:53 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222557513725670e+05 1.0e+00 5.49e-01  5e-01  6e-01 0:00.0
#     2     20 -1.231719723545968e+05 1.2e+00 5.39e-01  5e-01  6e-01 0:00.0
#     3     30 -1.220808963297287e+05 1.3e+00 5.16e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.230173199828777e+05 4.7e+00 1.91e-01  1e-01  2e-01 0:02.5
#   200   2000 -1.261440247874211e+05 4.9e+00 4.35e-02  1e-02  4e-02 0:05.5
#   300   3000 -1.265879956705949e+05 9.6e+00 1.06e-03  1e-04  6e-04 0:09.3
#   400   4000 -1.265906407089297e+05 7.7e+01 3.46e-04  1e-05  3e-04 0:12.8
#   500   5000 -1.265908486396249e+05 4.0e+02 7.26e-05  6e-07  7e-05 0:16.3
#   600   6000 -1.265908536969996e+05 2.7e+03 2.06e-06  3e-09  3e-06 0:20.1
#   700   7000 -1.265908537218787e+05 2.5e+04 2.10e-07  5e-11  5e-07 0:23.8
# NOTE (module=cma, iteration=707):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 7.9e+08 to 1.0e+08
#   800   8000 -1.265908537224551e+05 7.7e+04 2.96e-08  1e-12  1e-07 0:27.6
#   888   8880 -1.265908537224604e+05 3.7e+05 1.62e-09  2e-14  7e-09 0:31.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:18:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221652515874287e+05 1.0e+00 5.26e-01  5e-01  5e-01 0:00.0
#     2     20 -1.223203584031455e+05 1.2e+00 4.70e-01  4e-01  5e-01 0:00.0
#     3     30 -1.223018904791391e+05 1.2e+00 4.39e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.248501042634819e+05 1.1e+01 4.23e-02  7e-03  6e-02 0:02.7
#   200   2000 -1.252416497518424e+05 4.7e+01 1.08e-03  6e-05  2e-03 0:06.1
#   300   3000 -1.252416798907868e+05 8.1e+02 8.39e-05  5e-07  1e-04 0:09.5
#   400   4000 -1.252416802102664e+05 1.2e+04 5.30e-06  2e-09  8e-06 0:12.8
# NOTE (module=cma, iteration=432):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+09 to 9.6e+01
#   500   5000 -1.252416802106680e+05 5.4e+01 1.86e-06  4e-11  4e-06 0:16.2
#   600   6000 -1.252416802107245e+05 9.6e+02 2.02e-07  3e-13  5e-07 0:19.4
#   689   6890 -1.252416802107249e+05 1.4e+04 1.07e-07  2e-14  4e-07 0:22.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:18:49 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222670321079371e+05 1.0e+00 5.55e-01  5e-01  6e-01 0:00.0
#     2     20 -1.223068791151650e+05 1.2e+00 5.41e-01  5e-01  6e-01 0:00.1
#     3     30 -1.220945307807699e+05 1.3e+00 5.15e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.232781208591224e+05 4.1e+00 1.41e-01  7e-02  1e-01 0:02.4
#   200   2000 -1.245297455033556e+05 4.3e+00 4.59e-03  9e-04  3e-03 0:05.5
#   300   3000 -1.245404794216063e+05 3.8e+01 8.71e-05  3e-06  6e-05 0:08.9
#   400   4000 -1.245405371054265e+05 2.4e+02 3.62e-06  3e-08  4e-06 0:12.3
#   500   5000 -1.245405373577953e+05 1.8e+03 1.71e-07  2e-10  3e-07 0:15.7
#   600   6000 -1.245405373812955e+05 9.5e+03 1.36e-08  5e-12  3e-08 0:19.3
# NOTE (module=cma, iteration=626):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.5e+08 to 1.1e+06
#   700   7000 -1.245405373813839e+05 3.7e+03 1.53e-10  1e-14  4e-10 0:22.6
#   714   7140 -1.245405373813840e+05 4.4e+03 7.41e-11  6e-15  2e-10 0:23.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:19:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.226470827909392e+05 1.0e+00 5.28e-01  5e-01  5e-01 0:00.0
#     2     20 -1.234906025108190e+05 1.2e+00 4.93e-01  5e-01  5e-01 0:00.0
#     3     30 -1.227485193168104e+05 1.2e+00 4.82e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.263579111921503e+05 3.9e+00 7.60e-02  3e-02  8e-02 0:02.9
#   186   1860 -1.280054831945402e+05 1.4e+01 2.43e-03  3e-04  2e-03 0:06.9
#   200   2000 -1.280067676566302e+05 1.7e+01 1.02e-03  9e-05  1e-03 0:07.6
#   300   3000 -1.280103227779715e+05 1.3e+02 7.62e-05  3e-06  2e-04 0:12.6
#   400   4000 -1.280105164739100e+05 1.6e+02 3.38e-06  4e-08  4e-06 0:17.6
#   500   5000 -1.280105172590643e+05 6.3e+02 1.05e-07  4e-10  2e-07 0:22.8
#   600   6000 -1.280105172674242e+05 1.9e+03 1.41e-09  1e-12  2e-09 0:27.9
#   680   6800 -1.280105172674525e+05 5.3e+03 7.55e-11  3e-14  8e-11 0:31.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:19:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.222361478600894e+05 1.0e+00 5.78e-01  6e-01  6e-01 0:00.0
#     2     20 -1.238680506173440e+05 1.2e+00 5.49e-01  5e-01  6e-01 0:00.0
#     3     30 -1.222330869366927e+05 1.3e+00 5.50e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.260160940457927e+05 4.7e+00 4.37e-02  1e-02  4e-02 0:02.9
#   170   1700 -1.269593445679450e+05 8.6e+00 5.00e-03  1e-03  7e-03 0:06.9
#   200   2000 -1.269749412811797e+05 1.3e+01 1.48e-03  2e-04  2e-03 0:08.4
#   300   3000 -1.269779102521164e+05 9.0e+01 9.44e-05  2e-06  2e-04 0:13.1
#   400   4000 -1.269788027721421e+05 4.2e+02 3.84e-05  3e-07  8e-05 0:18.5
#   500   5000 -1.269788140665721e+05 2.9e+03 2.51e-06  6e-09  8e-06 0:22.9
#   600   6000 -1.269788164404926e+05 6.6e+03 2.44e-06  2e-09  7e-06 0:27.4
# NOTE (module=cma, iteration=658):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 5.1e+08 to 7.9e+06
#   700   7000 -1.269788165260876e+05 4.8e+03 5.05e-07  1e-10  2e-06 0:32.0
#   800   8000 -1.269788165281141e+05 2.8e+04 2.60e-08  1e-12  2e-07 0:36.5
#   900   9000 -1.269788165281509e+05 2.3e+05 3.30e-09  5e-14  2e-08 0:40.6
#  1000  10000 -1.269788165281602e+05 5.4e+05 3.20e-09  2e-14  2e-08 0:44.9
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1010  10100 -1.269788165281601e+05 5.9e+05 2.42e-09  1e-14  1e-08 0:45.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:20:34 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.238673278542457e+05 1.0e+00 5.28e-01  5e-01  5e-01 0:00.0
#     2     20 -1.221497069690608e+05 1.2e+00 5.01e-01  5e-01  5e-01 0:00.0
#     3     30 -1.220809603255214e+05 1.2e+00 4.78e-01  4e-01  5e-01 0:00.1
#   100   1000 -1.236317795974695e+05 3.2e+00 1.28e-02  5e-03  1e-02 0:02.7
#   200   2000 -1.236916633028379e+05 3.5e+01 1.14e-03  2e-04  1e-03 0:06.7
#   296   2960 -1.236916828757334e+05 1.4e+03 1.14e-04  7e-06  1e-04 0:11.7
#   300   3000 -1.236916829872762e+05 1.7e+03 1.25e-04  7e-06  1e-04 0:11.9
#   400   4000 -1.236916830171079e+05 9.7e+04 2.41e-05  4e-07  3e-05 0:15.1
#   500   5000 -1.236916830171424e+05 1.1e+01 3.71e-05  2e-05  6e-05 0:18.3
#   600   6000 -1.236916830171529e+05 4.1e+01 9.30e-06  3e-06  1e-05 0:21.5
#   700   7000 -1.236916830171505e+05 6.1e+01 3.43e-06  9e-07  4e-06 0:24.7
#   800   8000 -1.236916830171499e+05 2.4e+02 5.28e-06  3e-06  1e-05 0:27.8
#   850   8500 -1.236916830171539e+05 4.8e+02 3.26e-06  2e-06  1e-05 0:29.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:21:04 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221786394657239e+05 1.0e+00 5.89e-01  6e-01  6e-01 0:00.0
#     2     20 -1.230173558358760e+05 1.2e+00 5.96e-01  6e-01  6e-01 0:00.1
#     3     30 -1.227752107655398e+05 1.3e+00 6.32e-01  6e-01  7e-01 0:00.1
#   100   1000 -1.242528614505829e+05 9.3e+00 9.67e-02  3e-02  1e-01 0:02.8
#   200   2000 -1.270725905230021e+05 7.6e+00 4.98e-03  7e-04  3e-03 0:06.5
#   300   3000 -1.270824358833328e+05 5.3e+01 3.41e-04  1e-05  4e-04 0:11.1
#   400   4000 -1.270827428432987e+05 3.4e+02 3.61e-05  3e-07  5e-05 0:16.5
#   500   5000 -1.270827439887951e+05 2.1e+03 6.58e-06  1e-08  1e-05 0:21.2
#   600   6000 -1.270827440624702e+05 1.3e+04 2.56e-07  8e-11  5e-07 0:25.4
# NOTE (module=cma, iteration=627):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.5e+08 to 2.0e+07
#   700   7000 -1.270827440632676e+05 2.4e+04 1.67e-08  9e-13  4e-08 0:30.2
#   799   7990 -1.270827440632757e+05 2.0e+05 1.35e-09  1e-14  6e-09 0:34.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:21:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.220020000000000e+05 1.0e+00 5.22e-01  5e-01  5e-01 0:00.0
#     2     20 -1.220482480729748e+05 1.1e+00 5.14e-01  5e-01  5e-01 0:00.0
#     3     30 -1.223517097059696e+05 1.2e+00 5.00e-01  5e-01  5e-01 0:00.1
#   100   1000 -1.248048826985271e+05 5.4e+00 2.39e-01  1e-01  3e-01 0:02.4
#   200   2000 -1.267531198452716e+05 5.9e+00 1.25e-02  2e-03  9e-03 0:06.0
#   233   2330 -1.268127550587910e+05 4.6e+00 3.82e-03  8e-04  2e-03 0:07.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 11:21:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.221390970719806e+05 1.0e+00 5.58e-01  5e-01  6e-01 0:00.0
#     2     20 -1.222082053838683e+05 1.2e+00 5.28e-01  5e-01  6e-01 0:00.0
#     3     30 -1.238982441942593e+05 1.2e+00 5.34e-01  5e-01  6e-01 0:00.1
#   100   1000 -1.230556497715609e+05 4.6e+00 1.24e-01  6e-02  1e-01 0:02.4
#   200   2000 -1.237305573850443e+05 8.3e+00 7.42e-03  1e-03  8e-03 0:05.0
#   300   3000 -1.237496094801916e+05 5.1e+01 1.19e-04  3e-06  1e-04 0:07.7
#   400   4000 -1.237497228061314e+05 4.2e+02 4.98e-05  6e-07  7e-05 0:10.4
#   500   5000 -1.237497289240979e+05 2.8e+03 1.78e-06  3e-09  3e-06 0:13.2
#   600   6000 -1.237497289424678e+05 3.5e+04 6.06e-08  2e-11  2e-07 0:16.4
# NOTE (module=cma, iteration=616):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.9e+09 to 7.7e+07
#   700   7000 -1.237497289425968e+05 6.7e+04 4.05e-09  2e-13  2e-08 0:20.3
#   800   8000 -1.237497289426000e+05 6.4e+05 2.65e-09  3e-14  1e-08 0:23.1
# Tigray CMA complete. Total time: 881.71
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:22:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.890314307404030e+03 1.0e+00 1.47e-02  1e-02  2e-02 0:00.0
#     2     20 -2.116402062946421e+03 1.2e+00 1.48e-02  1e-02  2e-02 0:00.0
#     3     30 -2.284598391441235e+03 1.4e+00 1.51e-02  1e-02  2e-02 0:00.1
#   100   1000 -2.619809345353522e+03 1.2e+02 1.02e-03  3e-05  3e-03 0:02.4
#   200   2000 -2.619860125869315e+03 7.0e+03 2.28e-04  2e-07  1e-03 0:04.9
# NOTE (module=cma, iteration=218):
# condition in coordinate system exceeded 1.2e+08, rescaled to 1.0e+00,
# condition changed from 1.3e+08 to 1.5e+02
#   300   3000 -2.619860323590434e+03 7.0e+01 9.61e-06  1e-10  3e-05 0:08.0
#   400   4000 -2.619860323795113e+03 3.3e+03 4.62e-07  1e-13  2e-06 0:11.0
#   428   4280 -2.619860323795179e+03 1.4e+04 1.83e-07  2e-14  9e-07 0:11.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:22:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.890691169130884e+03 1.0e+00 1.60e-02  2e-02  2e-02 0:00.0
#     2     20 -1.966793689043133e+03 1.3e+00 1.82e-02  2e-02  2e-02 0:00.1
#     3     30 -1.977977620202934e+03 1.4e+00 1.91e-02  2e-02  2e-02 0:00.1
#   100   1000 -2.576893945396324e+03 1.4e+01 7.63e-03  9e-04  1e-02 0:02.5
#   200   2000 -2.577264105980783e+03 7.8e+02 6.67e-04  2e-06  2e-03 0:05.1
# NOTE (module=cma, iteration=266):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.1e+08 to 5.2e+01
#   300   3000 -2.577266063846330e+03 7.0e+00 7.16e-05  4e-09  2e-04 0:07.8
#   400   4000 -2.577266070659387e+03 6.9e+02 6.73e-06  8e-12  3e-05 0:10.4
# NOTE (module=cma, iteration=475):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.7e+08 to 8.5e+02
#   488   4880 -2.577266070666165e+03 3.5e+01 3.70e-07  2e-14  2e-06 0:12.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:22:38 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.066122306916370e+03 1.0e+00 1.51e-02  1e-02  2e-02 0:00.0
#     2     20 -2.043414053864404e+03 1.3e+00 1.70e-02  2e-02  2e-02 0:00.0
#     3     30 -2.070382123437357e+03 1.5e+00 1.70e-02  2e-02  2e-02 0:00.1
#   100   1000 -3.452568207121918e+03 2.5e+01 1.51e-03  1e-04  3e-03 0:02.9
#   200   2000 -3.452950915097504e+03 3.0e+02 4.85e-05  3e-07  8e-05 0:06.0
#   300   3000 -3.452952796865632e+03 3.0e+03 7.00e-07  6e-10  1e-06 0:08.8
# NOTE (module=cma, iteration=384):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.1e+01
#   400   4000 -3.452952801792514e+03 5.6e+00 1.32e-08  1e-12  2e-08 0:11.7
#   470   4700 -3.452952801800471e+03 2.8e+01 6.30e-10  2e-14  9e-10 0:13.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:22:53 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.480064009185000e+03 1.0e+00 1.59e-02  2e-02  2e-02 0:00.0
#     2     20 -2.496109152142836e+03 1.3e+00 1.65e-02  1e-02  2e-02 0:00.0
#     3     30 -2.551668532090518e+03 1.5e+00 1.67e-02  1e-02  2e-02 0:00.1
#   100   1000 -3.019591811598887e+03 3.0e+01 5.09e-04  3e-05  8e-04 0:02.7
#   200   2000 -3.019681368372018e+03 2.9e+03 6.98e-06  9e-09  2e-05 0:05.6
# NOTE (module=cma, iteration=238):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.7e+08 to 1.2e+02
#   300   3000 -3.019681382799048e+03 3.6e+01 3.98e-06  8e-11  2e-05 0:08.4
#   400   4000 -3.019681383045437e+03 2.6e+03 3.34e-07  1e-13  2e-06 0:11.2
#   434   4340 -3.019681383045471e+03 1.5e+04 1.63e-07  2e-14  1e-06 0:12.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:23:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.963106046338246e+03 1.0e+00 1.44e-02  1e-02  1e-02 0:00.0
#     2     20 -2.022969090770872e+03 1.2e+00 1.46e-02  1e-02  2e-02 0:00.0
#     3     30 -2.194715984975062e+03 1.3e+00 1.62e-02  1e-02  2e-02 0:00.1
#   100   1000 -2.382020349240727e+03 6.5e+01 8.55e-04  4e-05  2e-03 0:02.4
#   200   2000 -2.382020355838678e+03 3.4e+03 2.15e-05  2e-08  5e-05 0:04.9
# NOTE (module=cma, iteration=228):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.2e+08 to 1.7e+02
#   250   2500 -2.382020355838686e+03 1.3e+01 1.11e-05  1e-09  4e-05 0:06.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:23:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.162474380552495e+03 1.0e+00 1.51e-02  1e-02  2e-02 0:00.0
#     2     20 -2.325303734800133e+03 1.2e+00 1.51e-02  1e-02  2e-02 0:00.0
#     3     30 -2.311226730669890e+03 1.3e+00 1.56e-02  1e-02  2e-02 0:00.1
#   100   1000 -2.652074457610678e+03 1.1e+02 4.65e-04  6e-05  8e-04 0:02.5
#   200   2000 -2.652077887676181e+03 3.2e+03 7.25e-06  4e-08  1e-05 0:05.1
# NOTE (module=cma, iteration=298):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 7.7e+09 to 3.1e+02
#   300   3000 -2.652077893000340e+03 1.8e+01 9.63e-07  1e-10  2e-06 0:08.1
#   400   4000 -2.652077893031509e+03 5.2e+02 7.23e-08  4e-13  1e-07 0:11.1
#   499   4990 -2.652077893031511e+03 6.7e+03 7.38e-08  2e-14  2e-07 0:13.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:23:27 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.523368172672997e+03 1.0e+00 1.45e-02  1e-02  1e-02 0:00.0
#     2     20 -2.537502665675762e+03 1.2e+00 1.36e-02  1e-02  1e-02 0:00.1
#     3     30 -2.551469382987983e+03 1.3e+00 1.35e-02  1e-02  1e-02 0:00.1
#    18    180 -2.554064009185000e+03 2.3e+00 8.47e-03  6e-03  1e-02 0:00.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:23:27 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.313368975983541e+03 1.0e+00 1.55e-02  1e-02  2e-02 0:00.0
#     2     20 -2.516745202529608e+03 1.3e+00 1.70e-02  2e-02  2e-02 0:00.1
#     3     30 -2.624861714763062e+03 1.4e+00 1.67e-02  2e-02  2e-02 0:00.1
#    94    940 -3.768553425852733e+03 1.8e+01 1.24e-03  2e-04  2e-03 0:03.1
#   100   1000 -3.770931885038001e+03 2.4e+01 1.74e-03  2e-04  3e-03 0:03.3
#   200   2000 -3.813121244568784e+03 4.6e+01 5.50e-04  2e-05  7e-04 0:06.5
#   300   3000 -3.813194920159267e+03 6.8e+02 3.99e-05  1e-07  7e-05 0:09.7
#   400   4000 -3.813195750104665e+03 3.9e+03 8.33e-07  4e-10  1e-06 0:13.1
# NOTE (module=cma, iteration=431):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.6e+08 to 2.7e+01
#   500   5000 -3.813195751731187e+03 1.6e+01 2.45e-08  1e-12  6e-08 0:16.3
#   559   5590 -3.813195751735168e+03 7.4e+01 1.21e-09  2e-14  4e-09 0:18.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:23:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.677537754102248e+03 1.0e+00 1.49e-02  1e-02  2e-02 0:00.0
#     2     20 -2.787719234645422e+03 1.2e+00 1.48e-02  1e-02  2e-02 0:00.1
#     3     30 -2.974720578305487e+03 1.3e+00 1.52e-02  1e-02  2e-02 0:00.1
#   100   1000 -3.379891037830967e+03 3.6e+01 6.00e-04  3e-05  8e-04 0:03.0
#   200   2000 -3.379924254751768e+03 7.0e+02 5.87e-05  2e-07  1e-04 0:05.9
# NOTE (module=cma, iteration=272):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 2.6e+02
#   300   3000 -3.379924332778052e+03 1.3e+01 1.79e-06  9e-11  3e-06 0:08.9
#   400   4000 -3.379924332980103e+03 5.4e+02 6.31e-08  7e-14  2e-07 0:11.9
#   429   4290 -3.379924332980166e+03 1.7e+03 4.91e-08  2e-14  1e-07 0:12.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:24:00 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.843220486408258e+03 1.0e+00 1.48e-02  1e-02  2e-02 0:00.0
#     2     20 -1.883755557565007e+03 1.2e+00 1.44e-02  1e-02  2e-02 0:00.0
#     3     30 -1.978615361090625e+03 1.3e+00 1.39e-02  1e-02  1e-02 0:00.1
#   100   1000 -3.334937177771561e+03 8.9e+00 1.28e-03  2e-04  1e-03 0:03.0
#   200   2000 -3.335787780292600e+03 6.5e+01 2.22e-05  5e-07  3e-05 0:06.2
#   300   3000 -3.335788561326541e+03 5.4e+02 6.03e-07  2e-09  9e-07 0:09.4
#   400   4000 -3.335788563286507e+03 4.9e+03 4.90e-09  2e-12  8e-09 0:12.4
# NOTE (module=cma, iteration=436):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.3e+08 to 1.7e+01
#   500   5000 -3.335788563290859e+03 1.1e+01 3.44e-10  2e-14  7e-10 0:15.4
#   503   5030 -3.335788563290836e+03 1.3e+01 3.16e-10  2e-14  6e-10 0:15.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:24:16 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.370000563143816e+03 1.0e+00 1.47e-02  1e-02  2e-02 0:00.0
#     2     20 -2.608395965351967e+03 1.2e+00 1.56e-02  1e-02  2e-02 0:00.1
#     3     30 -2.833939513695610e+03 1.4e+00 1.65e-02  2e-02  2e-02 0:00.1
#   100   1000 -3.708010557707035e+03 1.7e+01 4.38e-04  3e-05  4e-04 0:03.0
#   200   2000 -3.708195652769710e+03 1.3e+02 2.25e-06  2e-08  2e-06 0:06.3
#   300   3000 -3.708195751307112e+03 1.8e+03 1.63e-07  2e-10  2e-07 0:09.3
# NOTE (module=cma, iteration=397):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.0e+08 to 4.3e+01
#   400   4000 -3.708195751734981e+03 7.2e+00 7.48e-10  9e-14  1e-09 0:12.3
#   426   4260 -3.708195751735228e+03 1.4e+01 2.15e-10  2e-14  3e-10 0:13.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:24:30 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.781371377219194e+03 1.0e+00 1.43e-02  1e-02  1e-02 0:00.0
#     2     20 -3.062414470779365e+03 1.2e+00 1.52e-02  1e-02  2e-02 0:00.1
#     3     30 -3.119168609045081e+03 1.3e+00 1.64e-02  2e-02  2e-02 0:00.1
#    85    850 -3.786214708304412e+03 9.5e+00 2.41e-03  4e-04  3e-03 0:03.1
#   100   1000 -3.787522427209073e+03 2.2e+01 1.37e-03  1e-04  3e-03 0:03.6
#   200   2000 -3.787859945789361e+03 8.8e+02 8.75e-05  3e-07  2e-04 0:06.9
# NOTE (module=cma, iteration=264):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.2e+08 to 5.7e+01
#   300   3000 -3.787860322407234e+03 1.0e+01 1.27e-05  8e-10  5e-05 0:09.9
#   400   4000 -3.787860323790427e+03 7.9e+02 2.48e-06  3e-12  1e-05 0:13.0
# NOTE (module=cma, iteration=453):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.6e+08 to 8.3e+02
#   477   4770 -3.787860323795151e+03 3.0e+01 2.92e-07  2e-14  2e-06 0:15.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:24:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.076894506451042e+03 1.0e+00 1.56e-02  2e-02  2e-02 0:00.0
#     2     20 -2.207373793230203e+03 1.2e+00 1.66e-02  2e-02  2e-02 0:00.0
#     3     30 -2.209273782350392e+03 1.4e+00 1.73e-02  2e-02  2e-02 0:00.1
#   100   1000 -3.032812468258021e+03 1.3e+01 6.65e-04  7e-05  8e-04 0:02.5
#   200   2000 -3.032860298358437e+03 5.6e+02 1.55e-05  5e-08  2e-05 0:05.0
# NOTE (module=cma, iteration=271):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.7e+08 to 1.2e+02
#   300   3000 -3.032860323694272e+03 1.1e+01 1.96e-06  8e-11  3e-06 0:07.8
#   400   4000 -3.032860323795132e+03 3.2e+02 3.54e-08  4e-14  7e-08 0:10.5
#   412   4120 -3.032860323795167e+03 6.3e+02 2.23e-08  2e-14  4e-08 0:10.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 11:24:58 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.859689467778416e+03 1.0e+00 1.56e-02  2e-02  2e-02 0:00.0
#     2     20 -1.969397987382051e+03 1.2e+00 1.58e-02  2e-02  2e-02 0:00.0
#     3     30 -2.012033985669339e+03 1.3e+00 1.79e-02  2e-02  2e-02 0:00.1
#   100   1000 -2.501838996381217e+03 3.0e+01 1.68e-04  8e-06  2e-04 0:02.5
#   200   2000 -2.501860320131856e+03 1.9e+03 2.23e-06  3e-09  4e-06 0:05.0
# NOTE (module=cma, iteration=239):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.8e+08 to 6.0e+02
#   300   3000 -2.501860323794351e+03 2.3e+01 8.04e-08  3e-12  2e-07 0:07.4
# ...
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.0e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=508)
#   warnings.warn(msg + ' (' +
#   600   6000 -2.496259655703398e+04 4.7e+01 3.21e-06  7e-07  4e-06 0:13.3
#   700   7000 -2.496259655703402e+04 2.6e+03 1.90e-06  8e-07  4e-06 0:15.7
#   714   7140 -2.496259655703402e+04 3.5e+03 1.02e-06  4e-07  2e-06 0:16.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:49:43 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.457420851160206e+04 1.0e+00 6.62e-01  6e-01  7e-01 0:00.0
#     2     20 -2.455578385303288e+04 1.2e+00 6.53e-01  6e-01  7e-01 0:00.0
#     3     30 -2.474493625710759e+04 1.3e+00 6.55e-01  6e-01  7e-01 0:00.1
#   100   1000 -2.536596404997344e+04 7.0e+00 1.14e-01  3e-02  1e-01 0:01.9
#   200   2000 -2.543762645799765e+04 1.4e+01 3.28e-03  4e-04  4e-03 0:04.4
#   300   3000 -2.543766531422527e+04 5.3e+02 5.07e-04  2e-05  7e-04 0:06.9
#   400   4000 -2.543766534610318e+04 2.4e+04 7.95e-05  1e-06  1e-04 0:09.4
#   500   5000 -2.543766534698800e+04 8.1e+05 2.22e-05  2e-07  4e-05 0:11.9
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=507)
#   warnings.warn(msg + ' (' +
#   600   6000 -2.543766534698906e+04 6.2e+01 7.37e-06  3e-06  9e-06 0:14.5
#   700   7000 -2.543766534698926e+04 2.3e+02 2.84e-06  1e-06  5e-06 0:17.0
#   800   8000 -2.543766534698926e+04 3.8e+02 2.56e-06  1e-06  5e-06 0:19.6
#   900   9000 -2.543766534698922e+04 4.9e+02 3.83e-06  1e-06  6e-06 0:22.1
#   985   9850 -2.543766534698924e+04 7.2e+02 1.31e-06  3e-07  2e-06 0:24.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:50:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.440360452076449e+04 1.0e+00 6.38e-01  6e-01  7e-01 0:00.0
#     2     20 -2.454692959010074e+04 1.2e+00 6.05e-01  6e-01  6e-01 0:00.0
#     3     30 -2.447586115622871e+04 1.2e+00 5.86e-01  6e-01  6e-01 0:00.1
#   100   1000 -2.486388023818807e+04 5.2e+00 2.21e-01  1e-01  3e-01 0:01.8
#   200   2000 -2.564010084244033e+04 7.4e+00 1.96e-02  4e-03  2e-02 0:03.9
#   300   3000 -2.567986015852655e+04 4.1e+01 6.18e-04  3e-05  6e-04 0:06.4
#   400   4000 -2.567990679509664e+04 1.7e+03 8.00e-05  3e-06  8e-05 0:08.8
#   500   5000 -2.567990680400296e+04 8.9e+04 3.52e-05  7e-07  4e-05 0:11.2
#   600   6000 -2.567990680527948e+04 7.1e+00 7.69e-06  2e-06  1e-05 0:13.6
#   700   7000 -2.567990680528089e+04 4.1e+01 1.87e-05  4e-06  3e-05 0:16.0
#   800   8000 -2.567990680528223e+04 2.1e+02 1.40e-05  3e-06  2e-05 0:18.5
#   900   9000 -2.567990680528095e+04 2.3e+02 1.47e-05  2e-06  2e-05 0:20.9
#  1000  10000 -2.567990680528135e+04 1.9e+02 1.64e-05  2e-06  2e-05 0:23.3
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -2.567990680528257e+04 3.2e+02 1.24e-05  1e-06  2e-05 0:25.8
#  1200  12000 -2.567990680527955e+04 4.0e+02 2.68e-05  2e-06  4e-05 0:28.2
#  1210  12100 -2.567990680528149e+04 4.6e+02 2.25e-05  1e-06  3e-05 0:28.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:50:39 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.434335693897678e+04 1.0e+00 6.08e-01  6e-01  6e-01 0:00.0
#     2     20 -2.444029268293362e+04 1.2e+00 6.52e-01  6e-01  7e-01 0:00.0
#     3     30 -2.428400000000000e+04 1.4e+00 6.80e-01  6e-01  8e-01 0:00.1
#   100   1000 -2.465942551613117e+04 4.4e+00 2.25e-01  1e-01  2e-01 0:01.8
#   200   2000 -2.516024680305485e+04 1.3e+01 1.45e-02  2e-03  2e-02 0:03.8
#   261   2610 -2.516800000000000e+04 6.7e+01 2.89e-03  7e-05  4e-03 0:05.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:50:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.428674745177968e+04 1.0e+00 6.73e-01  7e-01  7e-01 0:00.0
#     2     20 -2.464884174916588e+04 1.2e+00 6.33e-01  6e-01  7e-01 0:00.0
#     3     30 -2.442320976531112e+04 1.3e+00 6.26e-01  6e-01  7e-01 0:00.1
#   100   1000 -2.461400000000000e+04 5.6e+00 9.59e-01  6e-01  1e+00 0:01.7
#   200   2000 -2.426292007104770e+04 1.6e+01 1.41e+00  6e-01  3e+00 0:04.2
#   300   3000 -2.494463054587371e+04 1.8e+01 5.00e-02  1e-02  6e-02 0:06.7
#   400   4000 -2.524487915349677e+04 8.7e+00 4.34e-03  5e-04  2e-03 0:09.1
#   500   5000 -2.524509553833984e+04 3.9e+02 4.01e-04  2e-05  2e-04 0:11.6
#   600   6000 -2.524509571466447e+04 2.8e+04 2.87e-05  7e-07  2e-05 0:14.2
#   700   7000 -2.524509571480160e+04 2.4e+00 9.07e-06  6e-06  1e-05 0:16.7
#   800   8000 -2.524509571480679e+04 9.0e+00 1.97e-05  8e-06  3e-05 0:19.3
#   900   9000 -2.524509571480464e+04 2.3e+01 4.43e-06  1e-06  8e-06 0:21.7
#  1000  10000 -2.524509571480816e+04 3.2e+01 8.29e-07  2e-07  1e-06 0:24.1
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -2.524509571480817e+04 4.8e+01 8.70e-07  2e-07  8e-07 0:26.4
#  1200  12000 -2.524509571480634e+04 8.1e+01 9.57e-07  2e-07  7e-07 0:28.8
#  1300  13000 -2.524509571480622e+04 8.5e+01 6.57e-07  1e-07  4e-07 0:31.1
#  1315  13150 -2.524509571480416e+04 1.0e+02 9.63e-07  2e-07  5e-07 0:31.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:51:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.433352093423136e+04 1.0e+00 6.00e-01  6e-01  6e-01 0:00.0
#     2     20 -2.461545251422944e+04 1.1e+00 5.97e-01  6e-01  6e-01 0:00.0
#     3     30 -2.451773757575471e+04 1.3e+00 6.05e-01  6e-01  6e-01 0:00.1
#   100   1000 -2.509849054127927e+04 5.9e+00 2.36e-01  9e-02  3e-01 0:01.8
#   200   2000 -2.544369642141010e+04 2.5e+01 7.37e-03  5e-04  1e-02 0:04.0
#   251   2510 -2.544374893991700e+04 1.0e+02 3.42e-03  7e-05  5e-03 0:05.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:51:24 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.438700000000000e+04 1.0e+00 6.23e-01  6e-01  6e-01 0:00.0
#     2     20 -2.438438384571111e+04 1.1e+00 6.02e-01  6e-01  6e-01 0:00.0
#     3     30 -2.431879629740717e+04 1.2e+00 5.88e-01  5e-01  6e-01 0:00.1
#   100   1000 -2.431037595910255e+04 4.2e+00 4.12e-01  3e-01  5e-01 0:01.8
#   200   2000 -2.518683619384035e+04 8.1e+00 2.75e-03  4e-04  3e-03 0:04.2
#   300   3000 -2.519007614203703e+04 6.0e+01 4.90e-05  1e-06  5e-05 0:07.9
#   400   4000 -2.519007801302178e+04 9.7e+02 1.01e-05  2e-08  1e-05 0:10.3
#   500   5000 -2.519007803813968e+04 1.9e+04 2.98e-06  4e-10  4e-06 0:12.9
# NOTE (module=cma, iteration=501):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.9e+08 to 2.3e+02
#   600   6000 -2.519007803873714e+04 4.3e+01 3.83e-07  5e-12  6e-07 0:15.6
#   700   7000 -2.519007803873908e+04 6.3e+02 4.10e-08  4e-14  6e-08 0:18.7
#   727   7270 -2.519007803873910e+04 1.6e+03 3.17e-08  1e-14  5e-08 0:19.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:51:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.435409176917607e+04 1.0e+00 6.40e-01  6e-01  7e-01 0:00.0
#     2     20 -2.442616064734901e+04 1.2e+00 6.59e-01  6e-01  7e-01 0:00.0
#     3     30 -2.433930263420704e+04 1.3e+00 6.54e-01  6e-01  7e-01 0:00.1
#   100   1000 -2.474404015304233e+04 7.9e+00 4.79e-01  1e-01  7e-01 0:02.0
#   200   2000 -2.564061892261330e+04 9.2e+00 1.06e-02  2e-03  9e-03 0:04.4
#   300   3000 -2.565366094806244e+04 3.7e+01 4.28e-04  2e-05  4e-04 0:08.2
#   400   4000 -2.565366531839326e+04 8.6e+02 1.08e-04  5e-06  9e-05 0:11.3
#   500   5000 -2.565366534694893e+04 3.1e+04 6.99e-06  2e-07  6e-06 0:14.5
#   600   6000 -2.565366534698899e+04 2.8e+00 4.03e-06  3e-06  5e-06 0:18.6
#   700   7000 -2.565366534698915e+04 2.3e+01 3.85e-06  1e-06  5e-06 0:21.6
#   800   8000 -2.565366534698926e+04 6.3e+01 1.84e-06  7e-07  3e-06 0:24.6
#   900   9000 -2.565366534698907e+04 8.0e+01 2.13e-06  7e-07  3e-06 0:27.8
#  1000  10000 -2.565366534698896e+04 1.4e+02 1.05e-06  3e-07  1e-06 0:31.4
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1015  10150 -2.565366534698917e+04 1.6e+02 1.42e-06  4e-07  2e-06 0:32.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:52:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.440813491120411e+04 1.0e+00 6.48e-01  6e-01  7e-01 0:00.0
#     2     20 -2.427800000000000e+04 1.2e+00 6.04e-01  6e-01  6e-01 0:00.0
#     3     30 -2.431400000000000e+04 1.3e+00 5.87e-01  5e-01  6e-01 0:00.1
#   100   1000 -2.470048914312722e+04 6.9e+00 1.42e-01  7e-02  2e-01 0:02.7
#   200   2000 -2.496102665984446e+04 1.3e+01 2.18e-02  2e-03  2e-02 0:05.7
#   300   3000 -2.496259647453588e+04 3.7e+02 1.48e-03  6e-06  2e-03 0:08.5
#   400   4000 -2.496259655564600e+04 1.3e+04 3.54e-04  2e-07  4e-04 0:11.2
#   500   5000 -2.496259655701676e+04 7.3e+05 1.09e-04  2e-08  2e-04 0:14.0
#   600   6000 -2.496259655703398e+04 4.7e+01 3.21e-06  7e-07  4e-06 0:16.8
#   700   7000 -2.496259655703402e+04 2.6e+03 1.90e-06  8e-07  4e-06 0:19.7
#   714   7140 -2.496259655703402e+04 3.5e+03 1.02e-06  4e-07  2e-06 0:20.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:52:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.457420851160206e+04 1.0e+00 6.62e-01  6e-01  7e-01 0:00.0
#     2     20 -2.455578385303288e+04 1.2e+00 6.53e-01  6e-01  7e-01 0:00.0
#     3     30 -2.474493625710759e+04 1.3e+00 6.55e-01  6e-01  7e-01 0:00.1
#   100   1000 -2.536596404997344e+04 7.0e+00 1.14e-01  3e-02  1e-01 0:02.2
#   200   2000 -2.543762645799765e+04 1.4e+01 3.28e-03  4e-04  4e-03 0:05.3
#   300   3000 -2.543766531422527e+04 5.3e+02 5.07e-04  2e-05  7e-04 0:08.2
#   400   4000 -2.543766534610318e+04 2.4e+04 7.95e-05  1e-06  1e-04 0:11.2
#   500   5000 -2.543766534698800e+04 8.1e+05 2.22e-05  2e-07  4e-05 0:14.0
#   600   6000 -2.543766534698906e+04 6.2e+01 7.37e-06  3e-06  9e-06 0:16.9
#   700   7000 -2.543766534698926e+04 2.3e+02 2.84e-06  1e-06  5e-06 0:20.0
#   800   8000 -2.543766534698926e+04 3.8e+02 2.56e-06  1e-06  5e-06 0:23.2
#   900   9000 -2.543766534698922e+04 4.9e+02 3.83e-06  1e-06  6e-06 0:26.5
#   985   9850 -2.543766534698924e+04 7.2e+02 1.31e-06  3e-07  2e-06 0:29.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:53:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.440360452076449e+04 1.0e+00 6.38e-01  6e-01  7e-01 0:00.0
#     2     20 -2.454692959010074e+04 1.2e+00 6.05e-01  6e-01  6e-01 0:00.0
#     3     30 -2.447586115622871e+04 1.2e+00 5.86e-01  6e-01  6e-01 0:00.1
#   100   1000 -2.486388023818807e+04 5.2e+00 2.21e-01  1e-01  3e-01 0:02.1
#   200   2000 -2.564010084244033e+04 7.4e+00 1.96e-02  4e-03  2e-02 0:04.8
#   300   3000 -2.567986015852655e+04 4.1e+01 6.18e-04  3e-05  6e-04 0:07.7
#   400   4000 -2.567990679509664e+04 1.7e+03 8.00e-05  3e-06  8e-05 0:10.6
#   500   5000 -2.567990680400296e+04 8.9e+04 3.52e-05  7e-07  4e-05 0:13.4
#   600   6000 -2.567990680527948e+04 7.1e+00 7.69e-06  2e-06  1e-05 0:16.3
#   700   7000 -2.567990680528089e+04 4.1e+01 1.87e-05  4e-06  3e-05 0:19.4
#   800   8000 -2.567990680528223e+04 2.1e+02 1.40e-05  3e-06  2e-05 0:22.6
#   900   9000 -2.567990680528095e+04 2.3e+02 1.47e-05  2e-06  2e-05 0:25.5
#  1000  10000 -2.567990680528135e+04 1.9e+02 1.64e-05  2e-06  2e-05 0:28.6
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -2.567990680528257e+04 3.2e+02 1.24e-05  1e-06  2e-05 0:31.6
#  1200  12000 -2.567990680527955e+04 4.0e+02 2.68e-05  2e-06  4e-05 0:34.4
#  1210  12100 -2.567990680528149e+04 4.6e+02 2.25e-05  1e-06  3e-05 0:34.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:53:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.434335693897678e+04 1.0e+00 6.08e-01  6e-01  6e-01 0:00.0
#     2     20 -2.444029268293362e+04 1.2e+00 6.52e-01  6e-01  7e-01 0:00.0
#     3     30 -2.428400000000000e+04 1.4e+00 6.80e-01  6e-01  8e-01 0:00.1
#   100   1000 -2.465942551613117e+04 4.4e+00 2.25e-01  1e-01  2e-01 0:02.1
#   200   2000 -2.516024680305485e+04 1.3e+01 1.45e-02  2e-03  2e-02 0:04.7
#   261   2610 -2.516800000000000e+04 6.7e+01 2.89e-03  7e-05  4e-03 0:06.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:53:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.428674745177968e+04 1.0e+00 6.73e-01  7e-01  7e-01 0:00.0
#     2     20 -2.464884174916588e+04 1.2e+00 6.33e-01  6e-01  7e-01 0:00.0
#     3     30 -2.442320976531112e+04 1.3e+00 6.26e-01  6e-01  7e-01 0:00.1
#   100   1000 -2.461400000000000e+04 5.6e+00 9.59e-01  6e-01  1e+00 0:02.0
#   200   2000 -2.426292007104770e+04 1.6e+01 1.41e+00  6e-01  3e+00 0:04.0
#   300   3000 -2.494463054587371e+04 1.8e+01 5.00e-02  1e-02  6e-02 0:06.5
#   400   4000 -2.524487915349677e+04 8.7e+00 4.34e-03  5e-04  2e-03 0:09.1
#   500   5000 -2.524509553833984e+04 3.9e+02 4.01e-04  2e-05  2e-04 0:12.0
#   600   6000 -2.524509571466447e+04 2.8e+04 2.87e-05  7e-07  2e-05 0:14.8
#   700   7000 -2.524509571480160e+04 2.4e+00 9.07e-06  6e-06  1e-05 0:17.7
#   800   8000 -2.524509571480679e+04 9.0e+00 1.97e-05  8e-06  3e-05 0:20.5
#   900   9000 -2.524509571480464e+04 2.3e+01 4.43e-06  1e-06  8e-06 0:23.4
#  1000  10000 -2.524509571480816e+04 3.2e+01 8.29e-07  2e-07  1e-06 0:26.5
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#  1100  11000 -2.524509571480817e+04 4.8e+01 8.70e-07  2e-07  8e-07 0:29.8
#  1200  12000 -2.524509571480634e+04 8.1e+01 9.57e-07  2e-07  7e-07 0:32.7
#  1300  13000 -2.524509571480622e+04 8.5e+01 6.57e-07  1e-07  4e-07 0:35.5
#  1315  13150 -2.524509571480416e+04 1.0e+02 9.63e-07  2e-07  5e-07 0:36.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:54:33 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.433352093423136e+04 1.0e+00 6.00e-01  6e-01  6e-01 0:00.0
#     2     20 -2.461545251422944e+04 1.1e+00 5.97e-01  6e-01  6e-01 0:00.0
#     3     30 -2.451773757575471e+04 1.3e+00 6.05e-01  6e-01  6e-01 0:00.1
#   100   1000 -2.509849054127927e+04 5.9e+00 2.36e-01  9e-02  3e-01 0:02.3
#   200   2000 -2.544369642141010e+04 2.5e+01 7.37e-03  5e-04  1e-02 0:05.1
#   251   2510 -2.544374893991700e+04 1.0e+02 3.42e-03  7e-05  5e-03 0:06.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=1234, Mon Sep  5 12:54:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.438700000000000e+04 1.0e+00 6.23e-01  6e-01  6e-01 0:00.0
#     2     20 -2.438438384571111e+04 1.1e+00 6.02e-01  6e-01  6e-01 0:00.0
#     3     30 -2.431879629740717e+04 1.2e+00 5.88e-01  5e-01  6e-01 0:00.1
#   100   1000 -2.431037595910255e+04 4.2e+00 4.12e-01  3e-01  5e-01 0:02.1
#   200   2000 -2.518683619384035e+04 8.1e+00 2.75e-03  4e-04  3e-03 0:04.6
#   300   3000 -2.519007614203703e+04 6.0e+01 4.90e-05  1e-06  5e-05 0:08.1
#   400   4000 -2.519007801302178e+04 9.7e+02 1.01e-05  2e-08  1e-05 0:11.0
#   500   5000 -2.519007803813968e+04 1.9e+04 2.98e-06  4e-10  4e-06 0:14.2
# NOTE (module=cma, iteration=501):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 3.9e+08 to 2.3e+02
#   600   6000 -2.519007803873714e+04 4.3e+01 3.83e-07  5e-12  6e-07 0:17.1
#   700   7000 -2.519007803873908e+04 6.3e+02 4.10e-08  4e-14  6e-08 0:20.2
#   727   7270 -2.519007803873910e+04 1.6e+03 3.17e-08  1e-14  5e-08 0:21.0
# Benishangul Gumz CMA complete. Total time: 628.25
# Wall time: 1h 47min 31s

# %%
# %%time
n_starting_points = 30
maxits= 10000
# for maximum of 5. 
for i in ['Harari']:
    cma_region(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], df_all[i])
# Out:
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:55:02 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.602147830874216e+03 1.0e+00 5.72e-03  5e-03  6e-03 0:00.0
#     2     16 -4.635886679724620e+03 1.2e+00 5.60e-03  5e-03  5e-03 0:00.0
#     3     24 -4.669889605997425e+03 1.2e+00 7.21e-03  7e-03  7e-03 0:00.1
#   100    800 -4.991097155297782e+03 2.7e+03 6.41e-05  8e-07  4e-05 0:02.4
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=147)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584685e+03 2.9e+01 6.88e-07  2e-07  6e-07 0:04.9
#   300   2400 -4.991097159584667e+03 2.5e+02 9.80e-07  3e-08  5e-07 0:06.9
#   400   3200 -4.991097159584555e+03 1.7e+02 3.93e-06  5e-08  3e-07 0:09.0
#   500   4000 -4.991097159584666e+03 3.0e+02 8.30e-06  5e-08  2e-07 0:11.1
#   505   4040 -4.991097159584585e+03 2.9e+02 9.82e-06  5e-08  2e-07 0:11.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:55:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.732742166324022e+03 1.0e+00 1.19e-02  1e-02  1e-02 0:00.0
#     2     16 -4.781832746435990e+03 1.3e+00 1.38e-02  1e-02  2e-02 0:00.0
#     3     24 -4.882161884077336e+03 1.7e+00 1.81e-02  2e-02  2e-02 0:00.1
#   100    800 -4.991097158052147e+03 2.8e+04 4.98e-05  6e-07  7e-05 0:02.1
#   200   1600 -4.991097159584671e+03 1.4e+02 6.47e-07  3e-07  9e-07 0:04.2
#   300   2400 -4.991097159584669e+03 1.0e+02 4.13e-07  2e-08  8e-08 0:06.8
#   400   3200 -4.991097159584686e+03 1.4e+02 2.22e-06  9e-08  1e-07 0:09.2
#   500   4000 -4.991097159584659e+03 3.8e+02 4.88e-05  4e-07  1e-06 0:11.4
#   505   4040 -4.991097159584617e+03 4.9e+02 4.88e-05  3e-07  1e-06 0:11.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:55:27 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.734498918290130e+03 1.0e+00 1.72e-02  2e-02  2e-02 0:00.0
#     2     16 -4.695289532386486e+03 1.2e+00 1.76e-02  2e-02  2e-02 0:00.1
#     3     24 -4.875805874226759e+03 1.4e+00 1.64e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097157626216e+03 2.6e+04 3.33e-05  5e-07  5e-05 0:02.1
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=127)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584671e+03 1.2e+02 5.68e-07  1e-07  7e-07 0:04.2
#   300   2400 -4.991097159584661e+03 2.3e+02 5.40e-07  3e-08  3e-07 0:06.4
#   400   3200 -4.991097159584639e+03 1.2e+03 1.32e-06  4e-08  4e-07 0:08.9
#   500   4000 -4.991097159584639e+03 6.0e+02 6.84e-06  5e-08  2e-07 0:11.4
#   505   4040 -4.991097159584678e+03 4.5e+02 9.94e-06  7e-08  3e-07 0:11.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:55:39 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.737139927605122e+03 1.0e+00 2.22e-02  2e-02  2e-02 0:00.0
#     2     16 -4.913631522977117e+03 1.2e+00 2.57e-02  2e-02  3e-02 0:00.0
#     3     24 -4.959007441449000e+03 1.6e+00 2.77e-02  2e-02  3e-02 0:00.1
#   100    800 -4.991097158730647e+03 2.4e+04 2.79e-05  3e-07  3e-05 0:02.3
#   200   1600 -4.991097159584602e+03 8.0e+01 8.86e-07  7e-08  9e-07 0:04.7
#   300   2400 -4.991097159584658e+03 2.0e+02 1.07e-06  9e-09  4e-07 0:06.9
#   400   3200 -4.991097159584668e+03 8.3e+02 2.01e-06  1e-08  4e-07 0:09.2
#   500   4000 -4.991097159584621e+03 1.1e+03 1.12e-05  2e-08  6e-07 0:11.4
#   505   4040 -4.991097159584666e+03 1.5e+03 1.69e-05  4e-08  1e-06 0:11.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:55:52 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.745727657960761e+03 1.0e+00 2.83e-02  3e-02  3e-02 0:00.0
#     2     16 -4.949730946596804e+03 1.2e+00 3.32e-02  3e-02  4e-02 0:00.1
#     3     24 -4.901591779655573e+03 1.6e+00 3.49e-02  3e-02  4e-02 0:00.1
#   100    800 -4.993595694510658e+03 3.6e+03 1.53e-05  1e-08  4e-05 0:02.2
# NOTE (module=cma, iteration=114):
# condition in coordinate system exceeded 1.2e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 8.8e+01
#   198   1584 -4.993595713137450e+03 2.3e+03 1.32e-08  1e-14  1e-07 0:04.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:55:57 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.519147740650398e+03 1.0e+00 3.95e-02  4e-02  4e-02 0:00.0
#     2     16 -4.661824667729057e+03 1.4e+00 4.02e-02  4e-02  4e-02 0:00.0
#     3     24 -4.651361209988487e+03 1.3e+00 4.04e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097150147280e+03 2.8e+04 1.03e-04  9e-07  2e-04 0:02.2
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.2e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=127)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584678e+03 2.6e+02 5.11e-07  3e-08  5e-07 0:04.5
#   300   2400 -4.991097159584682e+03 6.9e+02 1.14e-06  3e-08  4e-07 0:06.8
#   400   3200 -4.991097159584661e+03 3.3e+03 2.34e-06  6e-08  8e-07 0:09.1
#   500   4000 -4.991097159584678e+03 1.8e+03 1.01e-05  3e-08  5e-07 0:11.3
#   570   4560 -4.991097159584666e+03 8.4e+02 5.25e-05  4e-08  5e-07 0:12.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:56:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.616658756869745e+03 1.0e+00 4.46e-02  4e-02  5e-02 0:00.0
#     2     16 -4.613646187568467e+03 1.5e+00 4.89e-02  4e-02  6e-02 0:00.0
#     3     24 -4.635596591300727e+03 1.9e+00 6.05e-02  5e-02  7e-02 0:00.1
#   100    800 -4.991097147831495e+03 6.1e+03 8.78e-05  1e-06  9e-05 0:02.1
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.0e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=137)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584685e+03 1.0e+02 1.22e-06  2e-07  2e-06 0:04.5
#   300   2400 -4.991097159584666e+03 5.7e+02 3.48e-07  2e-08  2e-07 0:06.9
#   400   3200 -4.991097159584637e+03 2.3e+03 1.11e-06  2e-08  5e-07 0:09.1
#   500   4000 -4.991097159584669e+03 3.5e+03 1.92e-05  8e-08  2e-06 0:11.4
#   600   4800 -4.991097159584683e+03 3.6e+03 3.71e-05  3e-08  9e-07 0:13.6
#   615   4920 -4.991097159584651e+03 4.3e+03 9.25e-05  6e-08  2e-06 0:14.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:56:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.692911052780513e+03 1.0e+00 4.95e-02  5e-02  5e-02 0:00.0
#     2     16 -4.949693210335277e+03 1.3e+00 4.09e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729548527581192e+03 1.3e+00 3.92e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097146458227e+03 7.6e+03 1.49e-04  1e-06  1e-04 0:02.4
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.3e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=135)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584685e+03 4.8e+02 1.26e-06  8e-07  2e-06 0:04.7
#   300   2400 -4.991097159584653e+03 2.3e+03 5.92e-07  1e-07  5e-07 0:06.7
#   400   3200 -4.991097159584672e+03 1.1e+04 1.10e-05  9e-07  3e-06 0:08.8
#   500   4000 -4.991097159584683e+03 3.9e+03 3.56e-05  8e-07  3e-06 0:10.9
#   505   4040 -4.991097159584674e+03 5.8e+03 3.25e-05  7e-07  3e-06 0:11.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:56:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.4
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=138)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:05.1
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:07.6
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:09.5
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:11.5
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:11.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:56:50 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:01.9
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.2e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=135)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:03.8
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.0
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:08.5
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:10.5
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:57:01 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.1
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.0
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.5
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:57:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.0
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.1
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:57:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.2
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.0e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=156)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.3
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.3
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:08.2
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:10.2
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:12.3
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:12.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:57:24 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:57:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.2
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.2
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:57:29 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.1
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.2e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=141)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.1
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.2
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:08.6
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:10.6
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:11.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:57:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.1
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.4
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:06.7
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:08.9
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:11.2
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:11.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:57:53 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.6
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.8e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=124)
#   warnings.warn(msg + ' (' +
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.7
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:06.8
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:08.9
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:10.9
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:11.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:58:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:01.9
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:03.9
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:06.0
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:08.2
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:10.3
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:10.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:58:16 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.1
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.1
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.1
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:08.1
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:10.3
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:58:28 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.2
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.3
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:58:32 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.1
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.2
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:58:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.1
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.2
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.3
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:08.5
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:11.1
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:13.1
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:13.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:58:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:58:52 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:03.8
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:03.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:58:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.0
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.1
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.0
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:07.9
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:09.8
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:10.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:59:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:01.9
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:03.9
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:05.8
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:07.7
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:09.6
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:09.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:59:17 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.1
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.3
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:06.3
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:08.5
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:10.6
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:10.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:59:29 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.0
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.1
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:06.2
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:08.2
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:10.2
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:10.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:59:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.0
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.0
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.1
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:08.3
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:10.3
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:59:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.2
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.4
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 12:59:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:01.9
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.0
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:00:01 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.0
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.8
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:07.6
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:10.0
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:12.3
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:14.8
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:15.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:00:17 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.1
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:00:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.1
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.8
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:05.0
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:05.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:00:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.2
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.4
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:07.1
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:09.1
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:11.2
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:11.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:00:36 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.0
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.2
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:06.3
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:08.3
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:10.4
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:10.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:00:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.0
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.0
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:06.0
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:08.1
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:10.2
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:10.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:00:58 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.2
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.4
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:07.0
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:09.1
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:11.3
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:11.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:01:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.2
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.5
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.8
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:09.1
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:11.6
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:11.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:01:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.7
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:05.3
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:05.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:01:29 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.5
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:05.0
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:05.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:01:34 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.3
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.5
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.9
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:09.1
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:11.2
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:13.3
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:13.8
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:01:49 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:01:50 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.1
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.2
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:01:54 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.5
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.8
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.8
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:08.8
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:10.9
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:11.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:02:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.0
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.0
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:06.2
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:08.6
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:10.9
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:11.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:02:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.4
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.6
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:06.8
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:09.0
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:11.4
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:11.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:02:30 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.4
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.7
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:07.1
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:09.6
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:11.9
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:12.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:02:43 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.4
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.9
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:07.3
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:09.7
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:12.1
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:12.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:02:57 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.3
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.6
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:03:02 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.2
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.3
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:03:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.2
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.5
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.9
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:09.2
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:11.8
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:14.1
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:14.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:03:22 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:03:22 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.2
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.4
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:03:27 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.2
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.4
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.6
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:08.8
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:11.1
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:11.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:03:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
# ...
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.2
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.5
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.5
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:08.5
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:10.4
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:38:28 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:03.8
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:03.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:38:32 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:01.9
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.0
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:38:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:01.9
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:03.9
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.1
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:08.0
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:10.2
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:12.1
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:12.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:38:50 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:38:50 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.1
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.1
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:38:55 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.2
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.4
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.6
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:09.1
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:11.2
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:11.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:39:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.3
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.3
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:06.5
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:09.3
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:11.7
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:11.8
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:39:20 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.5
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:05.0
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:07.3
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:09.2
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:11.3
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:11.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:39:32 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.4
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.5
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:07.0
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:09.5
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:11.9
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:12.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:39:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.3
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.3
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.2
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:08.1
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:10.2
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:39:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.2
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:40:01 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.0
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.0
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:40:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.1
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.1
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.2
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:08.4
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:10.4
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:12.8
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:13.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:40:20 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:40:20 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.2
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.2
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:40:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.0
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:01.9
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:03.8
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.1
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:08.2
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:10.3
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:10.8
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:40:36 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.3
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.7
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:07.0
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:09.0
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:11.2
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:11.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:40:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.4
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.5
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:06.7
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:08.8
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:10.8
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:10.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:41:00 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:01.9
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:03.8
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:05.7
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:07.6
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:09.4
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:09.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:41:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:01.9
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.2
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.1
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:08.0
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:09.9
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.0
# Harari CMA complete. Total time: 2779.71
# Wall time: 46min 19s

# %%
# %%time
n_starting_points = 30
maxits= 20000
# for maximum of 5. 
for i in ['Harari']:
    cma_region(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], df_all[i])
# Out:
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:41:22 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:03.8
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:03.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:41:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:01.9
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:03.8
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:03.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:41:30 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:01.9
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:05.0
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:07.5
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:09.6
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:11.8
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:14.0
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:14.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:41:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:41:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.0
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.6
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:41:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.0
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.5
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.4
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:08.3
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:10.3
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:10.8
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:42:03 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:01.9
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:03.8
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:05.7
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:07.6
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:10.0
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:10.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:42:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.4
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.8
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:07.1
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:09.1
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:11.1
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:11.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:42:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.0
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:03.9
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:05.9
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:07.9
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:09.8
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:10.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:42:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:01.9
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:03.8
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:05.7
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:07.5
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:09.4
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:09.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:42:47 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:03.7
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:03.8
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:42:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:01.9
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.0
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:42:55 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:01.9
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:03.9
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.0
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:08.3
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:10.3
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:12.3
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:12.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:43:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:43:09 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:03.7
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:03.8
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:43:13 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:01.8
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:03.7
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:05.6
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:07.6
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:09.9
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:10.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:43:24 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.2
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.1
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:06.0
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:08.0
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:10.1
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:10.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:43:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.3
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.6
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:07.1
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:09.3
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:11.5
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:11.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:43:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.0
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:03.8
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:05.8
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:08.0
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:09.9
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:10.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:43:59 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.5
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.8
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.9
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:09.2
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:11.5
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:11.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:44:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:03.8
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:03.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:44:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.1
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.5
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:44:20 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.4
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.7
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:07.1
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:09.4
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:11.5
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:13.6
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:14.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:44:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:44:36 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.0
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.0
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:44:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.2
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.6
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.8
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:09.0
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:11.2
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:11.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:44:53 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.4
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.6
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:07.0
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:09.4
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:12.3
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:12.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:45:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.0
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.1
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:06.4
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:08.5
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:10.6
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:10.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:45:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.2
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.2
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:06.3
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:08.2
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:10.1
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:10.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:45:29 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.0
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:03.9
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:05.8
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:07.9
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:10.2
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:45:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.1
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.4
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.5
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:45:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:01.9
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.5
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:45:50 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.1
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.6
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.8
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:09.1
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:11.3
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:13.7
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:14.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:46:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:46:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.0
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.0
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:46:10 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.2
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.3
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.4
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:08.5
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:10.8
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:11.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:46:22 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.1
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.2
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:05.7
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:08.4
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:11.1
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:13.2
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:13.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:46:36 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:01.9
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:03.9
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:05.9
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:08.2
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:10.6
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:10.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:46:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.2
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.6
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:06.9
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:09.0
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:11.3
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:11.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:47:00 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.7
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:06.1
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:08.8
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:11.1
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:13.9
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:14.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:47:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.1
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.4
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.6
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:47:20 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.6
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.9
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:05.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:47:26 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.4
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.7
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:07.1
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:09.6
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:11.8
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:14.1
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:14.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:47:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:47:42 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.1
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:04.3
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:47:46 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:02.2
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:04.3
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:06.5
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:09.0
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:11.2
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:11.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:47:59 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.1
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.4
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:06.7
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:09.0
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:11.2
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:11.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:48:11 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.6
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:05.1
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:07.4
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:10.2
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:12.4
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:12.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:48:24 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.1
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.4
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:06.7
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:09.1
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:11.0
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:11.2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:48:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.1
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.2
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.4
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:08.6
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:10.8
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:48:48 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:03.9
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:48:52 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.1
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.3
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.6
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:48:58 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:02.5
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.8
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.9
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:08.8
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:10.7
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:12.6
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:13.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:49:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:49:12 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:01.9
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:03.7
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:03.8
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:49:16 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.0
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:01.8
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:03.7
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:05.7
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:08.0
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:10.3
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:10.8
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:49:28 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.3
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.6
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:07.0
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:09.5
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:11.9
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:12.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:49:40 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.0
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.1
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:06.6
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:09.1
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:11.5
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:11.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:49:53 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.7
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.9
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:06.9
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:09.1
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:11.3
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:11.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:50:05 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.4
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.7
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:07.0
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:09.2
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:11.5
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:11.6
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:50:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.2
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.6
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.7
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 13:50:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.2
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:04.3
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.4
# ...
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:02.0
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:04.1
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:06.0
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:07.9
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:09.9
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:10.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:05:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:01.9
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:03.8
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:05.7
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:08.0
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:10.2
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:10.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:05:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:02.0
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:04.0
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:06.3
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:08.3
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:10.3
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:10.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:06:08 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.0
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.0
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:05.9
#   400   3200 -4.991097159584671e+03 8.4e+02 7.29e-06  1e-07  7e-07 0:07.9
#   500   4000 -4.991097159584602e+03 2.5e+03 4.80e-05  5e-07  3e-06 0:09.9
#   505   4040 -4.991097159584651e+03 1.9e+03 9.23e-05  8e-07  4e-06 0:10.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:06:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.701362091721219e+03 1.0e+00 5.97e-03  5e-03  6e-03 0:00.0
#     2     16 -4.708643552256774e+03 1.3e+00 7.14e-03  7e-03  8e-03 0:00.0
#     3     24 -4.774072814196464e+03 1.6e+00 9.15e-03  8e-03  1e-02 0:00.1
#   100    800 -4.993595685058142e+03 2.0e+03 1.57e-05  2e-08  3e-05 0:02.0
# NOTE (module=cma, iteration=124):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.3e+00
#   200   1600 -4.993595713137431e+03 2.7e+02 3.13e-08  4e-14  6e-08 0:04.0
#   205   1640 -4.993595713137443e+03 4.0e+02 1.58e-08  1e-14  3e-08 0:04.1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:06:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648060830732045e+03 1.0e+00 1.40e-02  1e-02  2e-02 0:00.0
#     2     16 -4.657695511691347e+03 1.3e+00 1.37e-02  1e-02  1e-02 0:00.0
#     3     24 -4.684315031889696e+03 1.2e+00 1.43e-02  1e-02  1e-02 0:00.1
#   100    800 -4.993595642517564e+03 1.1e+02 1.50e-05  5e-08  5e-06 0:02.0
# NOTE (module=cma, iteration=163):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 3.4e+00
#   200   1600 -4.993595713137451e+03 4.9e+01 1.17e-08  2e-14  6e-09 0:03.9
#   205   1640 -4.993595713137460e+03 5.9e+01 7.53e-09  1e-14  4e-09 0:04.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:06:27 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.646494548121680e+03 1.0e+00 1.75e-02  2e-02  2e-02 0:00.0
#     2     16 -4.644244598639247e+03 1.2e+00 1.83e-02  1e-02  2e-02 0:00.0
#     3     24 -4.649534189774644e+03 1.5e+00 1.57e-02  1e-02  2e-02 0:00.1
#   100    800 -4.991097156458578e+03 2.2e+03 3.08e-05  8e-07  2e-05 0:01.9
#   200   1600 -4.991097159584167e+03 5.3e+00 1.25e-07  3e-08  1e-07 0:04.0
#   300   2400 -4.991097159584488e+03 6.2e+01 5.02e-08  2e-09  3e-08 0:06.0
#   400   3200 -4.991097159584637e+03 1.5e+02 1.14e-07  8e-10  2e-08 0:08.1
#   500   4000 -4.991097159584679e+03 2.1e+02 3.01e-07  3e-10  1e-08 0:10.0
#   600   4800 -4.991097159584436e+03 2.7e+02 1.45e-06  3e-10  1e-08 0:12.0
#   620   4960 -4.991097159584091e+03 6.4e+02 3.85e-06  8e-10  4e-08 0:12.5
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:06:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.334556051806679e+03 1.0e+00 2.57e-02  2e-02  3e-02 0:00.0
#     2     16 -4.341853816171000e+03 1.3e+00 2.44e-02  2e-02  3e-02 0:00.0
#     3     24 -4.337068644841709e+03 1.4e+00 2.19e-02  2e-02  2e-02 0:00.1
#    20    160 -4.347272568049000e+03 4.4e+00 7.53e-03  4e-03  6e-03 0:00.4
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:06:41 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.706408543219757e+03 1.0e+00 3.59e-02  3e-02  4e-02 0:00.0
#     2     16 -4.972479994575273e+03 1.4e+00 4.65e-02  4e-02  5e-02 0:00.0
#     3     24 -4.748572148277990e+03 1.5e+00 4.86e-02  4e-02  5e-02 0:00.1
#   100    800 -4.993595675468038e+03 1.6e+03 2.12e-05  2e-08  3e-05 0:02.0
# NOTE (module=cma, iteration=130):
# condition in coordinate system exceeded 1.4e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 1.7e+01
#   200   1600 -4.993595713137460e+03 4.5e+02 2.87e-08  4e-14  8e-08 0:03.9
#   206   1648 -4.993595713137460e+03 7.0e+02 1.20e-08  1e-14  3e-08 0:04.0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:06:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.536537824038450e+03 1.0e+00 4.17e-02  4e-02  5e-02 0:00.0
#     2     16 -4.572187626646253e+03 1.5e+00 3.56e-02  3e-02  4e-02 0:00.0
#     3     24 -4.729188120303705e+03 1.8e+00 3.67e-02  3e-02  5e-02 0:00.1
#   100    800 -4.991097131743812e+03 5.8e+03 1.50e-04  2e-06  2e-04 0:01.9
#   200   1600 -4.991097159584626e+03 2.1e+02 1.63e-06  8e-07  2e-06 0:03.9
#   300   2400 -4.991097159584682e+03 4.7e+02 2.64e-07  3e-08  7e-08 0:05.9
#   400   3200 -4.991097159584668e+03 1.1e+03 5.52e-06  3e-07  9e-07 0:07.9
#   500   4000 -4.991097159584678e+03 1.2e+03 2.31e-05  4e-07  1e-06 0:09.9
#   520   4160 -4.991097159584641e+03 1.6e+03 2.02e-05  3e-07  8e-07 0:10.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:06:56 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.641727030247449e+03 1.0e+00 3.98e-02  4e-02  4e-02 0:00.0
#     2     16 -4.527323738343013e+03 1.2e+00 3.60e-02  3e-02  4e-02 0:00.0
#     3     24 -4.611518822047830e+03 1.3e+00 3.84e-02  4e-02  4e-02 0:00.1
#   100    800 -4.991097139157092e+03 1.4e+03 8.78e-05  1e-06  4e-05 0:01.9
#   200   1600 -4.991097159584659e+03 4.1e+00 4.46e-07  2e-07  3e-07 0:03.9
#   300   2400 -4.991097159584660e+03 1.0e+02 2.47e-07  2e-08  1e-07 0:05.9
#   400   3200 -4.991097159584637e+03 3.1e+02 6.27e-07  1e-08  2e-07 0:07.8
#   500   4000 -4.991097159584644e+03 1.6e+03 9.85e-06  6e-08  3e-06 0:09.8
#   505   4040 -4.991097159584476e+03 1.7e+03 1.02e-05  6e-08  3e-06 0:09.9
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:07:07 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.648974724293013e+03 1.0e+00 5.35e-02  5e-02  6e-02 0:00.0
#     2     16 -4.774431842509877e+03 1.5e+00 4.55e-02  3e-02  5e-02 0:00.0
#     3     24 -4.797542857250336e+03 1.8e+00 4.01e-02  3e-02  4e-02 0:00.1
#   100    800 -4.991097156140797e+03 3.6e+04 9.76e-05  7e-07  2e-04 0:02.0
#   200   1600 -4.991097159584685e+03 6.6e+02 5.96e-07  3e-08  6e-07 0:04.1
#   300   2400 -4.991097159584641e+03 1.8e+03 4.60e-07  3e-08  3e-07 0:06.3
#   400   3200 -4.991097159584670e+03 8.1e+03 6.78e-06  2e-07  3e-06 0:08.3
#   500   4000 -4.991097159584679e+03 1.0e+04 3.80e-05  2e-07  2e-06 0:10.2
#   505   4040 -4.991097159584681e+03 8.1e+03 3.99e-05  2e-07  2e-06 0:10.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:07:18 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.630166241535343e+03 1.0e+00 6.42e-02  6e-02  7e-02 0:00.0
#     2     16 -4.725414664053891e+03 1.5e+00 5.39e-02  4e-02  7e-02 0:00.0
#     3     24 -4.918841476253897e+03 1.9e+00 5.06e-02  4e-02  6e-02 0:00.1
#   100    800 -4.991097157579186e+03 1.3e+04 2.57e-05  3e-07  2e-05 0:01.9
#   200   1600 -4.991097159584670e+03 6.8e+01 1.83e-07  4e-08  2e-07 0:03.8
#   300   2400 -4.991097159584637e+03 3.4e+02 9.74e-07  5e-08  9e-07 0:05.9
#   400   3200 -4.991097159584671e+03 1.6e+03 1.54e-05  2e-06  1e-05 0:08.0
#   500   4000 -4.991097159584649e+03 2.9e+03 1.20e-05  4e-07  3e-06 0:10.1
#   510   4080 -4.991097159584644e+03 2.0e+03 1.74e-05  5e-07  3e-06 0:10.3
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=1234, Mon Sep  5 14:07:29 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 -4.569631782934011e+03 1.0e+00 6.40e-02  6e-02  7e-02 0:00.0
#     2     16 -4.805648698424073e+03 1.1e+00 5.90e-02  6e-02  6e-02 0:00.0
#     3     24 -4.709672818484622e+03 1.2e+00 5.70e-02  5e-02  6e-02 0:00.1
#   100    800 -4.991097157380384e+03 1.3e+04 3.62e-05  3e-07  3e-05 0:02.0
#   200   1600 -4.991097159584650e+03 8.3e+01 2.34e-06  4e-07  2e-06 0:04.2
#   300   2400 -4.991097159584660e+03 2.5e+02 1.01e-06  7e-08  2e-07 0:06.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-366-0bdc61ac1c6e> in cma_region(n, n_starting_points, max_iterations, data, data_sub, set_sigma)
#      48             es = cma.CMAEvolutionStrategy(generate_sp_proposed(sp, n).flatten(), sigma0=j,
#      49                                       inopts={'bounds': cma_bounds,'seed':1234})
# ---> 50             es.optimize(f, iterations=(max_iterations/ es.popsize))
#      51             fcma.append((es.result[1], es.result[0].reshape(n, 2), (time.time() - start_time), j))
#      52
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\interfaces.py in optimize(self, objective_fct, maxfun, iterations, min_iterations, args, verb_disp, callback, n_jobs, **kwargs)
#     206                 X = self.ask()  # deliver candidate solutions
#     207                 # fitvals = [objective_fct(x, *args) for x in X]
# --> 208                 fitvals = eval_all(X, args=args)
#     209                 cevals += len(fitvals)
#     210                 self.tell(X, fitvals)  # all the work is done here
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in __call__(self, solutions, fitness_function, args, timeout)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in <listcomp>(.0)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# <ipython-input-366-0bdc61ac1c6e> in f(x)
#      29         """
#      30         x = x.reshape(n,2) # reshape for input into expected enrolment.
# ---> 31         ee = expected_enrollment(df_ms_loc_sub, x, df_ms_enrol_sub, current_ms_dist_sub, ee_old_constant) # fitness function.
#      32         return ee*-1 # Multiply by -1 for maximising.
#      33
#
# <ipython-input-327-de7e669993ae> in expected_enrollment(middle_loc, x, middle_enroll, current_dist, ee_old_constant)
#      30     # index 0 = x, index 1 = MS, index 2 = distance, index 3 = shaped enrollment
#      31     d3 = pd.DataFrame(np.vstack((d_index[d2], d2[0], d_min[d2], shape(d_min[d2], middle_enroll[d2[0]]))).T)
# ---> 32     d32 = d3.loc[d3.groupby([1])[2].idxmin()] # find only nearby SS if MS is close to more than 1 SS.
#      33     d32 = d32.groupby(0)[3].sum() # The overall shaped enrollment for each school in x.
#      34     eei = np.sum(d32) # overall expected enrollment increase for each school in x.
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\groupby.py in wrapper(*args, **kwargs)
#     766
#     767             try:
# --> 768                 return self._python_apply_general(curried, self._obj_with_exclusions)
#     769             except TypeError as err:
#     770                 if not re.search(
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     890             data after applying f
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#     894         return self._wrap_applied_output(
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     162         result_values = None
#     163
# --> 164         sdata: FrameOrSeries = splitter._get_sorted_data()
#     165         if sdata.ndim == 2 and np.any(sdata.dtypes.apply(is_extension_array_dtype)):
#     166             # calling splitter.fast_apply will raise TypeError via apply_frame_axis0
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\ops.py in _get_sorted_data(self)
#     946
#     947     def _get_sorted_data(self) -> FrameOrSeries:
# --> 948         return self.data.take(self.sort_idx, axis=self.axis)
#     949
#     950     def _chop(self, sdata, slice_obj: slice) -> NDFrame:
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py in take(self, indices, axis, is_copy, **kwargs)
#     830
#     831         indices = ensure_platform_int(indices)
# --> 832         new_index = self.index.take(indices)
#     833         new_values = self._values.take(indices)
#     834
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#     718                     f"Unable to fill values because {cls_name} cannot contain NA"
#     719                 )
# --> 720             taken = self._values.take(indices)
#     721         return self._shallow_copy(taken)
#     722
#
# KeyboardInterrupt:

# %%
# %%time
n_starting_points = 30
maxits= 10000
# for maximum of 5. 
for i in ['Dire Dawa']:
    cma_region(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], df_all[i])
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:07:37 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.837057598085857e+03 1.0e+00 1.05e-02  1e-02  1e-02 0:00.0
#     2     20 -1.835963661451005e+03 1.2e+00 1.05e-02  1e-02  1e-02 0:00.1
#     3     30 -1.925204093620164e+03 1.3e+00 1.05e-02  1e-02  1e-02 0:00.1
#    96    960 -2.919897183606885e+03 3.8e+01 5.73e-04  3e-05  1e-03 0:03.1
#   100   1000 -2.919885651578026e+03 4.6e+01 5.17e-04  2e-05  1e-03 0:03.3
#   200   2000 -2.919924268874769e+03 2.9e+03 7.42e-05  1e-07  2e-04 0:06.6
# NOTE (module=cma, iteration=238):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.0e+08 to 1.9e+02
#   300   3000 -2.919924332873761e+03 2.8e+01 2.16e-06  5e-11  8e-06 0:10.2
#   400   4000 -2.919924332980169e+03 1.7e+03 1.22e-07  5e-14  4e-07 0:13.3
#   411   4110 -2.919924332980155e+03 2.9e+03 6.08e-08  2e-14  2e-07 0:13.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:07:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.251453067352552e+03 1.0e+00 2.21e-02  2e-02  2e-02 0:00.0
#     2     20 -2.605683817226834e+03 1.2e+00 2.50e-02  2e-02  3e-02 0:00.1
#     3     30 -2.627813956375760e+03 1.4e+00 2.73e-02  3e-02  3e-02 0:00.1
#    95    950 -3.234997956672672e+03 1.4e+01 4.84e-04  5e-05  6e-04 0:03.1
#   100   1000 -3.235126181540545e+03 1.7e+01 4.96e-04  4e-05  6e-04 0:03.3
#   200   2000 -3.235195602058528e+03 2.4e+02 4.33e-06  5e-08  1e-05 0:06.3
#   300   3000 -3.235195750494253e+03 4.1e+03 2.90e-07  3e-10  9e-07 0:09.3
# NOTE (module=cma, iteration=357):
# condition in coordinate system exceeded 1.2e+08, rescaled to 1.0e+00,
# condition changed from 1.5e+08 to 7.4e+01
#   400   4000 -3.235195751733904e+03 1.1e+01 2.95e-09  4e-13  1e-08 0:12.3
#   457   4570 -3.235195751735243e+03 5.5e+01 3.74e-10  2e-14  2e-09 0:14.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:08:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.804521341328169e+03 1.0e+00 3.15e-02  3e-02  3e-02 0:00.0
#     2     20 -1.950155919093532e+03 1.3e+00 3.40e-02  3e-02  4e-02 0:00.0
#     3     30 -1.945240195182662e+03 1.5e+00 3.48e-02  3e-02  4e-02 0:00.1
#   100   1000 -3.129812466610735e+03 2.1e+01 1.25e-03  1e-04  2e-03 0:02.8
#   200   2000 -3.130192513383824e+03 2.0e+02 1.16e-04  1e-06  2e-04 0:06.0
#   300   3000 -3.130195737778671e+03 3.0e+03 3.44e-06  3e-09  8e-06 0:08.8
# NOTE (module=cma, iteration=332):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.2e+08 to 1.5e+01
#   400   4000 -3.130195751702679e+03 3.7e+01 1.47e-07  2e-11  1e-06 0:11.8
#   500   5000 -3.130195751735136e+03 3.6e+02 2.24e-09  3e-14  2e-08 0:14.8
#   532   5320 -3.130195751735256e+03 1.1e+03 2.27e-09  1e-14  4e-08 0:15.8
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:08:23 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.036761744211830e+03 1.0e+00 4.49e-02  4e-02  5e-02 0:00.0
#     2     20 -1.931879748569672e+03 1.2e+00 4.39e-02  4e-02  4e-02 0:00.0
#     3     30 -2.002929642797935e+03 1.3e+00 4.61e-02  4e-02  5e-02 0:00.1
#    99    990 -2.560000000000000e+03 1.1e+01 1.10e-03  2e-04  1e-03 0:02.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:08:25 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.979511338422554e+03 1.0e+00 4.66e-02  5e-02  5e-02 0:00.0
#     2     20 -2.180931762460270e+03 1.2e+00 4.79e-02  4e-02  5e-02 0:00.1
#     3     30 -2.172328897232645e+03 1.4e+00 4.74e-02  4e-02  5e-02 0:00.1
#   100   1000 -3.234314450004646e+03 1.6e+01 1.38e-03  1e-04  2e-03 0:02.9
#   200   2000 -3.235193554322219e+03 1.4e+02 9.60e-05  1e-06  2e-04 0:06.1
#   300   3000 -3.235195728947172e+03 2.4e+03 2.55e-06  2e-09  5e-06 0:09.2
# NOTE (module=cma, iteration=386):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 2.3e+01
#   400   4000 -3.235195751697150e+03 4.8e+00 1.02e-07  1e-11  2e-07 0:12.5
#   500   5000 -3.235195751735103e+03 6.9e+01 3.75e-09  5e-14  1e-08 0:15.5
#   515   5150 -3.235195751735204e+03 9.5e+01 1.52e-09  2e-14  4e-09 0:16.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:08:42 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.061162524858283e+03 1.0e+00 5.67e-02  5e-02  6e-02 0:00.0
#     2     20 -2.190282201703508e+03 1.2e+00 5.80e-02  5e-02  6e-02 0:00.0
#     3     30 -2.271170980046471e+03 1.3e+00 6.43e-02  6e-02  7e-02 0:00.1
#   100   1000 -3.333513885702054e+03 1.6e+01 2.71e-03  2e-04  3e-03 0:03.1
#   200   2000 -3.333860112683250e+03 9.6e+02 1.05e-04  3e-07  2e-04 0:06.5
# NOTE (module=cma, iteration=272):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.4e+08 to 4.7e+01
#   300   3000 -3.333860323613806e+03 9.1e+00 2.14e-06  9e-11  3e-06 0:10.0
#   400   4000 -3.333860323794725e+03 6.3e+02 6.83e-07  6e-13  2e-06 0:13.1
#   446   4460 -3.333860323795177e+03 6.2e+03 1.16e-07  2e-14  4e-07 0:14.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:08:57 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.909592670420550e+03 1.0e+00 6.70e-02  6e-02  7e-02 0:00.0
#     2     20 -3.062789889791503e+03 1.2e+00 6.75e-02  6e-02  7e-02 0:00.1
#     3     30 -3.112837965618268e+03 1.3e+00 6.86e-02  6e-02  7e-02 0:00.1
#    90    900 -3.356518952106488e+03 1.8e+01 1.85e-03  4e-04  3e-03 0:03.2
#   100   1000 -3.356752962884829e+03 2.0e+01 1.76e-03  4e-04  3e-03 0:03.6
#   200   2000 -3.357006513585060e+03 2.0e+02 2.15e-05  1e-06  3e-05 0:06.9
#   300   3000 -3.357007568295342e+03 1.6e+03 2.29e-06  2e-08  4e-06 0:10.2
#   400   4000 -3.357007574091162e+03 1.5e+04 1.76e-08  2e-11  4e-08 0:13.5
# NOTE (module=cma, iteration=476):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 5.5e+09 to 1.6e+02
#   500   5000 -3.357007574100586e+03 1.6e+01 3.33e-10  4e-14  8e-10 0:17.1
#   529   5290 -3.357007574100604e+03 2.0e+01 2.49e-10  2e-14  5e-10 0:18.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:09:16 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.045175325630326e+03 1.0e+00 7.68e-02  7e-02  8e-02 0:00.0
#     2     20 -2.207553343247949e+03 1.2e+00 7.31e-02  7e-02  7e-02 0:00.1
#     3     30 -2.318401314825590e+03 1.3e+00 7.74e-02  7e-02  8e-02 0:00.1
#    81    810 -3.487064009185000e+03 6.2e+00 6.57e-03  1e-03  6e-03 0:02.5
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:09:19 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.587085599887153e+03 1.0e+00 8.30e-02  8e-02  8e-02 0:00.0
#     2     20 -2.691098065363847e+03 1.2e+00 7.47e-02  7e-02  8e-02 0:00.1
#     3     30 -2.819443154947627e+03 1.3e+00 6.91e-02  6e-02  7e-02 0:00.1
#   100   1000 -3.499592879141544e+03 2.5e+01 7.34e-04  4e-05  9e-04 0:03.1
#   200   2000 -3.499952639622945e+03 2.8e+02 5.72e-06  3e-08  9e-06 0:06.5
#   300   3000 -3.499952800691981e+03 4.5e+03 2.14e-07  1e-10  6e-07 0:09.9
# NOTE (module=cma, iteration=326):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.1e+08 to 2.1e+01
#   400   4000 -3.499952801792436e+03 1.8e+01 1.29e-08  1e-12  5e-08 0:13.3
#   459   4590 -3.499952801800559e+03 1.0e+02 7.16e-10  2e-14  2e-09 0:15.2
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:09:35 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.665615915944507e+03 1.0e+00 9.21e-02  9e-02  9e-02 0:00.0
#     2     20 -2.650066366167021e+03 1.2e+00 8.37e-02  8e-02  9e-02 0:00.1
#     3     30 -3.086369255424057e+03 1.3e+00 8.65e-02  8e-02  9e-02 0:00.1
#   100   1000 -3.812191488793307e+03 8.6e+00 1.11e-03  1e-04  9e-04 0:02.9
#   200   2000 -3.813192964020524e+03 1.0e+02 3.72e-05  5e-07  5e-05 0:06.0
#   300   3000 -3.813195737745882e+03 1.9e+03 9.12e-07  1e-09  2e-06 0:09.1
# NOTE (module=cma, iteration=392):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.8e+08 to 3.2e+01
#   400   4000 -3.813195751709904e+03 6.2e+00 2.29e-08  5e-12  6e-08 0:12.6
#   488   4880 -3.813195751735163e+03 3.4e+01 4.39e-10  2e-14  1e-09 0:15.6
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:09:51 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.964134964649620e+03 1.0e+00 9.71e-03  9e-03  1e-02 0:00.0
#     2     20 -1.959620802060397e+03 1.2e+00 9.95e-03  9e-03  1e-02 0:00.1
#     3     30 -1.972477718526443e+03 1.3e+00 9.77e-03  9e-03  1e-02 0:00.1
#    95    950 -3.215292983280477e+03 1.2e+01 5.68e-04  7e-05  7e-04 0:03.1
#   100   1000 -3.215496636480759e+03 1.4e+01 4.44e-04  4e-05  5e-04 0:03.3
#   200   2000 -3.215956478652102e+03 1.7e+02 1.40e-05  2e-07  2e-05 0:06.5
#   300   3000 -3.215957259369618e+03 2.3e+03 6.95e-07  7e-10  1e-06 0:09.4
# NOTE (module=cma, iteration=355):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.1e+08 to 2.8e+01
#   400   4000 -3.215957261904561e+03 1.1e+01 1.41e-08  2e-12  5e-08 0:12.2
#   463   4630 -3.215957261916917e+03 5.5e+01 4.70e-10  2e-14  1e-09 0:14.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:10:06 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.088394998227370e+03 1.0e+00 2.13e-02  2e-02  2e-02 0:00.0
#     2     20 -2.092728235299880e+03 1.3e+00 2.02e-02  2e-02  2e-02 0:00.0
#     3     30 -2.273399896827899e+03 1.3e+00 2.15e-02  2e-02  2e-02 0:00.1
#   100   1000 -2.451575616675918e+03 4.1e+01 2.64e-04  1e-05  4e-04 0:02.3
#   200   2000 -2.451621831781730e+03 2.7e+03 5.42e-06  4e-09  9e-06 0:04.6
# NOTE (module=cma, iteration=232):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.1e+08 to 3.6e+01
#   300   3000 -2.451621833953438e+03 6.2e+01 5.52e-07  8e-12  3e-06 0:07.1
#   381   3810 -2.451621833976978e+03 1.8e+03 3.21e-08  2e-14  2e-07 0:09.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:10:15 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.139734662215525e+03 1.0e+00 3.10e-02  3e-02  3e-02 0:00.0
#     2     20 -2.093325174981817e+03 1.3e+00 3.25e-02  3e-02  3e-02 0:00.0
#     3     30 -2.219216082915716e+03 1.4e+00 3.39e-02  3e-02  4e-02 0:00.1
#   100   1000 -2.623654267789352e+03 1.0e+02 1.12e-03  1e-04  2e-03 0:02.9
#   200   2000 -2.623672110107986e+03 3.9e+03 1.48e-04  7e-07  3e-04 0:05.7
# NOTE (module=cma, iteration=291):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.6e+10 to 4.4e+02
#   300   3000 -2.623672146030078e+03 2.8e+01 1.04e-05  2e-09  2e-05 0:08.3
#   400   4000 -2.623672146160363e+03 7.2e+02 6.41e-07  3e-12  1e-06 0:11.2
#   487   4870 -2.623672146160523e+03 4.8e+03 5.04e-08  2e-14  1e-07 0:13.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:10:30 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.812385839874933e+03 1.0e+00 3.75e-02  4e-02  4e-02 0:00.0
#     2     20 -2.832573748672974e+03 1.2e+00 3.92e-02  4e-02  4e-02 0:00.1
#     3     30 -2.959999642346380e+03 1.3e+00 4.24e-02  4e-02  5e-02 0:00.1
#   100   1000 -3.596586048428428e+03 1.1e+01 5.52e-03  7e-04  7e-03 0:02.8
#   200   2000 -3.597680767481823e+03 8.5e+02 2.56e-04  6e-07  4e-04 0:05.7
# NOTE (module=cma, iteration=254):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 1.7e+08 to 1.6e+02
#   300   3000 -3.597681378816520e+03 2.5e+01 3.91e-05  1e-09  1e-04 0:09.2
#   400   4000 -3.597681383044343e+03 1.4e+03 1.99e-06  1e-12  6e-06 0:12.6
#   449   4490 -3.597681383045540e+03 1.8e+04 2.44e-07  2e-14  1e-06 0:14.3
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:10:45 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.326514789605862e+03 1.0e+00 4.92e-02  5e-02  5e-02 0:00.0
#     2     20 -2.394414022076932e+03 1.2e+00 5.05e-02  5e-02  5e-02 0:00.1
#     3     30 -2.393684604684605e+03 1.3e+00 5.07e-02  5e-02  5e-02 0:00.1
#   100   1000 -3.154597673619871e+03 2.7e+01 1.70e-03  3e-04  2e-03 0:02.6
#   200   2000 -3.154671979113083e+03 1.5e+03 1.34e-04  1e-06  2e-04 0:05.7
# NOTE (module=cma, iteration=298):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 5.2e+09 to 2.6e+02
#   300   3000 -3.154672145680178e+03 1.5e+01 1.70e-05  4e-09  4e-05 0:08.9
#   400   4000 -3.154672146157234e+03 5.5e+02 3.33e-06  3e-11  9e-06 0:11.9
#   500   5000 -3.154672146160508e+03 5.2e+04 4.12e-07  1e-13  2e-06 0:14.6
#   504   5040 -3.154672146160523e+03 6.1e+04 4.67e-07  1e-13  3e-06 0:14.7
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:11:00 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.266160711348746e+03 1.0e+00 5.90e-02  6e-02  6e-02 0:00.0
#     2     20 -2.321318256691636e+03 1.2e+00 6.11e-02  6e-02  7e-02 0:00.1
#     3     30 -2.189212878356939e+03 1.3e+00 6.60e-02  6e-02  7e-02 0:00.1
#   100   1000 -2.662037276603582e+03 1.8e+01 4.13e-04  8e-05  4e-04 0:02.5
#   200   2000 -2.662141289132288e+03 2.7e+02 3.99e-06  8e-08  4e-06 0:05.1
#   300   3000 -2.662141463442574e+03 6.6e+03 9.26e-07  1e-09  2e-06 0:08.0
# NOTE (module=cma, iteration=374):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 4.1e+09 to 1.1e+09
#   400   4000 -2.662141465059098e+03 5.7e+04 1.79e-08  2e-12  4e-08 0:10.8
#   479   4790 -2.662141464959914e+03 1.2e+00 4.24e-09  4e-09  4e-09 0:13.1
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:11:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.570177564286706e+03 1.0e+00 7.17e-02  7e-02  7e-02 0:00.0
#     2     20 -3.019855607083133e+03 1.2e+00 6.92e-02  6e-02  7e-02 0:00.1
#     3     30 -2.680579936882868e+03 1.3e+00 6.70e-02  6e-02  7e-02 0:00.1
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\utilities\utils.py:343: UserWarning:
#         geno-pheno transformation introduced based on the
#         current covariance matrix with condition 1.1e+12 -> 1.0e+00,
#         injected solutions become "invalid" in this iteration (class=CMAEvolutionStrategy method=alleviate_conditioning iteration=477)
#   warnings.warn(msg + ' (' +
#   100   1000 -3.597639127930529e+03 2.0e+01 2.00e-03  2e-04  3e-03 0:03.0
#   200   2000 -3.597681034885688e+03 1.8e+03 5.65e-05  9e-08  1e-04 0:06.2
# NOTE (module=cma, iteration=252):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.5e+08 to 2.5e+02
#   300   3000 -3.597681382901275e+03 1.7e+01 1.88e-06  6e-11  5e-06 0:09.6
#   400   4000 -3.597681383045129e+03 1.3e+03 5.97e-07  3e-13  3e-06 0:12.6
#   441   4410 -3.597681383045524e+03 1.0e+04 2.23e-07  2e-14  1e-06 0:13.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:11:29 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.750719208621461e+03 1.0e+00 8.06e-02  7e-02  8e-02 0:00.0
#     2     20 -2.691618654181742e+03 1.3e+00 7.55e-02  7e-02  8e-02 0:00.1
#     3     30 -3.078712957086684e+03 1.3e+00 7.42e-02  7e-02  8e-02 0:00.1
#   100   1000 -3.597412502811731e+03 7.0e+00 1.85e-03  3e-04  2e-03 0:02.8
#   200   2000 -3.597681126058613e+03 6.6e+02 5.49e-05  1e-07  9e-05 0:06.2
# NOTE (module=cma, iteration=265):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.3e+08 to 3.5e+01
#   300   3000 -3.597681382862129e+03 6.7e+00 4.71e-06  3e-10  1e-05 0:09.3
#   400   4000 -3.597681383044935e+03 7.2e+02 8.43e-07  7e-13  2e-06 0:12.4
#   446   4460 -3.597681383045540e+03 4.9e+03 1.22e-07  1e-14  3e-07 0:13.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:11:43 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.897060570627084e+03 1.0e+00 8.10e-02  8e-02  8e-02 0:00.0
#     2     20 -3.060239064090675e+03 1.2e+00 8.55e-02  8e-02  9e-02 0:00.1
#     3     30 -2.672454525117912e+03 1.3e+00 8.47e-02  8e-02  9e-02 0:00.1
#   100   1000 -3.807593610271171e+03 6.9e+00 7.32e-03  1e-03  8e-03 0:03.1
#   200   2000 -3.813186893218332e+03 6.2e+01 8.64e-05  2e-06  9e-05 0:06.2
#   300   3000 -3.813195748824686e+03 4.6e+02 6.68e-07  2e-09  5e-07 0:09.3
#   400   4000 -3.813195751727574e+03 4.7e+03 8.47e-09  2e-12  1e-08 0:12.6
# NOTE (module=cma, iteration=438):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.2e+08 to 7.5e+01
#   477   4770 -3.813195751735171e+03 1.0e+01 2.19e-10  2e-14  2e-10 0:14.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:11:59 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.304818037770479e+03 1.0e+00 9.83e-02  9e-02  1e-01 0:00.0
#     2     20 -2.283572483245661e+03 1.2e+00 9.19e-02  9e-02  9e-02 0:00.0
#     3     30 -2.429946531012756e+03 1.2e+00 9.32e-02  9e-02  1e-01 0:00.1
#   100   1000 -3.427445856738681e+03 2.3e+01 1.97e-03  1e-04  3e-03 0:02.9
#   200   2000 -3.427617230304954e+03 2.4e+03 7.80e-05  1e-07  2e-04 0:06.4
# NOTE (module=cma, iteration=232):
# condition in coordinate system exceeded 1.1e+08, rescaled to 1.0e+00,
# condition changed from 2.0e+08 to 3.3e+02
#   300   3000 -3.427617373721319e+03 5.3e+01 1.11e-05  2e-10  6e-05 0:09.7
#   400   4000 -3.427617373860253e+03 5.9e+03 1.00e-06  3e-13  1e-05 0:12.8
# NOTE (module=cma, iteration=427):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 4.5e+08 to 1.3e+03
#   450   4500 -3.427617373860493e+03 5.2e+01 3.74e-07  2e-14  4e-06 0:14.4
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:12:14 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -1.823216440746206e+03 1.0e+00 1.01e-02  1e-02  1e-02 0:00.0
#     2     20 -1.930464253387072e+03 1.2e+00 1.14e-02  1e-02  1e-02 0:00.1
#     3     30 -1.995204391210392e+03 1.4e+00 1.27e-02  1e-02  1e-02 0:00.1
#    97    970 -2.482193406908644e+03 2.4e+01 1.07e-03  1e-04  2e-03 0:03.1
#   100   1000 -2.482525663731306e+03 2.7e+01 8.20e-04  9e-05  2e-03 0:03.2
#   200   2000 -2.482621756085757e+03 3.2e+03 2.03e-05  3e-08  6e-05 0:06.1
# NOTE (module=cma, iteration=227):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.9e+08 to 1.8e+02
#   300   3000 -2.482621833822260e+03 5.1e+01 2.14e-06  5e-11  1e-05 0:08.8
#   400   4000 -2.482621833976735e+03 3.4e+03 3.08e-07  1e-13  2e-06 0:11.4
#   422   4220 -2.482621833976968e+03 8.5e+03 1.26e-07  2e-14  7e-07 0:12.0
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:12:27 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.492173226374890e+03 1.0e+00 2.04e-02  2e-02  2e-02 0:00.0
#     2     20 -2.601275938104955e+03 1.3e+00 1.93e-02  2e-02  2e-02 0:00.1
#     3     30 -2.753225490097797e+03 1.3e+00 2.00e-02  2e-02  2e-02 0:00.1
#    99    990 -2.937546537000861e+03 4.0e+01 9.19e-04  5e-05  2e-03 0:03.1
#   100   1000 -2.937584837553382e+03 3.9e+01 9.10e-04  5e-05  2e-03 0:03.2
#   200   2000 -2.937952504051852e+03 3.0e+02 8.62e-06  6e-08  1e-05 0:06.6
#   300   3000 -2.937952799967023e+03 4.2e+03 5.11e-07  3e-10  1e-06 0:09.8
# NOTE (module=cma, iteration=354):
# condition in coordinate system exceeded 1.2e+08, rescaled to 1.0e+00,
# condition changed from 1.6e+08 to 7.9e+01
#   400   4000 -2.937952801798010e+03 1.7e+01 5.03e-09  4e-13  2e-08 0:13.1
#   456   4560 -2.937952801800539e+03 9.2e+01 5.71e-10  2e-14  3e-09 0:14.9
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:12:42 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.551654244475425e+03 1.0e+00 3.12e-02  3e-02  3e-02 0:00.0
#     2     20 -2.623860758900460e+03 1.2e+00 3.30e-02  3e-02  4e-02 0:00.1
#     3     30 -2.838036374590528e+03 1.3e+00 3.46e-02  3e-02  4e-02 0:00.1
#   100   1000 -3.113653670298763e+03 7.0e+01 9.79e-04  1e-04  2e-03 0:03.0
#   200   2000 -3.113672101257884e+03 5.0e+03 7.53e-05  3e-07  2e-04 0:06.1
# NOTE (module=cma, iteration=277):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 1.3e+10 to 2.7e+02
#   300   3000 -3.113672146076783e+03 4.0e+01 1.29e-05  1e-09  4e-05 0:09.0
#   400   4000 -3.113672146160366e+03 1.1e+03 5.52e-07  2e-12  2e-06 0:11.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-366-0bdc61ac1c6e> in cma_region(n, n_starting_points, max_iterations, data, data_sub, set_sigma)
#      48             es = cma.CMAEvolutionStrategy(generate_sp_proposed(sp, n).flatten(), sigma0=j,
#      49                                       inopts={'bounds': cma_bounds,'seed':1234})
# ---> 50             es.optimize(f, iterations=(max_iterations/ es.popsize))
#      51             fcma.append((es.result[1], es.result[0].reshape(n, 2), (time.time() - start_time), j))
#      52
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\interfaces.py in optimize(self, objective_fct, maxfun, iterations, min_iterations, args, verb_disp, callback, n_jobs, **kwargs)
#     206                 X = self.ask()  # deliver candidate solutions
#     207                 # fitvals = [objective_fct(x, *args) for x in X]
# --> 208                 fitvals = eval_all(X, args=args)
#     209                 cevals += len(fitvals)
#     210                 self.tell(X, fitvals)  # all the work is done here
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in __call__(self, solutions, fitness_function, args, timeout)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in <listcomp>(.0)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# <ipython-input-366-0bdc61ac1c6e> in f(x)
#      29         """
#      30         x = x.reshape(n,2) # reshape for input into expected enrolment.
# ---> 31         ee = expected_enrollment(df_ms_loc_sub, x, df_ms_enrol_sub, current_ms_dist_sub, ee_old_constant) # fitness function.
#      32         return ee*-1 # Multiply by -1 for maximising.
#      33
#
# <ipython-input-327-de7e669993ae> in expected_enrollment(middle_loc, x, middle_enroll, current_dist, ee_old_constant)
#      30     # index 0 = x, index 1 = MS, index 2 = distance, index 3 = shaped enrollment
#      31     d3 = pd.DataFrame(np.vstack((d_index[d2], d2[0], d_min[d2], shape(d_min[d2], middle_enroll[d2[0]]))).T)
# ---> 32     d32 = d3.loc[d3.groupby([1])[2].idxmin()] # find only nearby SS if MS is close to more than 1 SS.
#      33     d32 = d32.groupby(0)[3].sum() # The overall shaped enrollment for each school in x.
#      34     eei = np.sum(d32) # overall expected enrollment increase for each school in x.
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     774                 if validate:
#     775                     obj._check_label_or_level_ambiguity(gpr, axis=axis)
# --> 776                 in_axis, name, gpr = True, gpr, obj[gpr]
#     777                 exclusions.append(name)
#     778             elif obj._is_level_reference(gpr, axis=axis):
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2876                 if self.columns.nlevels > 1:
#    2877                     return self._getitem_multilevel(key)
# -> 2878                 return self._get_item_cache(key)
#    2879
#    2880         # Do we have a slicer (on rows)?
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    3539
#    3540             loc = self.columns.get_loc(item)
# -> 3541             values = self._mgr.iget(loc)
#    3542             res = self._box_col_values(values, loc)
#    3543
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in iget(self, i)
#     986         Return the data as a SingleBlockManager.
#     987         """
# --> 988         block = self.blocks[self.blknos[i]]
#     989         values = block.iget(self.blklocs[i])
#     990
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in blknos(self)
#     173         if self._blknos is None:
#     174             # Note: these can be altered by other BlockManager methods.
# --> 175             self._rebuild_blknos_and_blklocs()
#     176
#     177         return self._blknos
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     248             rl = blk.mgr_locs
#     249             new_blknos[rl.indexer] = blkno
# --> 250             new_blklocs[rl.indexer] = np.arange(len(rl))
#     251
#     252         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
# %%time
n_starting_points = 30
maxits= 20000
# for maximum of 5. 
for i in ['Dire Dawa']:
    cma_region(new_ss_regions_5[i], n_starting_points, maxits, df_all[i], df_all[i])
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=1234, Mon Sep  5 14:12:57 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -2.428382573440116e+03 1.0e+00 9.22e-03  9e-03  9e-03 0:00.0
#     2     20 -2.435086437298468e+03 1.2e+00 8.23e-03  8e-03  8e-03 0:00.1
#     3     30 -2.442517314368299e+03 1.3e+00 8.38e-03  7e-03  9e-03 0:00.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-366-0bdc61ac1c6e> in cma_region(n, n_starting_points, max_iterations, data, data_sub, set_sigma)
#      48             es = cma.CMAEvolutionStrategy(generate_sp_proposed(sp, n).flatten(), sigma0=j,
#      49                                       inopts={'bounds': cma_bounds,'seed':1234})
# ---> 50             es.optimize(f, iterations=(max_iterations/ es.popsize))
#      51             fcma.append((es.result[1], es.result[0].reshape(n, 2), (time.time() - start_time), j))
#      52
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\interfaces.py in optimize(self, objective_fct, maxfun, iterations, min_iterations, args, verb_disp, callback, n_jobs, **kwargs)
#     206                 X = self.ask()  # deliver candidate solutions
#     207                 # fitvals = [objective_fct(x, *args) for x in X]
# --> 208                 fitvals = eval_all(X, args=args)
#     209                 cevals += len(fitvals)
#     210                 self.tell(X, fitvals)  # all the work is done here
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in __call__(self, solutions, fitness_function, args, timeout)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\cma\optimization_tools.py in <listcomp>(.0)
#     280                              " passed in `__init__` or `__call__`")
#     281         if not self.pool:
# --> 282             return [fitness_function(x, *args) for x in solutions]
#     283         warning_str = ("`fitness_function` must be a function, not a"
#     284                        " `lambda` or an instancemethod, in order to work with"
#
# <ipython-input-366-0bdc61ac1c6e> in f(x)
#      29         """
#      30         x = x.reshape(n,2) # reshape for input into expected enrolment.
# ---> 31         ee = expected_enrollment(df_ms_loc_sub, x, df_ms_enrol_sub, current_ms_dist_sub, ee_old_constant) # fitness function.
#      32         return ee*-1 # Multiply by -1 for maximising.
#      33
#
# <ipython-input-327-de7e669993ae> in expected_enrollment(middle_loc, x, middle_enroll, current_dist, ee_old_constant)
#      31     d3 = pd.DataFrame(np.vstack((d_index[d2], d2[0], d_min[d2], shape(d_min[d2], middle_enroll[d2[0]]))).T)
#      32     d32 = d3.loc[d3.groupby([1])[2].idxmin()] # find only nearby SS if MS is close to more than 1 SS.
# ---> 33     d32 = d32.groupby(0)[3].sum() # The overall shaped enrollment for each school in x.
#      34     eei = np.sum(d32) # overall expected enrollment increase for each school in x.
#      35     # Find MS enrollment of MS if close to old SS.
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\groupby.py in sum(self, numeric_only, min_count)
#    1537     @doc(_groupby_agg_method_template, fname="sum", no=True, mc=0)
#    1538     def sum(self, numeric_only: bool = True, min_count: int = 0):
# -> 1539         return self._agg_general(
#    1540             numeric_only=numeric_only, min_count=min_count, alias="add", npfunc=np.sum
#    1541         )
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#     997         # try a cython aggregation if we can
#     998         try:
# --> 999             return self._cython_agg_general(
#    1000                 how=alias, alt=npfunc, numeric_only=numeric_only, min_count=min_count,
#    1001             )
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1031                 continue
#    1032
# -> 1033             result, agg_names = self.grouper.aggregate(
#    1034                 obj._values, how, min_count=min_count
#    1035             )
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\ops.py in aggregate(self, values, how, axis, min_count)
#     582         self, values, how: str, axis: int = 0, min_count: int = -1
#     583     ) -> Tuple[np.ndarray, Optional[List[str]]]:
# --> 584         return self._cython_operation(
#     585             "aggregate", values, how, axis, min_count=min_count
#     586         )
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     506         if vdim == 1:
#     507             values = values[:, None]
# --> 508             out_shape = (self.ngroups, arity)
#     509         else:
#     510             if axis > 0:
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\ops.py in ngroups(self)
#     295     @cache_readonly
#     296     def ngroups(self) -> int:
# --> 297         return len(self.result_index)
#     298
#     299     @property
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\ops.py in result_index(self)
#     306     def result_index(self) -> Index:
#     307         if not self.compressed and len(self.groupings) == 1:
# --> 308             return self.groupings[0].result_index.rename(self.names[0])
#     309
#     310         codes = self.reconstructed_codes
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\grouper.py in result_index(self)
#     570         if self.all_grouper is not None:
#     571             return recode_from_groupby(self.all_grouper, self.sort, self.group_index)
# --> 572         return self.group_index
#     573
#     574     @property
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\grouper.py in group_index(self)
#     575     def group_index(self) -> Index:
#     576         if self._group_index is None:
# --> 577             self._make_codes()
#     578         assert self._group_index is not None
#     579         return self._group_index
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\groupby\grouper.py in _make_codes(self)
#     591                 else:
#     592                     na_sentinel = -1
# --> 593                 codes, uniques = algorithms.factorize(
#     594                     self.grouper, sort=self.sort, na_sentinel=na_sentinel
#     595                 )
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     680
#     681     if sort and len(uniques) > 0:
# --> 682         uniques, codes = safe_sort(
#     683             uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     684         )
#
# c:\users\darra\appdata\local\programs\python\python38\lib\site-packages\pandas\core\algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    2094     if na_sentinel == -1:
#    2095         # take_1d is faster, but only works for na_sentinels of -1
# -> 2096         order2 = sorter.argsort()
#    2097         new_codes = take_1d(order2, codes, fill_value=-1)
#    2098         if verify:
#
# KeyboardInterrupt:

# %%
# %%time
n_starting_points = 30
maxits= 30000
# for maximum of 5. 
for i in df_all.keys():
    cma_region(new_ss_regions_10[i], n_starting_points, maxits, df_all[i], df_10[i], best_sigma[i])

# %%
# %%time
n_starting_points = 30
maxits= 30000
# for maximum of 5. 
for i in df_all.keys():
    cma_region(new_ss_regions_10[i], n_starting_points, maxits, df_all[i], df_all[i], best_sigma[i])

# %% [markdown]
# # Initial Solution
#
# Below is the original code.

# %%
### Original Function. 


def run(df, region, n):
    """ Function to run all experiments per region according to the total new schools proposed. 
        Doesn't return any value. It appends the results dataframe and creates a set of visualisations per region.
    """
    # limit geojson to only selected region
    # limit clean dataset to only selected region
    gdf_region = gpd.read_file('eth_shape_files/json//eth_admin1v2.json') # read in geojson
    gdf_region_shp = gdf_region.loc[gdf_region['ADM1_EN']==region]['geometry'].reset_index(drop=True)
    df = df.loc[df['ADM1_EN'] == region]
    
    # Find regional boundaries in lat lon.
    # Latitude is the Y axis, longitude is the X axis.
    bounds = gdf_region_shp.bounds 
    lat_bounds = bounds[['miny','maxy']].to_numpy(dtype=float)[0]
    lon_bounds = bounds[['minx','maxx']].to_numpy(dtype=float)[0]
    bounds = np.array([[lat_bounds[0], lon_bounds[0]], [lat_bounds[1], lon_bounds[1]]])
    # array - [[lower lat bounds, lower lon bounds],[upper lat bounds, upper lon bounds]]
    
    # CMA expects a list of size 2 for bounds
    x1y1 = np.repeat([bounds[0,:]],n, axis=0).flatten()
    x2y2 = np.repeat([bounds[1,:]],n, axis=0).flatten()
    boundsxy = [x1y1,x2y2]
    
    # Create subset arrays in numpy for input to the Fitness Function.
    # 1. df_middle_enroll: MS enrollment data. Only the last two grades used as predictors for expected SS enrollment
    # 2. df_middle_loc: MS location data- lat lon point data. 
    
    # 3. df_sec_enroll: SS enrollment data. Only grades 9 and 10 enrollment.
    # 4. df_sec_loc: SS location data- lat lon point data. 
    # 5. current_ms_distance: existing distances from MS to SS

    df_middle = df.loc[df['grade_7_8'] > 0]
    df_middle_enroll = df_middle['grade_7_8'].reset_index(drop=True).to_numpy(dtype=float) # 1
    df_middle_loc = df_middle['point'].reset_index(drop=True).to_numpy()
    df_middle_loc = np.array([np.array(i) for i in df_middle_loc], dtype=float) # 2

    df_sec = df.loc[ (df['gr_offer'] == 'G. 9-10') | (df['gr_offer'] == 'G. 9-12')]
    df_sec_enroll = df_sec['grade9_10'].reset_index(drop=True).to_numpy(dtype=float)
    df_sec_loc = df_sec['point'].reset_index(drop=True).to_numpy() 
    df_sec_loc = np.array([np.array(i) for i in df_sec_loc], dtype=float) # 3
    current_ms_distance = df_middle['nearest_lwr_sec'].to_numpy() # 5
    
    # Create a large initial sample of starting points. 
    sp = generate_random_sp(lat_bounds, lon_bounds)# Create a large sample of starting points
    sp = sp[check_region(sp, gdf_region_shp)] # only include points that are within regional boundaries.
    
    ee_old_constant = np.sum(df_sec_enroll) # existing enrollment for secondary. The constant figure. 

#     Uncomment below to use the top n MS as the starting point for CMA. 
#     best_sp = df_middle.nlargest(n, 'grade_7_8')['point'].reset_index(drop=True).to_numpy() 
#     best_sp = np.array([np.array(i) for i in best_sp], dtype=float) # 3

#     *** FITNESS FUNCTION ****

    def expected_enrollment(middle_loc, x, middle_enroll, current_dist):
        
        """ The Fitness Function returns the overall total expected enrollment increase given the new school locations x. 
        
            The function calculates the distance between each new school in x and the current middle schools to determine 
            the expected enrollment per new school. If a new school proposed is closer than the current secondary school, 
            enrollment from that subtracted from the overall enrollment gains. 
        
            Parameters:
                middle_loc: a vector of longitude and latitude coordinates of all middle schools
                x: a vector longitude and latitude coordinates for the newly proposed secondary schools
                middle_enroll: a vector of current enrollment at each middle school
                current_distnce: a vector of the current distances between each middle school and secondary school.
                            
            Returns:
                eei + ee_old (float): the expected enrollment increase from each school in x  (eei)
                                      + the current secondary enrollment (ee_old)
        
        """
        
        ee_old = ee_old_constant.copy() # Overall SS Enrollment
        d = haversine_vector(middle_loc,x, Unit.KILOMETERS, comb=True) # distance of MS to x. 
        d_min = np.min(d, axis=0) # select only closest schools to avoid duplication. 
        
        d_index = np.argmin(d, axis=0) # index of min distance of MS to x
        d2 = np.where((d_min <5) & (d_min < current_dist)) # limit to only schools < 5km and schools < current distance
        # Put into dataframe for manipulation in pandas
        # index 0 = x, index 1 = MS, index 2 = distance, index 3 = shaped enrollment 
        d3 = pd.DataFrame(np.vstack((d_index[d2], d2[0], d_min[d2], shape(d_min[d2], middle_enroll[d2[0]]))).T) 
        d32 = d3.loc[d3.groupby([1])[2].idxmin()] # find only nearby SS if MS is close to more than 1 SS.
        d32 = d32.groupby(0)[3].sum() # The overall shaped enrollment for each school in x.
        eei = np.sum(d32) # overall expected enrollment increase for each school in x.
        # Find MS enrollment of MS if close to old SS. 
        distance_current = np.sum(shape(current_dist[d2], middle_enroll[d2]))
        ee_old -= distance_current # subtract shaped enrollment from overall SS enrollment as new school is closer
        return eei + ee_old # return overall expected enrollment + current secondary enrollment

#     *** OBJECTIVE FUNCTION ****
    
    def f(x):
        """ The Objective Function returns the maximum expected enrollment.
        """
        x = x.reshape(n,2) # reshape for input into expected enrolment.
        test_case = expected_enrollment(df_middle_loc, x, df_middle_enroll, current_ms_distance) # run fitness function.
        return test_case*-1 # Multiply by -1 for maximising.
    
    
    # **** RESULTS ****
    
    create_results_table() # create table for results, if it doesn't already exist.
    results = pd.read_csv('results.csv')
    
    # *** ESTABLISH BENCHMARK ****
    
    # Basic Benchmark
    # Step 1. Find all MS with distance > 5km. 
    # Step 2. Sort by enrollment and select n schools with the highest enrollment
    # Step 3. Sum the enrollment to assume that the new schools will only serve n schoools.
    # This is the basic benchmark
    
    if (region == 'Addis Ababa') | (region == 'Dire Dawa'):  
        # Distances to secondary schools are lower in city administrations
        dd = df_middle[df_middle['nearest_lwr_sec'] > 2] # Find all PS > 2km distance in city administrations
    else:
        dd = df_middle[df_middle['nearest_lwr_sec'] > 5] # Find all PS > 5km distance in regions.
    dd = dd.sort_values(['grade_7_8'], ascending=False).head(n) # filter by number of SS to construct
    benchmark = sum(dd['grade_7_8']) # sum the enrollment for a basic indication of expected enrollment

    # Advanced Benchmark
    # Since MS with the highest enrollment are likely to be close to other MS, apply the fitness function to these schools
    # Step 1. Assume x is the locations of the top n schools
    # Step 2. Run fitness Function on these schools. 
    start_time = time.time()
    benchmark_loc = dd['point'].reset_index(drop=True).to_numpy()
    benchmark_loc = np.array([np.array(i) for i in benchmark_loc], dtype=float)
    benchmark_f = f(benchmark_loc) # Run Fitness Function
       
    # Store results
    
    row1 = (pd.Series({'region': region, 'proposed_schools_n': n,
                       'starting_point':np.nan, 'algorithm':'Basic Benchmark', 
                       'ee': abs(ee_old_constant - abs(benchmark)), 'eei': benchmark, 
                       'proposed_locations': benchmark_loc, 'time':0, 'sigma':np.nan}))
    
    row2 = (pd.Series({'region': region, 'proposed_schools_n': n,'starting_point': np.nan, 
                       'algorithm':'Advanced Benchmark', 'ee': round(abs(benchmark_f)),
                        'eei': round(abs(ee_old_constant  - abs(benchmark_f)),0), 
                        'proposed_locations': benchmark_loc, 'time':(time.time() - start_time), 'sigma':np.nan}))

    results = results.append(row1, ignore_index=True)
    results = results.append(row2, ignore_index=True)
    
    # Random Search Algorothm is used to see if an improved solution can be identified.
    
    # Set Parameters for experiments.
    n_starting_points = 30
    maxits = 20000 # max iterations
    
    # Best Sigma Values Identified. Uncommment to use.
    
#     best_sigma = {'Addis Ababa': 0.098445155,
#                  'Amhara': 0.86193024,
#                  'Benishangul Gumz': 0.443843224,
#                  'Dire Dawa': 0.15484862300000002,
#                  'Harari': 0.08544453699999999,
#                  'Oromia': 2.018435726,
#                  'SNNP': 0.14630103,
#                  'Somali': 0.34336816299999995,
#                  'Tigray': 0.555333321}
    
    def random_search(f, iterations):
        x = [generate_sp_proposed(sp, n) for _ in range(iterations)]
        fx = [[f(xi), xi] for xi in x]
        best_f, best_solution = min(fx, key=lambda x:x[0])
        return best_f, best_solution
    
    start_time_rs = time.time()
    fx = []
    for _ in range(n_starting_points):
        start_time = time.time()
        fx.append([random_search(f, maxits), time.time() - start_time])
        
    for i in range(0, len(fx)):
        row = (pd.Series({'region': region, 'proposed_schools_n': n,
                        'iteration':i, 'algorithm':'Random Search', 'ee':round(abs(fx[i][0][0]),0),
                                    'eei':round(abs(ee_old_constant - abs(fx[i][0][0])),0), 
                                    'proposed_locations': fx[i][0][1], 'time':fx[i][1], 'sigma':'NA'}))
        results = results.append(row, ignore_index=True)
        
    print(region, 'RS complete. Total time:', round(time.time() - start_time_rs,2))
    
    # Covariance Matrix Adaptation-  CMA
    
    # Sigma is the initial standard deviation. Problem variables need to be scaled per region.
    # Take 10 values between 0 and the variance of all MS
    sigma0 = 1.5*(np.sqrt(np.std(df_middle_loc[:,0])**2 + np.std(df_middle_loc[:,1])**2))
    sigmas = np.linspace(0, sigma0, 11)[1:] # Take 10 values evenly spaced out between 0 to sigma0
    
    start_time_cma = time.time()
    fcma = []
    for i in range(n_starting_points):
        start_time = time.time()
        for j in sigmas:
            es = cma.CMAEvolutionStrategy(generate_sp_proposed(sp, n).flatten(), sigma0=j,
                                      inopts={'bounds': boundsxy,'seed':1234})
            es.optimize(f, iterations=(maxits/ es.popsize))
            fcma.append((es.result[1], es.result[0].reshape(n, 2), (time.time() - start_time), j))
            
    for i in range(0, len(fcma)):
        row = (pd.Series({'region': region, 'proposed_schools_n': n,
                    'starting_point':i, 'algorithm':'CMA', 'ee':round(abs(fcma[i][0]),0),
                                'eei':round(abs(ee_old_constant - abs(fcma[i][0])),0), 
                                'proposed_locations': fcma[i][1], 'time':fcma[i][2], 'sigma':fcma[i][3]}))
        results = results.append(row, ignore_index=True)
    
    print(region, 'CMA complete. Total time:', round(time.time() - start_time_cma,2))
    
    results.to_csv('results.csv', index=False)

# %% [markdown]
# # Main

# %%
run(df, 'Harari', 5)

# %%
run(df, 'Addis Ababa', 5)

# %%
run(df, 'Amhara', 5)

# %%
run(df, 'Benishangul Gumz', 5)

# %%
run(df, 'Dire Dawa', 5)

# %%
run(df, 'Oromia', 5)

# %%
run(df, 'SNNP', 5)

# %%
run(df, 'Somali', 5)

# %%
run(df, 'Tigray', 5)
